# %%
import torch
from torch.utils.data import Dataset, DataLoader
import kagglehub
import torchvision.transforms as T
from torchvision.utils import make_grid
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
from tqdm import tqdm

# %%
from torch import nn
from torch.nn.utils.parametrizations import spectral_norm
import torch.nn.functional as F

# %%
to_tensor = T.ToTensor()

def load_image(path):
    return to_tensor(Image.open(path))


def show_images(imgs):
    # imgs is a tensor of shape: B x C x H x W
    grid = make_grid(imgs.detach().cpu(), nrow=4, padding=10, pad_value=1)
    plt.imshow(grid.permute(1, 2, 0))
    plt.axis("off")
    plt.gcf().set_figwidth(8)
    plt.show()

# %%
class Monet(Dataset):
    def __init__(self, img_size=256):
        self.data_path = kagglehub.dataset_download(
            "dimitreoliveira/monet-paintings-jpg-berkeley")
        self.img_names = os.listdir(self.data_path)
        self.img_names = list(filter(lambda s: os.path.isfile(os.path.join(self.data_path, s)), self.img_names))

        # resize images to lower resolution
        print("Image size:", img_size)
        if img_size == 256:
            self.resized_data_path = self.data_path
        else:
            self.resized_data_path = os.path.join(self.data_path, f"resized_{img_size}")

        print("Saving resized images...")
        for img_name in tqdm(self.img_names):
            resized_path = os.path.join(self.resized_data_path, img_name)
            if os.path.exists(resized_path):
                continue

            # resize to specified img size
            orig_img_path = os.path.join(self.data_path, img_name)
            with Image.open(orig_img_path) as img:
                resized_img = img.resize((img_size, img_size))
                # save
                os.makedirs(os.path.dirname(resized_path), exist_ok=True)
                resized_img.save(resized_path)

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, index):
        return load_image(os.path.join(self.resized_data_path, self.img_names[index]))

# %%
import requests
import zipfile

class LSUNChurchSubset(Dataset):
    def __init__(self, data_dir):

        self.data_path = os.path.abspath(os.path.join(data_dir, "lsun-subset"))
        os.makedirs(self.data_path, exist_ok=True)

        # download if not already downloaded
        if len(os.listdir(self.data_path)) == 2000:
            print("Data downloaded already")
        else:
            print("Downloading data")

            # get zip file from Adam's Duke Box
            zip_url = "https://duke.app.box.com/index.php?rm=box_download_shared_file&shared_name=0af4hdn4muor7rkickcrtp8ppk41n7dk&file_id=f_1713403290181"
            response = requests.get(zip_url, stream=True)
            response.raise_for_status()

            # write zip file to a temp file
            with open("temp.zip", "wb") as f:
                for chunk in response.iter_content(chunk_size=8192):
                    if chunk:
                        f.write(chunk)

            # extract files
            with zipfile.ZipFile("temp.zip", "r") as zip_ref:
                zip_ref.extractall(data_dir)

            # delete temp zip file
            os.remove("temp.zip")

        # get image names
        self.img_names = os.listdir(self.data_path)

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, index):
        return load_image(os.path.join(self.data_path, self.img_names[index]))


loader = DataLoader(LSUNChurchSubset("lsun-church-subset"), batch_size=4, shuffle=True)
imgs = next(iter(loader))
show_images(imgs)
# Out:
# Data downloaded already

# %%
monet = Monet()
lsun = LSUNChurchSubset("lsun-church-subset")

batch_size = 2
monet_loader = DataLoader(monet, batch_size=batch_size, shuffle=True)
lsun_loader = DataLoader(lsun, batch_size=batch_size, shuffle=True)
# Out:
# Image size: 256
# Saving resized images...
# 100%|██████████| 1193/1193 [00:00<00:00, 15683.06it/s]
# Data downloaded already

# %%
progressive_resolutions = [8, 16, 32, 64, 128, 256]
num_epochs_per_stage = 5  # how long should we train at each stage/resolution?

class GeneratorResidualBlock(nn.Module):
    def __init__(self, n_channels):
        super().__init__()
        self.layers = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(n_channels, n_channels, kernel_size=3),
            nn.InstanceNorm2d(n_channels),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(n_channels, n_channels, kernel_size=3),
            nn.InstanceNorm2d(n_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return x + self.layers(x)

class ConvBlock(nn.Module):
  def __init__(self, features_in, features_out, kernel_size, stride=1):
    super().__init__()
    self.layers = nn.Sequential(
        nn.ReflectionPad2d((kernel_size - 1) // 2),
        nn.Conv2d(features_in, features_out, kernel_size, stride=stride),
        nn.InstanceNorm2d(features_out),
        nn.ReLU()
    )
  def forward(self, x):
    return self.layers(x)


class FromRGBBlock(nn.Module):
  def __init__(self, resolution_out, features_out, kernel_size=1, stride=1):
    super().__init__()
    self.resolution_out = resolution_out
    self.conv = ConvBlock(3, features_out, kernel_size=kernel_size, stride=stride)

  def forward(self, x):
    x = F.interpolate(x, size=(self.resolution_out, self.resolution_out), mode='bilinear', align_corners=False)
    # convert to correct number of features
    return self.conv(x)


class ToRGBBlock(nn.Module):
  def __init__(self, features_in, kernel_size=1):
    super().__init__()
    self.layers = nn.Sequential(
        nn.ReflectionPad2d((kernel_size-1) // 2),
        nn.Conv2d(features_in, 3, kernel_size),
        nn.Sigmoid()
    )

  def forward(self, x):
    return self.layers(x)

# %%
class ProgGenerator(nn.Module):
    def __init__(self, step=0, alpha=0.0):
        super().__init__()

        self.step = step
        self.alpha = alpha

        # progressive downsampling layers
        self.downsample_blocks = nn.ModuleList([
            ConvBlock(64, 128, kernel_size=3, stride=2),
            ConvBlock(128, 256, kernel_size=3, stride=2),
        ])

        # residual blocks
        self.residual_blocks = nn.Sequential(
            *[GeneratorResidualBlock(256) for i in range(6)]
        )

        # progressive upsampling layers
        self.upsample_blocks = nn.ModuleList([
            nn.Sequential(
              nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1), # ConvTranspose2d with stride=2 doubles the spatial dimensions.
              nn.InstanceNorm2d(128),
              nn.ReLU()
            ),
            nn.Sequential(
              nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
              nn.InstanceNorm2d(64),
              nn.ReLU()
            )
        ])

        # from-RGB and to-RGB layers for each step
        self.from_rgb_layers = nn.ModuleList([
            FromRGBBlock(resolution_out=64, features_out=256, kernel_size=1),  # step 0
            FromRGBBlock(resolution_out=128, features_out=128, kernel_size=1),  # step 1
            FromRGBBlock(resolution_out=256, features_out=64, kernel_size=7),  # step 2
        ])
        self.to_rgb_layers = nn.ModuleList([
            ToRGBBlock(256, kernel_size=1),
            ToRGBBlock(128, kernel_size=1),
            ToRGBBlock(64, kernel_size=1)
        ])

    def forward(self, input): # x = input img, step = current resolution step (4x4 -> 8x8 -> 1024x1024), alpha = factor for resolution-blending
        # print("input shape", input.shape)

        # apply correct fromRGB layer
        x = self.from_rgb_layers[self.step](input)
        # print("after from rgb", x.shape)

        downsample_blocks_to_use = self.downsample_blocks[len(self.downsample_blocks)-self.step:len(self.downsample_blocks)]
        for i, block in enumerate(downsample_blocks_to_use):
          # on the first block, blend with what we had before when we weren't using that block
          if i == 0:
            # note that self.step isn't 0 here, because if it was, this for loop wouldn't run
            prev_x = self.from_rgb_layers[self.step-1](input)
            x = block(x)
            x = self.alpha * x + (1 - self.alpha) * prev_x
          else:
            x = block(x)

        # print("after downsample", x.shape)

        x = self.residual_blocks(x)
        # print("after residual", x.shape)

        upsample_blocks_to_use = self.upsample_blocks[:self.step]
        for block in upsample_blocks_to_use:
          prev_x = x.clone()
          x = block(x)
          # print(x.shape)
        # print("after upsample", x.shape)

        # convert to rgb
        x = self.to_rgb_layers[self.step](x)

        # if first step, no previous, so just return x
        if self.step == 0:
          return x

        # for other steps, interpolate between previous and current
        # convert prev to rgb
        prev_x = self.to_rgb_layers[self.step-1](prev_x)
        # convert prev to correct resolution
        prev_x = F.interpolate(prev_x, scale_factor=2, mode='bilinear', align_corners=False)
        # interpolate
        return self.alpha * x + (1 - self.alpha) * prev_x

g = ProgGenerator(step=2)
imgs = next(iter(lsun_loader))
g(imgs).shape
# Out:
# torch.Size([2, 3, 128, 128])

# %%
class ProgDiscriminator(nn.Module):
    def __init__(self, step=0, alpha=0.0):
        super().__init__()

        self.step = step
        self.alpha = alpha

        # from-RGB layers for each res
        self.from_rgb_layers = nn.ModuleList([
            FromRGBBlock(resolution_out=64, features_out=128, kernel_size=1),  # step 0
            FromRGBBlock(resolution_out=128, features_out=64, kernel_size=1),  # step 1
            # on step 2, conv0 will process the RGB image, no need to project to higher feature space
        ])

        self.blocks = nn.ModuleList([
            self._create_discriminator_block(3, 64),
            self._create_discriminator_block(64, 128),
            self._create_discriminator_block(128, 256),
            self._create_discriminator_block(256, 512),
        ])

        # final Conv -> Sigmoid layer
        self.final_layer = nn.Sequential(
            nn.Conv2d(512, 1, kernel_size=3, stride=1),
            nn.Flatten(1),
            nn.Sigmoid()
        )

    def _create_discriminator_block(self, features_in, features_out):
        return nn.Sequential(
            spectral_norm(nn.Conv2d(features_in, features_out, kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=True),
        )

    def forward(self, input):

        # print(f"Input shape: {input.shape}")

        # from RGB:
        if self.step < 2:
          x = self.from_rgb_layers[self.step](input)
        else:
          x = input
        # print(f"After from_rgb_layers[{self.step}]: {x.shape}")

        # discriminator blocks up to curr res:
        start_block_index = len(self.blocks)-2-self.step
        blocks_to_use = self.blocks[start_block_index:len(self.blocks)]
        for i, block in enumerate(blocks_to_use):
            # on entry, blend with what we were doing before
            if i == 0 and self.step >= 1:
                prev_x = self.from_rgb_layers[self.step-1](input)
                x = block(x)
                # print("boo", x.shape, prev_x.shape)
                x = self.alpha * x + (1 - self.alpha) * prev_x
            else:
                x = block(x)
            # print(f"After block: {x.shape}")

        # Final layer to output size 1 (use sigmoid)
        return self.final_layer(x)


d = ProgDiscriminator(step=2)
imgs = next(iter(lsun_loader))
d(imgs).shape
# Out:
# torch.Size([2, 196])

# %%
# # Let's check if it works:

import torch
# from torchsummary import summary
import torch.nn.functional as F

###### initial test ########
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
g = ProgGenerator(step=2)
d = ProgDiscriminator(step=2)

imgs = next(iter(lsun_loader))
print("Start Generator:")
fake_imgs = g(imgs)
print("Start Discriminator:")
d_output = d(fake_imgs)
print("output", d_output.shape)
# Out:
# Start Generator:
# Start Discriminator:
# output torch.Size([2, 196])

# %%
# Hyperparameters
num_epochs = 10
lr = 0.0002
lambda_cycle = 10
lambda_identity = 5

class FakeImageBuffer():
    def __init__(self, max_size=50):
        self.max_size = max_size
        self.img_history = []

    def swap(self, mini_batch):
        swapped_mini_batch = []
        for img in mini_batch.data:
            img = torch.unsqueeze(img, 0)
            if len(self.img_history) < self.max_size:
                self.img_history.append(img)
                swapped_mini_batch.append(img)
            else:
                if torch.rand(1) > 0.5:
                    # don't swap
                    swapped_mini_batch.append(img)
                else:
                    # pick random prev img to swap with
                    i = torch.randint(0, self.max_size, (1,))
                    img_from_history = self.img_history[i].clone()
                    # history image might be a different resolution, resize it before swapping
                    img_from_history = F.interpolate(img_from_history, size=img.shape[-2:], mode="bilinear", align_corners=False)
                    swapped_mini_batch.append(img_from_history)
                    self.img_history[i] = img
        return torch.cat(swapped_mini_batch)
    

# utility functions to save progress to an image file every once in a while
# so we don't have to stop the training to see what's going on

def imshow_on_axis(img, ax):
    np_img = img.detach().permute(1,2,0).cpu().numpy()
    ax.axis("off")
    ax.imshow(np_img)

def save_progress_file(real_x, real_y, fake_x, fake_y, cycle_x, cycle_y):
    fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(9, 6))
    axes[0][0].set_title("photo -->")
    imshow_on_axis(real_x[0], axes[0][0])
    axes[0][1].set_title("monet")
    imshow_on_axis(fake_y[0], axes[0][1])
    axes[0][2].set_title("--> photo")
    imshow_on_axis(cycle_x[0], axes[0][2])
    axes[1][0].set_title("monet -->")
    imshow_on_axis(real_y[0], axes[1][0])
    axes[1][1].set_title("photo")
    imshow_on_axis(fake_x[0], axes[1][1])
    axes[1][2].set_title("--> monet")
    imshow_on_axis(cycle_y[0], axes[1][2])
    fig.tight_layout()
    fig.savefig("progress.png")
    plt.close()  # don't print temp figures to the notebok

# %%
from torch.optim import Adam

class ProgressiveGANTrainer:
    def __init__(self, generator_g, generator_f, discriminator_x, discriminator_y, device, lr=0.0002):
        self.generator_g = generator_g.to(device)
        self.generator_f = generator_f.to(device)
        self.discriminator_x = discriminator_x.to(device)
        self.discriminator_y = discriminator_y.to(device)
        self.device = device

        # Loss functions
        self.adversarial_loss = nn.MSELoss()
        self.cycle_loss = nn.L1Loss()
        self.identity_loss = nn.L1Loss()

        # Optimizers
        self.optimizer_g = Adam(list(self.generator_g.parameters(
        )) + list(self.generator_f.parameters()), lr=lr, betas=(0.5, 0.999))
        self.optimizer_dx = Adam(
            self.discriminator_x.parameters(), lr=lr, betas=(0.5, 0.999))
        self.optimizer_dy = Adam(
            self.discriminator_y.parameters(), lr=lr, betas=(0.5, 0.999))

        # Fake image buffers
        self.fake_x_history = FakeImageBuffer()
        self.fake_y_history = FakeImageBuffer()

    def train(self, dataloaders, n_epochs, step, fixed_alpha=None):

        # Update models for current step
        self.generator_g.step = step
        self.generator_f.step = step
        self.discriminator_x.step = step
        self.discriminator_y.step = step

        lsun_loader, monet_loader = dataloaders
        batches_in_epoch = min(len(monet_loader), len(lsun_loader))

        for epoch in range(n_epochs):
            for b, (real_x, real_y) in enumerate(zip(lsun_loader, monet_loader)):
                real_x = real_x.to(self.device)
                real_y = real_y.to(self.device)
                # note - no need to resize input images, because the models will do this themselves

                # Update alpha
                batch_count = (epoch * batches_in_epoch) + b
                total_batch_count = n_epochs * batches_in_epoch
                alpha = fixed_alpha if fixed_alpha is not None else batch_count / total_batch_count

                self.generator_g.alpha = alpha
                self.generator_f.alpha = alpha
                self.discriminator_x.alpha = alpha
                self.discriminator_y.alpha = alpha

                # Train Generators
                self.optimizer_g.zero_grad()
                fake_y = self.generator_g(real_x)
                pred_fake_y = self.discriminator_y(fake_y)
                loss_g_adv = self.adversarial_loss(
                    pred_fake_y, torch.ones_like(pred_fake_y))
                fake_x = self.generator_f(real_y)
                pred_fake_x = self.discriminator_x(fake_x)
                loss_f_adv = self.adversarial_loss(
                    pred_fake_x, torch.ones_like(pred_fake_x))

                # Cycle Consistency Loss
                cycle_x = self.generator_f(fake_y)  # X -> Y -> X
                real_x_resized = F.interpolate(
                    real_x, size=cycle_x.shape[-2:], mode='bilinear', align_corners=False)  # added this line (Ellie)
                loss_cycle_x = self.cycle_loss(cycle_x, real_x_resized)

                cycle_y = self.generator_g(fake_x)  # Y -> X -> Y
                real_y_resized = F.interpolate(
                    real_y, size=cycle_y.shape[-2:], mode='bilinear', align_corners=False)  # added this line (Ellie)
                loss_cycle_y = self.cycle_loss(cycle_y, real_y_resized)

                # Identity Loss
                identity_x = self.generator_f(real_x)
                real_x_resized = F.interpolate(
                    real_x, size=identity_x.shape[-2:], mode='bilinear', align_corners=False)  # added this line (Ellie)
                loss_id_x = self.identity_loss(identity_x, real_x_resized)

                identity_y = self.generator_g(real_y)
                real_y_resized = F.interpolate(
                    real_y, size=identity_y.shape[-2:], mode='bilinear', align_corners=False)  # added this line (Ellie)
                loss_id_y = self.identity_loss(identity_y, real_y_resized)

                # Total Generator Loss
                loss_g = (loss_g_adv + loss_f_adv + lambda_cycle * (loss_cycle_x + loss_cycle_y) +
                          lambda_identity * (loss_id_x + loss_id_y))
                loss_g.backward()
                self.optimizer_g.step()

                # Train Discriminators
                self.optimizer_dx.zero_grad()
                pred_real_x = self.discriminator_x(real_x)
                loss_dx_real = self.adversarial_loss(
                    pred_real_x, torch.ones_like(pred_real_x))
                # fake_x = self.fake_x_history.swap(fake_x)
                pred_fake_x = self.discriminator_x(fake_x.detach())
                loss_dx_fake = self.adversarial_loss(
                    pred_fake_x, torch.zeros_like(pred_fake_x))
                loss_dx = (loss_dx_real + loss_dx_fake) * 0.5
                loss_dx.backward()
                self.optimizer_dx.step()

                self.optimizer_dy.zero_grad()
                pred_real_y = self.discriminator_y(real_y)
                loss_dy_real = self.adversarial_loss(
                    pred_real_y, torch.ones_like(pred_real_y))
                # fake_y = self.fake_y_history.swap(fake_y)
                pred_fake_y = self.discriminator_y(fake_y.detach())
                loss_dy_fake = self.adversarial_loss(
                    pred_fake_y, torch.zeros_like(pred_fake_y))
                loss_dy = (loss_dy_real + loss_dy_fake) * 0.5
                loss_dy.backward()
                self.optimizer_dy.step()

                if b % 25 == 0:
                    save_progress_file(real_x, real_y, fake_x,
                                       fake_y, cycle_x, cycle_y)

                print(f"Step {step} | alpha {alpha:.4f} | Epoch [{epoch+1}/{n_epochs}] | Batch [{b+1}/{batches_in_epoch}] "
                      f"| Loss G: {loss_g.item():.4f} | Loss DX: {loss_dx.item():.4f} | Loss DY: {loss_dy.item():.4f}")

            # Save models
            torch.save(self.generator_g.state_dict(),
                       f"progressive_generator_g_step{step}.pth")
            torch.save(self.generator_f.state_dict(),
                       f"progressive_generator_f_step{step}.pth")
            torch.save(self.discriminator_x.state_dict(),
                       f"progressive_discriminator_x_step{step}.pth")
            torch.save(self.discriminator_y.state_dict(),
                       f"progressive_discriminator_y_step{step}.pth")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize models
generator_g = ProgGenerator().to(device)  # original img -> monet
generator_f = ProgGenerator().to(device)  # monet -> cifar

discriminator_x = ProgDiscriminator().to(device)  # For real
discriminator_y = ProgDiscriminator().to(device)  # For Monet

# %%
# Create the trainer
trainer = ProgressiveGANTrainer(generator_g, generator_f, discriminator_x, discriminator_y, device)

# %%
trainer.train(dataloaders=(lsun_loader, monet_loader), n_epochs=1, step=0, fixed_alpha=0.0)
# Out:
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [1/597] | Loss G: 10.9711 | Loss DX: 0.2504 | Loss DY: 0.2498
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [2/597] | Loss G: 9.4755 | Loss DX: 0.2416 | Loss DY: 0.2574
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [3/597] | Loss G: 9.0949 | Loss DX: 0.2568 | Loss DY: 0.2590
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [4/597] | Loss G: 10.1960 | Loss DX: 0.2442 | Loss DY: 0.2219
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [5/597] | Loss G: 8.0516 | Loss DX: 0.2054 | Loss DY: 0.2286
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [6/597] | Loss G: 9.5457 | Loss DX: 0.1910 | Loss DY: 0.2257
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [7/597] | Loss G: 8.1188 | Loss DX: 0.2572 | Loss DY: 0.2202
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [8/597] | Loss G: 8.3811 | Loss DX: 0.2589 | Loss DY: 0.2636
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [9/597] | Loss G: 6.8333 | Loss DX: 0.2397 | Loss DY: 0.2416
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [10/597] | Loss G: 9.0479 | Loss DX: 0.2095 | Loss DY: 0.2436
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [11/597] | Loss G: 6.0981 | Loss DX: 0.1826 | Loss DY: 0.1881
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [12/597] | Loss G: 6.0724 | Loss DX: 0.2478 | Loss DY: 0.2399
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [13/597] | Loss G: 5.7377 | Loss DX: 0.2555 | Loss DY: 0.2674
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [14/597] | Loss G: 4.6443 | Loss DX: 0.2035 | Loss DY: 0.2763
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [15/597] | Loss G: 5.0457 | Loss DX: 0.2618 | Loss DY: 0.2321
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [16/597] | Loss G: 6.0103 | Loss DX: 0.2110 | Loss DY: 0.2345
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [17/597] | Loss G: 5.2716 | Loss DX: 0.2044 | Loss DY: 0.1957
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [18/597] | Loss G: 4.8497 | Loss DX: 0.1974 | Loss DY: 0.2409
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [19/597] | Loss G: 6.3893 | Loss DX: 0.2032 | Loss DY: 0.2490
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [20/597] | Loss G: 6.7573 | Loss DX: 0.2326 | Loss DY: 0.1723
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [21/597] | Loss G: 5.1295 | Loss DX: 0.1819 | Loss DY: 0.1858
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [22/597] | Loss G: 4.7219 | Loss DX: 0.2202 | Loss DY: 0.1502
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [23/597] | Loss G: 5.9774 | Loss DX: 0.2528 | Loss DY: 0.3777
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [24/597] | Loss G: 5.2584 | Loss DX: 0.2688 | Loss DY: 0.2069
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [25/597] | Loss G: 4.7984 | Loss DX: 0.1881 | Loss DY: 0.2620
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [26/597] | Loss G: 4.6804 | Loss DX: 0.2163 | Loss DY: 0.2472
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [27/597] | Loss G: 6.3860 | Loss DX: 0.2034 | Loss DY: 0.2775
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [28/597] | Loss G: 5.8967 | Loss DX: 0.2031 | Loss DY: 0.2672
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [29/597] | Loss G: 4.4268 | Loss DX: 0.2711 | Loss DY: 0.2383
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [30/597] | Loss G: 4.8771 | Loss DX: 0.2530 | Loss DY: 0.2213
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [31/597] | Loss G: 4.1621 | Loss DX: 0.2425 | Loss DY: 0.2483
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [32/597] | Loss G: 3.9784 | Loss DX: 0.2104 | Loss DY: 0.2503
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [33/597] | Loss G: 4.6952 | Loss DX: 0.2146 | Loss DY: 0.2704
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [34/597] | Loss G: 4.1293 | Loss DX: 0.1964 | Loss DY: 0.2347
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [35/597] | Loss G: 4.1105 | Loss DX: 0.2325 | Loss DY: 0.2344
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [36/597] | Loss G: 3.9793 | Loss DX: 0.2155 | Loss DY: 0.2194
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [37/597] | Loss G: 4.1691 | Loss DX: 0.2762 | Loss DY: 0.2094
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [38/597] | Loss G: 4.6044 | Loss DX: 0.2346 | Loss DY: 0.2136
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [39/597] | Loss G: 3.7672 | Loss DX: 0.1764 | Loss DY: 0.2566
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [40/597] | Loss G: 4.6223 | Loss DX: 0.1886 | Loss DY: 0.2422
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [41/597] | Loss G: 5.8523 | Loss DX: 0.1790 | Loss DY: 0.2148
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [42/597] | Loss G: 5.0671 | Loss DX: 0.2415 | Loss DY: 0.2435
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [43/597] | Loss G: 5.0407 | Loss DX: 0.2932 | Loss DY: 0.2957
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [44/597] | Loss G: 3.8124 | Loss DX: 0.2940 | Loss DY: 0.2765
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [45/597] | Loss G: 4.0416 | Loss DX: 0.1979 | Loss DY: 0.2318
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [46/597] | Loss G: 4.6136 | Loss DX: 0.2221 | Loss DY: 0.2584
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [47/597] | Loss G: 2.9445 | Loss DX: 0.3128 | Loss DY: 0.2721
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [48/597] | Loss G: 4.3353 | Loss DX: 0.2724 | Loss DY: 0.2328
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [49/597] | Loss G: 4.4413 | Loss DX: 0.2305 | Loss DY: 0.2438
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [50/597] | Loss G: 3.6343 | Loss DX: 0.2805 | Loss DY: 0.2526
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [51/597] | Loss G: 3.7129 | Loss DX: 0.2632 | Loss DY: 0.2534
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [52/597] | Loss G: 4.0419 | Loss DX: 0.2300 | Loss DY: 0.2506
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [53/597] | Loss G: 3.9375 | Loss DX: 0.2505 | Loss DY: 0.2209
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [54/597] | Loss G: 3.2988 | Loss DX: 0.2994 | Loss DY: 0.2283
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [55/597] | Loss G: 3.8541 | Loss DX: 0.2338 | Loss DY: 0.2122
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [56/597] | Loss G: 3.5090 | Loss DX: 0.2373 | Loss DY: 0.2433
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [57/597] | Loss G: 4.4926 | Loss DX: 0.2381 | Loss DY: 0.3211
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [58/597] | Loss G: 4.0814 | Loss DX: 0.2452 | Loss DY: 0.2923
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [59/597] | Loss G: 4.6499 | Loss DX: 0.2153 | Loss DY: 0.2401
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [60/597] | Loss G: 4.7526 | Loss DX: 0.2090 | Loss DY: 0.2225
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [61/597] | Loss G: 5.0387 | Loss DX: 0.2441 | Loss DY: 0.2381
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [62/597] | Loss G: 5.5810 | Loss DX: 0.2554 | Loss DY: 0.2437
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [63/597] | Loss G: 4.0576 | Loss DX: 0.2000 | Loss DY: 0.2417
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [64/597] | Loss G: 6.1611 | Loss DX: 0.2473 | Loss DY: 0.2288
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [65/597] | Loss G: 3.8184 | Loss DX: 0.2652 | Loss DY: 0.3043
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [66/597] | Loss G: 4.4392 | Loss DX: 0.2630 | Loss DY: 0.2855
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [67/597] | Loss G: 5.7695 | Loss DX: 0.2299 | Loss DY: 0.2426
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [68/597] | Loss G: 4.2910 | Loss DX: 0.2252 | Loss DY: 0.2364
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [69/597] | Loss G: 4.1822 | Loss DX: 0.2708 | Loss DY: 0.2379
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [70/597] | Loss G: 4.2836 | Loss DX: 0.2717 | Loss DY: 0.2343
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [71/597] | Loss G: 3.0716 | Loss DX: 0.2558 | Loss DY: 0.2407
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [72/597] | Loss G: 4.7487 | Loss DX: 0.2627 | Loss DY: 0.2334
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [73/597] | Loss G: 4.8411 | Loss DX: 0.2838 | Loss DY: 0.2268
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [74/597] | Loss G: 4.2089 | Loss DX: 0.2401 | Loss DY: 0.2527
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [75/597] | Loss G: 4.0838 | Loss DX: 0.2415 | Loss DY: 0.2688
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [76/597] | Loss G: 4.5761 | Loss DX: 0.2531 | Loss DY: 0.2350
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [77/597] | Loss G: 3.8587 | Loss DX: 0.2830 | Loss DY: 0.2397
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [78/597] | Loss G: 3.6991 | Loss DX: 0.2474 | Loss DY: 0.2752
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [79/597] | Loss G: 3.0043 | Loss DX: 0.2279 | Loss DY: 0.2293
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [80/597] | Loss G: 6.2136 | Loss DX: 0.2567 | Loss DY: 0.2798
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [81/597] | Loss G: 4.0633 | Loss DX: 0.2358 | Loss DY: 0.2534
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [82/597] | Loss G: 3.3077 | Loss DX: 0.2308 | Loss DY: 0.2463
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [83/597] | Loss G: 4.4652 | Loss DX: 0.2306 | Loss DY: 0.2229
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [84/597] | Loss G: 4.4584 | Loss DX: 0.2357 | Loss DY: 0.2529
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [85/597] | Loss G: 4.2986 | Loss DX: 0.2848 | Loss DY: 0.2498
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [86/597] | Loss G: 3.2678 | Loss DX: 0.2237 | Loss DY: 0.2207
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [87/597] | Loss G: 3.1641 | Loss DX: 0.2353 | Loss DY: 0.2555
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [88/597] | Loss G: 3.8480 | Loss DX: 0.2265 | Loss DY: 0.2293
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [89/597] | Loss G: 3.8970 | Loss DX: 0.2374 | Loss DY: 0.2548
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [90/597] | Loss G: 4.0562 | Loss DX: 0.2433 | Loss DY: 0.2622
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [91/597] | Loss G: 3.3717 | Loss DX: 0.2217 | Loss DY: 0.2329
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [92/597] | Loss G: 3.4668 | Loss DX: 0.2457 | Loss DY: 0.2286
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [93/597] | Loss G: 4.4264 | Loss DX: 0.2615 | Loss DY: 0.2658
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [94/597] | Loss G: 3.6990 | Loss DX: 0.2455 | Loss DY: 0.2670
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [95/597] | Loss G: 6.4495 | Loss DX: 0.2494 | Loss DY: 0.2693
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [96/597] | Loss G: 5.0199 | Loss DX: 0.2338 | Loss DY: 0.2322
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [97/597] | Loss G: 3.7118 | Loss DX: 0.2343 | Loss DY: 0.2386
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [98/597] | Loss G: 4.7380 | Loss DX: 0.2475 | Loss DY: 0.2670
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [99/597] | Loss G: 4.7801 | Loss DX: 0.2043 | Loss DY: 0.2621
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [100/597] | Loss G: 4.0593 | Loss DX: 0.2788 | Loss DY: 0.2423
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [101/597] | Loss G: 4.5813 | Loss DX: 0.2674 | Loss DY: 0.2346
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [102/597] | Loss G: 4.7746 | Loss DX: 0.2164 | Loss DY: 0.2324
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [103/597] | Loss G: 5.8290 | Loss DX: 0.2576 | Loss DY: 0.2394
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [104/597] | Loss G: 3.9881 | Loss DX: 0.2462 | Loss DY: 0.2424
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [105/597] | Loss G: 4.4380 | Loss DX: 0.2339 | Loss DY: 0.2574
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [106/597] | Loss G: 5.4313 | Loss DX: 0.2550 | Loss DY: 0.2298
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [107/597] | Loss G: 4.3173 | Loss DX: 0.2557 | Loss DY: 0.2393
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [108/597] | Loss G: 5.0790 | Loss DX: 0.2258 | Loss DY: 0.2444
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [109/597] | Loss G: 3.1791 | Loss DX: 0.2280 | Loss DY: 0.2460
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [110/597] | Loss G: 4.0092 | Loss DX: 0.2196 | Loss DY: 0.2551
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [111/597] | Loss G: 3.8967 | Loss DX: 0.2502 | Loss DY: 0.2112
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [112/597] | Loss G: 3.7026 | Loss DX: 0.2115 | Loss DY: 0.2695
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [113/597] | Loss G: 3.3457 | Loss DX: 0.2585 | Loss DY: 0.2691
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [114/597] | Loss G: 2.5151 | Loss DX: 0.2387 | Loss DY: 0.2666
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [115/597] | Loss G: 2.8582 | Loss DX: 0.2381 | Loss DY: 0.2419
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [116/597] | Loss G: 4.0202 | Loss DX: 0.2125 | Loss DY: 0.2326
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [117/597] | Loss G: 3.6840 | Loss DX: 0.2996 | Loss DY: 0.2402
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [118/597] | Loss G: 4.9472 | Loss DX: 0.2421 | Loss DY: 0.2390
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [119/597] | Loss G: 2.8665 | Loss DX: 0.2570 | Loss DY: 0.2390
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [120/597] | Loss G: 3.3611 | Loss DX: 0.2414 | Loss DY: 0.2359
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [121/597] | Loss G: 4.4207 | Loss DX: 0.2263 | Loss DY: 0.2415
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [122/597] | Loss G: 4.7047 | Loss DX: 0.2139 | Loss DY: 0.2305
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [123/597] | Loss G: 5.1660 | Loss DX: 0.2302 | Loss DY: 0.2171
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [124/597] | Loss G: 4.2196 | Loss DX: 0.2144 | Loss DY: 0.1885
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [125/597] | Loss G: 3.5581 | Loss DX: 0.2052 | Loss DY: 0.2338
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [126/597] | Loss G: 3.8728 | Loss DX: 0.1895 | Loss DY: 0.2097
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [127/597] | Loss G: 3.2723 | Loss DX: 0.2229 | Loss DY: 0.3082
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [128/597] | Loss G: 4.1006 | Loss DX: 0.2651 | Loss DY: 0.2596
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [129/597] | Loss G: 4.1359 | Loss DX: 0.2259 | Loss DY: 0.2781
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [130/597] | Loss G: 3.8676 | Loss DX: 0.2582 | Loss DY: 0.2703
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [131/597] | Loss G: 3.9295 | Loss DX: 0.2353 | Loss DY: 0.2700
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [132/597] | Loss G: 3.2322 | Loss DX: 0.2130 | Loss DY: 0.2433
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [133/597] | Loss G: 3.6701 | Loss DX: 0.2039 | Loss DY: 0.2566
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [134/597] | Loss G: 3.1463 | Loss DX: 0.2369 | Loss DY: 0.2492
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [135/597] | Loss G: 3.8032 | Loss DX: 0.2335 | Loss DY: 0.2421
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [136/597] | Loss G: 4.5797 | Loss DX: 0.2948 | Loss DY: 0.2603
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [137/597] | Loss G: 3.7396 | Loss DX: 0.2067 | Loss DY: 0.2480
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [138/597] | Loss G: 4.4038 | Loss DX: 0.2147 | Loss DY: 0.2348
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [139/597] | Loss G: 5.7923 | Loss DX: 0.2311 | Loss DY: 0.2535
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [140/597] | Loss G: 3.4198 | Loss DX: 0.2265 | Loss DY: 0.2472
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [141/597] | Loss G: 3.4467 | Loss DX: 0.2696 | Loss DY: 0.2504
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [142/597] | Loss G: 3.3989 | Loss DX: 0.2319 | Loss DY: 0.2325
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [143/597] | Loss G: 4.2311 | Loss DX: 0.2702 | Loss DY: 0.2434
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [144/597] | Loss G: 3.4299 | Loss DX: 0.2450 | Loss DY: 0.2455
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [145/597] | Loss G: 4.6634 | Loss DX: 0.2341 | Loss DY: 0.2327
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [146/597] | Loss G: 4.2279 | Loss DX: 0.2757 | Loss DY: 0.2459
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [147/597] | Loss G: 3.9802 | Loss DX: 0.2268 | Loss DY: 0.2293
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [148/597] | Loss G: 4.2687 | Loss DX: 0.2353 | Loss DY: 0.2126
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [149/597] | Loss G: 2.9208 | Loss DX: 0.2300 | Loss DY: 0.2480
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [150/597] | Loss G: 5.2731 | Loss DX: 0.2985 | Loss DY: 0.2914
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [151/597] | Loss G: 3.2369 | Loss DX: 0.2491 | Loss DY: 0.2812
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [152/597] | Loss G: 3.9768 | Loss DX: 0.2574 | Loss DY: 0.2566
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [153/597] | Loss G: 3.9549 | Loss DX: 0.2534 | Loss DY: 0.2632
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [154/597] | Loss G: 4.0012 | Loss DX: 0.2309 | Loss DY: 0.2387
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [155/597] | Loss G: 4.0540 | Loss DX: 0.2420 | Loss DY: 0.2386
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [156/597] | Loss G: 3.7753 | Loss DX: 0.2375 | Loss DY: 0.2424
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [157/597] | Loss G: 4.1784 | Loss DX: 0.2317 | Loss DY: 0.2321
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [158/597] | Loss G: 3.4491 | Loss DX: 0.2369 | Loss DY: 0.2240
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [159/597] | Loss G: 2.8998 | Loss DX: 0.2212 | Loss DY: 0.2516
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [160/597] | Loss G: 3.5901 | Loss DX: 0.2389 | Loss DY: 0.2512
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [161/597] | Loss G: 4.0005 | Loss DX: 0.1947 | Loss DY: 0.2050
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [162/597] | Loss G: 3.7081 | Loss DX: 0.2159 | Loss DY: 0.2523
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [163/597] | Loss G: 3.3009 | Loss DX: 0.2588 | Loss DY: 0.2422
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [164/597] | Loss G: 3.9715 | Loss DX: 0.2330 | Loss DY: 0.2128
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [165/597] | Loss G: 3.5744 | Loss DX: 0.2373 | Loss DY: 0.2585
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [166/597] | Loss G: 4.0486 | Loss DX: 0.2281 | Loss DY: 0.2597
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [167/597] | Loss G: 3.9020 | Loss DX: 0.2634 | Loss DY: 0.2993
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [168/597] | Loss G: 3.2364 | Loss DX: 0.2548 | Loss DY: 0.2603
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [169/597] | Loss G: 3.2613 | Loss DX: 0.2313 | Loss DY: 0.2430
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [170/597] | Loss G: 3.8984 | Loss DX: 0.2602 | Loss DY: 0.2467
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [171/597] | Loss G: 4.5756 | Loss DX: 0.2299 | Loss DY: 0.2625
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [172/597] | Loss G: 4.3486 | Loss DX: 0.2302 | Loss DY: 0.2391
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [173/597] | Loss G: 3.5014 | Loss DX: 0.2730 | Loss DY: 0.2419
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [174/597] | Loss G: 3.0791 | Loss DX: 0.2270 | Loss DY: 0.2399
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [175/597] | Loss G: 3.9332 | Loss DX: 0.2275 | Loss DY: 0.2501
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [176/597] | Loss G: 3.5660 | Loss DX: 0.2073 | Loss DY: 0.2536
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [177/597] | Loss G: 3.8083 | Loss DX: 0.2604 | Loss DY: 0.2597
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [178/597] | Loss G: 4.2696 | Loss DX: 0.2106 | Loss DY: 0.2414
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [179/597] | Loss G: 3.6123 | Loss DX: 0.1974 | Loss DY: 0.2440
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [180/597] | Loss G: 3.2130 | Loss DX: 0.2282 | Loss DY: 0.2558
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [181/597] | Loss G: 3.1407 | Loss DX: 0.2392 | Loss DY: 0.2483
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [182/597] | Loss G: 3.4941 | Loss DX: 0.2090 | Loss DY: 0.2402
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [183/597] | Loss G: 3.2209 | Loss DX: 0.2117 | Loss DY: 0.2486
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [184/597] | Loss G: 3.7273 | Loss DX: 0.2810 | Loss DY: 0.2348
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [185/597] | Loss G: 3.9125 | Loss DX: 0.2205 | Loss DY: 0.2411
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [186/597] | Loss G: 3.5550 | Loss DX: 0.2524 | Loss DY: 0.2578
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [187/597] | Loss G: 2.5136 | Loss DX: 0.2254 | Loss DY: 0.2404
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [188/597] | Loss G: 4.2041 | Loss DX: 0.1986 | Loss DY: 0.2269
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [189/597] | Loss G: 2.8828 | Loss DX: 0.2153 | Loss DY: 0.2403
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [190/597] | Loss G: 4.3539 | Loss DX: 0.2098 | Loss DY: 0.2502
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [191/597] | Loss G: 3.5819 | Loss DX: 0.2219 | Loss DY: 0.2302
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [192/597] | Loss G: 3.6999 | Loss DX: 0.2254 | Loss DY: 0.2504
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [193/597] | Loss G: 2.9249 | Loss DX: 0.1982 | Loss DY: 0.2623
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [194/597] | Loss G: 4.0258 | Loss DX: 0.2306 | Loss DY: 0.2505
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [195/597] | Loss G: 3.8329 | Loss DX: 0.2149 | Loss DY: 0.2521
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [196/597] | Loss G: 3.6734 | Loss DX: 0.2353 | Loss DY: 0.2217
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [197/597] | Loss G: 3.5131 | Loss DX: 0.2449 | Loss DY: 0.2628
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [198/597] | Loss G: 4.8917 | Loss DX: 0.1866 | Loss DY: 0.2557
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [199/597] | Loss G: 4.1514 | Loss DX: 0.2270 | Loss DY: 0.2419
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [200/597] | Loss G: 3.9015 | Loss DX: 0.2520 | Loss DY: 0.2401
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [201/597] | Loss G: 3.3485 | Loss DX: 0.2412 | Loss DY: 0.2487
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [202/597] | Loss G: 3.3931 | Loss DX: 0.2630 | Loss DY: 0.2558
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [203/597] | Loss G: 4.3758 | Loss DX: 0.2425 | Loss DY: 0.2328
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [204/597] | Loss G: 4.2320 | Loss DX: 0.2441 | Loss DY: 0.2324
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [205/597] | Loss G: 3.8081 | Loss DX: 0.1813 | Loss DY: 0.2388
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [206/597] | Loss G: 2.7944 | Loss DX: 0.2188 | Loss DY: 0.2561
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [207/597] | Loss G: 4.3619 | Loss DX: 0.2640 | Loss DY: 0.2444
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [208/597] | Loss G: 3.9403 | Loss DX: 0.2422 | Loss DY: 0.2618
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [209/597] | Loss G: 5.5342 | Loss DX: 0.2536 | Loss DY: 0.2652
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [210/597] | Loss G: 2.8124 | Loss DX: 0.2233 | Loss DY: 0.2484
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [211/597] | Loss G: 3.4034 | Loss DX: 0.2504 | Loss DY: 0.2533
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [212/597] | Loss G: 3.9697 | Loss DX: 0.2393 | Loss DY: 0.2440
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [213/597] | Loss G: 4.0879 | Loss DX: 0.2426 | Loss DY: 0.2469
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [214/597] | Loss G: 3.8703 | Loss DX: 0.2348 | Loss DY: 0.2520
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [215/597] | Loss G: 3.9769 | Loss DX: 0.2171 | Loss DY: 0.2470
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [216/597] | Loss G: 3.3705 | Loss DX: 0.2404 | Loss DY: 0.2498
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [217/597] | Loss G: 3.2625 | Loss DX: 0.2669 | Loss DY: 0.2437
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [218/597] | Loss G: 4.2011 | Loss DX: 0.2194 | Loss DY: 0.2378
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [219/597] | Loss G: 3.6556 | Loss DX: 0.2151 | Loss DY: 0.2430
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [220/597] | Loss G: 4.3734 | Loss DX: 0.2520 | Loss DY: 0.2507
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [221/597] | Loss G: 3.6126 | Loss DX: 0.2032 | Loss DY: 0.2421
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [222/597] | Loss G: 3.8675 | Loss DX: 0.2277 | Loss DY: 0.2450
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [223/597] | Loss G: 3.3548 | Loss DX: 0.2602 | Loss DY: 0.2422
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [224/597] | Loss G: 5.1140 | Loss DX: 0.1993 | Loss DY: 0.2426
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [225/597] | Loss G: 3.8450 | Loss DX: 0.2525 | Loss DY: 0.2395
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [226/597] | Loss G: 3.2008 | Loss DX: 0.2425 | Loss DY: 0.2529
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [227/597] | Loss G: 4.6456 | Loss DX: 0.2479 | Loss DY: 0.2852
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [228/597] | Loss G: 3.5453 | Loss DX: 0.2349 | Loss DY: 0.2328
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [229/597] | Loss G: 4.2974 | Loss DX: 0.1991 | Loss DY: 0.2377
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [230/597] | Loss G: 3.3474 | Loss DX: 0.2449 | Loss DY: 0.2470
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [231/597] | Loss G: 3.4596 | Loss DX: 0.2331 | Loss DY: 0.2436
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [232/597] | Loss G: 3.6101 | Loss DX: 0.2171 | Loss DY: 0.2312
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [233/597] | Loss G: 2.4924 | Loss DX: 0.2043 | Loss DY: 0.2455
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [234/597] | Loss G: 3.7247 | Loss DX: 0.2777 | Loss DY: 0.2419
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [235/597] | Loss G: 3.8634 | Loss DX: 0.2730 | Loss DY: 0.2523
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [236/597] | Loss G: 4.5871 | Loss DX: 0.2551 | Loss DY: 0.2484
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [237/597] | Loss G: 4.1545 | Loss DX: 0.1969 | Loss DY: 0.2379
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [238/597] | Loss G: 3.0414 | Loss DX: 0.2136 | Loss DY: 0.2388
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [239/597] | Loss G: 4.4951 | Loss DX: 0.1930 | Loss DY: 0.2171
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [240/597] | Loss G: 3.5639 | Loss DX: 0.2213 | Loss DY: 0.2492
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [241/597] | Loss G: 4.2460 | Loss DX: 0.2364 | Loss DY: 0.2681
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [242/597] | Loss G: 3.4652 | Loss DX: 0.2331 | Loss DY: 0.2399
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [243/597] | Loss G: 3.4330 | Loss DX: 0.1779 | Loss DY: 0.2118
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [244/597] | Loss G: 4.0823 | Loss DX: 0.1474 | Loss DY: 0.2027
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [245/597] | Loss G: 3.7532 | Loss DX: 0.2661 | Loss DY: 0.2530
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [246/597] | Loss G: 3.9963 | Loss DX: 0.2311 | Loss DY: 0.2366
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [247/597] | Loss G: 2.9871 | Loss DX: 0.2230 | Loss DY: 0.2508
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [248/597] | Loss G: 3.8928 | Loss DX: 0.1806 | Loss DY: 0.2535
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [249/597] | Loss G: 4.4070 | Loss DX: 0.2119 | Loss DY: 0.2471
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [250/597] | Loss G: 3.2722 | Loss DX: 0.2883 | Loss DY: 0.2583
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [251/597] | Loss G: 3.6743 | Loss DX: 0.2127 | Loss DY: 0.2430
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [252/597] | Loss G: 3.6693 | Loss DX: 0.2636 | Loss DY: 0.2433
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [253/597] | Loss G: 3.3101 | Loss DX: 0.2590 | Loss DY: 0.2598
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [254/597] | Loss G: 3.0030 | Loss DX: 0.2147 | Loss DY: 0.2591
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [255/597] | Loss G: 4.3674 | Loss DX: 0.1859 | Loss DY: 0.2309
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [256/597] | Loss G: 3.9887 | Loss DX: 0.1904 | Loss DY: 0.2324
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [257/597] | Loss G: 4.4127 | Loss DX: 0.2166 | Loss DY: 0.2270
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [258/597] | Loss G: 3.7780 | Loss DX: 0.2010 | Loss DY: 0.2185
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [259/597] | Loss G: 3.8066 | Loss DX: 0.2735 | Loss DY: 0.2178
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [260/597] | Loss G: 3.9936 | Loss DX: 0.1534 | Loss DY: 0.2241
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [261/597] | Loss G: 3.8971 | Loss DX: 0.2467 | Loss DY: 0.2728
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [262/597] | Loss G: 3.4973 | Loss DX: 0.1956 | Loss DY: 0.2422
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [263/597] | Loss G: 4.0824 | Loss DX: 0.2480 | Loss DY: 0.2788
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [264/597] | Loss G: 3.5801 | Loss DX: 0.2545 | Loss DY: 0.2496
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [265/597] | Loss G: 3.9136 | Loss DX: 0.2023 | Loss DY: 0.2553
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [266/597] | Loss G: 4.5322 | Loss DX: 0.2046 | Loss DY: 0.2765
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [267/597] | Loss G: 3.8460 | Loss DX: 0.2615 | Loss DY: 0.2527
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [268/597] | Loss G: 4.4182 | Loss DX: 0.2014 | Loss DY: 0.2479
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [269/597] | Loss G: 3.2695 | Loss DX: 0.1696 | Loss DY: 0.2413
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [270/597] | Loss G: 5.1323 | Loss DX: 0.2263 | Loss DY: 0.2503
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [271/597] | Loss G: 3.7449 | Loss DX: 0.1811 | Loss DY: 0.2397
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [272/597] | Loss G: 3.2914 | Loss DX: 0.1456 | Loss DY: 0.2235
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [273/597] | Loss G: 4.1714 | Loss DX: 0.1803 | Loss DY: 0.2538
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [274/597] | Loss G: 2.8481 | Loss DX: 0.2432 | Loss DY: 0.2524
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [275/597] | Loss G: 3.4547 | Loss DX: 0.3222 | Loss DY: 0.2601
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [276/597] | Loss G: 3.6039 | Loss DX: 0.2520 | Loss DY: 0.2244
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [277/597] | Loss G: 3.8532 | Loss DX: 0.2318 | Loss DY: 0.2349
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [278/597] | Loss G: 3.2641 | Loss DX: 0.2501 | Loss DY: 0.2551
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [279/597] | Loss G: 3.1646 | Loss DX: 0.2636 | Loss DY: 0.2337
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [280/597] | Loss G: 3.8355 | Loss DX: 0.2146 | Loss DY: 0.2392
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [281/597] | Loss G: 2.7965 | Loss DX: 0.2368 | Loss DY: 0.2617
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [282/597] | Loss G: 4.0323 | Loss DX: 0.2569 | Loss DY: 0.2538
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [283/597] | Loss G: 3.6665 | Loss DX: 0.2506 | Loss DY: 0.2521
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [284/597] | Loss G: 2.8874 | Loss DX: 0.2015 | Loss DY: 0.2498
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [285/597] | Loss G: 3.3769 | Loss DX: 0.2329 | Loss DY: 0.2337
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [286/597] | Loss G: 3.5451 | Loss DX: 0.2195 | Loss DY: 0.2378
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [287/597] | Loss G: 3.7493 | Loss DX: 0.1895 | Loss DY: 0.2178
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [288/597] | Loss G: 3.3259 | Loss DX: 0.2329 | Loss DY: 0.2300
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [289/597] | Loss G: 3.5192 | Loss DX: 0.2507 | Loss DY: 0.2392
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [290/597] | Loss G: 3.4610 | Loss DX: 0.1946 | Loss DY: 0.2190
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [291/597] | Loss G: 3.0275 | Loss DX: 0.2149 | Loss DY: 0.2508
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [292/597] | Loss G: 3.2259 | Loss DX: 0.1960 | Loss DY: 0.2240
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [293/597] | Loss G: 3.6343 | Loss DX: 0.2263 | Loss DY: 0.2146
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [294/597] | Loss G: 2.9425 | Loss DX: 0.1705 | Loss DY: 0.1927
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [295/597] | Loss G: 4.8673 | Loss DX: 0.2127 | Loss DY: 0.2648
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [296/597] | Loss G: 3.8435 | Loss DX: 0.1625 | Loss DY: 0.2460
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [297/597] | Loss G: 3.2798 | Loss DX: 0.1929 | Loss DY: 0.2377
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [298/597] | Loss G: 2.9490 | Loss DX: 0.2421 | Loss DY: 0.2827
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [299/597] | Loss G: 4.1161 | Loss DX: 0.2395 | Loss DY: 0.2517
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [300/597] | Loss G: 2.9256 | Loss DX: 0.2304 | Loss DY: 0.2340
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [301/597] | Loss G: 2.9719 | Loss DX: 0.1617 | Loss DY: 0.2014
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [302/597] | Loss G: 3.8899 | Loss DX: 0.2721 | Loss DY: 0.2303
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [303/597] | Loss G: 3.3900 | Loss DX: 0.2570 | Loss DY: 0.2600
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [304/597] | Loss G: 3.3998 | Loss DX: 0.2340 | Loss DY: 0.2575
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [305/597] | Loss G: 3.1681 | Loss DX: 0.2122 | Loss DY: 0.2262
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [306/597] | Loss G: 3.9513 | Loss DX: 0.2443 | Loss DY: 0.2329
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [307/597] | Loss G: 3.0857 | Loss DX: 0.2120 | Loss DY: 0.2513
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [308/597] | Loss G: 3.5583 | Loss DX: 0.2410 | Loss DY: 0.2337
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [309/597] | Loss G: 3.7547 | Loss DX: 0.1998 | Loss DY: 0.2192
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [310/597] | Loss G: 3.8219 | Loss DX: 0.1996 | Loss DY: 0.2479
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [311/597] | Loss G: 2.8586 | Loss DX: 0.2204 | Loss DY: 0.2512
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [312/597] | Loss G: 2.8468 | Loss DX: 0.2326 | Loss DY: 0.2372
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [313/597] | Loss G: 3.4616 | Loss DX: 0.2297 | Loss DY: 0.2537
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [314/597] | Loss G: 4.0701 | Loss DX: 0.1953 | Loss DY: 0.2407
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [315/597] | Loss G: 4.2509 | Loss DX: 0.2061 | Loss DY: 0.2496
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [316/597] | Loss G: 3.8155 | Loss DX: 0.1980 | Loss DY: 0.2176
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [317/597] | Loss G: 4.0220 | Loss DX: 0.2303 | Loss DY: 0.2495
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [318/597] | Loss G: 3.7409 | Loss DX: 0.1913 | Loss DY: 0.2397
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [319/597] | Loss G: 4.8012 | Loss DX: 0.1695 | Loss DY: 0.2330
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [320/597] | Loss G: 4.6431 | Loss DX: 0.2591 | Loss DY: 0.2389
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [321/597] | Loss G: 4.1258 | Loss DX: 0.3232 | Loss DY: 0.3008
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [322/597] | Loss G: 3.2101 | Loss DX: 0.2799 | Loss DY: 0.2636
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [323/597] | Loss G: 3.7499 | Loss DX: 0.2563 | Loss DY: 0.2769
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [324/597] | Loss G: 3.2886 | Loss DX: 0.2485 | Loss DY: 0.2417
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [325/597] | Loss G: 3.4605 | Loss DX: 0.2679 | Loss DY: 0.2313
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [326/597] | Loss G: 3.0864 | Loss DX: 0.2325 | Loss DY: 0.2505
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [327/597] | Loss G: 3.2307 | Loss DX: 0.2189 | Loss DY: 0.2290
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [328/597] | Loss G: 3.1368 | Loss DX: 0.2461 | Loss DY: 0.2633
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [329/597] | Loss G: 2.2570 | Loss DX: 0.2506 | Loss DY: 0.2549
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [330/597] | Loss G: 2.3367 | Loss DX: 0.2144 | Loss DY: 0.2459
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [331/597] | Loss G: 2.8886 | Loss DX: 0.2713 | Loss DY: 0.2539
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [332/597] | Loss G: 5.1711 | Loss DX: 0.2452 | Loss DY: 0.2371
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [333/597] | Loss G: 3.6661 | Loss DX: 0.2459 | Loss DY: 0.2480
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [334/597] | Loss G: 3.2267 | Loss DX: 0.1777 | Loss DY: 0.2252
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [335/597] | Loss G: 4.2230 | Loss DX: 0.2388 | Loss DY: 0.2562
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [336/597] | Loss G: 3.2922 | Loss DX: 0.1979 | Loss DY: 0.2276
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [337/597] | Loss G: 3.6320 | Loss DX: 0.2456 | Loss DY: 0.2354
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [338/597] | Loss G: 3.5778 | Loss DX: 0.2061 | Loss DY: 0.2227
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [339/597] | Loss G: 3.8671 | Loss DX: 0.2278 | Loss DY: 0.2302
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [340/597] | Loss G: 3.8933 | Loss DX: 0.1909 | Loss DY: 0.2245
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [341/597] | Loss G: 3.0238 | Loss DX: 0.2456 | Loss DY: 0.2433
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [342/597] | Loss G: 2.7646 | Loss DX: 0.2442 | Loss DY: 0.2426
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [343/597] | Loss G: 2.8156 | Loss DX: 0.2580 | Loss DY: 0.2406
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [344/597] | Loss G: 2.8616 | Loss DX: 0.2116 | Loss DY: 0.2308
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [345/597] | Loss G: 2.9207 | Loss DX: 0.2529 | Loss DY: 0.2652
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [346/597] | Loss G: 4.2344 | Loss DX: 0.2174 | Loss DY: 0.2276
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [347/597] | Loss G: 3.8517 | Loss DX: 0.1996 | Loss DY: 0.2307
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [348/597] | Loss G: 3.4370 | Loss DX: 0.2434 | Loss DY: 0.2337
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [349/597] | Loss G: 3.5835 | Loss DX: 0.2637 | Loss DY: 0.2521
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [350/597] | Loss G: 3.0361 | Loss DX: 0.2303 | Loss DY: 0.2449
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [351/597] | Loss G: 4.5642 | Loss DX: 0.2307 | Loss DY: 0.2469
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [352/597] | Loss G: 2.6383 | Loss DX: 0.1857 | Loss DY: 0.2067
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [353/597] | Loss G: 4.0042 | Loss DX: 0.2497 | Loss DY: 0.2533
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [354/597] | Loss G: 3.7783 | Loss DX: 0.2966 | Loss DY: 0.2894
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [355/597] | Loss G: 2.7131 | Loss DX: 0.2413 | Loss DY: 0.2627
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [356/597] | Loss G: 3.8219 | Loss DX: 0.2295 | Loss DY: 0.2382
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [357/597] | Loss G: 4.4968 | Loss DX: 0.2133 | Loss DY: 0.2277
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [358/597] | Loss G: 3.1095 | Loss DX: 0.1896 | Loss DY: 0.2140
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [359/597] | Loss G: 4.1306 | Loss DX: 0.1983 | Loss DY: 0.2250
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [360/597] | Loss G: 4.4159 | Loss DX: 0.1598 | Loss DY: 0.1972
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [361/597] | Loss G: 4.4319 | Loss DX: 0.1629 | Loss DY: 0.2338
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [362/597] | Loss G: 2.9489 | Loss DX: 0.1964 | Loss DY: 0.2309
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [363/597] | Loss G: 4.2059 | Loss DX: 0.2238 | Loss DY: 0.2515
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [364/597] | Loss G: 4.0686 | Loss DX: 0.1896 | Loss DY: 0.2292
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [365/597] | Loss G: 3.4893 | Loss DX: 0.2412 | Loss DY: 0.2520
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [366/597] | Loss G: 3.9516 | Loss DX: 0.1916 | Loss DY: 0.2183
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [367/597] | Loss G: 3.0110 | Loss DX: 0.2467 | Loss DY: 0.2571
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [368/597] | Loss G: 3.1779 | Loss DX: 0.2139 | Loss DY: 0.2612
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [369/597] | Loss G: 4.0201 | Loss DX: 0.1998 | Loss DY: 0.2407
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [370/597] | Loss G: 3.1459 | Loss DX: 0.2423 | Loss DY: 0.2666
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [371/597] | Loss G: 3.0773 | Loss DX: 0.2221 | Loss DY: 0.2310
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [372/597] | Loss G: 3.4973 | Loss DX: 0.2461 | Loss DY: 0.2391
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [373/597] | Loss G: 3.1445 | Loss DX: 0.2316 | Loss DY: 0.2398
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [374/597] | Loss G: 3.9885 | Loss DX: 0.2291 | Loss DY: 0.2546
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [375/597] | Loss G: 2.8469 | Loss DX: 0.1981 | Loss DY: 0.2334
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [376/597] | Loss G: 3.8535 | Loss DX: 0.2494 | Loss DY: 0.2531
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [377/597] | Loss G: 4.2450 | Loss DX: 0.2341 | Loss DY: 0.2883
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [378/597] | Loss G: 4.0895 | Loss DX: 0.2357 | Loss DY: 0.2316
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [379/597] | Loss G: 2.9388 | Loss DX: 0.2496 | Loss DY: 0.2244
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [380/597] | Loss G: 3.1593 | Loss DX: 0.1862 | Loss DY: 0.2422
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [381/597] | Loss G: 3.6939 | Loss DX: 0.1909 | Loss DY: 0.2069
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [382/597] | Loss G: 3.7708 | Loss DX: 0.3000 | Loss DY: 0.2338
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [383/597] | Loss G: 3.6629 | Loss DX: 0.2080 | Loss DY: 0.2342
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [384/597] | Loss G: 2.7963 | Loss DX: 0.2532 | Loss DY: 0.2605
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [385/597] | Loss G: 3.3254 | Loss DX: 0.2178 | Loss DY: 0.2233
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [386/597] | Loss G: 3.8300 | Loss DX: 0.1984 | Loss DY: 0.2268
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [387/597] | Loss G: 3.5948 | Loss DX: 0.1869 | Loss DY: 0.2600
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [388/597] | Loss G: 4.1475 | Loss DX: 0.2463 | Loss DY: 0.2626
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [389/597] | Loss G: 4.9373 | Loss DX: 0.1717 | Loss DY: 0.2007
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [390/597] | Loss G: 4.0091 | Loss DX: 0.2014 | Loss DY: 0.2288
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [391/597] | Loss G: 3.1947 | Loss DX: 0.2386 | Loss DY: 0.2757
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [392/597] | Loss G: 4.5954 | Loss DX: 0.1991 | Loss DY: 0.2254
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [393/597] | Loss G: 4.7394 | Loss DX: 0.2925 | Loss DY: 0.2889
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [394/597] | Loss G: 4.0850 | Loss DX: 0.2426 | Loss DY: 0.2421
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [395/597] | Loss G: 5.4499 | Loss DX: 0.2603 | Loss DY: 0.2694
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [396/597] | Loss G: 3.7998 | Loss DX: 0.2586 | Loss DY: 0.2504
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [397/597] | Loss G: 3.5852 | Loss DX: 0.2367 | Loss DY: 0.2352
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [398/597] | Loss G: 4.6611 | Loss DX: 0.2317 | Loss DY: 0.2473
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [399/597] | Loss G: 3.4576 | Loss DX: 0.2334 | Loss DY: 0.2471
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [400/597] | Loss G: 4.4231 | Loss DX: 0.2079 | Loss DY: 0.2428
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [401/597] | Loss G: 3.1316 | Loss DX: 0.2231 | Loss DY: 0.2343
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [402/597] | Loss G: 3.6299 | Loss DX: 0.2807 | Loss DY: 0.2481
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [403/597] | Loss G: 4.2102 | Loss DX: 0.2385 | Loss DY: 0.2303
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [404/597] | Loss G: 2.9872 | Loss DX: 0.1821 | Loss DY: 0.2245
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [405/597] | Loss G: 4.7260 | Loss DX: 0.2235 | Loss DY: 0.2226
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [406/597] | Loss G: 4.2925 | Loss DX: 0.2355 | Loss DY: 0.2475
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [407/597] | Loss G: 3.3931 | Loss DX: 0.2261 | Loss DY: 0.2356
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [408/597] | Loss G: 4.7856 | Loss DX: 0.2894 | Loss DY: 0.2663
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [409/597] | Loss G: 4.5617 | Loss DX: 0.2434 | Loss DY: 0.2345
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [410/597] | Loss G: 3.4706 | Loss DX: 0.2447 | Loss DY: 0.2624
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [411/597] | Loss G: 4.0941 | Loss DX: 0.2043 | Loss DY: 0.2293
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [412/597] | Loss G: 3.2252 | Loss DX: 0.2442 | Loss DY: 0.2470
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [413/597] | Loss G: 4.8844 | Loss DX: 0.1863 | Loss DY: 0.2156
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [414/597] | Loss G: 3.9977 | Loss DX: 0.1783 | Loss DY: 0.1940
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [415/597] | Loss G: 3.7427 | Loss DX: 0.1897 | Loss DY: 0.1937
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [416/597] | Loss G: 3.5385 | Loss DX: 0.1541 | Loss DY: 0.1856
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [417/597] | Loss G: 3.5533 | Loss DX: 0.1689 | Loss DY: 0.2229
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [418/597] | Loss G: 5.2111 | Loss DX: 0.2572 | Loss DY: 0.2364
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [419/597] | Loss G: 3.8335 | Loss DX: 0.2240 | Loss DY: 0.2799
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [420/597] | Loss G: 4.4797 | Loss DX: 0.1327 | Loss DY: 0.2083
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [421/597] | Loss G: 3.6606 | Loss DX: 0.1422 | Loss DY: 0.1757
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [422/597] | Loss G: 3.5429 | Loss DX: 0.2694 | Loss DY: 0.3460
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [423/597] | Loss G: 3.0630 | Loss DX: 0.2787 | Loss DY: 0.3068
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [424/597] | Loss G: 4.0854 | Loss DX: 0.2400 | Loss DY: 0.2375
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [425/597] | Loss G: 3.0235 | Loss DX: 0.1655 | Loss DY: 0.2437
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [426/597] | Loss G: 3.0970 | Loss DX: 0.2639 | Loss DY: 0.2570
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [427/597] | Loss G: 3.6117 | Loss DX: 0.2112 | Loss DY: 0.2301
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [428/597] | Loss G: 3.5979 | Loss DX: 0.2219 | Loss DY: 0.2414
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [429/597] | Loss G: 3.3823 | Loss DX: 0.2451 | Loss DY: 0.2303
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [430/597] | Loss G: 3.4054 | Loss DX: 0.2472 | Loss DY: 0.2749
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [431/597] | Loss G: 3.8773 | Loss DX: 0.1866 | Loss DY: 0.2382
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [432/597] | Loss G: 4.0607 | Loss DX: 0.1905 | Loss DY: 0.2267
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [433/597] | Loss G: 3.1423 | Loss DX: 0.1963 | Loss DY: 0.2257
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [434/597] | Loss G: 3.7736 | Loss DX: 0.1918 | Loss DY: 0.2430
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [435/597] | Loss G: 3.6828 | Loss DX: 0.1372 | Loss DY: 0.2071
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [436/597] | Loss G: 2.9035 | Loss DX: 0.2909 | Loss DY: 0.2522
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [437/597] | Loss G: 3.0725 | Loss DX: 0.2351 | Loss DY: 0.2494
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [438/597] | Loss G: 3.7825 | Loss DX: 0.1250 | Loss DY: 0.2014
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [439/597] | Loss G: 3.8441 | Loss DX: 0.2068 | Loss DY: 0.2206
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [440/597] | Loss G: 4.7390 | Loss DX: 0.1525 | Loss DY: 0.1955
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [441/597] | Loss G: 2.9731 | Loss DX: 0.2099 | Loss DY: 0.2283
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [442/597] | Loss G: 4.9554 | Loss DX: 0.2266 | Loss DY: 0.2465
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [443/597] | Loss G: 3.0619 | Loss DX: 0.2245 | Loss DY: 0.2397
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [444/597] | Loss G: 3.3612 | Loss DX: 0.2052 | Loss DY: 0.2359
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [445/597] | Loss G: 3.8043 | Loss DX: 0.1911 | Loss DY: 0.2373
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [446/597] | Loss G: 3.6788 | Loss DX: 0.1914 | Loss DY: 0.2559
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [447/597] | Loss G: 2.9184 | Loss DX: 0.4026 | Loss DY: 0.3045
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [448/597] | Loss G: 4.7481 | Loss DX: 0.2758 | Loss DY: 0.2545
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [449/597] | Loss G: 3.6120 | Loss DX: 0.2700 | Loss DY: 0.2501
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [450/597] | Loss G: 3.3016 | Loss DX: 0.2279 | Loss DY: 0.2354
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [451/597] | Loss G: 2.8133 | Loss DX: 0.2311 | Loss DY: 0.2343
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [452/597] | Loss G: 2.8285 | Loss DX: 0.2006 | Loss DY: 0.2185
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [453/597] | Loss G: 3.9279 | Loss DX: 0.1928 | Loss DY: 0.2273
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [454/597] | Loss G: 3.1755 | Loss DX: 0.2715 | Loss DY: 0.2565
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [455/597] | Loss G: 2.6176 | Loss DX: 0.2519 | Loss DY: 0.2329
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [456/597] | Loss G: 2.7755 | Loss DX: 0.2863 | Loss DY: 0.2331
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [457/597] | Loss G: 4.4816 | Loss DX: 0.1729 | Loss DY: 0.2077
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [458/597] | Loss G: 2.8196 | Loss DX: 0.2478 | Loss DY: 0.2300
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [459/597] | Loss G: 2.8492 | Loss DX: 0.2842 | Loss DY: 0.2698
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [460/597] | Loss G: 3.6766 | Loss DX: 0.1683 | Loss DY: 0.2157
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [461/597] | Loss G: 3.6619 | Loss DX: 0.2390 | Loss DY: 0.2711
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [462/597] | Loss G: 3.8627 | Loss DX: 0.2204 | Loss DY: 0.2303
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [463/597] | Loss G: 2.7478 | Loss DX: 0.2603 | Loss DY: 0.2774
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [464/597] | Loss G: 5.5278 | Loss DX: 0.2229 | Loss DY: 0.2094
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [465/597] | Loss G: 4.0871 | Loss DX: 0.2280 | Loss DY: 0.2270
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [466/597] | Loss G: 4.3546 | Loss DX: 0.2290 | Loss DY: 0.2363
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [467/597] | Loss G: 3.0584 | Loss DX: 0.2618 | Loss DY: 0.2572
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [468/597] | Loss G: 4.0424 | Loss DX: 0.1734 | Loss DY: 0.1876
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [469/597] | Loss G: 3.7113 | Loss DX: 0.2221 | Loss DY: 0.2129
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [470/597] | Loss G: 3.3034 | Loss DX: 0.2436 | Loss DY: 0.2631
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [471/597] | Loss G: 3.4857 | Loss DX: 0.2207 | Loss DY: 0.2476
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [472/597] | Loss G: 3.0825 | Loss DX: 0.1807 | Loss DY: 0.2248
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [473/597] | Loss G: 3.6980 | Loss DX: 0.1714 | Loss DY: 0.2027
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [474/597] | Loss G: 4.3757 | Loss DX: 0.2554 | Loss DY: 0.2672
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [475/597] | Loss G: 3.3871 | Loss DX: 0.2613 | Loss DY: 0.2933
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [476/597] | Loss G: 4.2786 | Loss DX: 0.2356 | Loss DY: 0.2714
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [477/597] | Loss G: 3.3462 | Loss DX: 0.2356 | Loss DY: 0.2532
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [478/597] | Loss G: 3.5088 | Loss DX: 0.2186 | Loss DY: 0.2335
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [479/597] | Loss G: 3.1419 | Loss DX: 0.2175 | Loss DY: 0.2555
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [480/597] | Loss G: 3.4669 | Loss DX: 0.1828 | Loss DY: 0.2232
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [481/597] | Loss G: 3.3007 | Loss DX: 0.2030 | Loss DY: 0.2161
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [482/597] | Loss G: 3.2809 | Loss DX: 0.2850 | Loss DY: 0.2500
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [483/597] | Loss G: 3.3805 | Loss DX: 0.1681 | Loss DY: 0.2238
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [484/597] | Loss G: 3.2343 | Loss DX: 0.1492 | Loss DY: 0.2136
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [485/597] | Loss G: 3.3924 | Loss DX: 0.2054 | Loss DY: 0.2426
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [486/597] | Loss G: 4.2823 | Loss DX: 0.2310 | Loss DY: 0.2342
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [487/597] | Loss G: 3.9909 | Loss DX: 0.2228 | Loss DY: 0.2790
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [488/597] | Loss G: 3.4023 | Loss DX: 0.2690 | Loss DY: 0.2585
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [489/597] | Loss G: 3.3042 | Loss DX: 0.1802 | Loss DY: 0.2242
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [490/597] | Loss G: 3.4759 | Loss DX: 0.2319 | Loss DY: 0.2073
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [491/597] | Loss G: 3.0567 | Loss DX: 0.2430 | Loss DY: 0.2501
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [492/597] | Loss G: 2.7755 | Loss DX: 0.2499 | Loss DY: 0.2528
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [493/597] | Loss G: 3.8343 | Loss DX: 0.2577 | Loss DY: 0.2426
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [494/597] | Loss G: 4.0217 | Loss DX: 0.2148 | Loss DY: 0.2282
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [495/597] | Loss G: 4.7232 | Loss DX: 0.2022 | Loss DY: 0.2136
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [496/597] | Loss G: 3.7096 | Loss DX: 0.2013 | Loss DY: 0.2673
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [497/597] | Loss G: 3.4816 | Loss DX: 0.1690 | Loss DY: 0.2320
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [498/597] | Loss G: 3.4185 | Loss DX: 0.2196 | Loss DY: 0.2378
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [499/597] | Loss G: 4.3777 | Loss DX: 0.1655 | Loss DY: 0.2442
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [500/597] | Loss G: 3.4602 | Loss DX: 0.1517 | Loss DY: 0.2020
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [501/597] | Loss G: 3.2788 | Loss DX: 0.1982 | Loss DY: 0.2302
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [502/597] | Loss G: 4.9115 | Loss DX: 0.1894 | Loss DY: 0.2275
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [503/597] | Loss G: 3.9152 | Loss DX: 0.1962 | Loss DY: 0.2159
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [504/597] | Loss G: 4.7810 | Loss DX: 0.1892 | Loss DY: 0.1996
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [505/597] | Loss G: 3.9743 | Loss DX: 0.2134 | Loss DY: 0.2538
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [506/597] | Loss G: 3.2574 | Loss DX: 0.1341 | Loss DY: 0.2119
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [507/597] | Loss G: 4.0723 | Loss DX: 0.3169 | Loss DY: 0.2529
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [508/597] | Loss G: 3.3533 | Loss DX: 0.2116 | Loss DY: 0.2462
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [509/597] | Loss G: 2.7578 | Loss DX: 0.3495 | Loss DY: 0.2660
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [510/597] | Loss G: 4.3573 | Loss DX: 0.2005 | Loss DY: 0.2157
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [511/597] | Loss G: 5.0517 | Loss DX: 0.2368 | Loss DY: 0.2187
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [512/597] | Loss G: 2.9543 | Loss DX: 0.2285 | Loss DY: 0.2358
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [513/597] | Loss G: 3.4733 | Loss DX: 0.1942 | Loss DY: 0.2139
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [514/597] | Loss G: 2.8385 | Loss DX: 0.2220 | Loss DY: 0.2413
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [515/597] | Loss G: 3.5106 | Loss DX: 0.2081 | Loss DY: 0.2240
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [516/597] | Loss G: 4.1556 | Loss DX: 0.1581 | Loss DY: 0.2018
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [517/597] | Loss G: 3.0893 | Loss DX: 0.2684 | Loss DY: 0.2309
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [518/597] | Loss G: 2.3598 | Loss DX: 0.2457 | Loss DY: 0.2219
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [519/597] | Loss G: 3.0018 | Loss DX: 0.2279 | Loss DY: 0.2495
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [520/597] | Loss G: 4.3511 | Loss DX: 0.2799 | Loss DY: 0.2499
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [521/597] | Loss G: 3.7966 | Loss DX: 0.2502 | Loss DY: 0.2727
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [522/597] | Loss G: 4.1654 | Loss DX: 0.2846 | Loss DY: 0.2735
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [523/597] | Loss G: 4.3368 | Loss DX: 0.2348 | Loss DY: 0.2311
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [524/597] | Loss G: 3.6065 | Loss DX: 0.2142 | Loss DY: 0.2258
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [525/597] | Loss G: 3.3854 | Loss DX: 0.2039 | Loss DY: 0.2283
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [526/597] | Loss G: 3.1651 | Loss DX: 0.1768 | Loss DY: 0.2209
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [527/597] | Loss G: 3.7792 | Loss DX: 0.2337 | Loss DY: 0.2118
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [528/597] | Loss G: 4.0281 | Loss DX: 0.1729 | Loss DY: 0.2344
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [529/597] | Loss G: 4.4121 | Loss DX: 0.2741 | Loss DY: 0.3017
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [530/597] | Loss G: 3.4360 | Loss DX: 0.1816 | Loss DY: 0.1950
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [531/597] | Loss G: 3.4435 | Loss DX: 0.1873 | Loss DY: 0.2146
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [532/597] | Loss G: 2.9372 | Loss DX: 0.1659 | Loss DY: 0.2207
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [533/597] | Loss G: 3.8755 | Loss DX: 0.1605 | Loss DY: 0.2305
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [534/597] | Loss G: 3.3297 | Loss DX: 0.1545 | Loss DY: 0.1906
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [535/597] | Loss G: 3.9823 | Loss DX: 0.2299 | Loss DY: 0.2347
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [536/597] | Loss G: 3.5634 | Loss DX: 0.2017 | Loss DY: 0.2262
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [537/597] | Loss G: 4.0242 | Loss DX: 0.1858 | Loss DY: 0.2681
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [538/597] | Loss G: 3.9061 | Loss DX: 0.1822 | Loss DY: 0.2162
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [539/597] | Loss G: 3.3902 | Loss DX: 0.2039 | Loss DY: 0.2158
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [540/597] | Loss G: 3.4610 | Loss DX: 0.2156 | Loss DY: 0.2204
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [541/597] | Loss G: 2.9058 | Loss DX: 0.2474 | Loss DY: 0.2532
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [542/597] | Loss G: 3.0691 | Loss DX: 0.2175 | Loss DY: 0.2309
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [543/597] | Loss G: 3.3976 | Loss DX: 0.1942 | Loss DY: 0.2034
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [544/597] | Loss G: 3.4358 | Loss DX: 0.2143 | Loss DY: 0.2353
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [545/597] | Loss G: 3.1342 | Loss DX: 0.2177 | Loss DY: 0.2143
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [546/597] | Loss G: 3.6284 | Loss DX: 0.2379 | Loss DY: 0.2679
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [547/597] | Loss G: 3.0396 | Loss DX: 0.2062 | Loss DY: 0.2482
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [548/597] | Loss G: 3.4573 | Loss DX: 0.2628 | Loss DY: 0.2317
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [549/597] | Loss G: 4.0796 | Loss DX: 0.2085 | Loss DY: 0.2384
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [550/597] | Loss G: 3.0323 | Loss DX: 0.2724 | Loss DY: 0.2547
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [551/597] | Loss G: 2.9574 | Loss DX: 0.2660 | Loss DY: 0.2592
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [552/597] | Loss G: 3.5276 | Loss DX: 0.1861 | Loss DY: 0.2175
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [553/597] | Loss G: 4.9968 | Loss DX: 0.1483 | Loss DY: 0.2040
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [554/597] | Loss G: 3.7783 | Loss DX: 0.2376 | Loss DY: 0.2439
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [555/597] | Loss G: 2.7544 | Loss DX: 0.1871 | Loss DY: 0.2056
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [556/597] | Loss G: 2.6347 | Loss DX: 0.2327 | Loss DY: 0.2319
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [557/597] | Loss G: 2.8180 | Loss DX: 0.1941 | Loss DY: 0.2229
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [558/597] | Loss G: 3.7197 | Loss DX: 0.2166 | Loss DY: 0.2204
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [559/597] | Loss G: 3.3000 | Loss DX: 0.1604 | Loss DY: 0.2097
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [560/597] | Loss G: 3.9796 | Loss DX: 0.2449 | Loss DY: 0.2237
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [561/597] | Loss G: 2.8628 | Loss DX: 0.1815 | Loss DY: 0.2022
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [562/597] | Loss G: 3.4584 | Loss DX: 0.2119 | Loss DY: 0.2188
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [563/597] | Loss G: 4.1707 | Loss DX: 0.2159 | Loss DY: 0.2143
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [564/597] | Loss G: 5.2654 | Loss DX: 0.1632 | Loss DY: 0.2284
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [565/597] | Loss G: 3.1835 | Loss DX: 0.2911 | Loss DY: 0.2790
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [566/597] | Loss G: 2.9572 | Loss DX: 0.2906 | Loss DY: 0.3011
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [567/597] | Loss G: 3.5517 | Loss DX: 0.2778 | Loss DY: 0.2189
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [568/597] | Loss G: 3.2423 | Loss DX: 0.2375 | Loss DY: 0.2609
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [569/597] | Loss G: 2.5587 | Loss DX: 0.2148 | Loss DY: 0.2398
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [570/597] | Loss G: 4.0470 | Loss DX: 0.2120 | Loss DY: 0.2402
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [571/597] | Loss G: 3.5410 | Loss DX: 0.2113 | Loss DY: 0.2424
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [572/597] | Loss G: 3.9420 | Loss DX: 0.1781 | Loss DY: 0.2026
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [573/597] | Loss G: 3.8167 | Loss DX: 0.1840 | Loss DY: 0.2348
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [574/597] | Loss G: 4.8629 | Loss DX: 0.1265 | Loss DY: 0.2012
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [575/597] | Loss G: 3.3664 | Loss DX: 0.3464 | Loss DY: 0.3037
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [576/597] | Loss G: 4.0141 | Loss DX: 0.2000 | Loss DY: 0.2458
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [577/597] | Loss G: 4.4091 | Loss DX: 0.2086 | Loss DY: 0.2519
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [578/597] | Loss G: 3.3930 | Loss DX: 0.1682 | Loss DY: 0.2328
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [579/597] | Loss G: 2.8531 | Loss DX: 0.1873 | Loss DY: 0.2022
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [580/597] | Loss G: 3.3861 | Loss DX: 0.3395 | Loss DY: 0.2129
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [581/597] | Loss G: 4.0764 | Loss DX: 0.2285 | Loss DY: 0.2280
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [582/597] | Loss G: 3.3777 | Loss DX: 0.2753 | Loss DY: 0.2330
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [583/597] | Loss G: 3.1161 | Loss DX: 0.2698 | Loss DY: 0.2559
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [584/597] | Loss G: 4.7611 | Loss DX: 0.2465 | Loss DY: 0.2902
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [585/597] | Loss G: 4.0159 | Loss DX: 0.2597 | Loss DY: 0.2273
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [586/597] | Loss G: 3.3389 | Loss DX: 0.2092 | Loss DY: 0.2283
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [587/597] | Loss G: 3.2943 | Loss DX: 0.2622 | Loss DY: 0.2810
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [588/597] | Loss G: 3.4829 | Loss DX: 0.2017 | Loss DY: 0.2479
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [589/597] | Loss G: 3.6372 | Loss DX: 0.1828 | Loss DY: 0.2418
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [590/597] | Loss G: 4.2546 | Loss DX: 0.1912 | Loss DY: 0.2350
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [591/597] | Loss G: 2.9941 | Loss DX: 0.1576 | Loss DY: 0.2283
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [592/597] | Loss G: 2.6510 | Loss DX: 0.2607 | Loss DY: 0.2549
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [593/597] | Loss G: 3.4761 | Loss DX: 0.1896 | Loss DY: 0.2065
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [594/597] | Loss G: 2.9450 | Loss DX: 0.1610 | Loss DY: 0.2082
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [595/597] | Loss G: 3.8878 | Loss DX: 0.1970 | Loss DY: 0.2522
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [596/597] | Loss G: 3.8238 | Loss DX: 0.2273 | Loss DY: 0.2217
# Step 0 | alpha 0.0000 | Epoch [1/1] | Batch [597/597] | Loss G: 5.4688 | Loss DX: 0.3408 | Loss DY: 0.3103

# %%
trainer.train(dataloaders=(lsun_loader, monet_loader), n_epochs=1, step=1)
# Out:
# Step 1 | alpha 0.0000 | Epoch [1/1] | Batch [1/597] | Loss G: 3.6304 | Loss DX: 0.2527 | Loss DY: 0.2494
# Step 1 | alpha 0.0017 | Epoch [1/1] | Batch [2/597] | Loss G: 3.8099 | Loss DX: 0.2218 | Loss DY: 0.2307
# Step 1 | alpha 0.0034 | Epoch [1/1] | Batch [3/597] | Loss G: 3.5699 | Loss DX: 0.3007 | Loss DY: 0.2502
# Step 1 | alpha 0.0050 | Epoch [1/1] | Batch [4/597] | Loss G: 3.1566 | Loss DX: 0.2767 | Loss DY: 0.2493
# Step 1 | alpha 0.0067 | Epoch [1/1] | Batch [5/597] | Loss G: 3.9678 | Loss DX: 0.2240 | Loss DY: 0.2411
# Step 1 | alpha 0.0084 | Epoch [1/1] | Batch [6/597] | Loss G: 3.5493 | Loss DX: 0.2377 | Loss DY: 0.2409
# Step 1 | alpha 0.0101 | Epoch [1/1] | Batch [7/597] | Loss G: 6.3613 | Loss DX: 0.2082 | Loss DY: 0.2100
# Step 1 | alpha 0.0117 | Epoch [1/1] | Batch [8/597] | Loss G: 3.3430 | Loss DX: 0.1733 | Loss DY: 0.1976
# Step 1 | alpha 0.0134 | Epoch [1/1] | Batch [9/597] | Loss G: 4.2086 | Loss DX: 0.1863 | Loss DY: 0.1956
# Step 1 | alpha 0.0151 | Epoch [1/1] | Batch [10/597] | Loss G: 3.5967 | Loss DX: 0.2387 | Loss DY: 0.2377
# Step 1 | alpha 0.0168 | Epoch [1/1] | Batch [11/597] | Loss G: 3.9592 | Loss DX: 0.3171 | Loss DY: 0.3142
# Step 1 | alpha 0.0184 | Epoch [1/1] | Batch [12/597] | Loss G: 3.2221 | Loss DX: 0.2224 | Loss DY: 0.2447
# Step 1 | alpha 0.0201 | Epoch [1/1] | Batch [13/597] | Loss G: 3.3411 | Loss DX: 0.2166 | Loss DY: 0.2493
# Step 1 | alpha 0.0218 | Epoch [1/1] | Batch [14/597] | Loss G: 3.6317 | Loss DX: 0.2084 | Loss DY: 0.2332
# Step 1 | alpha 0.0235 | Epoch [1/1] | Batch [15/597] | Loss G: 3.7623 | Loss DX: 0.1999 | Loss DY: 0.2193
# Step 1 | alpha 0.0251 | Epoch [1/1] | Batch [16/597] | Loss G: 3.1209 | Loss DX: 0.1777 | Loss DY: 0.2061
# Step 1 | alpha 0.0268 | Epoch [1/1] | Batch [17/597] | Loss G: 2.7831 | Loss DX: 0.2966 | Loss DY: 0.2712
# Step 1 | alpha 0.0285 | Epoch [1/1] | Batch [18/597] | Loss G: 3.6027 | Loss DX: 0.2551 | Loss DY: 0.2597
# Step 1 | alpha 0.0302 | Epoch [1/1] | Batch [19/597] | Loss G: 3.1964 | Loss DX: 0.2380 | Loss DY: 0.2327
# Step 1 | alpha 0.0318 | Epoch [1/1] | Batch [20/597] | Loss G: 4.0365 | Loss DX: 0.2456 | Loss DY: 0.2441
# Step 1 | alpha 0.0335 | Epoch [1/1] | Batch [21/597] | Loss G: 3.7121 | Loss DX: 0.1889 | Loss DY: 0.2190
# Step 1 | alpha 0.0352 | Epoch [1/1] | Batch [22/597] | Loss G: 4.0335 | Loss DX: 0.1897 | Loss DY: 0.1992
# Step 1 | alpha 0.0369 | Epoch [1/1] | Batch [23/597] | Loss G: 3.4876 | Loss DX: 0.2264 | Loss DY: 0.2286
# Step 1 | alpha 0.0385 | Epoch [1/1] | Batch [24/597] | Loss G: 2.8517 | Loss DX: 0.2128 | Loss DY: 0.2364
# Step 1 | alpha 0.0402 | Epoch [1/1] | Batch [25/597] | Loss G: 3.2391 | Loss DX: 0.1766 | Loss DY: 0.2140
# Step 1 | alpha 0.0419 | Epoch [1/1] | Batch [26/597] | Loss G: 3.5801 | Loss DX: 0.1976 | Loss DY: 0.2160
# Step 1 | alpha 0.0436 | Epoch [1/1] | Batch [27/597] | Loss G: 3.4008 | Loss DX: 0.1591 | Loss DY: 0.2237
# Step 1 | alpha 0.0452 | Epoch [1/1] | Batch [28/597] | Loss G: 4.1104 | Loss DX: 0.3137 | Loss DY: 0.2475
# Step 1 | alpha 0.0469 | Epoch [1/1] | Batch [29/597] | Loss G: 5.6932 | Loss DX: 0.2020 | Loss DY: 0.2360
# Step 1 | alpha 0.0486 | Epoch [1/1] | Batch [30/597] | Loss G: 5.9458 | Loss DX: 0.1565 | Loss DY: 0.1854
# Step 1 | alpha 0.0503 | Epoch [1/1] | Batch [31/597] | Loss G: 2.8890 | Loss DX: 0.2462 | Loss DY: 0.2858
# Step 1 | alpha 0.0519 | Epoch [1/1] | Batch [32/597] | Loss G: 2.9154 | Loss DX: 0.2647 | Loss DY: 0.2219
# Step 1 | alpha 0.0536 | Epoch [1/1] | Batch [33/597] | Loss G: 4.2102 | Loss DX: 0.2401 | Loss DY: 0.2105
# Step 1 | alpha 0.0553 | Epoch [1/1] | Batch [34/597] | Loss G: 3.7828 | Loss DX: 0.2840 | Loss DY: 0.2572
# Step 1 | alpha 0.0570 | Epoch [1/1] | Batch [35/597] | Loss G: 3.7019 | Loss DX: 0.2273 | Loss DY: 0.2405
# Step 1 | alpha 0.0586 | Epoch [1/1] | Batch [36/597] | Loss G: 2.9054 | Loss DX: 0.2305 | Loss DY: 0.2317
# Step 1 | alpha 0.0603 | Epoch [1/1] | Batch [37/597] | Loss G: 3.3410 | Loss DX: 0.2525 | Loss DY: 0.2649
# Step 1 | alpha 0.0620 | Epoch [1/1] | Batch [38/597] | Loss G: 3.6832 | Loss DX: 0.2262 | Loss DY: 0.2383
# Step 1 | alpha 0.0637 | Epoch [1/1] | Batch [39/597] | Loss G: 4.3387 | Loss DX: 0.1833 | Loss DY: 0.1982
# Step 1 | alpha 0.0653 | Epoch [1/1] | Batch [40/597] | Loss G: 4.7826 | Loss DX: 0.2175 | Loss DY: 0.2324
# Step 1 | alpha 0.0670 | Epoch [1/1] | Batch [41/597] | Loss G: 4.6684 | Loss DX: 0.1770 | Loss DY: 0.1847
# Step 1 | alpha 0.0687 | Epoch [1/1] | Batch [42/597] | Loss G: 3.6071 | Loss DX: 0.2529 | Loss DY: 0.2526
# Step 1 | alpha 0.0704 | Epoch [1/1] | Batch [43/597] | Loss G: 2.9608 | Loss DX: 0.3035 | Loss DY: 0.2825
# Step 1 | alpha 0.0720 | Epoch [1/1] | Batch [44/597] | Loss G: 3.3420 | Loss DX: 0.1765 | Loss DY: 0.2193
# Step 1 | alpha 0.0737 | Epoch [1/1] | Batch [45/597] | Loss G: 3.4647 | Loss DX: 0.2601 | Loss DY: 0.2424
# Step 1 | alpha 0.0754 | Epoch [1/1] | Batch [46/597] | Loss G: 2.9074 | Loss DX: 0.2222 | Loss DY: 0.2225
# Step 1 | alpha 0.0771 | Epoch [1/1] | Batch [47/597] | Loss G: 3.2625 | Loss DX: 0.1950 | Loss DY: 0.1906
# Step 1 | alpha 0.0787 | Epoch [1/1] | Batch [48/597] | Loss G: 3.8770 | Loss DX: 0.2324 | Loss DY: 0.2494
# Step 1 | alpha 0.0804 | Epoch [1/1] | Batch [49/597] | Loss G: 4.5886 | Loss DX: 0.2705 | Loss DY: 0.2512
# Step 1 | alpha 0.0821 | Epoch [1/1] | Batch [50/597] | Loss G: 3.1055 | Loss DX: 0.3030 | Loss DY: 0.3181
# Step 1 | alpha 0.0838 | Epoch [1/1] | Batch [51/597] | Loss G: 3.2958 | Loss DX: 0.2037 | Loss DY: 0.2502
# Step 1 | alpha 0.0854 | Epoch [1/1] | Batch [52/597] | Loss G: 2.6141 | Loss DX: 0.2038 | Loss DY: 0.2328
# Step 1 | alpha 0.0871 | Epoch [1/1] | Batch [53/597] | Loss G: 4.1308 | Loss DX: 0.2016 | Loss DY: 0.2263
# Step 1 | alpha 0.0888 | Epoch [1/1] | Batch [54/597] | Loss G: 3.5528 | Loss DX: 0.2192 | Loss DY: 0.2262
# Step 1 | alpha 0.0905 | Epoch [1/1] | Batch [55/597] | Loss G: 4.5531 | Loss DX: 0.2144 | Loss DY: 0.2301
# Step 1 | alpha 0.0921 | Epoch [1/1] | Batch [56/597] | Loss G: 2.9576 | Loss DX: 0.2408 | Loss DY: 0.2483
# Step 1 | alpha 0.0938 | Epoch [1/1] | Batch [57/597] | Loss G: 4.0283 | Loss DX: 0.2004 | Loss DY: 0.2336
# Step 1 | alpha 0.0955 | Epoch [1/1] | Batch [58/597] | Loss G: 2.8339 | Loss DX: 0.2499 | Loss DY: 0.2319
# Step 1 | alpha 0.0972 | Epoch [1/1] | Batch [59/597] | Loss G: 3.9843 | Loss DX: 0.2129 | Loss DY: 0.2306
# Step 1 | alpha 0.0988 | Epoch [1/1] | Batch [60/597] | Loss G: 2.9868 | Loss DX: 0.2013 | Loss DY: 0.2070
# Step 1 | alpha 0.1005 | Epoch [1/1] | Batch [61/597] | Loss G: 3.5875 | Loss DX: 0.2018 | Loss DY: 0.2117
# Step 1 | alpha 0.1022 | Epoch [1/1] | Batch [62/597] | Loss G: 3.4090 | Loss DX: 0.2365 | Loss DY: 0.2455
# Step 1 | alpha 0.1039 | Epoch [1/1] | Batch [63/597] | Loss G: 2.7845 | Loss DX: 0.2167 | Loss DY: 0.2448
# Step 1 | alpha 0.1055 | Epoch [1/1] | Batch [64/597] | Loss G: 5.0844 | Loss DX: 0.1753 | Loss DY: 0.2257
# Step 1 | alpha 0.1072 | Epoch [1/1] | Batch [65/597] | Loss G: 2.9759 | Loss DX: 0.3593 | Loss DY: 0.3104
# Step 1 | alpha 0.1089 | Epoch [1/1] | Batch [66/597] | Loss G: 3.2591 | Loss DX: 0.2057 | Loss DY: 0.2427
# Step 1 | alpha 0.1106 | Epoch [1/1] | Batch [67/597] | Loss G: 3.9048 | Loss DX: 0.2432 | Loss DY: 0.2273
# Step 1 | alpha 0.1122 | Epoch [1/1] | Batch [68/597] | Loss G: 3.7306 | Loss DX: 0.1980 | Loss DY: 0.2327
# Step 1 | alpha 0.1139 | Epoch [1/1] | Batch [69/597] | Loss G: 3.4602 | Loss DX: 0.2454 | Loss DY: 0.2734
# Step 1 | alpha 0.1156 | Epoch [1/1] | Batch [70/597] | Loss G: 4.1906 | Loss DX: 0.2270 | Loss DY: 0.2546
# Step 1 | alpha 0.1173 | Epoch [1/1] | Batch [71/597] | Loss G: 4.3191 | Loss DX: 0.2337 | Loss DY: 0.2253
# Step 1 | alpha 0.1189 | Epoch [1/1] | Batch [72/597] | Loss G: 4.1592 | Loss DX: 0.1726 | Loss DY: 0.2024
# Step 1 | alpha 0.1206 | Epoch [1/1] | Batch [73/597] | Loss G: 3.7585 | Loss DX: 0.2272 | Loss DY: 0.2287
# Step 1 | alpha 0.1223 | Epoch [1/1] | Batch [74/597] | Loss G: 3.2479 | Loss DX: 0.1528 | Loss DY: 0.2011
# Step 1 | alpha 0.1240 | Epoch [1/1] | Batch [75/597] | Loss G: 3.1689 | Loss DX: 0.2328 | Loss DY: 0.2140
# Step 1 | alpha 0.1256 | Epoch [1/1] | Batch [76/597] | Loss G: 3.7898 | Loss DX: 0.2370 | Loss DY: 0.2333
# Step 1 | alpha 0.1273 | Epoch [1/1] | Batch [77/597] | Loss G: 3.3881 | Loss DX: 0.2587 | Loss DY: 0.2512
# Step 1 | alpha 0.1290 | Epoch [1/1] | Batch [78/597] | Loss G: 2.7970 | Loss DX: 0.2050 | Loss DY: 0.2589
# Step 1 | alpha 0.1307 | Epoch [1/1] | Batch [79/597] | Loss G: 4.2384 | Loss DX: 0.1952 | Loss DY: 0.2635
# Step 1 | alpha 0.1323 | Epoch [1/1] | Batch [80/597] | Loss G: 3.2488 | Loss DX: 0.2094 | Loss DY: 0.2185
# Step 1 | alpha 0.1340 | Epoch [1/1] | Batch [81/597] | Loss G: 3.2046 | Loss DX: 0.1933 | Loss DY: 0.2088
# Step 1 | alpha 0.1357 | Epoch [1/1] | Batch [82/597] | Loss G: 2.8669 | Loss DX: 0.2442 | Loss DY: 0.2211
# Step 1 | alpha 0.1374 | Epoch [1/1] | Batch [83/597] | Loss G: 3.2427 | Loss DX: 0.2231 | Loss DY: 0.2058
# Step 1 | alpha 0.1390 | Epoch [1/1] | Batch [84/597] | Loss G: 3.7120 | Loss DX: 0.2112 | Loss DY: 0.2270
# Step 1 | alpha 0.1407 | Epoch [1/1] | Batch [85/597] | Loss G: 2.9758 | Loss DX: 0.1890 | Loss DY: 0.2134
# Step 1 | alpha 0.1424 | Epoch [1/1] | Batch [86/597] | Loss G: 3.6663 | Loss DX: 0.2211 | Loss DY: 0.2429
# Step 1 | alpha 0.1441 | Epoch [1/1] | Batch [87/597] | Loss G: 3.6197 | Loss DX: 0.1325 | Loss DY: 0.2344
# Step 1 | alpha 0.1457 | Epoch [1/1] | Batch [88/597] | Loss G: 3.1392 | Loss DX: 0.2433 | Loss DY: 0.2546
# Step 1 | alpha 0.1474 | Epoch [1/1] | Batch [89/597] | Loss G: 3.0004 | Loss DX: 0.2689 | Loss DY: 0.2521
# Step 1 | alpha 0.1491 | Epoch [1/1] | Batch [90/597] | Loss G: 2.8323 | Loss DX: 0.2273 | Loss DY: 0.2056
# Step 1 | alpha 0.1508 | Epoch [1/1] | Batch [91/597] | Loss G: 3.5894 | Loss DX: 0.2075 | Loss DY: 0.2169
# Step 1 | alpha 0.1524 | Epoch [1/1] | Batch [92/597] | Loss G: 3.6549 | Loss DX: 0.1907 | Loss DY: 0.2124
# Step 1 | alpha 0.1541 | Epoch [1/1] | Batch [93/597] | Loss G: 3.2071 | Loss DX: 0.2173 | Loss DY: 0.2122
# Step 1 | alpha 0.1558 | Epoch [1/1] | Batch [94/597] | Loss G: 2.9933 | Loss DX: 0.2304 | Loss DY: 0.2489
# Step 1 | alpha 0.1575 | Epoch [1/1] | Batch [95/597] | Loss G: 3.2370 | Loss DX: 0.2938 | Loss DY: 0.2792
# Step 1 | alpha 0.1591 | Epoch [1/1] | Batch [96/597] | Loss G: 3.5640 | Loss DX: 0.2179 | Loss DY: 0.2096
# Step 1 | alpha 0.1608 | Epoch [1/1] | Batch [97/597] | Loss G: 3.6545 | Loss DX: 0.2191 | Loss DY: 0.1879
# Step 1 | alpha 0.1625 | Epoch [1/1] | Batch [98/597] | Loss G: 3.2586 | Loss DX: 0.2527 | Loss DY: 0.2752
# Step 1 | alpha 0.1642 | Epoch [1/1] | Batch [99/597] | Loss G: 3.3844 | Loss DX: 0.1725 | Loss DY: 0.2256
# Step 1 | alpha 0.1658 | Epoch [1/1] | Batch [100/597] | Loss G: 2.9492 | Loss DX: 0.2382 | Loss DY: 0.2790
# Step 1 | alpha 0.1675 | Epoch [1/1] | Batch [101/597] | Loss G: 3.3568 | Loss DX: 0.2325 | Loss DY: 0.2338
# Step 1 | alpha 0.1692 | Epoch [1/1] | Batch [102/597] | Loss G: 4.1859 | Loss DX: 0.1889 | Loss DY: 0.2130
# Step 1 | alpha 0.1709 | Epoch [1/1] | Batch [103/597] | Loss G: 3.7145 | Loss DX: 0.2240 | Loss DY: 0.2219
# Step 1 | alpha 0.1725 | Epoch [1/1] | Batch [104/597] | Loss G: 3.7474 | Loss DX: 0.2404 | Loss DY: 0.2119
# Step 1 | alpha 0.1742 | Epoch [1/1] | Batch [105/597] | Loss G: 3.3588 | Loss DX: 0.2468 | Loss DY: 0.2333
# Step 1 | alpha 0.1759 | Epoch [1/1] | Batch [106/597] | Loss G: 3.7602 | Loss DX: 0.2180 | Loss DY: 0.2266
# Step 1 | alpha 0.1776 | Epoch [1/1] | Batch [107/597] | Loss G: 4.2983 | Loss DX: 0.2226 | Loss DY: 0.2168
# Step 1 | alpha 0.1792 | Epoch [1/1] | Batch [108/597] | Loss G: 4.3312 | Loss DX: 0.2310 | Loss DY: 0.2338
# Step 1 | alpha 0.1809 | Epoch [1/1] | Batch [109/597] | Loss G: 4.9743 | Loss DX: 0.2049 | Loss DY: 0.2091
# Step 1 | alpha 0.1826 | Epoch [1/1] | Batch [110/597] | Loss G: 3.9352 | Loss DX: 0.2093 | Loss DY: 0.2115
# Step 1 | alpha 0.1843 | Epoch [1/1] | Batch [111/597] | Loss G: 3.5116 | Loss DX: 0.1850 | Loss DY: 0.2184
# Step 1 | alpha 0.1859 | Epoch [1/1] | Batch [112/597] | Loss G: 3.1527 | Loss DX: 0.2114 | Loss DY: 0.2381
# Step 1 | alpha 0.1876 | Epoch [1/1] | Batch [113/597] | Loss G: 4.3491 | Loss DX: 0.2720 | Loss DY: 0.2665
# Step 1 | alpha 0.1893 | Epoch [1/1] | Batch [114/597] | Loss G: 3.9864 | Loss DX: 0.2387 | Loss DY: 0.2660
# Step 1 | alpha 0.1910 | Epoch [1/1] | Batch [115/597] | Loss G: 3.6659 | Loss DX: 0.2604 | Loss DY: 0.2574
# Step 1 | alpha 0.1926 | Epoch [1/1] | Batch [116/597] | Loss G: 3.7722 | Loss DX: 0.2203 | Loss DY: 0.2533
# Step 1 | alpha 0.1943 | Epoch [1/1] | Batch [117/597] | Loss G: 2.7764 | Loss DX: 0.2084 | Loss DY: 0.2308
# Step 1 | alpha 0.1960 | Epoch [1/1] | Batch [118/597] | Loss G: 4.9676 | Loss DX: 0.2023 | Loss DY: 0.1972
# Step 1 | alpha 0.1977 | Epoch [1/1] | Batch [119/597] | Loss G: 3.4655 | Loss DX: 0.3097 | Loss DY: 0.2833
# Step 1 | alpha 0.1993 | Epoch [1/1] | Batch [120/597] | Loss G: 3.7892 | Loss DX: 0.1605 | Loss DY: 0.2122
# Step 1 | alpha 0.2010 | Epoch [1/1] | Batch [121/597] | Loss G: 4.3872 | Loss DX: 0.2745 | Loss DY: 0.2489
# Step 1 | alpha 0.2027 | Epoch [1/1] | Batch [122/597] | Loss G: 2.9572 | Loss DX: 0.2782 | Loss DY: 0.2641
# Step 1 | alpha 0.2044 | Epoch [1/1] | Batch [123/597] | Loss G: 3.1344 | Loss DX: 0.2201 | Loss DY: 0.2328
# Step 1 | alpha 0.2060 | Epoch [1/1] | Batch [124/597] | Loss G: 3.4010 | Loss DX: 0.2284 | Loss DY: 0.2302
# Step 1 | alpha 0.2077 | Epoch [1/1] | Batch [125/597] | Loss G: 3.3533 | Loss DX: 0.2080 | Loss DY: 0.2202
# Step 1 | alpha 0.2094 | Epoch [1/1] | Batch [126/597] | Loss G: 2.9925 | Loss DX: 0.2669 | Loss DY: 0.2640
# Step 1 | alpha 0.2111 | Epoch [1/1] | Batch [127/597] | Loss G: 4.1695 | Loss DX: 0.1993 | Loss DY: 0.2398
# Step 1 | alpha 0.2127 | Epoch [1/1] | Batch [128/597] | Loss G: 4.4883 | Loss DX: 0.2970 | Loss DY: 0.2671
# Step 1 | alpha 0.2144 | Epoch [1/1] | Batch [129/597] | Loss G: 2.8914 | Loss DX: 0.1972 | Loss DY: 0.2095
# Step 1 | alpha 0.2161 | Epoch [1/1] | Batch [130/597] | Loss G: 2.6693 | Loss DX: 0.2516 | Loss DY: 0.2516
# Step 1 | alpha 0.2178 | Epoch [1/1] | Batch [131/597] | Loss G: 3.1325 | Loss DX: 0.2398 | Loss DY: 0.2276
# Step 1 | alpha 0.2194 | Epoch [1/1] | Batch [132/597] | Loss G: 3.3320 | Loss DX: 0.2484 | Loss DY: 0.2533
# Step 1 | alpha 0.2211 | Epoch [1/1] | Batch [133/597] | Loss G: 3.6177 | Loss DX: 0.2193 | Loss DY: 0.2339
# Step 1 | alpha 0.2228 | Epoch [1/1] | Batch [134/597] | Loss G: 3.0127 | Loss DX: 0.1991 | Loss DY: 0.2270
# Step 1 | alpha 0.2245 | Epoch [1/1] | Batch [135/597] | Loss G: 3.9399 | Loss DX: 0.2915 | Loss DY: 0.2468
# Step 1 | alpha 0.2261 | Epoch [1/1] | Batch [136/597] | Loss G: 3.8500 | Loss DX: 0.2457 | Loss DY: 0.2765
# Step 1 | alpha 0.2278 | Epoch [1/1] | Batch [137/597] | Loss G: 2.8441 | Loss DX: 0.2284 | Loss DY: 0.2179
# Step 1 | alpha 0.2295 | Epoch [1/1] | Batch [138/597] | Loss G: 3.9491 | Loss DX: 0.2037 | Loss DY: 0.2053
# Step 1 | alpha 0.2312 | Epoch [1/1] | Batch [139/597] | Loss G: 4.5668 | Loss DX: 0.2926 | Loss DY: 0.2656
# Step 1 | alpha 0.2328 | Epoch [1/1] | Batch [140/597] | Loss G: 3.3374 | Loss DX: 0.2259 | Loss DY: 0.2205
# Step 1 | alpha 0.2345 | Epoch [1/1] | Batch [141/597] | Loss G: 4.7582 | Loss DX: 0.2101 | Loss DY: 0.2190
# Step 1 | alpha 0.2362 | Epoch [1/1] | Batch [142/597] | Loss G: 3.9739 | Loss DX: 0.2127 | Loss DY: 0.2334
# Step 1 | alpha 0.2379 | Epoch [1/1] | Batch [143/597] | Loss G: 3.2389 | Loss DX: 0.2384 | Loss DY: 0.2246
# Step 1 | alpha 0.2395 | Epoch [1/1] | Batch [144/597] | Loss G: 3.4547 | Loss DX: 0.2177 | Loss DY: 0.2251
# Step 1 | alpha 0.2412 | Epoch [1/1] | Batch [145/597] | Loss G: 3.3760 | Loss DX: 0.2167 | Loss DY: 0.2069
# Step 1 | alpha 0.2429 | Epoch [1/1] | Batch [146/597] | Loss G: 3.1626 | Loss DX: 0.2034 | Loss DY: 0.2247
# Step 1 | alpha 0.2446 | Epoch [1/1] | Batch [147/597] | Loss G: 4.9201 | Loss DX: 0.2035 | Loss DY: 0.2409
# Step 1 | alpha 0.2462 | Epoch [1/1] | Batch [148/597] | Loss G: 2.9323 | Loss DX: 0.2192 | Loss DY: 0.2266
# Step 1 | alpha 0.2479 | Epoch [1/1] | Batch [149/597] | Loss G: 2.9425 | Loss DX: 0.1821 | Loss DY: 0.1815
# Step 1 | alpha 0.2496 | Epoch [1/1] | Batch [150/597] | Loss G: 3.1133 | Loss DX: 0.2622 | Loss DY: 0.2351
# Step 1 | alpha 0.2513 | Epoch [1/1] | Batch [151/597] | Loss G: 3.4908 | Loss DX: 0.2056 | Loss DY: 0.1881
# Step 1 | alpha 0.2529 | Epoch [1/1] | Batch [152/597] | Loss G: 3.3670 | Loss DX: 0.1963 | Loss DY: 0.1720
# Step 1 | alpha 0.2546 | Epoch [1/1] | Batch [153/597] | Loss G: 2.9276 | Loss DX: 0.2394 | Loss DY: 0.2402
# Step 1 | alpha 0.2563 | Epoch [1/1] | Batch [154/597] | Loss G: 4.2706 | Loss DX: 0.1991 | Loss DY: 0.2048
# Step 1 | alpha 0.2580 | Epoch [1/1] | Batch [155/597] | Loss G: 3.1902 | Loss DX: 0.2412 | Loss DY: 0.2552
# Step 1 | alpha 0.2596 | Epoch [1/1] | Batch [156/597] | Loss G: 4.1255 | Loss DX: 0.2116 | Loss DY: 0.2672
# Step 1 | alpha 0.2613 | Epoch [1/1] | Batch [157/597] | Loss G: 3.6152 | Loss DX: 0.2371 | Loss DY: 0.2603
# Step 1 | alpha 0.2630 | Epoch [1/1] | Batch [158/597] | Loss G: 4.6380 | Loss DX: 0.1847 | Loss DY: 0.1982
# Step 1 | alpha 0.2647 | Epoch [1/1] | Batch [159/597] | Loss G: 5.0273 | Loss DX: 0.1871 | Loss DY: 0.2091
# Step 1 | alpha 0.2663 | Epoch [1/1] | Batch [160/597] | Loss G: 3.0235 | Loss DX: 0.2525 | Loss DY: 0.2337
# Step 1 | alpha 0.2680 | Epoch [1/1] | Batch [161/597] | Loss G: 3.8624 | Loss DX: 0.1951 | Loss DY: 0.2214
# Step 1 | alpha 0.2697 | Epoch [1/1] | Batch [162/597] | Loss G: 3.6585 | Loss DX: 0.2259 | Loss DY: 0.2346
# Step 1 | alpha 0.2714 | Epoch [1/1] | Batch [163/597] | Loss G: 3.4698 | Loss DX: 0.2202 | Loss DY: 0.2519
# Step 1 | alpha 0.2730 | Epoch [1/1] | Batch [164/597] | Loss G: 2.6937 | Loss DX: 0.2518 | Loss DY: 0.2628
# Step 1 | alpha 0.2747 | Epoch [1/1] | Batch [165/597] | Loss G: 3.7699 | Loss DX: 0.1996 | Loss DY: 0.2376
# Step 1 | alpha 0.2764 | Epoch [1/1] | Batch [166/597] | Loss G: 3.3803 | Loss DX: 0.2430 | Loss DY: 0.2363
# Step 1 | alpha 0.2781 | Epoch [1/1] | Batch [167/597] | Loss G: 3.5124 | Loss DX: 0.2112 | Loss DY: 0.2399
# Step 1 | alpha 0.2797 | Epoch [1/1] | Batch [168/597] | Loss G: 3.3087 | Loss DX: 0.1982 | Loss DY: 0.2252
# Step 1 | alpha 0.2814 | Epoch [1/1] | Batch [169/597] | Loss G: 3.5956 | Loss DX: 0.2446 | Loss DY: 0.2518
# Step 1 | alpha 0.2831 | Epoch [1/1] | Batch [170/597] | Loss G: 4.1174 | Loss DX: 0.2343 | Loss DY: 0.2360
# Step 1 | alpha 0.2848 | Epoch [1/1] | Batch [171/597] | Loss G: 3.2730 | Loss DX: 0.2028 | Loss DY: 0.2236
# Step 1 | alpha 0.2864 | Epoch [1/1] | Batch [172/597] | Loss G: 3.2328 | Loss DX: 0.2201 | Loss DY: 0.2158
# Step 1 | alpha 0.2881 | Epoch [1/1] | Batch [173/597] | Loss G: 4.1261 | Loss DX: 0.1168 | Loss DY: 0.1579
# Step 1 | alpha 0.2898 | Epoch [1/1] | Batch [174/597] | Loss G: 3.2838 | Loss DX: 0.1876 | Loss DY: 0.2376
# Step 1 | alpha 0.2915 | Epoch [1/1] | Batch [175/597] | Loss G: 3.4864 | Loss DX: 0.1948 | Loss DY: 0.2078
# Step 1 | alpha 0.2931 | Epoch [1/1] | Batch [176/597] | Loss G: 3.0168 | Loss DX: 0.3055 | Loss DY: 0.2625
# Step 1 | alpha 0.2948 | Epoch [1/1] | Batch [177/597] | Loss G: 3.0656 | Loss DX: 0.2995 | Loss DY: 0.2844
# Step 1 | alpha 0.2965 | Epoch [1/1] | Batch [178/597] | Loss G: 3.5182 | Loss DX: 0.2252 | Loss DY: 0.2317
# Step 1 | alpha 0.2982 | Epoch [1/1] | Batch [179/597] | Loss G: 3.6588 | Loss DX: 0.2625 | Loss DY: 0.2416
# Step 1 | alpha 0.2998 | Epoch [1/1] | Batch [180/597] | Loss G: 3.2333 | Loss DX: 0.2475 | Loss DY: 0.2439
# Step 1 | alpha 0.3015 | Epoch [1/1] | Batch [181/597] | Loss G: 3.9191 | Loss DX: 0.2551 | Loss DY: 0.2690
# Step 1 | alpha 0.3032 | Epoch [1/1] | Batch [182/597] | Loss G: 4.1165 | Loss DX: 0.2130 | Loss DY: 0.2155
# Step 1 | alpha 0.3049 | Epoch [1/1] | Batch [183/597] | Loss G: 4.1880 | Loss DX: 0.2271 | Loss DY: 0.2229
# Step 1 | alpha 0.3065 | Epoch [1/1] | Batch [184/597] | Loss G: 3.3047 | Loss DX: 0.2451 | Loss DY: 0.2250
# Step 1 | alpha 0.3082 | Epoch [1/1] | Batch [185/597] | Loss G: 3.6905 | Loss DX: 0.1942 | Loss DY: 0.2126
# Step 1 | alpha 0.3099 | Epoch [1/1] | Batch [186/597] | Loss G: 3.2571 | Loss DX: 0.1901 | Loss DY: 0.1810
# Step 1 | alpha 0.3116 | Epoch [1/1] | Batch [187/597] | Loss G: 2.9162 | Loss DX: 0.2460 | Loss DY: 0.2664
# Step 1 | alpha 0.3132 | Epoch [1/1] | Batch [188/597] | Loss G: 3.8904 | Loss DX: 0.2412 | Loss DY: 0.2147
# Step 1 | alpha 0.3149 | Epoch [1/1] | Batch [189/597] | Loss G: 3.3066 | Loss DX: 0.1626 | Loss DY: 0.1865
# Step 1 | alpha 0.3166 | Epoch [1/1] | Batch [190/597] | Loss G: 2.8283 | Loss DX: 0.1948 | Loss DY: 0.2251
# Step 1 | alpha 0.3183 | Epoch [1/1] | Batch [191/597] | Loss G: 3.4192 | Loss DX: 0.2046 | Loss DY: 0.2118
# Step 1 | alpha 0.3199 | Epoch [1/1] | Batch [192/597] | Loss G: 3.4664 | Loss DX: 0.2911 | Loss DY: 0.2762
# Step 1 | alpha 0.3216 | Epoch [1/1] | Batch [193/597] | Loss G: 3.8085 | Loss DX: 0.1796 | Loss DY: 0.2161
# Step 1 | alpha 0.3233 | Epoch [1/1] | Batch [194/597] | Loss G: 2.8662 | Loss DX: 0.1726 | Loss DY: 0.1863
# Step 1 | alpha 0.3250 | Epoch [1/1] | Batch [195/597] | Loss G: 3.7206 | Loss DX: 0.2456 | Loss DY: 0.2562
# Step 1 | alpha 0.3266 | Epoch [1/1] | Batch [196/597] | Loss G: 3.5130 | Loss DX: 0.2089 | Loss DY: 0.2024
# Step 1 | alpha 0.3283 | Epoch [1/1] | Batch [197/597] | Loss G: 4.4003 | Loss DX: 0.2198 | Loss DY: 0.2627
# Step 1 | alpha 0.3300 | Epoch [1/1] | Batch [198/597] | Loss G: 3.9976 | Loss DX: 0.2101 | Loss DY: 0.2073
# Step 1 | alpha 0.3317 | Epoch [1/1] | Batch [199/597] | Loss G: 4.2734 | Loss DX: 0.1871 | Loss DY: 0.1932
# Step 1 | alpha 0.3333 | Epoch [1/1] | Batch [200/597] | Loss G: 3.0555 | Loss DX: 0.2210 | Loss DY: 0.2225
# Step 1 | alpha 0.3350 | Epoch [1/1] | Batch [201/597] | Loss G: 3.2173 | Loss DX: 0.2538 | Loss DY: 0.2162
# Step 1 | alpha 0.3367 | Epoch [1/1] | Batch [202/597] | Loss G: 3.1778 | Loss DX: 0.2675 | Loss DY: 0.2776
# Step 1 | alpha 0.3384 | Epoch [1/1] | Batch [203/597] | Loss G: 2.7936 | Loss DX: 0.2478 | Loss DY: 0.2579
# Step 1 | alpha 0.3400 | Epoch [1/1] | Batch [204/597] | Loss G: 3.2858 | Loss DX: 0.2180 | Loss DY: 0.2490
# Step 1 | alpha 0.3417 | Epoch [1/1] | Batch [205/597] | Loss G: 4.6142 | Loss DX: 0.1828 | Loss DY: 0.2109
# Step 1 | alpha 0.3434 | Epoch [1/1] | Batch [206/597] | Loss G: 3.9690 | Loss DX: 0.1581 | Loss DY: 0.1953
# Step 1 | alpha 0.3451 | Epoch [1/1] | Batch [207/597] | Loss G: 3.5503 | Loss DX: 0.2155 | Loss DY: 0.2267
# Step 1 | alpha 0.3467 | Epoch [1/1] | Batch [208/597] | Loss G: 3.1735 | Loss DX: 0.2049 | Loss DY: 0.2462
# Step 1 | alpha 0.3484 | Epoch [1/1] | Batch [209/597] | Loss G: 3.5033 | Loss DX: 0.1748 | Loss DY: 0.2248
# Step 1 | alpha 0.3501 | Epoch [1/1] | Batch [210/597] | Loss G: 4.3780 | Loss DX: 0.1861 | Loss DY: 0.2521
# Step 1 | alpha 0.3518 | Epoch [1/1] | Batch [211/597] | Loss G: 4.4041 | Loss DX: 0.1739 | Loss DY: 0.2692
# Step 1 | alpha 0.3534 | Epoch [1/1] | Batch [212/597] | Loss G: 3.7756 | Loss DX: 0.1889 | Loss DY: 0.2062
# Step 1 | alpha 0.3551 | Epoch [1/1] | Batch [213/597] | Loss G: 3.0174 | Loss DX: 0.2177 | Loss DY: 0.2234
# Step 1 | alpha 0.3568 | Epoch [1/1] | Batch [214/597] | Loss G: 3.6449 | Loss DX: 0.3318 | Loss DY: 0.2643
# Step 1 | alpha 0.3585 | Epoch [1/1] | Batch [215/597] | Loss G: 3.7273 | Loss DX: 0.1933 | Loss DY: 0.2165
# Step 1 | alpha 0.3601 | Epoch [1/1] | Batch [216/597] | Loss G: 2.6092 | Loss DX: 0.2076 | Loss DY: 0.2299
# Step 1 | alpha 0.3618 | Epoch [1/1] | Batch [217/597] | Loss G: 3.2061 | Loss DX: 0.1972 | Loss DY: 0.2059
# Step 1 | alpha 0.3635 | Epoch [1/1] | Batch [218/597] | Loss G: 3.1743 | Loss DX: 0.2276 | Loss DY: 0.2283
# Step 1 | alpha 0.3652 | Epoch [1/1] | Batch [219/597] | Loss G: 3.6981 | Loss DX: 0.1957 | Loss DY: 0.1866
# Step 1 | alpha 0.3668 | Epoch [1/1] | Batch [220/597] | Loss G: 3.6427 | Loss DX: 0.1914 | Loss DY: 0.2102
# Step 1 | alpha 0.3685 | Epoch [1/1] | Batch [221/597] | Loss G: 3.9724 | Loss DX: 0.1985 | Loss DY: 0.2667
# Step 1 | alpha 0.3702 | Epoch [1/1] | Batch [222/597] | Loss G: 3.4969 | Loss DX: 0.2619 | Loss DY: 0.2333
# Step 1 | alpha 0.3719 | Epoch [1/1] | Batch [223/597] | Loss G: 3.4212 | Loss DX: 0.2676 | Loss DY: 0.3011
# Step 1 | alpha 0.3735 | Epoch [1/1] | Batch [224/597] | Loss G: 3.7241 | Loss DX: 0.2326 | Loss DY: 0.2583
# Step 1 | alpha 0.3752 | Epoch [1/1] | Batch [225/597] | Loss G: 3.8760 | Loss DX: 0.2149 | Loss DY: 0.2225
# Step 1 | alpha 0.3769 | Epoch [1/1] | Batch [226/597] | Loss G: 5.1613 | Loss DX: 0.1810 | Loss DY: 0.2424
# Step 1 | alpha 0.3786 | Epoch [1/1] | Batch [227/597] | Loss G: 4.0556 | Loss DX: 0.2133 | Loss DY: 0.2323
# Step 1 | alpha 0.3802 | Epoch [1/1] | Batch [228/597] | Loss G: 2.6127 | Loss DX: 0.2533 | Loss DY: 0.2534
# Step 1 | alpha 0.3819 | Epoch [1/1] | Batch [229/597] | Loss G: 3.0288 | Loss DX: 0.2391 | Loss DY: 0.2519
# Step 1 | alpha 0.3836 | Epoch [1/1] | Batch [230/597] | Loss G: 3.3091 | Loss DX: 0.2410 | Loss DY: 0.2321
# Step 1 | alpha 0.3853 | Epoch [1/1] | Batch [231/597] | Loss G: 3.2251 | Loss DX: 0.2682 | Loss DY: 0.2605
# Step 1 | alpha 0.3869 | Epoch [1/1] | Batch [232/597] | Loss G: 4.7815 | Loss DX: 0.2146 | Loss DY: 0.2360
# Step 1 | alpha 0.3886 | Epoch [1/1] | Batch [233/597] | Loss G: 3.1778 | Loss DX: 0.2367 | Loss DY: 0.2534
# Step 1 | alpha 0.3903 | Epoch [1/1] | Batch [234/597] | Loss G: 3.7820 | Loss DX: 0.2182 | Loss DY: 0.2377
# Step 1 | alpha 0.3920 | Epoch [1/1] | Batch [235/597] | Loss G: 3.3048 | Loss DX: 0.2519 | Loss DY: 0.2515
# Step 1 | alpha 0.3936 | Epoch [1/1] | Batch [236/597] | Loss G: 3.5882 | Loss DX: 0.2128 | Loss DY: 0.2248
# Step 1 | alpha 0.3953 | Epoch [1/1] | Batch [237/597] | Loss G: 4.1627 | Loss DX: 0.2833 | Loss DY: 0.2750
# Step 1 | alpha 0.3970 | Epoch [1/1] | Batch [238/597] | Loss G: 3.6380 | Loss DX: 0.2080 | Loss DY: 0.2261
# Step 1 | alpha 0.3987 | Epoch [1/1] | Batch [239/597] | Loss G: 3.0408 | Loss DX: 0.2524 | Loss DY: 0.2414
# Step 1 | alpha 0.4003 | Epoch [1/1] | Batch [240/597] | Loss G: 3.2981 | Loss DX: 0.2273 | Loss DY: 0.2248
# Step 1 | alpha 0.4020 | Epoch [1/1] | Batch [241/597] | Loss G: 3.4231 | Loss DX: 0.2093 | Loss DY: 0.2059
# Step 1 | alpha 0.4037 | Epoch [1/1] | Batch [242/597] | Loss G: 2.9369 | Loss DX: 0.2175 | Loss DY: 0.2076
# Step 1 | alpha 0.4054 | Epoch [1/1] | Batch [243/597] | Loss G: 3.8074 | Loss DX: 0.2338 | Loss DY: 0.2208
# Step 1 | alpha 0.4070 | Epoch [1/1] | Batch [244/597] | Loss G: 2.8396 | Loss DX: 0.2401 | Loss DY: 0.2384
# Step 1 | alpha 0.4087 | Epoch [1/1] | Batch [245/597] | Loss G: 3.4119 | Loss DX: 0.2439 | Loss DY: 0.2403
# Step 1 | alpha 0.4104 | Epoch [1/1] | Batch [246/597] | Loss G: 4.0048 | Loss DX: 0.2074 | Loss DY: 0.1979
# Step 1 | alpha 0.4121 | Epoch [1/1] | Batch [247/597] | Loss G: 4.0770 | Loss DX: 0.1965 | Loss DY: 0.1708
# Step 1 | alpha 0.4137 | Epoch [1/1] | Batch [248/597] | Loss G: 3.7357 | Loss DX: 0.1924 | Loss DY: 0.1999
# Step 1 | alpha 0.4154 | Epoch [1/1] | Batch [249/597] | Loss G: 3.1236 | Loss DX: 0.2278 | Loss DY: 0.2437
# Step 1 | alpha 0.4171 | Epoch [1/1] | Batch [250/597] | Loss G: 3.7146 | Loss DX: 0.2055 | Loss DY: 0.2727
# Step 1 | alpha 0.4188 | Epoch [1/1] | Batch [251/597] | Loss G: 3.6883 | Loss DX: 0.1389 | Loss DY: 0.1722
# Step 1 | alpha 0.4204 | Epoch [1/1] | Batch [252/597] | Loss G: 4.5730 | Loss DX: 0.2159 | Loss DY: 0.3010
# Step 1 | alpha 0.4221 | Epoch [1/1] | Batch [253/597] | Loss G: 3.3064 | Loss DX: 0.1965 | Loss DY: 0.2309
# Step 1 | alpha 0.4238 | Epoch [1/1] | Batch [254/597] | Loss G: 4.4455 | Loss DX: 0.2820 | Loss DY: 0.2474
# Step 1 | alpha 0.4255 | Epoch [1/1] | Batch [255/597] | Loss G: 3.3545 | Loss DX: 0.2843 | Loss DY: 0.2502
# Step 1 | alpha 0.4271 | Epoch [1/1] | Batch [256/597] | Loss G: 3.2490 | Loss DX: 0.1655 | Loss DY: 0.2400
# Step 1 | alpha 0.4288 | Epoch [1/1] | Batch [257/597] | Loss G: 3.6629 | Loss DX: 0.2724 | Loss DY: 0.2264
# Step 1 | alpha 0.4305 | Epoch [1/1] | Batch [258/597] | Loss G: 3.2415 | Loss DX: 0.2459 | Loss DY: 0.2367
# Step 1 | alpha 0.4322 | Epoch [1/1] | Batch [259/597] | Loss G: 4.1888 | Loss DX: 0.1716 | Loss DY: 0.2207
# Step 1 | alpha 0.4338 | Epoch [1/1] | Batch [260/597] | Loss G: 2.7517 | Loss DX: 0.2034 | Loss DY: 0.2420
# Step 1 | alpha 0.4355 | Epoch [1/1] | Batch [261/597] | Loss G: 5.2145 | Loss DX: 0.2346 | Loss DY: 0.2610
# Step 1 | alpha 0.4372 | Epoch [1/1] | Batch [262/597] | Loss G: 3.5467 | Loss DX: 0.2527 | Loss DY: 0.2585
# Step 1 | alpha 0.4389 | Epoch [1/1] | Batch [263/597] | Loss G: 3.9081 | Loss DX: 0.2369 | Loss DY: 0.2306
# Step 1 | alpha 0.4405 | Epoch [1/1] | Batch [264/597] | Loss G: 3.3093 | Loss DX: 0.2231 | Loss DY: 0.2444
# Step 1 | alpha 0.4422 | Epoch [1/1] | Batch [265/597] | Loss G: 2.9669 | Loss DX: 0.1891 | Loss DY: 0.2023
# Step 1 | alpha 0.4439 | Epoch [1/1] | Batch [266/597] | Loss G: 3.4295 | Loss DX: 0.2094 | Loss DY: 0.2420
# Step 1 | alpha 0.4456 | Epoch [1/1] | Batch [267/597] | Loss G: 5.3041 | Loss DX: 0.2199 | Loss DY: 0.2282
# Step 1 | alpha 0.4472 | Epoch [1/1] | Batch [268/597] | Loss G: 4.0969 | Loss DX: 0.2481 | Loss DY: 0.2553
# Step 1 | alpha 0.4489 | Epoch [1/1] | Batch [269/597] | Loss G: 3.4982 | Loss DX: 0.2579 | Loss DY: 0.2627
# Step 1 | alpha 0.4506 | Epoch [1/1] | Batch [270/597] | Loss G: 4.2892 | Loss DX: 0.2029 | Loss DY: 0.2032
# Step 1 | alpha 0.4523 | Epoch [1/1] | Batch [271/597] | Loss G: 4.4092 | Loss DX: 0.1973 | Loss DY: 0.2397
# Step 1 | alpha 0.4539 | Epoch [1/1] | Batch [272/597] | Loss G: 3.0269 | Loss DX: 0.2291 | Loss DY: 0.2471
# Step 1 | alpha 0.4556 | Epoch [1/1] | Batch [273/597] | Loss G: 3.1362 | Loss DX: 0.3073 | Loss DY: 0.2823
# Step 1 | alpha 0.4573 | Epoch [1/1] | Batch [274/597] | Loss G: 3.8149 | Loss DX: 0.2078 | Loss DY: 0.2264
# Step 1 | alpha 0.4590 | Epoch [1/1] | Batch [275/597] | Loss G: 2.9637 | Loss DX: 0.2018 | Loss DY: 0.2456
# Step 1 | alpha 0.4606 | Epoch [1/1] | Batch [276/597] | Loss G: 4.0022 | Loss DX: 0.2410 | Loss DY: 0.2374
# Step 1 | alpha 0.4623 | Epoch [1/1] | Batch [277/597] | Loss G: 3.3328 | Loss DX: 0.2169 | Loss DY: 0.2402
# Step 1 | alpha 0.4640 | Epoch [1/1] | Batch [278/597] | Loss G: 3.9706 | Loss DX: 0.1721 | Loss DY: 0.1997
# Step 1 | alpha 0.4657 | Epoch [1/1] | Batch [279/597] | Loss G: 3.2919 | Loss DX: 0.2491 | Loss DY: 0.2440
# Step 1 | alpha 0.4673 | Epoch [1/1] | Batch [280/597] | Loss G: 3.4781 | Loss DX: 0.2711 | Loss DY: 0.2315
# Step 1 | alpha 0.4690 | Epoch [1/1] | Batch [281/597] | Loss G: 4.0279 | Loss DX: 0.1969 | Loss DY: 0.2288
# Step 1 | alpha 0.4707 | Epoch [1/1] | Batch [282/597] | Loss G: 3.4309 | Loss DX: 0.1730 | Loss DY: 0.1872
# Step 1 | alpha 0.4724 | Epoch [1/1] | Batch [283/597] | Loss G: 4.7890 | Loss DX: 0.1987 | Loss DY: 0.1936
# Step 1 | alpha 0.4740 | Epoch [1/1] | Batch [284/597] | Loss G: 2.8140 | Loss DX: 0.2267 | Loss DY: 0.2133
# Step 1 | alpha 0.4757 | Epoch [1/1] | Batch [285/597] | Loss G: 3.3989 | Loss DX: 0.2134 | Loss DY: 0.2130
# Step 1 | alpha 0.4774 | Epoch [1/1] | Batch [286/597] | Loss G: 4.0323 | Loss DX: 0.2282 | Loss DY: 0.2537
# Step 1 | alpha 0.4791 | Epoch [1/1] | Batch [287/597] | Loss G: 2.9797 | Loss DX: 0.2243 | Loss DY: 0.2231
# Step 1 | alpha 0.4807 | Epoch [1/1] | Batch [288/597] | Loss G: 2.8017 | Loss DX: 0.1677 | Loss DY: 0.1995
# Step 1 | alpha 0.4824 | Epoch [1/1] | Batch [289/597] | Loss G: 3.4545 | Loss DX: 0.1792 | Loss DY: 0.2275
# Step 1 | alpha 0.4841 | Epoch [1/1] | Batch [290/597] | Loss G: 4.0106 | Loss DX: 0.2509 | Loss DY: 0.2386
# Step 1 | alpha 0.4858 | Epoch [1/1] | Batch [291/597] | Loss G: 4.0149 | Loss DX: 0.1989 | Loss DY: 0.2102
# Step 1 | alpha 0.4874 | Epoch [1/1] | Batch [292/597] | Loss G: 3.2587 | Loss DX: 0.2696 | Loss DY: 0.2660
# Step 1 | alpha 0.4891 | Epoch [1/1] | Batch [293/597] | Loss G: 3.4686 | Loss DX: 0.1771 | Loss DY: 0.1971
# Step 1 | alpha 0.4908 | Epoch [1/1] | Batch [294/597] | Loss G: 4.2321 | Loss DX: 0.1486 | Loss DY: 0.2695
# Step 1 | alpha 0.4925 | Epoch [1/1] | Batch [295/597] | Loss G: 3.5618 | Loss DX: 0.1209 | Loss DY: 0.2075
# Step 1 | alpha 0.4941 | Epoch [1/1] | Batch [296/597] | Loss G: 4.3776 | Loss DX: 0.3778 | Loss DY: 0.2591
# Step 1 | alpha 0.4958 | Epoch [1/1] | Batch [297/597] | Loss G: 2.9528 | Loss DX: 0.2867 | Loss DY: 0.2540
# Step 1 | alpha 0.4975 | Epoch [1/1] | Batch [298/597] | Loss G: 3.7374 | Loss DX: 0.2246 | Loss DY: 0.2332
# Step 1 | alpha 0.4992 | Epoch [1/1] | Batch [299/597] | Loss G: 3.4115 | Loss DX: 0.2451 | Loss DY: 0.2283
# Step 1 | alpha 0.5008 | Epoch [1/1] | Batch [300/597] | Loss G: 3.2624 | Loss DX: 0.2666 | Loss DY: 0.2436
# Step 1 | alpha 0.5025 | Epoch [1/1] | Batch [301/597] | Loss G: 4.8622 | Loss DX: 0.1695 | Loss DY: 0.1818
# Step 1 | alpha 0.5042 | Epoch [1/1] | Batch [302/597] | Loss G: 3.2151 | Loss DX: 0.2168 | Loss DY: 0.1872
# Step 1 | alpha 0.5059 | Epoch [1/1] | Batch [303/597] | Loss G: 2.7967 | Loss DX: 0.1930 | Loss DY: 0.2056
# Step 1 | alpha 0.5075 | Epoch [1/1] | Batch [304/597] | Loss G: 4.2762 | Loss DX: 0.2041 | Loss DY: 0.1753
# Step 1 | alpha 0.5092 | Epoch [1/1] | Batch [305/597] | Loss G: 4.0791 | Loss DX: 0.2248 | Loss DY: 0.2407
# Step 1 | alpha 0.5109 | Epoch [1/1] | Batch [306/597] | Loss G: 4.5302 | Loss DX: 0.1896 | Loss DY: 0.1987
# Step 1 | alpha 0.5126 | Epoch [1/1] | Batch [307/597] | Loss G: 3.3027 | Loss DX: 0.2029 | Loss DY: 0.2131
# Step 1 | alpha 0.5142 | Epoch [1/1] | Batch [308/597] | Loss G: 3.8676 | Loss DX: 0.3067 | Loss DY: 0.2919
# Step 1 | alpha 0.5159 | Epoch [1/1] | Batch [309/597] | Loss G: 3.7817 | Loss DX: 0.2815 | Loss DY: 0.2699
# Step 1 | alpha 0.5176 | Epoch [1/1] | Batch [310/597] | Loss G: 3.4553 | Loss DX: 0.2208 | Loss DY: 0.2221
# Step 1 | alpha 0.5193 | Epoch [1/1] | Batch [311/597] | Loss G: 4.3614 | Loss DX: 0.2369 | Loss DY: 0.2317
# Step 1 | alpha 0.5209 | Epoch [1/1] | Batch [312/597] | Loss G: 3.6025 | Loss DX: 0.2496 | Loss DY: 0.2372
# Step 1 | alpha 0.5226 | Epoch [1/1] | Batch [313/597] | Loss G: 2.8861 | Loss DX: 0.2517 | Loss DY: 0.2774
# Step 1 | alpha 0.5243 | Epoch [1/1] | Batch [314/597] | Loss G: 3.3276 | Loss DX: 0.2490 | Loss DY: 0.2424
# Step 1 | alpha 0.5260 | Epoch [1/1] | Batch [315/597] | Loss G: 3.0472 | Loss DX: 0.1994 | Loss DY: 0.2378
# Step 1 | alpha 0.5276 | Epoch [1/1] | Batch [316/597] | Loss G: 4.1851 | Loss DX: 0.2242 | Loss DY: 0.2566
# Step 1 | alpha 0.5293 | Epoch [1/1] | Batch [317/597] | Loss G: 4.0500 | Loss DX: 0.1986 | Loss DY: 0.2135
# Step 1 | alpha 0.5310 | Epoch [1/1] | Batch [318/597] | Loss G: 3.3039 | Loss DX: 0.2319 | Loss DY: 0.2260
# Step 1 | alpha 0.5327 | Epoch [1/1] | Batch [319/597] | Loss G: 2.6369 | Loss DX: 0.2819 | Loss DY: 0.2476
# Step 1 | alpha 0.5343 | Epoch [1/1] | Batch [320/597] | Loss G: 3.1982 | Loss DX: 0.2533 | Loss DY: 0.2403
# Step 1 | alpha 0.5360 | Epoch [1/1] | Batch [321/597] | Loss G: 3.4591 | Loss DX: 0.2032 | Loss DY: 0.2244
# Step 1 | alpha 0.5377 | Epoch [1/1] | Batch [322/597] | Loss G: 2.8512 | Loss DX: 0.2063 | Loss DY: 0.2438
# Step 1 | alpha 0.5394 | Epoch [1/1] | Batch [323/597] | Loss G: 3.7038 | Loss DX: 0.2892 | Loss DY: 0.2260
# Step 1 | alpha 0.5410 | Epoch [1/1] | Batch [324/597] | Loss G: 2.9444 | Loss DX: 0.2082 | Loss DY: 0.2055
# Step 1 | alpha 0.5427 | Epoch [1/1] | Batch [325/597] | Loss G: 3.4365 | Loss DX: 0.2342 | Loss DY: 0.2453
# Step 1 | alpha 0.5444 | Epoch [1/1] | Batch [326/597] | Loss G: 4.4840 | Loss DX: 0.2098 | Loss DY: 0.1925
# Step 1 | alpha 0.5461 | Epoch [1/1] | Batch [327/597] | Loss G: 3.3286 | Loss DX: 0.2177 | Loss DY: 0.2217
# Step 1 | alpha 0.5477 | Epoch [1/1] | Batch [328/597] | Loss G: 3.2834 | Loss DX: 0.2594 | Loss DY: 0.2206
# Step 1 | alpha 0.5494 | Epoch [1/1] | Batch [329/597] | Loss G: 3.4120 | Loss DX: 0.2772 | Loss DY: 0.2701
# Step 1 | alpha 0.5511 | Epoch [1/1] | Batch [330/597] | Loss G: 3.4835 | Loss DX: 0.2454 | Loss DY: 0.2307
# Step 1 | alpha 0.5528 | Epoch [1/1] | Batch [331/597] | Loss G: 2.9452 | Loss DX: 0.2126 | Loss DY: 0.2067
# Step 1 | alpha 0.5544 | Epoch [1/1] | Batch [332/597] | Loss G: 3.3207 | Loss DX: 0.2565 | Loss DY: 0.2587
# Step 1 | alpha 0.5561 | Epoch [1/1] | Batch [333/597] | Loss G: 3.5635 | Loss DX: 0.2672 | Loss DY: 0.2450
# Step 1 | alpha 0.5578 | Epoch [1/1] | Batch [334/597] | Loss G: 3.3539 | Loss DX: 0.2387 | Loss DY: 0.2017
# Step 1 | alpha 0.5595 | Epoch [1/1] | Batch [335/597] | Loss G: 4.4453 | Loss DX: 0.2402 | Loss DY: 0.2346
# Step 1 | alpha 0.5611 | Epoch [1/1] | Batch [336/597] | Loss G: 3.4002 | Loss DX: 0.2293 | Loss DY: 0.2412
# Step 1 | alpha 0.5628 | Epoch [1/1] | Batch [337/597] | Loss G: 3.4302 | Loss DX: 0.2210 | Loss DY: 0.3038
# Step 1 | alpha 0.5645 | Epoch [1/1] | Batch [338/597] | Loss G: 3.3556 | Loss DX: 0.1737 | Loss DY: 0.1915
# Step 1 | alpha 0.5662 | Epoch [1/1] | Batch [339/597] | Loss G: 4.4293 | Loss DX: 0.2025 | Loss DY: 0.2157
# Step 1 | alpha 0.5678 | Epoch [1/1] | Batch [340/597] | Loss G: 3.6981 | Loss DX: 0.1830 | Loss DY: 0.2018
# Step 1 | alpha 0.5695 | Epoch [1/1] | Batch [341/597] | Loss G: 2.9933 | Loss DX: 0.2823 | Loss DY: 0.1981
# Step 1 | alpha 0.5712 | Epoch [1/1] | Batch [342/597] | Loss G: 3.9149 | Loss DX: 0.2253 | Loss DY: 0.2095
# Step 1 | alpha 0.5729 | Epoch [1/1] | Batch [343/597] | Loss G: 3.6984 | Loss DX: 0.1524 | Loss DY: 0.1622
# Step 1 | alpha 0.5745 | Epoch [1/1] | Batch [344/597] | Loss G: 3.0044 | Loss DX: 0.2382 | Loss DY: 0.2410
# Step 1 | alpha 0.5762 | Epoch [1/1] | Batch [345/597] | Loss G: 3.3825 | Loss DX: 0.1484 | Loss DY: 0.1512
# Step 1 | alpha 0.5779 | Epoch [1/1] | Batch [346/597] | Loss G: 3.3980 | Loss DX: 0.2165 | Loss DY: 0.2498
# Step 1 | alpha 0.5796 | Epoch [1/1] | Batch [347/597] | Loss G: 4.1546 | Loss DX: 0.1916 | Loss DY: 0.2801
# Step 1 | alpha 0.5812 | Epoch [1/1] | Batch [348/597] | Loss G: 2.7945 | Loss DX: 0.2570 | Loss DY: 0.2629
# Step 1 | alpha 0.5829 | Epoch [1/1] | Batch [349/597] | Loss G: 5.3755 | Loss DX: 0.2175 | Loss DY: 0.1935
# Step 1 | alpha 0.5846 | Epoch [1/1] | Batch [350/597] | Loss G: 3.3884 | Loss DX: 0.1931 | Loss DY: 0.2160
# Step 1 | alpha 0.5863 | Epoch [1/1] | Batch [351/597] | Loss G: 4.4104 | Loss DX: 0.2781 | Loss DY: 0.2730
# Step 1 | alpha 0.5879 | Epoch [1/1] | Batch [352/597] | Loss G: 3.3175 | Loss DX: 0.3555 | Loss DY: 0.2886
# Step 1 | alpha 0.5896 | Epoch [1/1] | Batch [353/597] | Loss G: 4.1515 | Loss DX: 0.1724 | Loss DY: 0.2180
# Step 1 | alpha 0.5913 | Epoch [1/1] | Batch [354/597] | Loss G: 4.5467 | Loss DX: 0.2263 | Loss DY: 0.2352
# Step 1 | alpha 0.5930 | Epoch [1/1] | Batch [355/597] | Loss G: 3.6473 | Loss DX: 0.1998 | Loss DY: 0.2057
# Step 1 | alpha 0.5946 | Epoch [1/1] | Batch [356/597] | Loss G: 3.1370 | Loss DX: 0.1697 | Loss DY: 0.2092
# Step 1 | alpha 0.5963 | Epoch [1/1] | Batch [357/597] | Loss G: 4.0242 | Loss DX: 0.2789 | Loss DY: 0.2392
# Step 1 | alpha 0.5980 | Epoch [1/1] | Batch [358/597] | Loss G: 3.7889 | Loss DX: 0.2098 | Loss DY: 0.2223
# Step 1 | alpha 0.5997 | Epoch [1/1] | Batch [359/597] | Loss G: 3.0824 | Loss DX: 0.2443 | Loss DY: 0.2234
# Step 1 | alpha 0.6013 | Epoch [1/1] | Batch [360/597] | Loss G: 3.5221 | Loss DX: 0.2247 | Loss DY: 0.1939
# Step 1 | alpha 0.6030 | Epoch [1/1] | Batch [361/597] | Loss G: 3.2931 | Loss DX: 0.2651 | Loss DY: 0.2241
# Step 1 | alpha 0.6047 | Epoch [1/1] | Batch [362/597] | Loss G: 3.3097 | Loss DX: 0.2067 | Loss DY: 0.2068
# Step 1 | alpha 0.6064 | Epoch [1/1] | Batch [363/597] | Loss G: 3.4931 | Loss DX: 0.2015 | Loss DY: 0.2232
# Step 1 | alpha 0.6080 | Epoch [1/1] | Batch [364/597] | Loss G: 5.3589 | Loss DX: 0.1861 | Loss DY: 0.1713
# Step 1 | alpha 0.6097 | Epoch [1/1] | Batch [365/597] | Loss G: 4.7729 | Loss DX: 0.2196 | Loss DY: 0.2348
# Step 1 | alpha 0.6114 | Epoch [1/1] | Batch [366/597] | Loss G: 4.4314 | Loss DX: 0.2025 | Loss DY: 0.2050
# Step 1 | alpha 0.6131 | Epoch [1/1] | Batch [367/597] | Loss G: 3.9071 | Loss DX: 0.3238 | Loss DY: 0.2860
# Step 1 | alpha 0.6147 | Epoch [1/1] | Batch [368/597] | Loss G: 3.4169 | Loss DX: 0.2216 | Loss DY: 0.1848
# Step 1 | alpha 0.6164 | Epoch [1/1] | Batch [369/597] | Loss G: 4.0055 | Loss DX: 0.2486 | Loss DY: 0.2590
# Step 1 | alpha 0.6181 | Epoch [1/1] | Batch [370/597] | Loss G: 3.4439 | Loss DX: 0.2365 | Loss DY: 0.2638
# Step 1 | alpha 0.6198 | Epoch [1/1] | Batch [371/597] | Loss G: 4.3151 | Loss DX: 0.2819 | Loss DY: 0.2442
# Step 1 | alpha 0.6214 | Epoch [1/1] | Batch [372/597] | Loss G: 3.3997 | Loss DX: 0.2459 | Loss DY: 0.2512
# Step 1 | alpha 0.6231 | Epoch [1/1] | Batch [373/597] | Loss G: 3.8113 | Loss DX: 0.2132 | Loss DY: 0.1778
# Step 1 | alpha 0.6248 | Epoch [1/1] | Batch [374/597] | Loss G: 2.8431 | Loss DX: 0.2317 | Loss DY: 0.2491
# Step 1 | alpha 0.6265 | Epoch [1/1] | Batch [375/597] | Loss G: 3.3747 | Loss DX: 0.2266 | Loss DY: 0.2153
# Step 1 | alpha 0.6281 | Epoch [1/1] | Batch [376/597] | Loss G: 3.3418 | Loss DX: 0.2023 | Loss DY: 0.2196
# Step 1 | alpha 0.6298 | Epoch [1/1] | Batch [377/597] | Loss G: 3.8591 | Loss DX: 0.2736 | Loss DY: 0.2666
# Step 1 | alpha 0.6315 | Epoch [1/1] | Batch [378/597] | Loss G: 3.7706 | Loss DX: 0.2227 | Loss DY: 0.2625
# Step 1 | alpha 0.6332 | Epoch [1/1] | Batch [379/597] | Loss G: 3.6591 | Loss DX: 0.2208 | Loss DY: 0.2302
# Step 1 | alpha 0.6348 | Epoch [1/1] | Batch [380/597] | Loss G: 3.9586 | Loss DX: 0.2285 | Loss DY: 0.2211
# Step 1 | alpha 0.6365 | Epoch [1/1] | Batch [381/597] | Loss G: 3.2662 | Loss DX: 0.2588 | Loss DY: 0.2140
# Step 1 | alpha 0.6382 | Epoch [1/1] | Batch [382/597] | Loss G: 4.3251 | Loss DX: 0.2380 | Loss DY: 0.2040
# Step 1 | alpha 0.6399 | Epoch [1/1] | Batch [383/597] | Loss G: 3.4743 | Loss DX: 0.2662 | Loss DY: 0.2173
# Step 1 | alpha 0.6415 | Epoch [1/1] | Batch [384/597] | Loss G: 3.9518 | Loss DX: 0.2546 | Loss DY: 0.2266
# Step 1 | alpha 0.6432 | Epoch [1/1] | Batch [385/597] | Loss G: 4.5036 | Loss DX: 0.2607 | Loss DY: 0.3139
# Step 1 | alpha 0.6449 | Epoch [1/1] | Batch [386/597] | Loss G: 3.4299 | Loss DX: 0.1761 | Loss DY: 0.1681
# Step 1 | alpha 0.6466 | Epoch [1/1] | Batch [387/597] | Loss G: 3.0460 | Loss DX: 0.2501 | Loss DY: 0.2322
# Step 1 | alpha 0.6482 | Epoch [1/1] | Batch [388/597] | Loss G: 3.5313 | Loss DX: 0.2413 | Loss DY: 0.2638
# Step 1 | alpha 0.6499 | Epoch [1/1] | Batch [389/597] | Loss G: 3.6025 | Loss DX: 0.2508 | Loss DY: 0.2098
# Step 1 | alpha 0.6516 | Epoch [1/1] | Batch [390/597] | Loss G: 3.2764 | Loss DX: 0.1942 | Loss DY: 0.1736
# Step 1 | alpha 0.6533 | Epoch [1/1] | Batch [391/597] | Loss G: 3.4857 | Loss DX: 0.2162 | Loss DY: 0.2137
# Step 1 | alpha 0.6549 | Epoch [1/1] | Batch [392/597] | Loss G: 3.7468 | Loss DX: 0.2229 | Loss DY: 0.1651
# Step 1 | alpha 0.6566 | Epoch [1/1] | Batch [393/597] | Loss G: 4.1666 | Loss DX: 0.1402 | Loss DY: 0.1712
# Step 1 | alpha 0.6583 | Epoch [1/1] | Batch [394/597] | Loss G: 4.3090 | Loss DX: 0.1459 | Loss DY: 0.1485
# Step 1 | alpha 0.6600 | Epoch [1/1] | Batch [395/597] | Loss G: 3.2766 | Loss DX: 0.2263 | Loss DY: 0.1976
# Step 1 | alpha 0.6616 | Epoch [1/1] | Batch [396/597] | Loss G: 3.1700 | Loss DX: 0.1699 | Loss DY: 0.2222
# Step 1 | alpha 0.6633 | Epoch [1/1] | Batch [397/597] | Loss G: 2.9742 | Loss DX: 0.2325 | Loss DY: 0.2854
# Step 1 | alpha 0.6650 | Epoch [1/1] | Batch [398/597] | Loss G: 3.0613 | Loss DX: 0.2648 | Loss DY: 0.2060
# Step 1 | alpha 0.6667 | Epoch [1/1] | Batch [399/597] | Loss G: 3.0036 | Loss DX: 0.2724 | Loss DY: 0.2738
# Step 1 | alpha 0.6683 | Epoch [1/1] | Batch [400/597] | Loss G: 3.9829 | Loss DX: 0.2572 | Loss DY: 0.2133
# Step 1 | alpha 0.6700 | Epoch [1/1] | Batch [401/597] | Loss G: 3.4876 | Loss DX: 0.1992 | Loss DY: 0.2154
# Step 1 | alpha 0.6717 | Epoch [1/1] | Batch [402/597] | Loss G: 3.1953 | Loss DX: 0.2086 | Loss DY: 0.2199
# Step 1 | alpha 0.6734 | Epoch [1/1] | Batch [403/597] | Loss G: 3.2850 | Loss DX: 0.2674 | Loss DY: 0.2547
# Step 1 | alpha 0.6750 | Epoch [1/1] | Batch [404/597] | Loss G: 3.4671 | Loss DX: 0.2113 | Loss DY: 0.2712
# Step 1 | alpha 0.6767 | Epoch [1/1] | Batch [405/597] | Loss G: 3.8845 | Loss DX: 0.2320 | Loss DY: 0.2386
# Step 1 | alpha 0.6784 | Epoch [1/1] | Batch [406/597] | Loss G: 3.8402 | Loss DX: 0.2282 | Loss DY: 0.2133
# Step 1 | alpha 0.6801 | Epoch [1/1] | Batch [407/597] | Loss G: 3.6963 | Loss DX: 0.2958 | Loss DY: 0.2913
# Step 1 | alpha 0.6817 | Epoch [1/1] | Batch [408/597] | Loss G: 4.7792 | Loss DX: 0.1723 | Loss DY: 0.2376
# Step 1 | alpha 0.6834 | Epoch [1/1] | Batch [409/597] | Loss G: 3.6472 | Loss DX: 0.2211 | Loss DY: 0.2089
# Step 1 | alpha 0.6851 | Epoch [1/1] | Batch [410/597] | Loss G: 3.8558 | Loss DX: 0.1912 | Loss DY: 0.2470
# Step 1 | alpha 0.6868 | Epoch [1/1] | Batch [411/597] | Loss G: 2.8379 | Loss DX: 0.2152 | Loss DY: 0.2431
# Step 1 | alpha 0.6884 | Epoch [1/1] | Batch [412/597] | Loss G: 3.0556 | Loss DX: 0.2791 | Loss DY: 0.2436
# Step 1 | alpha 0.6901 | Epoch [1/1] | Batch [413/597] | Loss G: 3.0594 | Loss DX: 0.2291 | Loss DY: 0.2421
# Step 1 | alpha 0.6918 | Epoch [1/1] | Batch [414/597] | Loss G: 3.1484 | Loss DX: 0.3147 | Loss DY: 0.2642
# Step 1 | alpha 0.6935 | Epoch [1/1] | Batch [415/597] | Loss G: 4.8724 | Loss DX: 0.2434 | Loss DY: 0.2127
# Step 1 | alpha 0.6951 | Epoch [1/1] | Batch [416/597] | Loss G: 3.6519 | Loss DX: 0.2295 | Loss DY: 0.2541
# Step 1 | alpha 0.6968 | Epoch [1/1] | Batch [417/597] | Loss G: 3.4140 | Loss DX: 0.2091 | Loss DY: 0.2196
# Step 1 | alpha 0.6985 | Epoch [1/1] | Batch [418/597] | Loss G: 3.4530 | Loss DX: 0.2357 | Loss DY: 0.2544
# Step 1 | alpha 0.7002 | Epoch [1/1] | Batch [419/597] | Loss G: 3.7358 | Loss DX: 0.2096 | Loss DY: 0.2359
# Step 1 | alpha 0.7018 | Epoch [1/1] | Batch [420/597] | Loss G: 3.2425 | Loss DX: 0.2792 | Loss DY: 0.2648
# Step 1 | alpha 0.7035 | Epoch [1/1] | Batch [421/597] | Loss G: 3.6994 | Loss DX: 0.1869 | Loss DY: 0.1824
# Step 1 | alpha 0.7052 | Epoch [1/1] | Batch [422/597] | Loss G: 3.4807 | Loss DX: 0.2347 | Loss DY: 0.2403
# Step 1 | alpha 0.7069 | Epoch [1/1] | Batch [423/597] | Loss G: 3.6327 | Loss DX: 0.2461 | Loss DY: 0.2355
# Step 1 | alpha 0.7085 | Epoch [1/1] | Batch [424/597] | Loss G: 3.7689 | Loss DX: 0.2551 | Loss DY: 0.2244
# Step 1 | alpha 0.7102 | Epoch [1/1] | Batch [425/597] | Loss G: 4.1669 | Loss DX: 0.2142 | Loss DY: 0.2582
# Step 1 | alpha 0.7119 | Epoch [1/1] | Batch [426/597] | Loss G: 3.1913 | Loss DX: 0.1895 | Loss DY: 0.2171
# Step 1 | alpha 0.7136 | Epoch [1/1] | Batch [427/597] | Loss G: 2.9696 | Loss DX: 0.2444 | Loss DY: 0.2484
# Step 1 | alpha 0.7152 | Epoch [1/1] | Batch [428/597] | Loss G: 3.8682 | Loss DX: 0.2512 | Loss DY: 0.2222
# Step 1 | alpha 0.7169 | Epoch [1/1] | Batch [429/597] | Loss G: 3.1113 | Loss DX: 0.2293 | Loss DY: 0.1989
# Step 1 | alpha 0.7186 | Epoch [1/1] | Batch [430/597] | Loss G: 3.8110 | Loss DX: 0.2101 | Loss DY: 0.1919
# Step 1 | alpha 0.7203 | Epoch [1/1] | Batch [431/597] | Loss G: 3.8143 | Loss DX: 0.2097 | Loss DY: 0.2211
# Step 1 | alpha 0.7219 | Epoch [1/1] | Batch [432/597] | Loss G: 3.6611 | Loss DX: 0.2269 | Loss DY: 0.2136
# Step 1 | alpha 0.7236 | Epoch [1/1] | Batch [433/597] | Loss G: 4.1774 | Loss DX: 0.2213 | Loss DY: 0.2153
# Step 1 | alpha 0.7253 | Epoch [1/1] | Batch [434/597] | Loss G: 3.2865 | Loss DX: 0.2134 | Loss DY: 0.2568
# Step 1 | alpha 0.7270 | Epoch [1/1] | Batch [435/597] | Loss G: 3.2944 | Loss DX: 0.1996 | Loss DY: 0.1998
# Step 1 | alpha 0.7286 | Epoch [1/1] | Batch [436/597] | Loss G: 3.4483 | Loss DX: 0.2069 | Loss DY: 0.2500
# Step 1 | alpha 0.7303 | Epoch [1/1] | Batch [437/597] | Loss G: 4.2802 | Loss DX: 0.2186 | Loss DY: 0.2605
# Step 1 | alpha 0.7320 | Epoch [1/1] | Batch [438/597] | Loss G: 2.9050 | Loss DX: 0.2816 | Loss DY: 0.2555
# Step 1 | alpha 0.7337 | Epoch [1/1] | Batch [439/597] | Loss G: 3.4840 | Loss DX: 0.2170 | Loss DY: 0.2219
# Step 1 | alpha 0.7353 | Epoch [1/1] | Batch [440/597] | Loss G: 3.3088 | Loss DX: 0.1824 | Loss DY: 0.2008
# Step 1 | alpha 0.7370 | Epoch [1/1] | Batch [441/597] | Loss G: 4.6669 | Loss DX: 0.2720 | Loss DY: 0.2290
# Step 1 | alpha 0.7387 | Epoch [1/1] | Batch [442/597] | Loss G: 3.5895 | Loss DX: 0.2544 | Loss DY: 0.2025
# Step 1 | alpha 0.7404 | Epoch [1/1] | Batch [443/597] | Loss G: 3.3633 | Loss DX: 0.2206 | Loss DY: 0.2316
# Step 1 | alpha 0.7420 | Epoch [1/1] | Batch [444/597] | Loss G: 3.6399 | Loss DX: 0.2525 | Loss DY: 0.2725
# Step 1 | alpha 0.7437 | Epoch [1/1] | Batch [445/597] | Loss G: 5.0278 | Loss DX: 0.1678 | Loss DY: 0.1732
# Step 1 | alpha 0.7454 | Epoch [1/1] | Batch [446/597] | Loss G: 3.9308 | Loss DX: 0.2205 | Loss DY: 0.2241
# Step 1 | alpha 0.7471 | Epoch [1/1] | Batch [447/597] | Loss G: 3.8281 | Loss DX: 0.2350 | Loss DY: 0.1973
# Step 1 | alpha 0.7487 | Epoch [1/1] | Batch [448/597] | Loss G: 3.5800 | Loss DX: 0.2371 | Loss DY: 0.2566
# Step 1 | alpha 0.7504 | Epoch [1/1] | Batch [449/597] | Loss G: 3.2805 | Loss DX: 0.2030 | Loss DY: 0.2041
# Step 1 | alpha 0.7521 | Epoch [1/1] | Batch [450/597] | Loss G: 2.7489 | Loss DX: 0.1748 | Loss DY: 0.2191
# Step 1 | alpha 0.7538 | Epoch [1/1] | Batch [451/597] | Loss G: 3.2504 | Loss DX: 0.2725 | Loss DY: 0.2468
# Step 1 | alpha 0.7554 | Epoch [1/1] | Batch [452/597] | Loss G: 3.8744 | Loss DX: 0.1526 | Loss DY: 0.1779
# Step 1 | alpha 0.7571 | Epoch [1/1] | Batch [453/597] | Loss G: 3.3827 | Loss DX: 0.2601 | Loss DY: 0.2296
# Step 1 | alpha 0.7588 | Epoch [1/1] | Batch [454/597] | Loss G: 3.9572 | Loss DX: 0.1873 | Loss DY: 0.1907
# Step 1 | alpha 0.7605 | Epoch [1/1] | Batch [455/597] | Loss G: 3.3982 | Loss DX: 0.2395 | Loss DY: 0.2325
# Step 1 | alpha 0.7621 | Epoch [1/1] | Batch [456/597] | Loss G: 3.8133 | Loss DX: 0.2507 | Loss DY: 0.2215
# Step 1 | alpha 0.7638 | Epoch [1/1] | Batch [457/597] | Loss G: 4.0681 | Loss DX: 0.2517 | Loss DY: 0.2449
# Step 1 | alpha 0.7655 | Epoch [1/1] | Batch [458/597] | Loss G: 2.9063 | Loss DX: 0.2135 | Loss DY: 0.2117
# Step 1 | alpha 0.7672 | Epoch [1/1] | Batch [459/597] | Loss G: 3.4540 | Loss DX: 0.2265 | Loss DY: 0.2531
# Step 1 | alpha 0.7688 | Epoch [1/1] | Batch [460/597] | Loss G: 3.8920 | Loss DX: 0.1994 | Loss DY: 0.1948
# Step 1 | alpha 0.7705 | Epoch [1/1] | Batch [461/597] | Loss G: 3.9869 | Loss DX: 0.2167 | Loss DY: 0.1825
# Step 1 | alpha 0.7722 | Epoch [1/1] | Batch [462/597] | Loss G: 3.3489 | Loss DX: 0.2050 | Loss DY: 0.2434
# Step 1 | alpha 0.7739 | Epoch [1/1] | Batch [463/597] | Loss G: 2.9889 | Loss DX: 0.2115 | Loss DY: 0.2079
# Step 1 | alpha 0.7755 | Epoch [1/1] | Batch [464/597] | Loss G: 4.3368 | Loss DX: 0.2572 | Loss DY: 0.2071
# Step 1 | alpha 0.7772 | Epoch [1/1] | Batch [465/597] | Loss G: 3.7736 | Loss DX: 0.2105 | Loss DY: 0.1784
# Step 1 | alpha 0.7789 | Epoch [1/1] | Batch [466/597] | Loss G: 3.5291 | Loss DX: 0.2281 | Loss DY: 0.1868
# Step 1 | alpha 0.7806 | Epoch [1/1] | Batch [467/597] | Loss G: 3.4902 | Loss DX: 0.1625 | Loss DY: 0.2025
# Step 1 | alpha 0.7822 | Epoch [1/1] | Batch [468/597] | Loss G: 3.6182 | Loss DX: 0.2091 | Loss DY: 0.1894
# Step 1 | alpha 0.7839 | Epoch [1/1] | Batch [469/597] | Loss G: 4.4388 | Loss DX: 0.1468 | Loss DY: 0.2431
# Step 1 | alpha 0.7856 | Epoch [1/1] | Batch [470/597] | Loss G: 4.0139 | Loss DX: 0.2453 | Loss DY: 0.3022
# Step 1 | alpha 0.7873 | Epoch [1/1] | Batch [471/597] | Loss G: 4.3768 | Loss DX: 0.2668 | Loss DY: 0.2769
# Step 1 | alpha 0.7889 | Epoch [1/1] | Batch [472/597] | Loss G: 4.3250 | Loss DX: 0.2265 | Loss DY: 0.2561
# Step 1 | alpha 0.7906 | Epoch [1/1] | Batch [473/597] | Loss G: 3.4476 | Loss DX: 0.2873 | Loss DY: 0.3020
# Step 1 | alpha 0.7923 | Epoch [1/1] | Batch [474/597] | Loss G: 3.6677 | Loss DX: 0.1831 | Loss DY: 0.2230
# Step 1 | alpha 0.7940 | Epoch [1/1] | Batch [475/597] | Loss G: 2.8748 | Loss DX: 0.2262 | Loss DY: 0.2178
# Step 1 | alpha 0.7956 | Epoch [1/1] | Batch [476/597] | Loss G: 4.4758 | Loss DX: 0.2231 | Loss DY: 0.2740
# Step 1 | alpha 0.7973 | Epoch [1/1] | Batch [477/597] | Loss G: 3.1317 | Loss DX: 0.2326 | Loss DY: 0.2435
# Step 1 | alpha 0.7990 | Epoch [1/1] | Batch [478/597] | Loss G: 2.7572 | Loss DX: 0.2468 | Loss DY: 0.2355
# Step 1 | alpha 0.8007 | Epoch [1/1] | Batch [479/597] | Loss G: 3.8397 | Loss DX: 0.2459 | Loss DY: 0.2607
# Step 1 | alpha 0.8023 | Epoch [1/1] | Batch [480/597] | Loss G: 3.0378 | Loss DX: 0.2141 | Loss DY: 0.2383
# Step 1 | alpha 0.8040 | Epoch [1/1] | Batch [481/597] | Loss G: 3.2503 | Loss DX: 0.2599 | Loss DY: 0.2394
# Step 1 | alpha 0.8057 | Epoch [1/1] | Batch [482/597] | Loss G: 3.0218 | Loss DX: 0.2447 | Loss DY: 0.2453
# Step 1 | alpha 0.8074 | Epoch [1/1] | Batch [483/597] | Loss G: 3.1340 | Loss DX: 0.2099 | Loss DY: 0.2104
# Step 1 | alpha 0.8090 | Epoch [1/1] | Batch [484/597] | Loss G: 4.1933 | Loss DX: 0.2259 | Loss DY: 0.2193
# Step 1 | alpha 0.8107 | Epoch [1/1] | Batch [485/597] | Loss G: 3.3474 | Loss DX: 0.2041 | Loss DY: 0.2505
# Step 1 | alpha 0.8124 | Epoch [1/1] | Batch [486/597] | Loss G: 3.0406 | Loss DX: 0.2216 | Loss DY: 0.2311
# Step 1 | alpha 0.8141 | Epoch [1/1] | Batch [487/597] | Loss G: 3.4204 | Loss DX: 0.2416 | Loss DY: 0.2527
# Step 1 | alpha 0.8157 | Epoch [1/1] | Batch [488/597] | Loss G: 3.3390 | Loss DX: 0.2263 | Loss DY: 0.2546
# Step 1 | alpha 0.8174 | Epoch [1/1] | Batch [489/597] | Loss G: 2.9343 | Loss DX: 0.2305 | Loss DY: 0.2456
# Step 1 | alpha 0.8191 | Epoch [1/1] | Batch [490/597] | Loss G: 3.7500 | Loss DX: 0.2190 | Loss DY: 0.2296
# Step 1 | alpha 0.8208 | Epoch [1/1] | Batch [491/597] | Loss G: 2.9400 | Loss DX: 0.2340 | Loss DY: 0.2193
# Step 1 | alpha 0.8224 | Epoch [1/1] | Batch [492/597] | Loss G: 4.1230 | Loss DX: 0.1636 | Loss DY: 0.2037
# Step 1 | alpha 0.8241 | Epoch [1/1] | Batch [493/597] | Loss G: 3.3391 | Loss DX: 0.2134 | Loss DY: 0.2181
# Step 1 | alpha 0.8258 | Epoch [1/1] | Batch [494/597] | Loss G: 2.9260 | Loss DX: 0.2056 | Loss DY: 0.2026
# Step 1 | alpha 0.8275 | Epoch [1/1] | Batch [495/597] | Loss G: 3.3895 | Loss DX: 0.2350 | Loss DY: 0.2373
# Step 1 | alpha 0.8291 | Epoch [1/1] | Batch [496/597] | Loss G: 3.7418 | Loss DX: 0.2074 | Loss DY: 0.2045
# Step 1 | alpha 0.8308 | Epoch [1/1] | Batch [497/597] | Loss G: 3.2526 | Loss DX: 0.2821 | Loss DY: 0.2279
# Step 1 | alpha 0.8325 | Epoch [1/1] | Batch [498/597] | Loss G: 3.3503 | Loss DX: 0.2370 | Loss DY: 0.2914
# Step 1 | alpha 0.8342 | Epoch [1/1] | Batch [499/597] | Loss G: 3.7945 | Loss DX: 0.2396 | Loss DY: 0.2943
# Step 1 | alpha 0.8358 | Epoch [1/1] | Batch [500/597] | Loss G: 2.9857 | Loss DX: 0.2332 | Loss DY: 0.2086
# Step 1 | alpha 0.8375 | Epoch [1/1] | Batch [501/597] | Loss G: 4.2044 | Loss DX: 0.2006 | Loss DY: 0.1894
# Step 1 | alpha 0.8392 | Epoch [1/1] | Batch [502/597] | Loss G: 3.9549 | Loss DX: 0.2342 | Loss DY: 0.2155
# Step 1 | alpha 0.8409 | Epoch [1/1] | Batch [503/597] | Loss G: 3.4611 | Loss DX: 0.1694 | Loss DY: 0.2125
# Step 1 | alpha 0.8425 | Epoch [1/1] | Batch [504/597] | Loss G: 4.6305 | Loss DX: 0.2039 | Loss DY: 0.2367
# Step 1 | alpha 0.8442 | Epoch [1/1] | Batch [505/597] | Loss G: 3.2871 | Loss DX: 0.2250 | Loss DY: 0.2338
# Step 1 | alpha 0.8459 | Epoch [1/1] | Batch [506/597] | Loss G: 2.6714 | Loss DX: 0.2327 | Loss DY: 0.1893
# Step 1 | alpha 0.8476 | Epoch [1/1] | Batch [507/597] | Loss G: 3.9771 | Loss DX: 0.2400 | Loss DY: 0.2511
# Step 1 | alpha 0.8492 | Epoch [1/1] | Batch [508/597] | Loss G: 3.8166 | Loss DX: 0.2241 | Loss DY: 0.2174
# Step 1 | alpha 0.8509 | Epoch [1/1] | Batch [509/597] | Loss G: 3.5797 | Loss DX: 0.1496 | Loss DY: 0.2188
# Step 1 | alpha 0.8526 | Epoch [1/1] | Batch [510/597] | Loss G: 4.7190 | Loss DX: 0.1907 | Loss DY: 0.2372
# Step 1 | alpha 0.8543 | Epoch [1/1] | Batch [511/597] | Loss G: 3.9598 | Loss DX: 0.1942 | Loss DY: 0.2228
# Step 1 | alpha 0.8559 | Epoch [1/1] | Batch [512/597] | Loss G: 4.3566 | Loss DX: 0.1849 | Loss DY: 0.2207
# Step 1 | alpha 0.8576 | Epoch [1/1] | Batch [513/597] | Loss G: 3.4388 | Loss DX: 0.2384 | Loss DY: 0.2367
# Step 1 | alpha 0.8593 | Epoch [1/1] | Batch [514/597] | Loss G: 3.3334 | Loss DX: 0.3062 | Loss DY: 0.2631
# Step 1 | alpha 0.8610 | Epoch [1/1] | Batch [515/597] | Loss G: 3.6090 | Loss DX: 0.2198 | Loss DY: 0.2253
# Step 1 | alpha 0.8626 | Epoch [1/1] | Batch [516/597] | Loss G: 3.4243 | Loss DX: 0.2082 | Loss DY: 0.2036
# Step 1 | alpha 0.8643 | Epoch [1/1] | Batch [517/597] | Loss G: 2.9979 | Loss DX: 0.2254 | Loss DY: 0.2314
# Step 1 | alpha 0.8660 | Epoch [1/1] | Batch [518/597] | Loss G: 4.4166 | Loss DX: 0.2416 | Loss DY: 0.2141
# Step 1 | alpha 0.8677 | Epoch [1/1] | Batch [519/597] | Loss G: 4.2604 | Loss DX: 0.2460 | Loss DY: 0.2415
# Step 1 | alpha 0.8693 | Epoch [1/1] | Batch [520/597] | Loss G: 3.2302 | Loss DX: 0.2338 | Loss DY: 0.2517
# Step 1 | alpha 0.8710 | Epoch [1/1] | Batch [521/597] | Loss G: 4.0865 | Loss DX: 0.2287 | Loss DY: 0.2245
# Step 1 | alpha 0.8727 | Epoch [1/1] | Batch [522/597] | Loss G: 2.8827 | Loss DX: 0.2278 | Loss DY: 0.1910
# Step 1 | alpha 0.8744 | Epoch [1/1] | Batch [523/597] | Loss G: 5.3214 | Loss DX: 0.2101 | Loss DY: 0.1805
# Step 1 | alpha 0.8760 | Epoch [1/1] | Batch [524/597] | Loss G: 3.5826 | Loss DX: 0.2593 | Loss DY: 0.3073
# Step 1 | alpha 0.8777 | Epoch [1/1] | Batch [525/597] | Loss G: 3.7437 | Loss DX: 0.2252 | Loss DY: 0.2204
# Step 1 | alpha 0.8794 | Epoch [1/1] | Batch [526/597] | Loss G: 4.3225 | Loss DX: 0.2276 | Loss DY: 0.2467
# Step 1 | alpha 0.8811 | Epoch [1/1] | Batch [527/597] | Loss G: 3.7893 | Loss DX: 0.2361 | Loss DY: 0.2112
# Step 1 | alpha 0.8827 | Epoch [1/1] | Batch [528/597] | Loss G: 3.7974 | Loss DX: 0.2171 | Loss DY: 0.2244
# Step 1 | alpha 0.8844 | Epoch [1/1] | Batch [529/597] | Loss G: 4.4104 | Loss DX: 0.2376 | Loss DY: 0.2747
# Step 1 | alpha 0.8861 | Epoch [1/1] | Batch [530/597] | Loss G: 3.9709 | Loss DX: 0.2163 | Loss DY: 0.2088
# Step 1 | alpha 0.8878 | Epoch [1/1] | Batch [531/597] | Loss G: 3.8614 | Loss DX: 0.2079 | Loss DY: 0.2149
# Step 1 | alpha 0.8894 | Epoch [1/1] | Batch [532/597] | Loss G: 3.6660 | Loss DX: 0.2079 | Loss DY: 0.2204
# Step 1 | alpha 0.8911 | Epoch [1/1] | Batch [533/597] | Loss G: 3.7744 | Loss DX: 0.1961 | Loss DY: 0.1792
# Step 1 | alpha 0.8928 | Epoch [1/1] | Batch [534/597] | Loss G: 3.9728 | Loss DX: 0.2479 | Loss DY: 0.2043
# Step 1 | alpha 0.8945 | Epoch [1/1] | Batch [535/597] | Loss G: 4.0578 | Loss DX: 0.2170 | Loss DY: 0.2536
# Step 1 | alpha 0.8961 | Epoch [1/1] | Batch [536/597] | Loss G: 4.3113 | Loss DX: 0.1896 | Loss DY: 0.1974
# Step 1 | alpha 0.8978 | Epoch [1/1] | Batch [537/597] | Loss G: 3.4472 | Loss DX: 0.2268 | Loss DY: 0.2501
# Step 1 | alpha 0.8995 | Epoch [1/1] | Batch [538/597] | Loss G: 3.6068 | Loss DX: 0.2187 | Loss DY: 0.2441
# Step 1 | alpha 0.9012 | Epoch [1/1] | Batch [539/597] | Loss G: 3.7425 | Loss DX: 0.1836 | Loss DY: 0.2183
# Step 1 | alpha 0.9028 | Epoch [1/1] | Batch [540/597] | Loss G: 2.9234 | Loss DX: 0.2170 | Loss DY: 0.2633
# Step 1 | alpha 0.9045 | Epoch [1/1] | Batch [541/597] | Loss G: 4.6861 | Loss DX: 0.1257 | Loss DY: 0.2132
# Step 1 | alpha 0.9062 | Epoch [1/1] | Batch [542/597] | Loss G: 4.3620 | Loss DX: 0.2542 | Loss DY: 0.2742
# Step 1 | alpha 0.9079 | Epoch [1/1] | Batch [543/597] | Loss G: 3.7958 | Loss DX: 0.1767 | Loss DY: 0.2627
# Step 1 | alpha 0.9095 | Epoch [1/1] | Batch [544/597] | Loss G: 3.5747 | Loss DX: 0.2413 | Loss DY: 0.2353
# Step 1 | alpha 0.9112 | Epoch [1/1] | Batch [545/597] | Loss G: 3.4837 | Loss DX: 0.2828 | Loss DY: 0.2340
# Step 1 | alpha 0.9129 | Epoch [1/1] | Batch [546/597] | Loss G: 3.0094 | Loss DX: 0.2408 | Loss DY: 0.2338
# Step 1 | alpha 0.9146 | Epoch [1/1] | Batch [547/597] | Loss G: 3.1468 | Loss DX: 0.2482 | Loss DY: 0.2213
# Step 1 | alpha 0.9162 | Epoch [1/1] | Batch [548/597] | Loss G: 3.8956 | Loss DX: 0.2056 | Loss DY: 0.2203
# Step 1 | alpha 0.9179 | Epoch [1/1] | Batch [549/597] | Loss G: 3.6304 | Loss DX: 0.2211 | Loss DY: 0.1762
# Step 1 | alpha 0.9196 | Epoch [1/1] | Batch [550/597] | Loss G: 3.1499 | Loss DX: 0.2073 | Loss DY: 0.2239
# Step 1 | alpha 0.9213 | Epoch [1/1] | Batch [551/597] | Loss G: 3.1292 | Loss DX: 0.2050 | Loss DY: 0.2323
# Step 1 | alpha 0.9229 | Epoch [1/1] | Batch [552/597] | Loss G: 3.1159 | Loss DX: 0.2258 | Loss DY: 0.3641
# Step 1 | alpha 0.9246 | Epoch [1/1] | Batch [553/597] | Loss G: 3.2929 | Loss DX: 0.2199 | Loss DY: 0.2499
# Step 1 | alpha 0.9263 | Epoch [1/1] | Batch [554/597] | Loss G: 3.4378 | Loss DX: 0.2477 | Loss DY: 0.2424
# Step 1 | alpha 0.9280 | Epoch [1/1] | Batch [555/597] | Loss G: 3.5325 | Loss DX: 0.2695 | Loss DY: 0.2570
# Step 1 | alpha 0.9296 | Epoch [1/1] | Batch [556/597] | Loss G: 3.9286 | Loss DX: 0.2648 | Loss DY: 0.1977
# Step 1 | alpha 0.9313 | Epoch [1/1] | Batch [557/597] | Loss G: 2.9973 | Loss DX: 0.2005 | Loss DY: 0.1670
# Step 1 | alpha 0.9330 | Epoch [1/1] | Batch [558/597] | Loss G: 3.1437 | Loss DX: 0.2460 | Loss DY: 0.1954
# Step 1 | alpha 0.9347 | Epoch [1/1] | Batch [559/597] | Loss G: 3.7799 | Loss DX: 0.2170 | Loss DY: 0.2259
# Step 1 | alpha 0.9363 | Epoch [1/1] | Batch [560/597] | Loss G: 4.6126 | Loss DX: 0.2172 | Loss DY: 0.2717
# Step 1 | alpha 0.9380 | Epoch [1/1] | Batch [561/597] | Loss G: 4.4453 | Loss DX: 0.2434 | Loss DY: 0.3058
# Step 1 | alpha 0.9397 | Epoch [1/1] | Batch [562/597] | Loss G: 3.6382 | Loss DX: 0.2396 | Loss DY: 0.2846
# Step 1 | alpha 0.9414 | Epoch [1/1] | Batch [563/597] | Loss G: 3.9430 | Loss DX: 0.2333 | Loss DY: 0.2848
# Step 1 | alpha 0.9430 | Epoch [1/1] | Batch [564/597] | Loss G: 2.9734 | Loss DX: 0.2191 | Loss DY: 0.2522
# Step 1 | alpha 0.9447 | Epoch [1/1] | Batch [565/597] | Loss G: 2.7445 | Loss DX: 0.2800 | Loss DY: 0.2596
# Step 1 | alpha 0.9464 | Epoch [1/1] | Batch [566/597] | Loss G: 2.3793 | Loss DX: 0.2944 | Loss DY: 0.2535
# Step 1 | alpha 0.9481 | Epoch [1/1] | Batch [567/597] | Loss G: 4.2732 | Loss DX: 0.2211 | Loss DY: 0.2168
# Step 1 | alpha 0.9497 | Epoch [1/1] | Batch [568/597] | Loss G: 3.3081 | Loss DX: 0.2169 | Loss DY: 0.2131
# Step 1 | alpha 0.9514 | Epoch [1/1] | Batch [569/597] | Loss G: 3.3553 | Loss DX: 0.2288 | Loss DY: 0.2522
# Step 1 | alpha 0.9531 | Epoch [1/1] | Batch [570/597] | Loss G: 4.1845 | Loss DX: 0.1930 | Loss DY: 0.2132
# Step 1 | alpha 0.9548 | Epoch [1/1] | Batch [571/597] | Loss G: 4.2432 | Loss DX: 0.2322 | Loss DY: 0.2237
# Step 1 | alpha 0.9564 | Epoch [1/1] | Batch [572/597] | Loss G: 4.2974 | Loss DX: 0.2383 | Loss DY: 0.2367
# Step 1 | alpha 0.9581 | Epoch [1/1] | Batch [573/597] | Loss G: 3.3069 | Loss DX: 0.1528 | Loss DY: 0.1763
# Step 1 | alpha 0.9598 | Epoch [1/1] | Batch [574/597] | Loss G: 3.3742 | Loss DX: 0.2254 | Loss DY: 0.2132
# Step 1 | alpha 0.9615 | Epoch [1/1] | Batch [575/597] | Loss G: 3.1654 | Loss DX: 0.2110 | Loss DY: 0.2148
# Step 1 | alpha 0.9631 | Epoch [1/1] | Batch [576/597] | Loss G: 3.0862 | Loss DX: 0.1702 | Loss DY: 0.2341
# Step 1 | alpha 0.9648 | Epoch [1/1] | Batch [577/597] | Loss G: 3.1286 | Loss DX: 0.1869 | Loss DY: 0.2207
# Step 1 | alpha 0.9665 | Epoch [1/1] | Batch [578/597] | Loss G: 3.7327 | Loss DX: 0.2403 | Loss DY: 0.2567
# Step 1 | alpha 0.9682 | Epoch [1/1] | Batch [579/597] | Loss G: 3.1590 | Loss DX: 0.3232 | Loss DY: 0.2429
# Step 1 | alpha 0.9698 | Epoch [1/1] | Batch [580/597] | Loss G: 3.2271 | Loss DX: 0.2213 | Loss DY: 0.2228
# Step 1 | alpha 0.9715 | Epoch [1/1] | Batch [581/597] | Loss G: 2.5336 | Loss DX: 0.2432 | Loss DY: 0.2359
# Step 1 | alpha 0.9732 | Epoch [1/1] | Batch [582/597] | Loss G: 3.3253 | Loss DX: 0.2155 | Loss DY: 0.2341
# Step 1 | alpha 0.9749 | Epoch [1/1] | Batch [583/597] | Loss G: 3.1060 | Loss DX: 0.2199 | Loss DY: 0.2222
# Step 1 | alpha 0.9765 | Epoch [1/1] | Batch [584/597] | Loss G: 3.2966 | Loss DX: 0.2224 | Loss DY: 0.2151
# Step 1 | alpha 0.9782 | Epoch [1/1] | Batch [585/597] | Loss G: 4.4320 | Loss DX: 0.2568 | Loss DY: 0.1827
# Step 1 | alpha 0.9799 | Epoch [1/1] | Batch [586/597] | Loss G: 4.8382 | Loss DX: 0.1757 | Loss DY: 0.2087
# Step 1 | alpha 0.9816 | Epoch [1/1] | Batch [587/597] | Loss G: 2.7797 | Loss DX: 0.2122 | Loss DY: 0.2268
# Step 1 | alpha 0.9832 | Epoch [1/1] | Batch [588/597] | Loss G: 3.4623 | Loss DX: 0.2316 | Loss DY: 0.2367
# Step 1 | alpha 0.9849 | Epoch [1/1] | Batch [589/597] | Loss G: 3.7468 | Loss DX: 0.1882 | Loss DY: 0.2217
# Step 1 | alpha 0.9866 | Epoch [1/1] | Batch [590/597] | Loss G: 3.2936 | Loss DX: 0.2418 | Loss DY: 0.2155
# Step 1 | alpha 0.9883 | Epoch [1/1] | Batch [591/597] | Loss G: 4.1477 | Loss DX: 0.2091 | Loss DY: 0.2285
# Step 1 | alpha 0.9899 | Epoch [1/1] | Batch [592/597] | Loss G: 3.6897 | Loss DX: 0.2972 | Loss DY: 0.2477
# Step 1 | alpha 0.9916 | Epoch [1/1] | Batch [593/597] | Loss G: 4.0360 | Loss DX: 0.2326 | Loss DY: 0.2200
# Step 1 | alpha 0.9933 | Epoch [1/1] | Batch [594/597] | Loss G: 3.7085 | Loss DX: 0.2018 | Loss DY: 0.1925
# Step 1 | alpha 0.9950 | Epoch [1/1] | Batch [595/597] | Loss G: 4.7359 | Loss DX: 0.2142 | Loss DY: 0.2295
# Step 1 | alpha 0.9966 | Epoch [1/1] | Batch [596/597] | Loss G: 4.0364 | Loss DX: 0.2294 | Loss DY: 0.1820
# Step 1 | alpha 0.9983 | Epoch [1/1] | Batch [597/597] | Loss G: 3.6403 | Loss DX: 0.1685 | Loss DY: 0.1804

# %%
trainer.train(dataloaders=(lsun_loader, monet_loader), n_epochs=1, step=1, fixed_alpha=1.0)
# Out:
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [1/597] | Loss G: 3.3913 | Loss DX: 0.2246 | Loss DY: 0.1611
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [2/597] | Loss G: 3.3584 | Loss DX: 0.2147 | Loss DY: 0.1996
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [3/597] | Loss G: 3.5445 | Loss DX: 0.2314 | Loss DY: 0.2325
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [4/597] | Loss G: 4.5586 | Loss DX: 0.2210 | Loss DY: 0.2709
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [5/597] | Loss G: 4.6000 | Loss DX: 0.2108 | Loss DY: 0.2560
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [6/597] | Loss G: 4.0950 | Loss DX: 0.2018 | Loss DY: 0.2179
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [7/597] | Loss G: 3.2651 | Loss DX: 0.1840 | Loss DY: 0.2328
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [8/597] | Loss G: 4.2323 | Loss DX: 0.1450 | Loss DY: 0.2117
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [9/597] | Loss G: 3.8035 | Loss DX: 0.2376 | Loss DY: 0.2096
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [10/597] | Loss G: 3.2322 | Loss DX: 0.1830 | Loss DY: 0.1766
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [11/597] | Loss G: 3.8770 | Loss DX: 0.2185 | Loss DY: 0.1765
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [12/597] | Loss G: 3.4949 | Loss DX: 0.2849 | Loss DY: 0.2417
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [13/597] | Loss G: 2.8267 | Loss DX: 0.1851 | Loss DY: 0.1665
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [14/597] | Loss G: 3.5657 | Loss DX: 0.2471 | Loss DY: 0.2678
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [15/597] | Loss G: 3.9390 | Loss DX: 0.2299 | Loss DY: 0.2671
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [16/597] | Loss G: 3.2809 | Loss DX: 0.2090 | Loss DY: 0.2366
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [17/597] | Loss G: 3.8081 | Loss DX: 0.2128 | Loss DY: 0.2907
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [18/597] | Loss G: 3.7662 | Loss DX: 0.1721 | Loss DY: 0.2206
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [19/597] | Loss G: 3.5108 | Loss DX: 0.2378 | Loss DY: 0.2527
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [20/597] | Loss G: 3.3137 | Loss DX: 0.2367 | Loss DY: 0.2083
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [21/597] | Loss G: 3.0575 | Loss DX: 0.1955 | Loss DY: 0.2307
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [22/597] | Loss G: 3.3929 | Loss DX: 0.1997 | Loss DY: 0.2388
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [23/597] | Loss G: 3.2348 | Loss DX: 0.2488 | Loss DY: 0.2267
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [24/597] | Loss G: 3.7401 | Loss DX: 0.1425 | Loss DY: 0.2695
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [25/597] | Loss G: 3.8971 | Loss DX: 0.3154 | Loss DY: 0.2406
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [26/597] | Loss G: 3.6472 | Loss DX: 0.3588 | Loss DY: 0.2395
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [27/597] | Loss G: 3.0119 | Loss DX: 0.2033 | Loss DY: 0.2046
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [28/597] | Loss G: 2.6464 | Loss DX: 0.2535 | Loss DY: 0.2591
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [29/597] | Loss G: 3.2017 | Loss DX: 0.2071 | Loss DY: 0.2436
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [30/597] | Loss G: 2.8090 | Loss DX: 0.2588 | Loss DY: 0.2421
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [31/597] | Loss G: 3.6156 | Loss DX: 0.2443 | Loss DY: 0.2484
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [32/597] | Loss G: 3.3378 | Loss DX: 0.2344 | Loss DY: 0.2374
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [33/597] | Loss G: 5.8972 | Loss DX: 0.2930 | Loss DY: 0.2275
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [34/597] | Loss G: 3.0550 | Loss DX: 0.2028 | Loss DY: 0.2130
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [35/597] | Loss G: 3.6325 | Loss DX: 0.2308 | Loss DY: 0.2220
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [36/597] | Loss G: 3.6498 | Loss DX: 0.2562 | Loss DY: 0.2353
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [37/597] | Loss G: 4.3451 | Loss DX: 0.2766 | Loss DY: 0.2863
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [38/597] | Loss G: 3.7585 | Loss DX: 0.2085 | Loss DY: 0.2508
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [39/597] | Loss G: 3.6718 | Loss DX: 0.2219 | Loss DY: 0.2124
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [40/597] | Loss G: 3.3216 | Loss DX: 0.2455 | Loss DY: 0.2409
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [41/597] | Loss G: 4.2265 | Loss DX: 0.2220 | Loss DY: 0.2323
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [42/597] | Loss G: 3.6799 | Loss DX: 0.2424 | Loss DY: 0.2217
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [43/597] | Loss G: 5.4389 | Loss DX: 0.2283 | Loss DY: 0.2343
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [44/597] | Loss G: 4.2300 | Loss DX: 0.2174 | Loss DY: 0.2134
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [45/597] | Loss G: 3.6410 | Loss DX: 0.2311 | Loss DY: 0.2388
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [46/597] | Loss G: 5.4846 | Loss DX: 0.2882 | Loss DY: 0.2386
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [47/597] | Loss G: 4.1011 | Loss DX: 0.2169 | Loss DY: 0.2165
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [48/597] | Loss G: 3.6627 | Loss DX: 0.2472 | Loss DY: 0.2513
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [49/597] | Loss G: 3.3469 | Loss DX: 0.2433 | Loss DY: 0.2431
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [50/597] | Loss G: 3.9737 | Loss DX: 0.2340 | Loss DY: 0.2321
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [51/597] | Loss G: 3.3424 | Loss DX: 0.2996 | Loss DY: 0.2473
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [52/597] | Loss G: 3.2593 | Loss DX: 0.2001 | Loss DY: 0.1801
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [53/597] | Loss G: 3.4194 | Loss DX: 0.2359 | Loss DY: 0.2633
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [54/597] | Loss G: 3.9446 | Loss DX: 0.2454 | Loss DY: 0.2146
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [55/597] | Loss G: 2.7847 | Loss DX: 0.2017 | Loss DY: 0.2171
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [56/597] | Loss G: 3.0376 | Loss DX: 0.2474 | Loss DY: 0.2450
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [57/597] | Loss G: 4.3126 | Loss DX: 0.2494 | Loss DY: 0.2839
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [58/597] | Loss G: 3.0471 | Loss DX: 0.2128 | Loss DY: 0.2488
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [59/597] | Loss G: 3.4777 | Loss DX: 0.2087 | Loss DY: 0.2191
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [60/597] | Loss G: 3.9736 | Loss DX: 0.2081 | Loss DY: 0.2516
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [61/597] | Loss G: 3.6880 | Loss DX: 0.2151 | Loss DY: 0.2030
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [62/597] | Loss G: 3.6473 | Loss DX: 0.1591 | Loss DY: 0.1989
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [63/597] | Loss G: 2.7650 | Loss DX: 0.2525 | Loss DY: 0.2311
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [64/597] | Loss G: 3.9557 | Loss DX: 0.3013 | Loss DY: 0.2661
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [65/597] | Loss G: 4.2094 | Loss DX: 0.1966 | Loss DY: 0.2252
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [66/597] | Loss G: 4.1784 | Loss DX: 0.2248 | Loss DY: 0.2197
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [67/597] | Loss G: 4.8596 | Loss DX: 0.2307 | Loss DY: 0.2409
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [68/597] | Loss G: 4.3989 | Loss DX: 0.2299 | Loss DY: 0.2287
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [69/597] | Loss G: 3.4345 | Loss DX: 0.2241 | Loss DY: 0.2088
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [70/597] | Loss G: 3.8289 | Loss DX: 0.1978 | Loss DY: 0.2236
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [71/597] | Loss G: 3.9383 | Loss DX: 0.2144 | Loss DY: 0.2535
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [72/597] | Loss G: 5.0697 | Loss DX: 0.2593 | Loss DY: 0.2133
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [73/597] | Loss G: 4.0373 | Loss DX: 0.2150 | Loss DY: 0.1768
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [74/597] | Loss G: 3.8297 | Loss DX: 0.2237 | Loss DY: 0.2306
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [75/597] | Loss G: 3.6829 | Loss DX: 0.2251 | Loss DY: 0.2209
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [76/597] | Loss G: 4.4591 | Loss DX: 0.1177 | Loss DY: 0.1517
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [77/597] | Loss G: 3.6301 | Loss DX: 0.2564 | Loss DY: 0.2465
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [78/597] | Loss G: 5.0634 | Loss DX: 0.1665 | Loss DY: 0.1875
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [79/597] | Loss G: 4.1729 | Loss DX: 0.1804 | Loss DY: 0.2284
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [80/597] | Loss G: 3.4943 | Loss DX: 0.2398 | Loss DY: 0.2653
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [81/597] | Loss G: 3.8751 | Loss DX: 0.2325 | Loss DY: 0.2814
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [82/597] | Loss G: 3.6082 | Loss DX: 0.1838 | Loss DY: 0.1980
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [83/597] | Loss G: 4.1930 | Loss DX: 0.1942 | Loss DY: 0.2170
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [84/597] | Loss G: 3.6550 | Loss DX: 0.1991 | Loss DY: 0.1871
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [85/597] | Loss G: 3.0923 | Loss DX: 0.2304 | Loss DY: 0.2288
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [86/597] | Loss G: 2.9600 | Loss DX: 0.1985 | Loss DY: 0.2092
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [87/597] | Loss G: 3.3067 | Loss DX: 0.1789 | Loss DY: 0.2110
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [88/597] | Loss G: 3.5422 | Loss DX: 0.2372 | Loss DY: 0.2490
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [89/597] | Loss G: 4.4062 | Loss DX: 0.2988 | Loss DY: 0.2282
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [90/597] | Loss G: 4.3644 | Loss DX: 0.2014 | Loss DY: 0.2505
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [91/597] | Loss G: 3.6737 | Loss DX: 0.2321 | Loss DY: 0.2396
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [92/597] | Loss G: 3.7728 | Loss DX: 0.2094 | Loss DY: 0.2268
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [93/597] | Loss G: 2.8194 | Loss DX: 0.2622 | Loss DY: 0.2452
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [94/597] | Loss G: 4.1408 | Loss DX: 0.2528 | Loss DY: 0.1905
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [95/597] | Loss G: 3.9430 | Loss DX: 0.2201 | Loss DY: 0.2180
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [96/597] | Loss G: 3.7868 | Loss DX: 0.2212 | Loss DY: 0.2618
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [97/597] | Loss G: 2.3722 | Loss DX: 0.2295 | Loss DY: 0.2703
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [98/597] | Loss G: 3.1077 | Loss DX: 0.2183 | Loss DY: 0.1991
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [99/597] | Loss G: 5.4642 | Loss DX: 0.1618 | Loss DY: 0.1891
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [100/597] | Loss G: 3.5939 | Loss DX: 0.2169 | Loss DY: 0.2279
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [101/597] | Loss G: 3.9781 | Loss DX: 0.2377 | Loss DY: 0.2213
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [102/597] | Loss G: 3.0593 | Loss DX: 0.2702 | Loss DY: 0.2596
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [103/597] | Loss G: 4.2132 | Loss DX: 0.2056 | Loss DY: 0.2741
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [104/597] | Loss G: 3.1794 | Loss DX: 0.2766 | Loss DY: 0.2426
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [105/597] | Loss G: 3.5869 | Loss DX: 0.1778 | Loss DY: 0.1963
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [106/597] | Loss G: 4.5816 | Loss DX: 0.1576 | Loss DY: 0.2469
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [107/597] | Loss G: 3.8359 | Loss DX: 0.1670 | Loss DY: 0.2129
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [108/597] | Loss G: 4.0665 | Loss DX: 0.1760 | Loss DY: 0.2115
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [109/597] | Loss G: 4.3113 | Loss DX: 0.1599 | Loss DY: 0.2205
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [110/597] | Loss G: 3.4593 | Loss DX: 0.2134 | Loss DY: 0.2127
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [111/597] | Loss G: 3.3958 | Loss DX: 0.1685 | Loss DY: 0.2076
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [112/597] | Loss G: 3.4168 | Loss DX: 0.3367 | Loss DY: 0.2177
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [113/597] | Loss G: 3.7293 | Loss DX: 0.2089 | Loss DY: 0.2151
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [114/597] | Loss G: 3.7267 | Loss DX: 0.2486 | Loss DY: 0.2303
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [115/597] | Loss G: 3.3900 | Loss DX: 0.2197 | Loss DY: 0.2091
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [116/597] | Loss G: 3.2659 | Loss DX: 0.2735 | Loss DY: 0.2088
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [117/597] | Loss G: 3.2731 | Loss DX: 0.2202 | Loss DY: 0.2043
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [118/597] | Loss G: 4.2862 | Loss DX: 0.2322 | Loss DY: 0.1758
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [119/597] | Loss G: 4.1231 | Loss DX: 0.1559 | Loss DY: 0.1676
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [120/597] | Loss G: 3.2742 | Loss DX: 0.2571 | Loss DY: 0.2868
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [121/597] | Loss G: 2.8840 | Loss DX: 0.2082 | Loss DY: 0.2006
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [122/597] | Loss G: 3.2579 | Loss DX: 0.2604 | Loss DY: 0.2546
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [123/597] | Loss G: 3.4723 | Loss DX: 0.1755 | Loss DY: 0.2309
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [124/597] | Loss G: 3.6125 | Loss DX: 0.2527 | Loss DY: 0.2202
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [125/597] | Loss G: 3.0817 | Loss DX: 0.2744 | Loss DY: 0.3033
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [126/597] | Loss G: 3.3188 | Loss DX: 0.2872 | Loss DY: 0.2790
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [127/597] | Loss G: 3.2480 | Loss DX: 0.1920 | Loss DY: 0.2216
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [128/597] | Loss G: 3.7539 | Loss DX: 0.2490 | Loss DY: 0.2516
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [129/597] | Loss G: 4.1038 | Loss DX: 0.2370 | Loss DY: 0.2910
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [130/597] | Loss G: 4.5871 | Loss DX: 0.2808 | Loss DY: 0.2693
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [131/597] | Loss G: 2.8113 | Loss DX: 0.2233 | Loss DY: 0.2414
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [132/597] | Loss G: 3.9758 | Loss DX: 0.2320 | Loss DY: 0.2714
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [133/597] | Loss G: 4.3176 | Loss DX: 0.2140 | Loss DY: 0.2421
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [134/597] | Loss G: 2.7210 | Loss DX: 0.2422 | Loss DY: 0.2486
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [135/597] | Loss G: 3.2609 | Loss DX: 0.2351 | Loss DY: 0.2382
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [136/597] | Loss G: 3.2371 | Loss DX: 0.2491 | Loss DY: 0.2464
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [137/597] | Loss G: 3.7320 | Loss DX: 0.2368 | Loss DY: 0.2620
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [138/597] | Loss G: 4.0809 | Loss DX: 0.2009 | Loss DY: 0.2207
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [139/597] | Loss G: 4.3326 | Loss DX: 0.1909 | Loss DY: 0.2166
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [140/597] | Loss G: 3.6024 | Loss DX: 0.1596 | Loss DY: 0.2044
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [141/597] | Loss G: 3.9465 | Loss DX: 0.2507 | Loss DY: 0.2284
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [142/597] | Loss G: 3.6742 | Loss DX: 0.2294 | Loss DY: 0.2049
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [143/597] | Loss G: 3.8739 | Loss DX: 0.1723 | Loss DY: 0.2339
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [144/597] | Loss G: 4.0075 | Loss DX: 0.1482 | Loss DY: 0.2148
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [145/597] | Loss G: 3.2613 | Loss DX: 0.2467 | Loss DY: 0.2175
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [146/597] | Loss G: 4.8136 | Loss DX: 0.2534 | Loss DY: 0.2234
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [147/597] | Loss G: 3.4672 | Loss DX: 0.2128 | Loss DY: 0.2290
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [148/597] | Loss G: 2.9318 | Loss DX: 0.1897 | Loss DY: 0.1975
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [149/597] | Loss G: 4.5498 | Loss DX: 0.1962 | Loss DY: 0.2228
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [150/597] | Loss G: 3.3597 | Loss DX: 0.1420 | Loss DY: 0.2053
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [151/597] | Loss G: 3.5682 | Loss DX: 0.1268 | Loss DY: 0.1690
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [152/597] | Loss G: 3.2718 | Loss DX: 0.2122 | Loss DY: 0.2080
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [153/597] | Loss G: 3.3396 | Loss DX: 0.2585 | Loss DY: 0.2241
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [154/597] | Loss G: 3.3177 | Loss DX: 0.2000 | Loss DY: 0.2231
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [155/597] | Loss G: 3.2869 | Loss DX: 0.1586 | Loss DY: 0.1697
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [156/597] | Loss G: 3.6691 | Loss DX: 0.2933 | Loss DY: 0.2658
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [157/597] | Loss G: 2.5680 | Loss DX: 0.1984 | Loss DY: 0.2047
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [158/597] | Loss G: 2.9465 | Loss DX: 0.2575 | Loss DY: 0.2865
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [159/597] | Loss G: 2.7718 | Loss DX: 0.1635 | Loss DY: 0.2092
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [160/597] | Loss G: 3.3197 | Loss DX: 0.1780 | Loss DY: 0.1733
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [161/597] | Loss G: 4.3049 | Loss DX: 0.2104 | Loss DY: 0.2236
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [162/597] | Loss G: 3.7017 | Loss DX: 0.3032 | Loss DY: 0.2532
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [163/597] | Loss G: 5.3335 | Loss DX: 0.1123 | Loss DY: 0.1866
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [164/597] | Loss G: 3.4695 | Loss DX: 0.1853 | Loss DY: 0.1933
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [165/597] | Loss G: 4.7738 | Loss DX: 0.2408 | Loss DY: 0.2287
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [166/597] | Loss G: 3.2337 | Loss DX: 0.2252 | Loss DY: 0.1934
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [167/597] | Loss G: 3.5815 | Loss DX: 0.2867 | Loss DY: 0.2192
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [168/597] | Loss G: 2.9301 | Loss DX: 0.2086 | Loss DY: 0.1687
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [169/597] | Loss G: 4.4266 | Loss DX: 0.2008 | Loss DY: 0.2254
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [170/597] | Loss G: 3.7809 | Loss DX: 0.1943 | Loss DY: 0.2469
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [171/597] | Loss G: 2.9547 | Loss DX: 0.1982 | Loss DY: 0.1956
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [172/597] | Loss G: 3.1380 | Loss DX: 0.2342 | Loss DY: 0.2108
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [173/597] | Loss G: 3.6958 | Loss DX: 0.1915 | Loss DY: 0.2422
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [174/597] | Loss G: 3.5041 | Loss DX: 0.1644 | Loss DY: 0.1921
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [175/597] | Loss G: 3.4316 | Loss DX: 0.2694 | Loss DY: 0.2389
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [176/597] | Loss G: 3.4207 | Loss DX: 0.2147 | Loss DY: 0.2250
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [177/597] | Loss G: 3.1889 | Loss DX: 0.1471 | Loss DY: 0.1983
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [178/597] | Loss G: 3.8871 | Loss DX: 0.2312 | Loss DY: 0.2364
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [179/597] | Loss G: 3.4311 | Loss DX: 0.2382 | Loss DY: 0.2822
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [180/597] | Loss G: 3.9713 | Loss DX: 0.2856 | Loss DY: 0.2760
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [181/597] | Loss G: 3.4776 | Loss DX: 0.2713 | Loss DY: 0.2494
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [182/597] | Loss G: 3.2020 | Loss DX: 0.2125 | Loss DY: 0.2674
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [183/597] | Loss G: 3.6225 | Loss DX: 0.2782 | Loss DY: 0.2328
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [184/597] | Loss G: 2.9194 | Loss DX: 0.2370 | Loss DY: 0.2362
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [185/597] | Loss G: 4.3817 | Loss DX: 0.2162 | Loss DY: 0.2361
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [186/597] | Loss G: 3.9367 | Loss DX: 0.2610 | Loss DY: 0.2607
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [187/597] | Loss G: 3.9437 | Loss DX: 0.2316 | Loss DY: 0.2110
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [188/597] | Loss G: 4.5162 | Loss DX: 0.2593 | Loss DY: 0.2643
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [189/597] | Loss G: 2.9084 | Loss DX: 0.1845 | Loss DY: 0.2278
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [190/597] | Loss G: 3.2878 | Loss DX: 0.2181 | Loss DY: 0.2318
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [191/597] | Loss G: 4.5627 | Loss DX: 0.2028 | Loss DY: 0.2294
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [192/597] | Loss G: 3.2135 | Loss DX: 0.2687 | Loss DY: 0.2105
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [193/597] | Loss G: 2.8785 | Loss DX: 0.2677 | Loss DY: 0.2441
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [194/597] | Loss G: 3.0273 | Loss DX: 0.2697 | Loss DY: 0.2330
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [195/597] | Loss G: 3.2089 | Loss DX: 0.2187 | Loss DY: 0.1953
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [196/597] | Loss G: 3.4050 | Loss DX: 0.2137 | Loss DY: 0.2265
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [197/597] | Loss G: 3.4170 | Loss DX: 0.2036 | Loss DY: 0.2048
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [198/597] | Loss G: 3.7522 | Loss DX: 0.2020 | Loss DY: 0.1991
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [199/597] | Loss G: 3.5814 | Loss DX: 0.1660 | Loss DY: 0.2049
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [200/597] | Loss G: 3.3070 | Loss DX: 0.1955 | Loss DY: 0.2020
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [201/597] | Loss G: 3.6596 | Loss DX: 0.2282 | Loss DY: 0.2220
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [202/597] | Loss G: 3.2597 | Loss DX: 0.2418 | Loss DY: 0.2339
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [203/597] | Loss G: 3.4557 | Loss DX: 0.2829 | Loss DY: 0.2578
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [204/597] | Loss G: 3.3341 | Loss DX: 0.2196 | Loss DY: 0.2164
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [205/597] | Loss G: 3.7961 | Loss DX: 0.1910 | Loss DY: 0.2317
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [206/597] | Loss G: 3.9423 | Loss DX: 0.2113 | Loss DY: 0.2367
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [207/597] | Loss G: 3.9963 | Loss DX: 0.2263 | Loss DY: 0.2284
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [208/597] | Loss G: 3.6440 | Loss DX: 0.3131 | Loss DY: 0.2869
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [209/597] | Loss G: 3.2111 | Loss DX: 0.2598 | Loss DY: 0.2207
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [210/597] | Loss G: 2.9544 | Loss DX: 0.2369 | Loss DY: 0.2736
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [211/597] | Loss G: 4.2689 | Loss DX: 0.2598 | Loss DY: 0.2736
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [212/597] | Loss G: 2.4743 | Loss DX: 0.2274 | Loss DY: 0.2484
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [213/597] | Loss G: 2.7811 | Loss DX: 0.2189 | Loss DY: 0.2100
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [214/597] | Loss G: 3.9683 | Loss DX: 0.2181 | Loss DY: 0.2461
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [215/597] | Loss G: 4.7278 | Loss DX: 0.2247 | Loss DY: 0.2270
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [216/597] | Loss G: 3.3226 | Loss DX: 0.2397 | Loss DY: 0.2352
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [217/597] | Loss G: 3.1603 | Loss DX: 0.2360 | Loss DY: 0.2337
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [218/597] | Loss G: 3.1279 | Loss DX: 0.2300 | Loss DY: 0.2540
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [219/597] | Loss G: 2.9716 | Loss DX: 0.2217 | Loss DY: 0.2326
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [220/597] | Loss G: 3.8461 | Loss DX: 0.2215 | Loss DY: 0.2244
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [221/597] | Loss G: 3.7622 | Loss DX: 0.2185 | Loss DY: 0.2368
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [222/597] | Loss G: 3.0125 | Loss DX: 0.1957 | Loss DY: 0.2195
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [223/597] | Loss G: 2.8686 | Loss DX: 0.2234 | Loss DY: 0.2210
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [224/597] | Loss G: 3.7597 | Loss DX: 0.2296 | Loss DY: 0.2452
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [225/597] | Loss G: 2.8574 | Loss DX: 0.1718 | Loss DY: 0.2061
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [226/597] | Loss G: 3.3425 | Loss DX: 0.2163 | Loss DY: 0.1965
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [227/597] | Loss G: 2.9881 | Loss DX: 0.1920 | Loss DY: 0.2046
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [228/597] | Loss G: 3.0496 | Loss DX: 0.2470 | Loss DY: 0.2258
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [229/597] | Loss G: 2.5614 | Loss DX: 0.2093 | Loss DY: 0.2623
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [230/597] | Loss G: 3.4541 | Loss DX: 0.2120 | Loss DY: 0.1963
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [231/597] | Loss G: 4.1144 | Loss DX: 0.2350 | Loss DY: 0.1914
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [232/597] | Loss G: 3.6658 | Loss DX: 0.2354 | Loss DY: 0.2344
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [233/597] | Loss G: 3.4325 | Loss DX: 0.2105 | Loss DY: 0.2067
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [234/597] | Loss G: 3.3869 | Loss DX: 0.3140 | Loss DY: 0.1883
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [235/597] | Loss G: 3.3712 | Loss DX: 0.2000 | Loss DY: 0.1568
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [236/597] | Loss G: 3.9107 | Loss DX: 0.1888 | Loss DY: 0.1723
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [237/597] | Loss G: 2.7032 | Loss DX: 0.1938 | Loss DY: 0.2507
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [238/597] | Loss G: 4.1972 | Loss DX: 0.2255 | Loss DY: 0.2360
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [239/597] | Loss G: 4.1184 | Loss DX: 0.2822 | Loss DY: 0.3699
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [240/597] | Loss G: 3.0000 | Loss DX: 0.2503 | Loss DY: 0.2539
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [241/597] | Loss G: 2.7054 | Loss DX: 0.2348 | Loss DY: 0.2698
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [242/597] | Loss G: 4.4715 | Loss DX: 0.1544 | Loss DY: 0.2329
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [243/597] | Loss G: 3.2912 | Loss DX: 0.1915 | Loss DY: 0.2212
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [244/597] | Loss G: 3.3399 | Loss DX: 0.1998 | Loss DY: 0.2071
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [245/597] | Loss G: 4.2557 | Loss DX: 0.2620 | Loss DY: 0.1940
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [246/597] | Loss G: 3.2333 | Loss DX: 0.1498 | Loss DY: 0.2919
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [247/597] | Loss G: 4.4017 | Loss DX: 0.1173 | Loss DY: 0.1723
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [248/597] | Loss G: 3.4310 | Loss DX: 0.2390 | Loss DY: 0.2182
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [249/597] | Loss G: 3.8106 | Loss DX: 0.2319 | Loss DY: 0.2231
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [250/597] | Loss G: 2.9890 | Loss DX: 0.3347 | Loss DY: 0.2805
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [251/597] | Loss G: 2.8476 | Loss DX: 0.2610 | Loss DY: 0.2450
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [252/597] | Loss G: 2.8387 | Loss DX: 0.2338 | Loss DY: 0.2533
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [253/597] | Loss G: 3.1528 | Loss DX: 0.1723 | Loss DY: 0.2199
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [254/597] | Loss G: 3.0142 | Loss DX: 0.1396 | Loss DY: 0.2179
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [255/597] | Loss G: 5.3632 | Loss DX: 0.2241 | Loss DY: 0.2250
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [256/597] | Loss G: 3.7053 | Loss DX: 0.3359 | Loss DY: 0.2434
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [257/597] | Loss G: 4.1567 | Loss DX: 0.2146 | Loss DY: 0.2137
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [258/597] | Loss G: 4.6468 | Loss DX: 0.2600 | Loss DY: 0.2312
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [259/597] | Loss G: 3.4479 | Loss DX: 0.2470 | Loss DY: 0.2381
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [260/597] | Loss G: 5.0489 | Loss DX: 0.2808 | Loss DY: 0.2282
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [261/597] | Loss G: 3.1525 | Loss DX: 0.2151 | Loss DY: 0.2371
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [262/597] | Loss G: 4.1991 | Loss DX: 0.2046 | Loss DY: 0.2282
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [263/597] | Loss G: 3.5423 | Loss DX: 0.2015 | Loss DY: 0.2299
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [264/597] | Loss G: 4.4903 | Loss DX: 0.2412 | Loss DY: 0.2513
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [265/597] | Loss G: 5.1530 | Loss DX: 0.2239 | Loss DY: 0.2750
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [266/597] | Loss G: 3.1388 | Loss DX: 0.2954 | Loss DY: 0.2421
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [267/597] | Loss G: 3.1208 | Loss DX: 0.2654 | Loss DY: 0.2711
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [268/597] | Loss G: 4.3250 | Loss DX: 0.1968 | Loss DY: 0.2127
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [269/597] | Loss G: 3.8455 | Loss DX: 0.2038 | Loss DY: 0.1886
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [270/597] | Loss G: 3.5236 | Loss DX: 0.2291 | Loss DY: 0.2098
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [271/597] | Loss G: 3.4118 | Loss DX: 0.2232 | Loss DY: 0.1747
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [272/597] | Loss G: 5.3163 | Loss DX: 0.1753 | Loss DY: 0.1977
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [273/597] | Loss G: 4.2134 | Loss DX: 0.1858 | Loss DY: 0.2338
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [274/597] | Loss G: 3.3484 | Loss DX: 0.2151 | Loss DY: 0.1958
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [275/597] | Loss G: 3.6853 | Loss DX: 0.2689 | Loss DY: 0.2642
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [276/597] | Loss G: 3.6994 | Loss DX: 0.1502 | Loss DY: 0.1710
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [277/597] | Loss G: 4.2451 | Loss DX: 0.2495 | Loss DY: 0.2479
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [278/597] | Loss G: 3.3909 | Loss DX: 0.2095 | Loss DY: 0.2236
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [279/597] | Loss G: 2.9550 | Loss DX: 0.2309 | Loss DY: 0.2354
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [280/597] | Loss G: 2.9584 | Loss DX: 0.2496 | Loss DY: 0.2468
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [281/597] | Loss G: 4.7014 | Loss DX: 0.2264 | Loss DY: 0.2355
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [282/597] | Loss G: 3.5017 | Loss DX: 0.1994 | Loss DY: 0.2261
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [283/597] | Loss G: 3.5493 | Loss DX: 0.1556 | Loss DY: 0.1731
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [284/597] | Loss G: 3.3522 | Loss DX: 0.2217 | Loss DY: 0.2087
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [285/597] | Loss G: 3.3608 | Loss DX: 0.2303 | Loss DY: 0.2301
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [286/597] | Loss G: 3.5825 | Loss DX: 0.3284 | Loss DY: 0.3521
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [287/597] | Loss G: 3.2831 | Loss DX: 0.1845 | Loss DY: 0.2206
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [288/597] | Loss G: 3.1002 | Loss DX: 0.2538 | Loss DY: 0.2561
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [289/597] | Loss G: 3.1033 | Loss DX: 0.2110 | Loss DY: 0.2235
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [290/597] | Loss G: 3.2474 | Loss DX: 0.2476 | Loss DY: 0.2140
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [291/597] | Loss G: 3.3648 | Loss DX: 0.2849 | Loss DY: 0.2335
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [292/597] | Loss G: 3.7066 | Loss DX: 0.1952 | Loss DY: 0.2379
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [293/597] | Loss G: 3.1333 | Loss DX: 0.1721 | Loss DY: 0.1875
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [294/597] | Loss G: 3.9583 | Loss DX: 0.2116 | Loss DY: 0.1856
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [295/597] | Loss G: 4.2847 | Loss DX: 0.2770 | Loss DY: 0.2431
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [296/597] | Loss G: 4.9211 | Loss DX: 0.2491 | Loss DY: 0.2736
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [297/597] | Loss G: 3.3890 | Loss DX: 0.2118 | Loss DY: 0.2278
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [298/597] | Loss G: 2.7211 | Loss DX: 0.1959 | Loss DY: 0.2261
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [299/597] | Loss G: 3.1531 | Loss DX: 0.2307 | Loss DY: 0.2282
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [300/597] | Loss G: 3.4668 | Loss DX: 0.1831 | Loss DY: 0.2632
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [301/597] | Loss G: 3.9370 | Loss DX: 0.1804 | Loss DY: 0.2290
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [302/597] | Loss G: 3.2884 | Loss DX: 0.2044 | Loss DY: 0.2147
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [303/597] | Loss G: 3.0029 | Loss DX: 0.2369 | Loss DY: 0.2680
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [304/597] | Loss G: 3.3067 | Loss DX: 0.2245 | Loss DY: 0.2134
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [305/597] | Loss G: 4.4594 | Loss DX: 0.2056 | Loss DY: 0.2118
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [306/597] | Loss G: 3.9332 | Loss DX: 0.2068 | Loss DY: 0.2406
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [307/597] | Loss G: 2.5973 | Loss DX: 0.1706 | Loss DY: 0.2291
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [308/597] | Loss G: 3.7396 | Loss DX: 0.1974 | Loss DY: 0.2354
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [309/597] | Loss G: 3.5302 | Loss DX: 0.2381 | Loss DY: 0.1959
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [310/597] | Loss G: 4.3425 | Loss DX: 0.1086 | Loss DY: 0.2007
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [311/597] | Loss G: 2.6371 | Loss DX: 0.2436 | Loss DY: 0.2624
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [312/597] | Loss G: 2.8445 | Loss DX: 0.1590 | Loss DY: 0.2175
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [313/597] | Loss G: 3.2205 | Loss DX: 0.2366 | Loss DY: 0.2800
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [314/597] | Loss G: 4.2474 | Loss DX: 0.2228 | Loss DY: 0.2010
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [315/597] | Loss G: 2.9464 | Loss DX: 0.2028 | Loss DY: 0.2466
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [316/597] | Loss G: 3.2554 | Loss DX: 0.2394 | Loss DY: 0.2347
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [317/597] | Loss G: 5.1163 | Loss DX: 0.1482 | Loss DY: 0.2029
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [318/597] | Loss G: 3.1378 | Loss DX: 0.2854 | Loss DY: 0.2333
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [319/597] | Loss G: 3.2311 | Loss DX: 0.2324 | Loss DY: 0.2038
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [320/597] | Loss G: 4.0588 | Loss DX: 0.2165 | Loss DY: 0.2351
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [321/597] | Loss G: 3.5437 | Loss DX: 0.2868 | Loss DY: 0.2152
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [322/597] | Loss G: 3.7681 | Loss DX: 0.2111 | Loss DY: 0.1936
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [323/597] | Loss G: 3.1473 | Loss DX: 0.2155 | Loss DY: 0.2380
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [324/597] | Loss G: 3.2468 | Loss DX: 0.1932 | Loss DY: 0.2090
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [325/597] | Loss G: 3.9861 | Loss DX: 0.1610 | Loss DY: 0.1728
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [326/597] | Loss G: 4.1391 | Loss DX: 0.1979 | Loss DY: 0.2103
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [327/597] | Loss G: 3.5951 | Loss DX: 0.2033 | Loss DY: 0.2223
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [328/597] | Loss G: 5.2381 | Loss DX: 0.1720 | Loss DY: 0.1946
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [329/597] | Loss G: 3.5824 | Loss DX: 0.2249 | Loss DY: 0.2137
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [330/597] | Loss G: 4.3292 | Loss DX: 0.2346 | Loss DY: 0.2461
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [331/597] | Loss G: 2.8683 | Loss DX: 0.2720 | Loss DY: 0.2728
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [332/597] | Loss G: 3.8701 | Loss DX: 0.2121 | Loss DY: 0.2011
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [333/597] | Loss G: 2.7133 | Loss DX: 0.3120 | Loss DY: 0.2457
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [334/597] | Loss G: 3.5378 | Loss DX: 0.2378 | Loss DY: 0.2324
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [335/597] | Loss G: 3.4645 | Loss DX: 0.1646 | Loss DY: 0.1742
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [336/597] | Loss G: 4.0854 | Loss DX: 0.2444 | Loss DY: 0.2284
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [337/597] | Loss G: 3.6169 | Loss DX: 0.1834 | Loss DY: 0.1729
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [338/597] | Loss G: 3.3302 | Loss DX: 0.2282 | Loss DY: 0.2293
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [339/597] | Loss G: 3.8910 | Loss DX: 0.2228 | Loss DY: 0.2517
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [340/597] | Loss G: 3.0824 | Loss DX: 0.2225 | Loss DY: 0.2158
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [341/597] | Loss G: 3.0284 | Loss DX: 0.1675 | Loss DY: 0.2220
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [342/597] | Loss G: 3.3956 | Loss DX: 0.2352 | Loss DY: 0.2189
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [343/597] | Loss G: 3.8342 | Loss DX: 0.2367 | Loss DY: 0.2341
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [344/597] | Loss G: 3.9813 | Loss DX: 0.2561 | Loss DY: 0.2412
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [345/597] | Loss G: 3.7215 | Loss DX: 0.1870 | Loss DY: 0.1636
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [346/597] | Loss G: 2.9941 | Loss DX: 0.1960 | Loss DY: 0.2083
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [347/597] | Loss G: 4.6751 | Loss DX: 0.1841 | Loss DY: 0.1674
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [348/597] | Loss G: 2.9225 | Loss DX: 0.1977 | Loss DY: 0.1913
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [349/597] | Loss G: 3.5737 | Loss DX: 0.1974 | Loss DY: 0.1967
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [350/597] | Loss G: 4.1462 | Loss DX: 0.2205 | Loss DY: 0.2186
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [351/597] | Loss G: 4.3286 | Loss DX: 0.2066 | Loss DY: 0.3213
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [352/597] | Loss G: 3.9872 | Loss DX: 0.1972 | Loss DY: 0.2337
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [353/597] | Loss G: 3.5757 | Loss DX: 0.1855 | Loss DY: 0.2482
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [354/597] | Loss G: 3.2490 | Loss DX: 0.2224 | Loss DY: 0.2601
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [355/597] | Loss G: 2.8520 | Loss DX: 0.2452 | Loss DY: 0.2716
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [356/597] | Loss G: 4.1343 | Loss DX: 0.2106 | Loss DY: 0.2123
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [357/597] | Loss G: 2.5493 | Loss DX: 0.2083 | Loss DY: 0.2128
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [358/597] | Loss G: 3.4466 | Loss DX: 0.1768 | Loss DY: 0.2201
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [359/597] | Loss G: 3.0593 | Loss DX: 0.1471 | Loss DY: 0.2048
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [360/597] | Loss G: 4.1224 | Loss DX: 0.1751 | Loss DY: 0.2208
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [361/597] | Loss G: 3.0307 | Loss DX: 0.2473 | Loss DY: 0.2356
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [362/597] | Loss G: 3.3471 | Loss DX: 0.1584 | Loss DY: 0.1950
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [363/597] | Loss G: 2.9935 | Loss DX: 0.2088 | Loss DY: 0.2887
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [364/597] | Loss G: 3.2272 | Loss DX: 0.2452 | Loss DY: 0.2761
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [365/597] | Loss G: 3.9616 | Loss DX: 0.2092 | Loss DY: 0.2390
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [366/597] | Loss G: 2.7599 | Loss DX: 0.2925 | Loss DY: 0.2265
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [367/597] | Loss G: 3.6907 | Loss DX: 0.2690 | Loss DY: 0.1974
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [368/597] | Loss G: 4.1463 | Loss DX: 0.2430 | Loss DY: 0.2449
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [369/597] | Loss G: 3.5301 | Loss DX: 0.2523 | Loss DY: 0.2399
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [370/597] | Loss G: 3.6064 | Loss DX: 0.2171 | Loss DY: 0.1860
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [371/597] | Loss G: 3.5267 | Loss DX: 0.2161 | Loss DY: 0.2394
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [372/597] | Loss G: 3.2467 | Loss DX: 0.2298 | Loss DY: 0.2520
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [373/597] | Loss G: 3.6986 | Loss DX: 0.2562 | Loss DY: 0.2708
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [374/597] | Loss G: 3.3221 | Loss DX: 0.2163 | Loss DY: 0.2432
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [375/597] | Loss G: 2.7281 | Loss DX: 0.2420 | Loss DY: 0.2311
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [376/597] | Loss G: 2.9490 | Loss DX: 0.2175 | Loss DY: 0.2368
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [377/597] | Loss G: 3.2185 | Loss DX: 0.2042 | Loss DY: 0.2060
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [378/597] | Loss G: 2.6727 | Loss DX: 0.2714 | Loss DY: 0.2547
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [379/597] | Loss G: 3.8783 | Loss DX: 0.2375 | Loss DY: 0.2278
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [380/597] | Loss G: 3.7305 | Loss DX: 0.2291 | Loss DY: 0.2120
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [381/597] | Loss G: 3.7788 | Loss DX: 0.2565 | Loss DY: 0.2616
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [382/597] | Loss G: 4.4064 | Loss DX: 0.2087 | Loss DY: 0.2036
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [383/597] | Loss G: 3.0047 | Loss DX: 0.2209 | Loss DY: 0.1956
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [384/597] | Loss G: 2.9458 | Loss DX: 0.2086 | Loss DY: 0.2199
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [385/597] | Loss G: 3.4346 | Loss DX: 0.2746 | Loss DY: 0.3231
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [386/597] | Loss G: 2.8810 | Loss DX: 0.1953 | Loss DY: 0.2549
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [387/597] | Loss G: 3.1016 | Loss DX: 0.2270 | Loss DY: 0.2070
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [388/597] | Loss G: 3.9200 | Loss DX: 0.1721 | Loss DY: 0.2032
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [389/597] | Loss G: 3.5700 | Loss DX: 0.1500 | Loss DY: 0.2253
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [390/597] | Loss G: 3.7356 | Loss DX: 0.1893 | Loss DY: 0.2038
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [391/597] | Loss G: 2.6965 | Loss DX: 0.2465 | Loss DY: 0.2323
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [392/597] | Loss G: 3.2234 | Loss DX: 0.1541 | Loss DY: 0.2039
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [393/597] | Loss G: 3.6132 | Loss DX: 0.2353 | Loss DY: 0.2580
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [394/597] | Loss G: 3.9103 | Loss DX: 0.2213 | Loss DY: 0.1983
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [395/597] | Loss G: 3.6527 | Loss DX: 0.2270 | Loss DY: 0.2347
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [396/597] | Loss G: 3.1752 | Loss DX: 0.2645 | Loss DY: 0.2366
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [397/597] | Loss G: 4.3577 | Loss DX: 0.2369 | Loss DY: 0.2138
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [398/597] | Loss G: 4.1451 | Loss DX: 0.2331 | Loss DY: 0.2198
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [399/597] | Loss G: 3.4019 | Loss DX: 0.2348 | Loss DY: 0.2200
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [400/597] | Loss G: 3.2647 | Loss DX: 0.2160 | Loss DY: 0.2186
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [401/597] | Loss G: 4.1013 | Loss DX: 0.1825 | Loss DY: 0.2099
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [402/597] | Loss G: 4.0203 | Loss DX: 0.1213 | Loss DY: 0.1449
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [403/597] | Loss G: 3.9388 | Loss DX: 0.1796 | Loss DY: 0.2270
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [404/597] | Loss G: 3.2777 | Loss DX: 0.1681 | Loss DY: 0.1781
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [405/597] | Loss G: 4.1548 | Loss DX: 0.2123 | Loss DY: 0.2021
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [406/597] | Loss G: 3.3374 | Loss DX: 0.2426 | Loss DY: 0.2225
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [407/597] | Loss G: 3.4602 | Loss DX: 0.2586 | Loss DY: 0.2501
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [408/597] | Loss G: 4.2342 | Loss DX: 0.1392 | Loss DY: 0.2104
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [409/597] | Loss G: 3.2659 | Loss DX: 0.2035 | Loss DY: 0.3047
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [410/597] | Loss G: 3.0939 | Loss DX: 0.2626 | Loss DY: 0.2457
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [411/597] | Loss G: 3.5727 | Loss DX: 0.1275 | Loss DY: 0.1425
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [412/597] | Loss G: 2.8548 | Loss DX: 0.2262 | Loss DY: 0.2174
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [413/597] | Loss G: 3.0467 | Loss DX: 0.2068 | Loss DY: 0.2231
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [414/597] | Loss G: 3.4659 | Loss DX: 0.1709 | Loss DY: 0.2521
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [415/597] | Loss G: 3.1596 | Loss DX: 0.2607 | Loss DY: 0.2923
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [416/597] | Loss G: 3.9804 | Loss DX: 0.2548 | Loss DY: 0.2208
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [417/597] | Loss G: 2.8516 | Loss DX: 0.2299 | Loss DY: 0.2384
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [418/597] | Loss G: 3.2302 | Loss DX: 0.1971 | Loss DY: 0.1992
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [419/597] | Loss G: 3.4661 | Loss DX: 0.2122 | Loss DY: 0.1997
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [420/597] | Loss G: 3.3999 | Loss DX: 0.2050 | Loss DY: 0.2153
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [421/597] | Loss G: 3.4322 | Loss DX: 0.1498 | Loss DY: 0.2175
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [422/597] | Loss G: 2.7963 | Loss DX: 0.2506 | Loss DY: 0.2489
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [423/597] | Loss G: 3.2272 | Loss DX: 0.2264 | Loss DY: 0.2325
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [424/597] | Loss G: 3.6423 | Loss DX: 0.1868 | Loss DY: 0.2221
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [425/597] | Loss G: 2.7331 | Loss DX: 0.2074 | Loss DY: 0.2144
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [426/597] | Loss G: 3.2640 | Loss DX: 0.2212 | Loss DY: 0.2077
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [427/597] | Loss G: 4.0076 | Loss DX: 0.3047 | Loss DY: 0.2801
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [428/597] | Loss G: 4.2956 | Loss DX: 0.1559 | Loss DY: 0.2252
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [429/597] | Loss G: 3.3613 | Loss DX: 0.1299 | Loss DY: 0.1618
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [430/597] | Loss G: 3.0907 | Loss DX: 0.2637 | Loss DY: 0.2835
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [431/597] | Loss G: 3.0997 | Loss DX: 0.1665 | Loss DY: 0.1604
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [432/597] | Loss G: 3.1373 | Loss DX: 0.3053 | Loss DY: 0.2747
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [433/597] | Loss G: 2.9588 | Loss DX: 0.2330 | Loss DY: 0.2589
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [434/597] | Loss G: 4.1824 | Loss DX: 0.2427 | Loss DY: 0.1879
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [435/597] | Loss G: 3.5918 | Loss DX: 0.2159 | Loss DY: 0.1861
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [436/597] | Loss G: 3.6525 | Loss DX: 0.1261 | Loss DY: 0.1836
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [437/597] | Loss G: 3.7541 | Loss DX: 0.2139 | Loss DY: 0.2067
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [438/597] | Loss G: 4.0952 | Loss DX: 0.2521 | Loss DY: 0.3107
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [439/597] | Loss G: 3.0648 | Loss DX: 0.2441 | Loss DY: 0.2034
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [440/597] | Loss G: 3.5897 | Loss DX: 0.2602 | Loss DY: 0.2170
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [441/597] | Loss G: 3.6454 | Loss DX: 0.1747 | Loss DY: 0.1604
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [442/597] | Loss G: 3.1785 | Loss DX: 0.2250 | Loss DY: 0.2002
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [443/597] | Loss G: 4.4204 | Loss DX: 0.1893 | Loss DY: 0.2650
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [444/597] | Loss G: 2.5001 | Loss DX: 0.2706 | Loss DY: 0.2408
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [445/597] | Loss G: 3.8046 | Loss DX: 0.2012 | Loss DY: 0.2170
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [446/597] | Loss G: 3.1718 | Loss DX: 0.1543 | Loss DY: 0.2084
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [447/597] | Loss G: 3.1118 | Loss DX: 0.1941 | Loss DY: 0.2343
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [448/597] | Loss G: 3.9595 | Loss DX: 0.2063 | Loss DY: 0.2309
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [449/597] | Loss G: 3.5058 | Loss DX: 0.2541 | Loss DY: 0.2507
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [450/597] | Loss G: 4.4440 | Loss DX: 0.2051 | Loss DY: 0.2492
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [451/597] | Loss G: 3.7314 | Loss DX: 0.2729 | Loss DY: 0.2319
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [452/597] | Loss G: 3.4515 | Loss DX: 0.2383 | Loss DY: 0.2312
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [453/597] | Loss G: 2.9283 | Loss DX: 0.2001 | Loss DY: 0.1967
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [454/597] | Loss G: 4.0604 | Loss DX: 0.2395 | Loss DY: 0.2790
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [455/597] | Loss G: 3.0817 | Loss DX: 0.1722 | Loss DY: 0.2232
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [456/597] | Loss G: 3.1098 | Loss DX: 0.2635 | Loss DY: 0.2222
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [457/597] | Loss G: 3.1819 | Loss DX: 0.2051 | Loss DY: 0.2452
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [458/597] | Loss G: 3.0778 | Loss DX: 0.1973 | Loss DY: 0.2316
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [459/597] | Loss G: 3.4287 | Loss DX: 0.2645 | Loss DY: 0.2220
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [460/597] | Loss G: 3.6064 | Loss DX: 0.1437 | Loss DY: 0.2001
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [461/597] | Loss G: 3.0277 | Loss DX: 0.1661 | Loss DY: 0.2106
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [462/597] | Loss G: 3.4773 | Loss DX: 0.1754 | Loss DY: 0.2267
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [463/597] | Loss G: 3.7822 | Loss DX: 0.1501 | Loss DY: 0.1824
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [464/597] | Loss G: 3.5150 | Loss DX: 0.2233 | Loss DY: 0.1931
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [465/597] | Loss G: 3.5736 | Loss DX: 0.2953 | Loss DY: 0.2423
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [466/597] | Loss G: 3.2001 | Loss DX: 0.3124 | Loss DY: 0.2582
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [467/597] | Loss G: 3.3837 | Loss DX: 0.2346 | Loss DY: 0.2448
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [468/597] | Loss G: 3.1854 | Loss DX: 0.1780 | Loss DY: 0.2192
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [469/597] | Loss G: 4.3587 | Loss DX: 0.1994 | Loss DY: 0.1912
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [470/597] | Loss G: 3.1565 | Loss DX: 0.2246 | Loss DY: 0.2263
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [471/597] | Loss G: 3.9930 | Loss DX: 0.2345 | Loss DY: 0.2363
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [472/597] | Loss G: 4.0407 | Loss DX: 0.2384 | Loss DY: 0.2199
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [473/597] | Loss G: 2.7443 | Loss DX: 0.2091 | Loss DY: 0.2223
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [474/597] | Loss G: 3.0433 | Loss DX: 0.2007 | Loss DY: 0.2596
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [475/597] | Loss G: 3.2819 | Loss DX: 0.2521 | Loss DY: 0.2587
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [476/597] | Loss G: 3.4602 | Loss DX: 0.2453 | Loss DY: 0.2549
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [477/597] | Loss G: 4.1924 | Loss DX: 0.1832 | Loss DY: 0.1645
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [478/597] | Loss G: 3.8070 | Loss DX: 0.3191 | Loss DY: 0.2555
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [479/597] | Loss G: 3.8338 | Loss DX: 0.2351 | Loss DY: 0.1895
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [480/597] | Loss G: 4.2597 | Loss DX: 0.1946 | Loss DY: 0.2253
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [481/597] | Loss G: 3.3861 | Loss DX: 0.2358 | Loss DY: 0.2207
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [482/597] | Loss G: 3.8366 | Loss DX: 0.2291 | Loss DY: 0.2207
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [483/597] | Loss G: 6.5509 | Loss DX: 0.2413 | Loss DY: 0.2720
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [484/597] | Loss G: 3.3124 | Loss DX: 0.2147 | Loss DY: 0.1826
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [485/597] | Loss G: 3.1295 | Loss DX: 0.2611 | Loss DY: 0.2579
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [486/597] | Loss G: 4.5255 | Loss DX: 0.2176 | Loss DY: 0.1914
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [487/597] | Loss G: 3.6232 | Loss DX: 0.1946 | Loss DY: 0.1863
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [488/597] | Loss G: 3.5850 | Loss DX: 0.1909 | Loss DY: 0.2040
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [489/597] | Loss G: 2.9307 | Loss DX: 0.2503 | Loss DY: 0.2199
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [490/597] | Loss G: 4.0423 | Loss DX: 0.2324 | Loss DY: 0.1983
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [491/597] | Loss G: 3.2496 | Loss DX: 0.2820 | Loss DY: 0.2014
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [492/597] | Loss G: 2.9273 | Loss DX: 0.2412 | Loss DY: 0.2714
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [493/597] | Loss G: 2.6525 | Loss DX: 0.2060 | Loss DY: 0.2347
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [494/597] | Loss G: 2.6108 | Loss DX: 0.2223 | Loss DY: 0.2445
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [495/597] | Loss G: 3.0958 | Loss DX: 0.2355 | Loss DY: 0.2552
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [496/597] | Loss G: 2.8996 | Loss DX: 0.2271 | Loss DY: 0.2816
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [497/597] | Loss G: 2.9086 | Loss DX: 0.2621 | Loss DY: 0.3039
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [498/597] | Loss G: 3.8342 | Loss DX: 0.2657 | Loss DY: 0.2404
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [499/597] | Loss G: 3.1453 | Loss DX: 0.2213 | Loss DY: 0.2148
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [500/597] | Loss G: 3.2427 | Loss DX: 0.2276 | Loss DY: 0.2157
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [501/597] | Loss G: 3.0308 | Loss DX: 0.1441 | Loss DY: 0.1645
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [502/597] | Loss G: 2.8204 | Loss DX: 0.2093 | Loss DY: 0.2192
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [503/597] | Loss G: 3.5677 | Loss DX: 0.2210 | Loss DY: 0.2348
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [504/597] | Loss G: 3.5361 | Loss DX: 0.2156 | Loss DY: 0.1841
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [505/597] | Loss G: 3.2756 | Loss DX: 0.2476 | Loss DY: 0.2416
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [506/597] | Loss G: 2.9509 | Loss DX: 0.1708 | Loss DY: 0.1951
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [507/597] | Loss G: 3.5306 | Loss DX: 0.2309 | Loss DY: 0.1821
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [508/597] | Loss G: 3.0764 | Loss DX: 0.2181 | Loss DY: 0.2441
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [509/597] | Loss G: 3.2239 | Loss DX: 0.2055 | Loss DY: 0.2453
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [510/597] | Loss G: 3.1577 | Loss DX: 0.2264 | Loss DY: 0.2282
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [511/597] | Loss G: 3.8750 | Loss DX: 0.2528 | Loss DY: 0.2521
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [512/597] | Loss G: 2.6801 | Loss DX: 0.2940 | Loss DY: 0.3035
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [513/597] | Loss G: 3.6062 | Loss DX: 0.1822 | Loss DY: 0.2004
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [514/597] | Loss G: 3.4029 | Loss DX: 0.1461 | Loss DY: 0.1966
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [515/597] | Loss G: 3.0458 | Loss DX: 0.1386 | Loss DY: 0.2246
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [516/597] | Loss G: 3.0697 | Loss DX: 0.1919 | Loss DY: 0.2026
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [517/597] | Loss G: 3.1361 | Loss DX: 0.2056 | Loss DY: 0.2258
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [518/597] | Loss G: 3.4921 | Loss DX: 0.2266 | Loss DY: 0.2723
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [519/597] | Loss G: 3.7229 | Loss DX: 0.2675 | Loss DY: 0.2721
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [520/597] | Loss G: 3.7787 | Loss DX: 0.2369 | Loss DY: 0.2395
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [521/597] | Loss G: 3.9461 | Loss DX: 0.2976 | Loss DY: 0.2860
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [522/597] | Loss G: 2.5782 | Loss DX: 0.2250 | Loss DY: 0.2477
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [523/597] | Loss G: 3.0892 | Loss DX: 0.2793 | Loss DY: 0.2480
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [524/597] | Loss G: 3.7708 | Loss DX: 0.2522 | Loss DY: 0.1941
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [525/597] | Loss G: 3.1196 | Loss DX: 0.2296 | Loss DY: 0.2353
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [526/597] | Loss G: 3.3973 | Loss DX: 0.2510 | Loss DY: 0.2375
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [527/597] | Loss G: 3.7090 | Loss DX: 0.1939 | Loss DY: 0.2213
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [528/597] | Loss G: 2.5110 | Loss DX: 0.2350 | Loss DY: 0.2343
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [529/597] | Loss G: 3.2329 | Loss DX: 0.2389 | Loss DY: 0.2432
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [530/597] | Loss G: 3.4624 | Loss DX: 0.2151 | Loss DY: 0.2043
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [531/597] | Loss G: 2.5131 | Loss DX: 0.2207 | Loss DY: 0.2305
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [532/597] | Loss G: 2.9410 | Loss DX: 0.2253 | Loss DY: 0.2359
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [533/597] | Loss G: 3.4347 | Loss DX: 0.1990 | Loss DY: 0.2302
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [534/597] | Loss G: 3.6668 | Loss DX: 0.2293 | Loss DY: 0.2129
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [535/597] | Loss G: 2.9389 | Loss DX: 0.2443 | Loss DY: 0.2364
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [536/597] | Loss G: 2.7811 | Loss DX: 0.2340 | Loss DY: 0.2667
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [537/597] | Loss G: 2.7857 | Loss DX: 0.1804 | Loss DY: 0.2103
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [538/597] | Loss G: 3.6269 | Loss DX: 0.1851 | Loss DY: 0.2400
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [539/597] | Loss G: 3.7119 | Loss DX: 0.2113 | Loss DY: 0.2324
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [540/597] | Loss G: 3.5708 | Loss DX: 0.2009 | Loss DY: 0.2138
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [541/597] | Loss G: 3.0967 | Loss DX: 0.2206 | Loss DY: 0.2393
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [542/597] | Loss G: 3.0590 | Loss DX: 0.2957 | Loss DY: 0.2927
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [543/597] | Loss G: 2.8090 | Loss DX: 0.2429 | Loss DY: 0.2611
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [544/597] | Loss G: 3.3344 | Loss DX: 0.1582 | Loss DY: 0.1764
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [545/597] | Loss G: 4.7384 | Loss DX: 0.2410 | Loss DY: 0.2587
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [546/597] | Loss G: 3.4607 | Loss DX: 0.1842 | Loss DY: 0.2265
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [547/597] | Loss G: 3.0732 | Loss DX: 0.2085 | Loss DY: 0.2206
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [548/597] | Loss G: 3.3662 | Loss DX: 0.1968 | Loss DY: 0.2110
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [549/597] | Loss G: 4.7353 | Loss DX: 0.2154 | Loss DY: 0.1937
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [550/597] | Loss G: 3.0460 | Loss DX: 0.2109 | Loss DY: 0.1940
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [551/597] | Loss G: 3.5538 | Loss DX: 0.1858 | Loss DY: 0.2207
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [552/597] | Loss G: 2.7171 | Loss DX: 0.2517 | Loss DY: 0.2084
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [553/597] | Loss G: 2.8761 | Loss DX: 0.2534 | Loss DY: 0.2307
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [554/597] | Loss G: 3.0861 | Loss DX: 0.1877 | Loss DY: 0.1966
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [555/597] | Loss G: 2.9979 | Loss DX: 0.2084 | Loss DY: 0.2070
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [556/597] | Loss G: 3.7049 | Loss DX: 0.1938 | Loss DY: 0.1570
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [557/597] | Loss G: 3.3743 | Loss DX: 0.2019 | Loss DY: 0.1869
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [558/597] | Loss G: 3.4632 | Loss DX: 0.1857 | Loss DY: 0.2163
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [559/597] | Loss G: 4.1278 | Loss DX: 0.1942 | Loss DY: 0.2398
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [560/597] | Loss G: 4.1426 | Loss DX: 0.2457 | Loss DY: 0.2433
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [561/597] | Loss G: 2.9338 | Loss DX: 0.2408 | Loss DY: 0.2901
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [562/597] | Loss G: 3.5804 | Loss DX: 0.2176 | Loss DY: 0.2288
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [563/597] | Loss G: 3.0740 | Loss DX: 0.2916 | Loss DY: 0.3329
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [564/597] | Loss G: 3.1603 | Loss DX: 0.2121 | Loss DY: 0.2596
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [565/597] | Loss G: 3.2754 | Loss DX: 0.2298 | Loss DY: 0.2211
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [566/597] | Loss G: 3.0207 | Loss DX: 0.1685 | Loss DY: 0.2456
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [567/597] | Loss G: 3.7019 | Loss DX: 0.3169 | Loss DY: 0.2282
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [568/597] | Loss G: 3.4704 | Loss DX: 0.2261 | Loss DY: 0.2191
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [569/597] | Loss G: 2.8782 | Loss DX: 0.2159 | Loss DY: 0.2275
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [570/597] | Loss G: 3.0341 | Loss DX: 0.2260 | Loss DY: 0.2481
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [571/597] | Loss G: 2.5544 | Loss DX: 0.2405 | Loss DY: 0.2391
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [572/597] | Loss G: 3.9952 | Loss DX: 0.2072 | Loss DY: 0.2087
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [573/597] | Loss G: 4.4264 | Loss DX: 0.1402 | Loss DY: 0.2040
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [574/597] | Loss G: 3.2273 | Loss DX: 0.2191 | Loss DY: 0.2307
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [575/597] | Loss G: 3.5297 | Loss DX: 0.1572 | Loss DY: 0.1790
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [576/597] | Loss G: 3.5460 | Loss DX: 0.2459 | Loss DY: 0.2260
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [577/597] | Loss G: 3.4460 | Loss DX: 0.2564 | Loss DY: 0.1901
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [578/597] | Loss G: 2.6280 | Loss DX: 0.2253 | Loss DY: 0.2362
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [579/597] | Loss G: 3.3142 | Loss DX: 0.2057 | Loss DY: 0.1905
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [580/597] | Loss G: 3.6186 | Loss DX: 0.2308 | Loss DY: 0.1837
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [581/597] | Loss G: 2.9135 | Loss DX: 0.2969 | Loss DY: 0.2900
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [582/597] | Loss G: 2.8596 | Loss DX: 0.2168 | Loss DY: 0.2829
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [583/597] | Loss G: 3.0224 | Loss DX: 0.2029 | Loss DY: 0.2249
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [584/597] | Loss G: 2.9862 | Loss DX: 0.1754 | Loss DY: 0.2009
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [585/597] | Loss G: 2.5723 | Loss DX: 0.2653 | Loss DY: 0.2867
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [586/597] | Loss G: 3.5016 | Loss DX: 0.2420 | Loss DY: 0.2784
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [587/597] | Loss G: 3.7895 | Loss DX: 0.2023 | Loss DY: 0.2063
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [588/597] | Loss G: 2.7324 | Loss DX: 0.2105 | Loss DY: 0.2511
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [589/597] | Loss G: 3.0103 | Loss DX: 0.1302 | Loss DY: 0.2125
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [590/597] | Loss G: 3.4113 | Loss DX: 0.2212 | Loss DY: 0.2554
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [591/597] | Loss G: 3.9839 | Loss DX: 0.2161 | Loss DY: 0.2317
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [592/597] | Loss G: 2.4828 | Loss DX: 0.2465 | Loss DY: 0.2554
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [593/597] | Loss G: 3.0556 | Loss DX: 0.2103 | Loss DY: 0.1938
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [594/597] | Loss G: 2.6750 | Loss DX: 0.2929 | Loss DY: 0.2564
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [595/597] | Loss G: 3.6464 | Loss DX: 0.2881 | Loss DY: 0.2426
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [596/597] | Loss G: 3.2947 | Loss DX: 0.2541 | Loss DY: 0.2619
# Step 1 | alpha 1.0000 | Epoch [1/1] | Batch [597/597] | Loss G: 3.3796 | Loss DX: 0.2183 | Loss DY: 0.2234

# %%
trainer.train(dataloaders=(lsun_loader, monet_loader), n_epochs=1, step=2)
# Out:
# Step 2 | alpha 0.0000 | Epoch [1/1] | Batch [1/597] | Loss G: 3.1801 | Loss DX: 0.2314 | Loss DY: 0.2308
# Step 2 | alpha 0.0017 | Epoch [1/1] | Batch [2/597] | Loss G: 3.0200 | Loss DX: 0.2537 | Loss DY: 0.2327
# Step 2 | alpha 0.0034 | Epoch [1/1] | Batch [3/597] | Loss G: 3.7164 | Loss DX: 0.2213 | Loss DY: 0.2161
# Step 2 | alpha 0.0050 | Epoch [1/1] | Batch [4/597] | Loss G: 3.0729 | Loss DX: 0.2236 | Loss DY: 0.2310
# Step 2 | alpha 0.0067 | Epoch [1/1] | Batch [5/597] | Loss G: 4.0672 | Loss DX: 0.2110 | Loss DY: 0.2050
# Step 2 | alpha 0.0084 | Epoch [1/1] | Batch [6/597] | Loss G: 3.5389 | Loss DX: 0.3109 | Loss DY: 0.2480
# Step 2 | alpha 0.0101 | Epoch [1/1] | Batch [7/597] | Loss G: 4.0456 | Loss DX: 0.1983 | Loss DY: 0.1922
# Step 2 | alpha 0.0117 | Epoch [1/1] | Batch [8/597] | Loss G: 2.6414 | Loss DX: 0.2070 | Loss DY: 0.1817
# Step 2 | alpha 0.0134 | Epoch [1/1] | Batch [9/597] | Loss G: 3.8178 | Loss DX: 0.1761 | Loss DY: 0.1868
# Step 2 | alpha 0.0151 | Epoch [1/1] | Batch [10/597] | Loss G: 3.8927 | Loss DX: 0.1628 | Loss DY: 0.2247
# Step 2 | alpha 0.0168 | Epoch [1/1] | Batch [11/597] | Loss G: 2.8260 | Loss DX: 0.1704 | Loss DY: 0.1920
# Step 2 | alpha 0.0184 | Epoch [1/1] | Batch [12/597] | Loss G: 4.3039 | Loss DX: 0.1925 | Loss DY: 0.2411
# Step 2 | alpha 0.0201 | Epoch [1/1] | Batch [13/597] | Loss G: 3.5416 | Loss DX: 0.1597 | Loss DY: 0.1678
# Step 2 | alpha 0.0218 | Epoch [1/1] | Batch [14/597] | Loss G: 3.4665 | Loss DX: 0.2515 | Loss DY: 0.2153
# Step 2 | alpha 0.0235 | Epoch [1/1] | Batch [15/597] | Loss G: 2.9657 | Loss DX: 0.2529 | Loss DY: 0.2217
# Step 2 | alpha 0.0251 | Epoch [1/1] | Batch [16/597] | Loss G: 3.6915 | Loss DX: 0.2252 | Loss DY: 0.2162
# Step 2 | alpha 0.0268 | Epoch [1/1] | Batch [17/597] | Loss G: 3.6148 | Loss DX: 0.2047 | Loss DY: 0.1563
# Step 2 | alpha 0.0285 | Epoch [1/1] | Batch [18/597] | Loss G: 3.1830 | Loss DX: 0.1942 | Loss DY: 0.1907
# Step 2 | alpha 0.0302 | Epoch [1/1] | Batch [19/597] | Loss G: 3.0338 | Loss DX: 0.2409 | Loss DY: 0.2558
# Step 2 | alpha 0.0318 | Epoch [1/1] | Batch [20/597] | Loss G: 3.1674 | Loss DX: 0.2550 | Loss DY: 0.2324
# Step 2 | alpha 0.0335 | Epoch [1/1] | Batch [21/597] | Loss G: 3.0334 | Loss DX: 0.2153 | Loss DY: 0.2157
# Step 2 | alpha 0.0352 | Epoch [1/1] | Batch [22/597] | Loss G: 3.8536 | Loss DX: 0.2509 | Loss DY: 0.2074
# Step 2 | alpha 0.0369 | Epoch [1/1] | Batch [23/597] | Loss G: 3.0556 | Loss DX: 0.2252 | Loss DY: 0.2379
# Step 2 | alpha 0.0385 | Epoch [1/1] | Batch [24/597] | Loss G: 3.5474 | Loss DX: 0.2778 | Loss DY: 0.2612
# Step 2 | alpha 0.0402 | Epoch [1/1] | Batch [25/597] | Loss G: 2.8675 | Loss DX: 0.2312 | Loss DY: 0.2195
# Step 2 | alpha 0.0419 | Epoch [1/1] | Batch [26/597] | Loss G: 5.1876 | Loss DX: 0.1704 | Loss DY: 0.2435
# Step 2 | alpha 0.0436 | Epoch [1/1] | Batch [27/597] | Loss G: 3.7066 | Loss DX: 0.2083 | Loss DY: 0.2135
# Step 2 | alpha 0.0452 | Epoch [1/1] | Batch [28/597] | Loss G: 3.1906 | Loss DX: 0.2612 | Loss DY: 0.2323
# Step 2 | alpha 0.0469 | Epoch [1/1] | Batch [29/597] | Loss G: 3.4403 | Loss DX: 0.1792 | Loss DY: 0.2263
# Step 2 | alpha 0.0486 | Epoch [1/1] | Batch [30/597] | Loss G: 3.5539 | Loss DX: 0.2261 | Loss DY: 0.2432
# Step 2 | alpha 0.0503 | Epoch [1/1] | Batch [31/597] | Loss G: 3.5914 | Loss DX: 0.1544 | Loss DY: 0.1776
# Step 2 | alpha 0.0519 | Epoch [1/1] | Batch [32/597] | Loss G: 4.1577 | Loss DX: 0.2198 | Loss DY: 0.2232
# Step 2 | alpha 0.0536 | Epoch [1/1] | Batch [33/597] | Loss G: 3.1998 | Loss DX: 0.2721 | Loss DY: 0.2510
# Step 2 | alpha 0.0553 | Epoch [1/1] | Batch [34/597] | Loss G: 3.3073 | Loss DX: 0.2390 | Loss DY: 0.2848
# Step 2 | alpha 0.0570 | Epoch [1/1] | Batch [35/597] | Loss G: 3.5881 | Loss DX: 0.2469 | Loss DY: 0.2094
# Step 2 | alpha 0.0586 | Epoch [1/1] | Batch [36/597] | Loss G: 3.1802 | Loss DX: 0.2380 | Loss DY: 0.2500
# Step 2 | alpha 0.0603 | Epoch [1/1] | Batch [37/597] | Loss G: 3.3776 | Loss DX: 0.1897 | Loss DY: 0.1834
# Step 2 | alpha 0.0620 | Epoch [1/1] | Batch [38/597] | Loss G: 3.1332 | Loss DX: 0.1393 | Loss DY: 0.1806
# Step 2 | alpha 0.0637 | Epoch [1/1] | Batch [39/597] | Loss G: 3.0107 | Loss DX: 0.1342 | Loss DY: 0.2172
# Step 2 | alpha 0.0653 | Epoch [1/1] | Batch [40/597] | Loss G: 3.4469 | Loss DX: 0.2963 | Loss DY: 0.2647
# Step 2 | alpha 0.0670 | Epoch [1/1] | Batch [41/597] | Loss G: 3.1807 | Loss DX: 0.2726 | Loss DY: 0.2233
# Step 2 | alpha 0.0687 | Epoch [1/1] | Batch [42/597] | Loss G: 3.2164 | Loss DX: 0.2294 | Loss DY: 0.2136
# Step 2 | alpha 0.0704 | Epoch [1/1] | Batch [43/597] | Loss G: 3.3471 | Loss DX: 0.1804 | Loss DY: 0.2177
# Step 2 | alpha 0.0720 | Epoch [1/1] | Batch [44/597] | Loss G: 3.0822 | Loss DX: 0.2195 | Loss DY: 0.2044
# Step 2 | alpha 0.0737 | Epoch [1/1] | Batch [45/597] | Loss G: 3.5827 | Loss DX: 0.2064 | Loss DY: 0.2487
# Step 2 | alpha 0.0754 | Epoch [1/1] | Batch [46/597] | Loss G: 3.4135 | Loss DX: 0.2696 | Loss DY: 0.2211
# Step 2 | alpha 0.0771 | Epoch [1/1] | Batch [47/597] | Loss G: 3.9064 | Loss DX: 0.2762 | Loss DY: 0.2265
# Step 2 | alpha 0.0787 | Epoch [1/1] | Batch [48/597] | Loss G: 2.9723 | Loss DX: 0.1982 | Loss DY: 0.2087
# Step 2 | alpha 0.0804 | Epoch [1/1] | Batch [49/597] | Loss G: 3.0461 | Loss DX: 0.2671 | Loss DY: 0.2107
# Step 2 | alpha 0.0821 | Epoch [1/1] | Batch [50/597] | Loss G: 3.6540 | Loss DX: 0.1957 | Loss DY: 0.2505
# Step 2 | alpha 0.0838 | Epoch [1/1] | Batch [51/597] | Loss G: 2.9789 | Loss DX: 0.2564 | Loss DY: 0.2287
# Step 2 | alpha 0.0854 | Epoch [1/1] | Batch [52/597] | Loss G: 3.7799 | Loss DX: 0.2089 | Loss DY: 0.1869
# Step 2 | alpha 0.0871 | Epoch [1/1] | Batch [53/597] | Loss G: 3.9830 | Loss DX: 0.2029 | Loss DY: 0.1839
# Step 2 | alpha 0.0888 | Epoch [1/1] | Batch [54/597] | Loss G: 2.8093 | Loss DX: 0.2085 | Loss DY: 0.2226
# Step 2 | alpha 0.0905 | Epoch [1/1] | Batch [55/597] | Loss G: 3.5319 | Loss DX: 0.1915 | Loss DY: 0.2193
# Step 2 | alpha 0.0921 | Epoch [1/1] | Batch [56/597] | Loss G: 3.2065 | Loss DX: 0.1918 | Loss DY: 0.1610
# Step 2 | alpha 0.0938 | Epoch [1/1] | Batch [57/597] | Loss G: 3.6493 | Loss DX: 0.1525 | Loss DY: 0.1672
# Step 2 | alpha 0.0955 | Epoch [1/1] | Batch [58/597] | Loss G: 4.2387 | Loss DX: 0.1747 | Loss DY: 0.2062
# Step 2 | alpha 0.0972 | Epoch [1/1] | Batch [59/597] | Loss G: 3.4606 | Loss DX: 0.1785 | Loss DY: 0.2089
# Step 2 | alpha 0.0988 | Epoch [1/1] | Batch [60/597] | Loss G: 3.3119 | Loss DX: 0.2327 | Loss DY: 0.2973
# Step 2 | alpha 0.1005 | Epoch [1/1] | Batch [61/597] | Loss G: 3.1862 | Loss DX: 0.2049 | Loss DY: 0.2166
# Step 2 | alpha 0.1022 | Epoch [1/1] | Batch [62/597] | Loss G: 2.7102 | Loss DX: 0.2040 | Loss DY: 0.2369
# Step 2 | alpha 0.1039 | Epoch [1/1] | Batch [63/597] | Loss G: 3.3999 | Loss DX: 0.2144 | Loss DY: 0.2350
# Step 2 | alpha 0.1055 | Epoch [1/1] | Batch [64/597] | Loss G: 3.5631 | Loss DX: 0.1922 | Loss DY: 0.2194
# Step 2 | alpha 0.1072 | Epoch [1/1] | Batch [65/597] | Loss G: 2.9291 | Loss DX: 0.2638 | Loss DY: 0.2321
# Step 2 | alpha 0.1089 | Epoch [1/1] | Batch [66/597] | Loss G: 4.0710 | Loss DX: 0.2038 | Loss DY: 0.2004
# Step 2 | alpha 0.1106 | Epoch [1/1] | Batch [67/597] | Loss G: 3.2831 | Loss DX: 0.2718 | Loss DY: 0.2519
# Step 2 | alpha 0.1122 | Epoch [1/1] | Batch [68/597] | Loss G: 4.0085 | Loss DX: 0.1363 | Loss DY: 0.2245
# Step 2 | alpha 0.1139 | Epoch [1/1] | Batch [69/597] | Loss G: 4.7392 | Loss DX: 0.2220 | Loss DY: 0.2424
# Step 2 | alpha 0.1156 | Epoch [1/1] | Batch [70/597] | Loss G: 3.5073 | Loss DX: 0.2749 | Loss DY: 0.2768
# Step 2 | alpha 0.1173 | Epoch [1/1] | Batch [71/597] | Loss G: 3.5570 | Loss DX: 0.1295 | Loss DY: 0.2247
# Step 2 | alpha 0.1189 | Epoch [1/1] | Batch [72/597] | Loss G: 3.4839 | Loss DX: 0.2834 | Loss DY: 0.2544
# Step 2 | alpha 0.1206 | Epoch [1/1] | Batch [73/597] | Loss G: 3.7047 | Loss DX: 0.1239 | Loss DY: 0.2275
# Step 2 | alpha 0.1223 | Epoch [1/1] | Batch [74/597] | Loss G: 3.8476 | Loss DX: 0.1708 | Loss DY: 0.1699
# Step 2 | alpha 0.1240 | Epoch [1/1] | Batch [75/597] | Loss G: 3.9002 | Loss DX: 0.2986 | Loss DY: 0.2461
# Step 2 | alpha 0.1256 | Epoch [1/1] | Batch [76/597] | Loss G: 3.3959 | Loss DX: 0.1914 | Loss DY: 0.2058
# Step 2 | alpha 0.1273 | Epoch [1/1] | Batch [77/597] | Loss G: 3.1910 | Loss DX: 0.2573 | Loss DY: 0.2257
# Step 2 | alpha 0.1290 | Epoch [1/1] | Batch [78/597] | Loss G: 4.2481 | Loss DX: 0.2254 | Loss DY: 0.2342
# Step 2 | alpha 0.1307 | Epoch [1/1] | Batch [79/597] | Loss G: 3.3950 | Loss DX: 0.2528 | Loss DY: 0.2445
# Step 2 | alpha 0.1323 | Epoch [1/1] | Batch [80/597] | Loss G: 2.9617 | Loss DX: 0.1731 | Loss DY: 0.1935
# Step 2 | alpha 0.1340 | Epoch [1/1] | Batch [81/597] | Loss G: 3.5786 | Loss DX: 0.1893 | Loss DY: 0.2061
# Step 2 | alpha 0.1357 | Epoch [1/1] | Batch [82/597] | Loss G: 3.4172 | Loss DX: 0.2145 | Loss DY: 0.2130
# Step 2 | alpha 0.1374 | Epoch [1/1] | Batch [83/597] | Loss G: 3.0550 | Loss DX: 0.2046 | Loss DY: 0.2439
# Step 2 | alpha 0.1390 | Epoch [1/1] | Batch [84/597] | Loss G: 4.4254 | Loss DX: 0.3251 | Loss DY: 0.2501
# Step 2 | alpha 0.1407 | Epoch [1/1] | Batch [85/597] | Loss G: 3.6233 | Loss DX: 0.1818 | Loss DY: 0.1979
# Step 2 | alpha 0.1424 | Epoch [1/1] | Batch [86/597] | Loss G: 3.5085 | Loss DX: 0.2304 | Loss DY: 0.1655
# Step 2 | alpha 0.1441 | Epoch [1/1] | Batch [87/597] | Loss G: 3.7496 | Loss DX: 0.2156 | Loss DY: 0.1958
# Step 2 | alpha 0.1457 | Epoch [1/1] | Batch [88/597] | Loss G: 3.9945 | Loss DX: 0.2521 | Loss DY: 0.1969
# Step 2 | alpha 0.1474 | Epoch [1/1] | Batch [89/597] | Loss G: 4.2383 | Loss DX: 0.2099 | Loss DY: 0.2361
# Step 2 | alpha 0.1491 | Epoch [1/1] | Batch [90/597] | Loss G: 3.2997 | Loss DX: 0.2358 | Loss DY: 0.2683
# Step 2 | alpha 0.1508 | Epoch [1/1] | Batch [91/597] | Loss G: 3.5548 | Loss DX: 0.2819 | Loss DY: 0.3008
# Step 2 | alpha 0.1524 | Epoch [1/1] | Batch [92/597] | Loss G: 4.3089 | Loss DX: 0.2439 | Loss DY: 0.1822
# Step 2 | alpha 0.1541 | Epoch [1/1] | Batch [93/597] | Loss G: 3.5195 | Loss DX: 0.2639 | Loss DY: 0.2926
# Step 2 | alpha 0.1558 | Epoch [1/1] | Batch [94/597] | Loss G: 3.2479 | Loss DX: 0.2463 | Loss DY: 0.2023
# Step 2 | alpha 0.1575 | Epoch [1/1] | Batch [95/597] | Loss G: 4.8594 | Loss DX: 0.1991 | Loss DY: 0.2272
# Step 2 | alpha 0.1591 | Epoch [1/1] | Batch [96/597] | Loss G: 3.5697 | Loss DX: 0.2588 | Loss DY: 0.2081
# Step 2 | alpha 0.1608 | Epoch [1/1] | Batch [97/597] | Loss G: 2.9369 | Loss DX: 0.2511 | Loss DY: 0.2621
# Step 2 | alpha 0.1625 | Epoch [1/1] | Batch [98/597] | Loss G: 2.6182 | Loss DX: 0.2329 | Loss DY: 0.1916
# Step 2 | alpha 0.1642 | Epoch [1/1] | Batch [99/597] | Loss G: 3.4754 | Loss DX: 0.2505 | Loss DY: 0.2306
# Step 2 | alpha 0.1658 | Epoch [1/1] | Batch [100/597] | Loss G: 4.0689 | Loss DX: 0.2615 | Loss DY: 0.2508
# Step 2 | alpha 0.1675 | Epoch [1/1] | Batch [101/597] | Loss G: 3.2378 | Loss DX: 0.2452 | Loss DY: 0.2298
# Step 2 | alpha 0.1692 | Epoch [1/1] | Batch [102/597] | Loss G: 4.2024 | Loss DX: 0.2321 | Loss DY: 0.2596
# Step 2 | alpha 0.1709 | Epoch [1/1] | Batch [103/597] | Loss G: 2.7959 | Loss DX: 0.2265 | Loss DY: 0.2291
# Step 2 | alpha 0.1725 | Epoch [1/1] | Batch [104/597] | Loss G: 3.4706 | Loss DX: 0.2105 | Loss DY: 0.1842
# Step 2 | alpha 0.1742 | Epoch [1/1] | Batch [105/597] | Loss G: 3.0419 | Loss DX: 0.2526 | Loss DY: 0.1812
# Step 2 | alpha 0.1759 | Epoch [1/1] | Batch [106/597] | Loss G: 3.0030 | Loss DX: 0.2118 | Loss DY: 0.2293
# Step 2 | alpha 0.1776 | Epoch [1/1] | Batch [107/597] | Loss G: 3.2229 | Loss DX: 0.2184 | Loss DY: 0.1933
# Step 2 | alpha 0.1792 | Epoch [1/1] | Batch [108/597] | Loss G: 3.1748 | Loss DX: 0.2300 | Loss DY: 0.2547
# Step 2 | alpha 0.1809 | Epoch [1/1] | Batch [109/597] | Loss G: 3.5814 | Loss DX: 0.2206 | Loss DY: 0.2150
# Step 2 | alpha 0.1826 | Epoch [1/1] | Batch [110/597] | Loss G: 3.9008 | Loss DX: 0.1736 | Loss DY: 0.1299
# Step 2 | alpha 0.1843 | Epoch [1/1] | Batch [111/597] | Loss G: 3.5470 | Loss DX: 0.2628 | Loss DY: 0.2341
# Step 2 | alpha 0.1859 | Epoch [1/1] | Batch [112/597] | Loss G: 3.6595 | Loss DX: 0.1654 | Loss DY: 0.2350
# Step 2 | alpha 0.1876 | Epoch [1/1] | Batch [113/597] | Loss G: 3.7123 | Loss DX: 0.2326 | Loss DY: 0.1937
# Step 2 | alpha 0.1893 | Epoch [1/1] | Batch [114/597] | Loss G: 4.4510 | Loss DX: 0.1791 | Loss DY: 0.2592
# Step 2 | alpha 0.1910 | Epoch [1/1] | Batch [115/597] | Loss G: 4.7227 | Loss DX: 0.2203 | Loss DY: 0.1901
# Step 2 | alpha 0.1926 | Epoch [1/1] | Batch [116/597] | Loss G: 2.9316 | Loss DX: 0.2537 | Loss DY: 0.2011
# Step 2 | alpha 0.1943 | Epoch [1/1] | Batch [117/597] | Loss G: 3.3799 | Loss DX: 0.2212 | Loss DY: 0.2313
# Step 2 | alpha 0.1960 | Epoch [1/1] | Batch [118/597] | Loss G: 4.6346 | Loss DX: 0.2068 | Loss DY: 0.2277
# Step 2 | alpha 0.1977 | Epoch [1/1] | Batch [119/597] | Loss G: 3.7772 | Loss DX: 0.2310 | Loss DY: 0.2359
# Step 2 | alpha 0.1993 | Epoch [1/1] | Batch [120/597] | Loss G: 3.7425 | Loss DX: 0.1666 | Loss DY: 0.2000
# Step 2 | alpha 0.2010 | Epoch [1/1] | Batch [121/597] | Loss G: 3.7851 | Loss DX: 0.2196 | Loss DY: 0.2036
# Step 2 | alpha 0.2027 | Epoch [1/1] | Batch [122/597] | Loss G: 3.3014 | Loss DX: 0.2667 | Loss DY: 0.2535
# Step 2 | alpha 0.2044 | Epoch [1/1] | Batch [123/597] | Loss G: 3.6834 | Loss DX: 0.2261 | Loss DY: 0.2651
# Step 2 | alpha 0.2060 | Epoch [1/1] | Batch [124/597] | Loss G: 3.3713 | Loss DX: 0.2593 | Loss DY: 0.2285
# Step 2 | alpha 0.2077 | Epoch [1/1] | Batch [125/597] | Loss G: 3.1654 | Loss DX: 0.2217 | Loss DY: 0.2208
# Step 2 | alpha 0.2094 | Epoch [1/1] | Batch [126/597] | Loss G: 2.9845 | Loss DX: 0.2603 | Loss DY: 0.2272
# Step 2 | alpha 0.2111 | Epoch [1/1] | Batch [127/597] | Loss G: 3.2583 | Loss DX: 0.2772 | Loss DY: 0.2110
# Step 2 | alpha 0.2127 | Epoch [1/1] | Batch [128/597] | Loss G: 3.5922 | Loss DX: 0.2245 | Loss DY: 0.2576
# Step 2 | alpha 0.2144 | Epoch [1/1] | Batch [129/597] | Loss G: 4.4500 | Loss DX: 0.2074 | Loss DY: 0.1662
# Step 2 | alpha 0.2161 | Epoch [1/1] | Batch [130/597] | Loss G: 3.8025 | Loss DX: 0.2275 | Loss DY: 0.2409
# Step 2 | alpha 0.2178 | Epoch [1/1] | Batch [131/597] | Loss G: 3.4172 | Loss DX: 0.2172 | Loss DY: 0.2345
# Step 2 | alpha 0.2194 | Epoch [1/1] | Batch [132/597] | Loss G: 3.8369 | Loss DX: 0.1766 | Loss DY: 0.2024
# Step 2 | alpha 0.2211 | Epoch [1/1] | Batch [133/597] | Loss G: 3.7856 | Loss DX: 0.2210 | Loss DY: 0.2536
# Step 2 | alpha 0.2228 | Epoch [1/1] | Batch [134/597] | Loss G: 3.4746 | Loss DX: 0.2223 | Loss DY: 0.2196
# Step 2 | alpha 0.2245 | Epoch [1/1] | Batch [135/597] | Loss G: 3.8684 | Loss DX: 0.1951 | Loss DY: 0.1709
# Step 2 | alpha 0.2261 | Epoch [1/1] | Batch [136/597] | Loss G: 3.3723 | Loss DX: 0.2211 | Loss DY: 0.2125
# Step 2 | alpha 0.2278 | Epoch [1/1] | Batch [137/597] | Loss G: 3.3112 | Loss DX: 0.1592 | Loss DY: 0.2353
# Step 2 | alpha 0.2295 | Epoch [1/1] | Batch [138/597] | Loss G: 3.5027 | Loss DX: 0.2055 | Loss DY: 0.1768
# Step 2 | alpha 0.2312 | Epoch [1/1] | Batch [139/597] | Loss G: 3.7359 | Loss DX: 0.2236 | Loss DY: 0.2456
# Step 2 | alpha 0.2328 | Epoch [1/1] | Batch [140/597] | Loss G: 3.7723 | Loss DX: 0.1872 | Loss DY: 0.2040
# Step 2 | alpha 0.2345 | Epoch [1/1] | Batch [141/597] | Loss G: 4.0266 | Loss DX: 0.1619 | Loss DY: 0.2133
# Step 2 | alpha 0.2362 | Epoch [1/1] | Batch [142/597] | Loss G: 3.3727 | Loss DX: 0.2460 | Loss DY: 0.1976
# Step 2 | alpha 0.2379 | Epoch [1/1] | Batch [143/597] | Loss G: 3.6808 | Loss DX: 0.3019 | Loss DY: 0.2823
# Step 2 | alpha 0.2395 | Epoch [1/1] | Batch [144/597] | Loss G: 3.5292 | Loss DX: 0.2370 | Loss DY: 0.2927
# Step 2 | alpha 0.2412 | Epoch [1/1] | Batch [145/597] | Loss G: 3.8306 | Loss DX: 0.2064 | Loss DY: 0.1793
# Step 2 | alpha 0.2429 | Epoch [1/1] | Batch [146/597] | Loss G: 3.5687 | Loss DX: 0.1902 | Loss DY: 0.2391
# Step 2 | alpha 0.2446 | Epoch [1/1] | Batch [147/597] | Loss G: 3.8558 | Loss DX: 0.2131 | Loss DY: 0.2314
# Step 2 | alpha 0.2462 | Epoch [1/1] | Batch [148/597] | Loss G: 3.7008 | Loss DX: 0.1858 | Loss DY: 0.1938
# Step 2 | alpha 0.2479 | Epoch [1/1] | Batch [149/597] | Loss G: 3.2257 | Loss DX: 0.2050 | Loss DY: 0.1949
# Step 2 | alpha 0.2496 | Epoch [1/1] | Batch [150/597] | Loss G: 3.2419 | Loss DX: 0.2999 | Loss DY: 0.2466
# Step 2 | alpha 0.2513 | Epoch [1/1] | Batch [151/597] | Loss G: 3.3836 | Loss DX: 0.1673 | Loss DY: 0.2654
# Step 2 | alpha 0.2529 | Epoch [1/1] | Batch [152/597] | Loss G: 2.8644 | Loss DX: 0.2599 | Loss DY: 0.2479
# Step 2 | alpha 0.2546 | Epoch [1/1] | Batch [153/597] | Loss G: 3.6335 | Loss DX: 0.2125 | Loss DY: 0.2681
# Step 2 | alpha 0.2563 | Epoch [1/1] | Batch [154/597] | Loss G: 3.3457 | Loss DX: 0.1925 | Loss DY: 0.2184
# Step 2 | alpha 0.2580 | Epoch [1/1] | Batch [155/597] | Loss G: 3.1969 | Loss DX: 0.2578 | Loss DY: 0.2539
# Step 2 | alpha 0.2596 | Epoch [1/1] | Batch [156/597] | Loss G: 3.0636 | Loss DX: 0.2630 | Loss DY: 0.2609
# Step 2 | alpha 0.2613 | Epoch [1/1] | Batch [157/597] | Loss G: 4.4588 | Loss DX: 0.2231 | Loss DY: 0.2240
# Step 2 | alpha 0.2630 | Epoch [1/1] | Batch [158/597] | Loss G: 4.0672 | Loss DX: 0.1726 | Loss DY: 0.2066
# Step 2 | alpha 0.2647 | Epoch [1/1] | Batch [159/597] | Loss G: 3.8079 | Loss DX: 0.2058 | Loss DY: 0.2201
# Step 2 | alpha 0.2663 | Epoch [1/1] | Batch [160/597] | Loss G: 4.0695 | Loss DX: 0.2460 | Loss DY: 0.2596
# Step 2 | alpha 0.2680 | Epoch [1/1] | Batch [161/597] | Loss G: 3.6043 | Loss DX: 0.2246 | Loss DY: 0.1895
# Step 2 | alpha 0.2697 | Epoch [1/1] | Batch [162/597] | Loss G: 3.8044 | Loss DX: 0.1718 | Loss DY: 0.2057
# Step 2 | alpha 0.2714 | Epoch [1/1] | Batch [163/597] | Loss G: 3.6662 | Loss DX: 0.2162 | Loss DY: 0.1900
# Step 2 | alpha 0.2730 | Epoch [1/1] | Batch [164/597] | Loss G: 4.1445 | Loss DX: 0.2283 | Loss DY: 0.2326
# Step 2 | alpha 0.2747 | Epoch [1/1] | Batch [165/597] | Loss G: 4.5407 | Loss DX: 0.2244 | Loss DY: 0.2142
# Step 2 | alpha 0.2764 | Epoch [1/1] | Batch [166/597] | Loss G: 3.7963 | Loss DX: 0.1536 | Loss DY: 0.1723
# Step 2 | alpha 0.2781 | Epoch [1/1] | Batch [167/597] | Loss G: 3.0936 | Loss DX: 0.2909 | Loss DY: 0.2757
# Step 2 | alpha 0.2797 | Epoch [1/1] | Batch [168/597] | Loss G: 2.8792 | Loss DX: 0.2197 | Loss DY: 0.2237
# Step 2 | alpha 0.2814 | Epoch [1/1] | Batch [169/597] | Loss G: 3.0427 | Loss DX: 0.2065 | Loss DY: 0.2623
# Step 2 | alpha 0.2831 | Epoch [1/1] | Batch [170/597] | Loss G: 3.5308 | Loss DX: 0.3122 | Loss DY: 0.2518
# Step 2 | alpha 0.2848 | Epoch [1/1] | Batch [171/597] | Loss G: 3.1923 | Loss DX: 0.2403 | Loss DY: 0.2194
# Step 2 | alpha 0.2864 | Epoch [1/1] | Batch [172/597] | Loss G: 3.1622 | Loss DX: 0.2498 | Loss DY: 0.2203
# Step 2 | alpha 0.2881 | Epoch [1/1] | Batch [173/597] | Loss G: 3.2997 | Loss DX: 0.2219 | Loss DY: 0.2225
# Step 2 | alpha 0.2898 | Epoch [1/1] | Batch [174/597] | Loss G: 3.9582 | Loss DX: 0.2130 | Loss DY: 0.1960
# Step 2 | alpha 0.2915 | Epoch [1/1] | Batch [175/597] | Loss G: 4.9245 | Loss DX: 0.1835 | Loss DY: 0.2234
# Step 2 | alpha 0.2931 | Epoch [1/1] | Batch [176/597] | Loss G: 4.4144 | Loss DX: 0.2440 | Loss DY: 0.2374
# Step 2 | alpha 0.2948 | Epoch [1/1] | Batch [177/597] | Loss G: 3.2669 | Loss DX: 0.2341 | Loss DY: 0.2404
# Step 2 | alpha 0.2965 | Epoch [1/1] | Batch [178/597] | Loss G: 3.2953 | Loss DX: 0.1815 | Loss DY: 0.2032
# Step 2 | alpha 0.2982 | Epoch [1/1] | Batch [179/597] | Loss G: 2.9562 | Loss DX: 0.2392 | Loss DY: 0.2251
# Step 2 | alpha 0.2998 | Epoch [1/1] | Batch [180/597] | Loss G: 4.5348 | Loss DX: 0.2143 | Loss DY: 0.1737
# Step 2 | alpha 0.3015 | Epoch [1/1] | Batch [181/597] | Loss G: 3.4220 | Loss DX: 0.2645 | Loss DY: 0.2748
# Step 2 | alpha 0.3032 | Epoch [1/1] | Batch [182/597] | Loss G: 2.8847 | Loss DX: 0.2256 | Loss DY: 0.2895
# Step 2 | alpha 0.3049 | Epoch [1/1] | Batch [183/597] | Loss G: 4.3964 | Loss DX: 0.2026 | Loss DY: 0.2278
# Step 2 | alpha 0.3065 | Epoch [1/1] | Batch [184/597] | Loss G: 3.1384 | Loss DX: 0.2143 | Loss DY: 0.2331
# Step 2 | alpha 0.3082 | Epoch [1/1] | Batch [185/597] | Loss G: 3.3238 | Loss DX: 0.2103 | Loss DY: 0.2218
# Step 2 | alpha 0.3099 | Epoch [1/1] | Batch [186/597] | Loss G: 3.0853 | Loss DX: 0.2342 | Loss DY: 0.2099
# Step 2 | alpha 0.3116 | Epoch [1/1] | Batch [187/597] | Loss G: 3.4183 | Loss DX: 0.2074 | Loss DY: 0.2333
# Step 2 | alpha 0.3132 | Epoch [1/1] | Batch [188/597] | Loss G: 3.6388 | Loss DX: 0.2039 | Loss DY: 0.1612
# Step 2 | alpha 0.3149 | Epoch [1/1] | Batch [189/597] | Loss G: 3.4155 | Loss DX: 0.1655 | Loss DY: 0.1911
# Step 2 | alpha 0.3166 | Epoch [1/1] | Batch [190/597] | Loss G: 2.9183 | Loss DX: 0.2421 | Loss DY: 0.2129
# Step 2 | alpha 0.3183 | Epoch [1/1] | Batch [191/597] | Loss G: 3.0057 | Loss DX: 0.2441 | Loss DY: 0.2158
# Step 2 | alpha 0.3199 | Epoch [1/1] | Batch [192/597] | Loss G: 3.8237 | Loss DX: 0.2172 | Loss DY: 0.1965
# Step 2 | alpha 0.3216 | Epoch [1/1] | Batch [193/597] | Loss G: 3.7735 | Loss DX: 0.1289 | Loss DY: 0.1641
# Step 2 | alpha 0.3233 | Epoch [1/1] | Batch [194/597] | Loss G: 3.2987 | Loss DX: 0.2253 | Loss DY: 0.2602
# Step 2 | alpha 0.3250 | Epoch [1/1] | Batch [195/597] | Loss G: 3.7769 | Loss DX: 0.2783 | Loss DY: 0.2817
# Step 2 | alpha 0.3266 | Epoch [1/1] | Batch [196/597] | Loss G: 6.4276 | Loss DX: 0.2110 | Loss DY: 0.2089
# Step 2 | alpha 0.3283 | Epoch [1/1] | Batch [197/597] | Loss G: 3.4358 | Loss DX: 0.2101 | Loss DY: 0.2065
# Step 2 | alpha 0.3300 | Epoch [1/1] | Batch [198/597] | Loss G: 2.8211 | Loss DX: 0.2098 | Loss DY: 0.2185
# Step 2 | alpha 0.3317 | Epoch [1/1] | Batch [199/597] | Loss G: 3.7166 | Loss DX: 0.1825 | Loss DY: 0.1862
# Step 2 | alpha 0.3333 | Epoch [1/1] | Batch [200/597] | Loss G: 4.0524 | Loss DX: 0.2222 | Loss DY: 0.2287
# Step 2 | alpha 0.3350 | Epoch [1/1] | Batch [201/597] | Loss G: 3.8044 | Loss DX: 0.2036 | Loss DY: 0.1812
# Step 2 | alpha 0.3367 | Epoch [1/1] | Batch [202/597] | Loss G: 3.4159 | Loss DX: 0.2441 | Loss DY: 0.2543
# Step 2 | alpha 0.3384 | Epoch [1/1] | Batch [203/597] | Loss G: 3.4348 | Loss DX: 0.2314 | Loss DY: 0.2748
# Step 2 | alpha 0.3400 | Epoch [1/1] | Batch [204/597] | Loss G: 4.1971 | Loss DX: 0.1806 | Loss DY: 0.1784
# Step 2 | alpha 0.3417 | Epoch [1/1] | Batch [205/597] | Loss G: 3.5222 | Loss DX: 0.2223 | Loss DY: 0.2190
# Step 2 | alpha 0.3434 | Epoch [1/1] | Batch [206/597] | Loss G: 3.7778 | Loss DX: 0.2050 | Loss DY: 0.2187
# Step 2 | alpha 0.3451 | Epoch [1/1] | Batch [207/597] | Loss G: 2.8402 | Loss DX: 0.2496 | Loss DY: 0.2195
# Step 2 | alpha 0.3467 | Epoch [1/1] | Batch [208/597] | Loss G: 3.6969 | Loss DX: 0.2215 | Loss DY: 0.2120
# Step 2 | alpha 0.3484 | Epoch [1/1] | Batch [209/597] | Loss G: 3.4123 | Loss DX: 0.1888 | Loss DY: 0.1740
# Step 2 | alpha 0.3501 | Epoch [1/1] | Batch [210/597] | Loss G: 3.9007 | Loss DX: 0.2697 | Loss DY: 0.2609
# Step 2 | alpha 0.3518 | Epoch [1/1] | Batch [211/597] | Loss G: 3.3887 | Loss DX: 0.2125 | Loss DY: 0.1927
# Step 2 | alpha 0.3534 | Epoch [1/1] | Batch [212/597] | Loss G: 4.3583 | Loss DX: 0.2167 | Loss DY: 0.2126
# Step 2 | alpha 0.3551 | Epoch [1/1] | Batch [213/597] | Loss G: 3.3325 | Loss DX: 0.2283 | Loss DY: 0.2030
# Step 2 | alpha 0.3568 | Epoch [1/1] | Batch [214/597] | Loss G: 3.4001 | Loss DX: 0.2136 | Loss DY: 0.2278
# Step 2 | alpha 0.3585 | Epoch [1/1] | Batch [215/597] | Loss G: 4.8379 | Loss DX: 0.2047 | Loss DY: 0.2264
# Step 2 | alpha 0.3601 | Epoch [1/1] | Batch [216/597] | Loss G: 3.1972 | Loss DX: 0.2332 | Loss DY: 0.2333
# Step 2 | alpha 0.3618 | Epoch [1/1] | Batch [217/597] | Loss G: 4.2001 | Loss DX: 0.1835 | Loss DY: 0.2038
# Step 2 | alpha 0.3635 | Epoch [1/1] | Batch [218/597] | Loss G: 2.9406 | Loss DX: 0.1858 | Loss DY: 0.2521
# Step 2 | alpha 0.3652 | Epoch [1/1] | Batch [219/597] | Loss G: 3.9081 | Loss DX: 0.2053 | Loss DY: 0.1793
# Step 2 | alpha 0.3668 | Epoch [1/1] | Batch [220/597] | Loss G: 3.5805 | Loss DX: 0.1906 | Loss DY: 0.2477
# Step 2 | alpha 0.3685 | Epoch [1/1] | Batch [221/597] | Loss G: 3.5461 | Loss DX: 0.1471 | Loss DY: 0.1915
# Step 2 | alpha 0.3702 | Epoch [1/1] | Batch [222/597] | Loss G: 3.3391 | Loss DX: 0.2793 | Loss DY: 0.2265
# Step 2 | alpha 0.3719 | Epoch [1/1] | Batch [223/597] | Loss G: 2.7504 | Loss DX: 0.2046 | Loss DY: 0.2203
# Step 2 | alpha 0.3735 | Epoch [1/1] | Batch [224/597] | Loss G: 3.2787 | Loss DX: 0.2653 | Loss DY: 0.2428
# Step 2 | alpha 0.3752 | Epoch [1/1] | Batch [225/597] | Loss G: 3.4351 | Loss DX: 0.2402 | Loss DY: 0.2000
# Step 2 | alpha 0.3769 | Epoch [1/1] | Batch [226/597] | Loss G: 3.3184 | Loss DX: 0.2477 | Loss DY: 0.2114
# Step 2 | alpha 0.3786 | Epoch [1/1] | Batch [227/597] | Loss G: 3.9141 | Loss DX: 0.2100 | Loss DY: 0.1863
# Step 2 | alpha 0.3802 | Epoch [1/1] | Batch [228/597] | Loss G: 3.1292 | Loss DX: 0.2472 | Loss DY: 0.2353
# Step 2 | alpha 0.3819 | Epoch [1/1] | Batch [229/597] | Loss G: 3.6040 | Loss DX: 0.1936 | Loss DY: 0.2166
# Step 2 | alpha 0.3836 | Epoch [1/1] | Batch [230/597] | Loss G: 5.7174 | Loss DX: 0.1997 | Loss DY: 0.2145
# Step 2 | alpha 0.3853 | Epoch [1/1] | Batch [231/597] | Loss G: 4.3081 | Loss DX: 0.2301 | Loss DY: 0.1947
# Step 2 | alpha 0.3869 | Epoch [1/1] | Batch [232/597] | Loss G: 3.6822 | Loss DX: 0.2036 | Loss DY: 0.1776
# Step 2 | alpha 0.3886 | Epoch [1/1] | Batch [233/597] | Loss G: 3.7044 | Loss DX: 0.2078 | Loss DY: 0.2682
# Step 2 | alpha 0.3903 | Epoch [1/1] | Batch [234/597] | Loss G: 3.6085 | Loss DX: 0.2474 | Loss DY: 0.2497
# Step 2 | alpha 0.3920 | Epoch [1/1] | Batch [235/597] | Loss G: 4.1831 | Loss DX: 0.2277 | Loss DY: 0.2420
# Step 2 | alpha 0.3936 | Epoch [1/1] | Batch [236/597] | Loss G: 3.9663 | Loss DX: 0.1734 | Loss DY: 0.1707
# Step 2 | alpha 0.3953 | Epoch [1/1] | Batch [237/597] | Loss G: 4.0024 | Loss DX: 0.2594 | Loss DY: 0.2560
# Step 2 | alpha 0.3970 | Epoch [1/1] | Batch [238/597] | Loss G: 3.9422 | Loss DX: 0.1807 | Loss DY: 0.2176
# Step 2 | alpha 0.3987 | Epoch [1/1] | Batch [239/597] | Loss G: 3.4638 | Loss DX: 0.2256 | Loss DY: 0.2013
# Step 2 | alpha 0.4003 | Epoch [1/1] | Batch [240/597] | Loss G: 2.6054 | Loss DX: 0.2868 | Loss DY: 0.2578
# Step 2 | alpha 0.4020 | Epoch [1/1] | Batch [241/597] | Loss G: 2.5410 | Loss DX: 0.1796 | Loss DY: 0.2029
# Step 2 | alpha 0.4037 | Epoch [1/1] | Batch [242/597] | Loss G: 3.6372 | Loss DX: 0.2021 | Loss DY: 0.2125
# Step 2 | alpha 0.4054 | Epoch [1/1] | Batch [243/597] | Loss G: 3.4595 | Loss DX: 0.1819 | Loss DY: 0.2024
# Step 2 | alpha 0.4070 | Epoch [1/1] | Batch [244/597] | Loss G: 3.5571 | Loss DX: 0.1931 | Loss DY: 0.2194
# Step 2 | alpha 0.4087 | Epoch [1/1] | Batch [245/597] | Loss G: 4.4448 | Loss DX: 0.2477 | Loss DY: 0.2591
# Step 2 | alpha 0.4104 | Epoch [1/1] | Batch [246/597] | Loss G: 3.9438 | Loss DX: 0.1646 | Loss DY: 0.1963
# Step 2 | alpha 0.4121 | Epoch [1/1] | Batch [247/597] | Loss G: 3.5359 | Loss DX: 0.2351 | Loss DY: 0.2056
# Step 2 | alpha 0.4137 | Epoch [1/1] | Batch [248/597] | Loss G: 2.7804 | Loss DX: 0.2815 | Loss DY: 0.2595
# Step 2 | alpha 0.4154 | Epoch [1/1] | Batch [249/597] | Loss G: 5.2793 | Loss DX: 0.1560 | Loss DY: 0.2644
# Step 2 | alpha 0.4171 | Epoch [1/1] | Batch [250/597] | Loss G: 3.8734 | Loss DX: 0.2029 | Loss DY: 0.1934
# Step 2 | alpha 0.4188 | Epoch [1/1] | Batch [251/597] | Loss G: 3.3214 | Loss DX: 0.2429 | Loss DY: 0.2472
# Step 2 | alpha 0.4204 | Epoch [1/1] | Batch [252/597] | Loss G: 3.3403 | Loss DX: 0.2567 | Loss DY: 0.2305
# Step 2 | alpha 0.4221 | Epoch [1/1] | Batch [253/597] | Loss G: 3.7228 | Loss DX: 0.2120 | Loss DY: 0.1891
# Step 2 | alpha 0.4238 | Epoch [1/1] | Batch [254/597] | Loss G: 3.1420 | Loss DX: 0.2232 | Loss DY: 0.2047
# Step 2 | alpha 0.4255 | Epoch [1/1] | Batch [255/597] | Loss G: 3.5665 | Loss DX: 0.1999 | Loss DY: 0.2256
# Step 2 | alpha 0.4271 | Epoch [1/1] | Batch [256/597] | Loss G: 3.5543 | Loss DX: 0.2433 | Loss DY: 0.2097
# Step 2 | alpha 0.4288 | Epoch [1/1] | Batch [257/597] | Loss G: 3.0312 | Loss DX: 0.1903 | Loss DY: 0.1927
# Step 2 | alpha 0.4305 | Epoch [1/1] | Batch [258/597] | Loss G: 3.3433 | Loss DX: 0.2651 | Loss DY: 0.2167
# Step 2 | alpha 0.4322 | Epoch [1/1] | Batch [259/597] | Loss G: 3.6030 | Loss DX: 0.1376 | Loss DY: 0.1848
# Step 2 | alpha 0.4338 | Epoch [1/1] | Batch [260/597] | Loss G: 2.9245 | Loss DX: 0.2399 | Loss DY: 0.2178
# Step 2 | alpha 0.4355 | Epoch [1/1] | Batch [261/597] | Loss G: 2.7148 | Loss DX: 0.2473 | Loss DY: 0.2397
# Step 2 | alpha 0.4372 | Epoch [1/1] | Batch [262/597] | Loss G: 3.5755 | Loss DX: 0.2383 | Loss DY: 0.2239
# Step 2 | alpha 0.4389 | Epoch [1/1] | Batch [263/597] | Loss G: 4.1129 | Loss DX: 0.1873 | Loss DY: 0.1877
# Step 2 | alpha 0.4405 | Epoch [1/1] | Batch [264/597] | Loss G: 3.5679 | Loss DX: 0.2455 | Loss DY: 0.2282
# Step 2 | alpha 0.4422 | Epoch [1/1] | Batch [265/597] | Loss G: 4.1519 | Loss DX: 0.1773 | Loss DY: 0.1804
# Step 2 | alpha 0.4439 | Epoch [1/1] | Batch [266/597] | Loss G: 3.2474 | Loss DX: 0.2388 | Loss DY: 0.2153
# Step 2 | alpha 0.4456 | Epoch [1/1] | Batch [267/597] | Loss G: 4.3922 | Loss DX: 0.1827 | Loss DY: 0.2777
# Step 2 | alpha 0.4472 | Epoch [1/1] | Batch [268/597] | Loss G: 3.8068 | Loss DX: 0.1874 | Loss DY: 0.1977
# Step 2 | alpha 0.4489 | Epoch [1/1] | Batch [269/597] | Loss G: 4.3116 | Loss DX: 0.2006 | Loss DY: 0.1922
# Step 2 | alpha 0.4506 | Epoch [1/1] | Batch [270/597] | Loss G: 3.1939 | Loss DX: 0.1819 | Loss DY: 0.2076
# Step 2 | alpha 0.4523 | Epoch [1/1] | Batch [271/597] | Loss G: 3.9669 | Loss DX: 0.2041 | Loss DY: 0.2520
# Step 2 | alpha 0.4539 | Epoch [1/1] | Batch [272/597] | Loss G: 4.5360 | Loss DX: 0.2809 | Loss DY: 0.2301
# Step 2 | alpha 0.4556 | Epoch [1/1] | Batch [273/597] | Loss G: 2.7934 | Loss DX: 0.2572 | Loss DY: 0.2501
# Step 2 | alpha 0.4573 | Epoch [1/1] | Batch [274/597] | Loss G: 3.7735 | Loss DX: 0.2491 | Loss DY: 0.2187
# Step 2 | alpha 0.4590 | Epoch [1/1] | Batch [275/597] | Loss G: 2.8142 | Loss DX: 0.2289 | Loss DY: 0.2447
# Step 2 | alpha 0.4606 | Epoch [1/1] | Batch [276/597] | Loss G: 2.7889 | Loss DX: 0.2193 | Loss DY: 0.2149
# Step 2 | alpha 0.4623 | Epoch [1/1] | Batch [277/597] | Loss G: 4.5363 | Loss DX: 0.2094 | Loss DY: 0.2619
# Step 2 | alpha 0.4640 | Epoch [1/1] | Batch [278/597] | Loss G: 3.4742 | Loss DX: 0.2089 | Loss DY: 0.2167
# Step 2 | alpha 0.4657 | Epoch [1/1] | Batch [279/597] | Loss G: 3.4734 | Loss DX: 0.2136 | Loss DY: 0.2231
# Step 2 | alpha 0.4673 | Epoch [1/1] | Batch [280/597] | Loss G: 3.8298 | Loss DX: 0.2544 | Loss DY: 0.2712
# Step 2 | alpha 0.4690 | Epoch [1/1] | Batch [281/597] | Loss G: 3.4725 | Loss DX: 0.2169 | Loss DY: 0.2130
# Step 2 | alpha 0.4707 | Epoch [1/1] | Batch [282/597] | Loss G: 2.9142 | Loss DX: 0.2531 | Loss DY: 0.2024
# Step 2 | alpha 0.4724 | Epoch [1/1] | Batch [283/597] | Loss G: 4.6070 | Loss DX: 0.2456 | Loss DY: 0.2821
# Step 2 | alpha 0.4740 | Epoch [1/1] | Batch [284/597] | Loss G: 3.5722 | Loss DX: 0.2184 | Loss DY: 0.2345
# Step 2 | alpha 0.4757 | Epoch [1/1] | Batch [285/597] | Loss G: 3.3632 | Loss DX: 0.2595 | Loss DY: 0.2031
# Step 2 | alpha 0.4774 | Epoch [1/1] | Batch [286/597] | Loss G: 3.5589 | Loss DX: 0.1983 | Loss DY: 0.2242
# Step 2 | alpha 0.4791 | Epoch [1/1] | Batch [287/597] | Loss G: 4.1588 | Loss DX: 0.1687 | Loss DY: 0.1802
# Step 2 | alpha 0.4807 | Epoch [1/1] | Batch [288/597] | Loss G: 3.5982 | Loss DX: 0.1602 | Loss DY: 0.1912
# Step 2 | alpha 0.4824 | Epoch [1/1] | Batch [289/597] | Loss G: 3.3460 | Loss DX: 0.2399 | Loss DY: 0.2187
# Step 2 | alpha 0.4841 | Epoch [1/1] | Batch [290/597] | Loss G: 3.4938 | Loss DX: 0.2022 | Loss DY: 0.1988
# Step 2 | alpha 0.4858 | Epoch [1/1] | Batch [291/597] | Loss G: 3.6944 | Loss DX: 0.2152 | Loss DY: 0.2232
# Step 2 | alpha 0.4874 | Epoch [1/1] | Batch [292/597] | Loss G: 3.5310 | Loss DX: 0.1999 | Loss DY: 0.1543
# Step 2 | alpha 0.4891 | Epoch [1/1] | Batch [293/597] | Loss G: 3.3236 | Loss DX: 0.1894 | Loss DY: 0.1967
# Step 2 | alpha 0.4908 | Epoch [1/1] | Batch [294/597] | Loss G: 3.2475 | Loss DX: 0.2716 | Loss DY: 0.2720
# Step 2 | alpha 0.4925 | Epoch [1/1] | Batch [295/597] | Loss G: 3.7894 | Loss DX: 0.1835 | Loss DY: 0.1734
# Step 2 | alpha 0.4941 | Epoch [1/1] | Batch [296/597] | Loss G: 3.8213 | Loss DX: 0.2092 | Loss DY: 0.2487
# Step 2 | alpha 0.4958 | Epoch [1/1] | Batch [297/597] | Loss G: 3.3913 | Loss DX: 0.2720 | Loss DY: 0.2895
# Step 2 | alpha 0.4975 | Epoch [1/1] | Batch [298/597] | Loss G: 3.3075 | Loss DX: 0.1601 | Loss DY: 0.1979
# Step 2 | alpha 0.4992 | Epoch [1/1] | Batch [299/597] | Loss G: 3.2042 | Loss DX: 0.2363 | Loss DY: 0.2687
# Step 2 | alpha 0.5008 | Epoch [1/1] | Batch [300/597] | Loss G: 3.3302 | Loss DX: 0.2600 | Loss DY: 0.2527
# Step 2 | alpha 0.5025 | Epoch [1/1] | Batch [301/597] | Loss G: 3.2312 | Loss DX: 0.2351 | Loss DY: 0.2274
# Step 2 | alpha 0.5042 | Epoch [1/1] | Batch [302/597] | Loss G: 3.4205 | Loss DX: 0.1982 | Loss DY: 0.2186
# Step 2 | alpha 0.5059 | Epoch [1/1] | Batch [303/597] | Loss G: 3.5680 | Loss DX: 0.2346 | Loss DY: 0.2170
# Step 2 | alpha 0.5075 | Epoch [1/1] | Batch [304/597] | Loss G: 3.6376 | Loss DX: 0.2476 | Loss DY: 0.2173
# Step 2 | alpha 0.5092 | Epoch [1/1] | Batch [305/597] | Loss G: 3.7054 | Loss DX: 0.2727 | Loss DY: 0.2237
# Step 2 | alpha 0.5109 | Epoch [1/1] | Batch [306/597] | Loss G: 2.9342 | Loss DX: 0.2161 | Loss DY: 0.1942
# Step 2 | alpha 0.5126 | Epoch [1/1] | Batch [307/597] | Loss G: 3.7261 | Loss DX: 0.2031 | Loss DY: 0.2034
# Step 2 | alpha 0.5142 | Epoch [1/1] | Batch [308/597] | Loss G: 4.6360 | Loss DX: 0.2331 | Loss DY: 0.2157
# Step 2 | alpha 0.5159 | Epoch [1/1] | Batch [309/597] | Loss G: 3.8434 | Loss DX: 0.2417 | Loss DY: 0.2365
# Step 2 | alpha 0.5176 | Epoch [1/1] | Batch [310/597] | Loss G: 4.0316 | Loss DX: 0.2017 | Loss DY: 0.2144
# Step 2 | alpha 0.5193 | Epoch [1/1] | Batch [311/597] | Loss G: 4.9977 | Loss DX: 0.2046 | Loss DY: 0.2574
# Step 2 | alpha 0.5209 | Epoch [1/1] | Batch [312/597] | Loss G: 3.8776 | Loss DX: 0.2267 | Loss DY: 0.2476
# Step 2 | alpha 0.5226 | Epoch [1/1] | Batch [313/597] | Loss G: 3.1207 | Loss DX: 0.1910 | Loss DY: 0.2008
# Step 2 | alpha 0.5243 | Epoch [1/1] | Batch [314/597] | Loss G: 3.3060 | Loss DX: 0.2186 | Loss DY: 0.1987
# Step 2 | alpha 0.5260 | Epoch [1/1] | Batch [315/597] | Loss G: 3.7831 | Loss DX: 0.1708 | Loss DY: 0.2348
# Step 2 | alpha 0.5276 | Epoch [1/1] | Batch [316/597] | Loss G: 3.1688 | Loss DX: 0.1934 | Loss DY: 0.2229
# Step 2 | alpha 0.5293 | Epoch [1/1] | Batch [317/597] | Loss G: 3.3911 | Loss DX: 0.1371 | Loss DY: 0.1994
# Step 2 | alpha 0.5310 | Epoch [1/1] | Batch [318/597] | Loss G: 3.9393 | Loss DX: 0.2114 | Loss DY: 0.2301
# Step 2 | alpha 0.5327 | Epoch [1/1] | Batch [319/597] | Loss G: 3.5733 | Loss DX: 0.1605 | Loss DY: 0.1760
# Step 2 | alpha 0.5343 | Epoch [1/1] | Batch [320/597] | Loss G: 3.2590 | Loss DX: 0.2925 | Loss DY: 0.2366
# Step 2 | alpha 0.5360 | Epoch [1/1] | Batch [321/597] | Loss G: 3.1319 | Loss DX: 0.2353 | Loss DY: 0.1869
# Step 2 | alpha 0.5377 | Epoch [1/1] | Batch [322/597] | Loss G: 3.0338 | Loss DX: 0.2404 | Loss DY: 0.2678
# Step 2 | alpha 0.5394 | Epoch [1/1] | Batch [323/597] | Loss G: 3.7758 | Loss DX: 0.2009 | Loss DY: 0.2100
# Step 2 | alpha 0.5410 | Epoch [1/1] | Batch [324/597] | Loss G: 3.4854 | Loss DX: 0.1935 | Loss DY: 0.2107
# Step 2 | alpha 0.5427 | Epoch [1/1] | Batch [325/597] | Loss G: 3.9127 | Loss DX: 0.2131 | Loss DY: 0.2031
# Step 2 | alpha 0.5444 | Epoch [1/1] | Batch [326/597] | Loss G: 3.4713 | Loss DX: 0.1640 | Loss DY: 0.2205
# Step 2 | alpha 0.5461 | Epoch [1/1] | Batch [327/597] | Loss G: 3.2044 | Loss DX: 0.2131 | Loss DY: 0.2282
# Step 2 | alpha 0.5477 | Epoch [1/1] | Batch [328/597] | Loss G: 3.6657 | Loss DX: 0.1332 | Loss DY: 0.1966
# Step 2 | alpha 0.5494 | Epoch [1/1] | Batch [329/597] | Loss G: 4.2147 | Loss DX: 0.1579 | Loss DY: 0.1499
# Step 2 | alpha 0.5511 | Epoch [1/1] | Batch [330/597] | Loss G: 3.0499 | Loss DX: 0.2892 | Loss DY: 0.2477
# Step 2 | alpha 0.5528 | Epoch [1/1] | Batch [331/597] | Loss G: 4.2237 | Loss DX: 0.2353 | Loss DY: 0.2526
# Step 2 | alpha 0.5544 | Epoch [1/1] | Batch [332/597] | Loss G: 3.3170 | Loss DX: 0.2020 | Loss DY: 0.1820
# Step 2 | alpha 0.5561 | Epoch [1/1] | Batch [333/597] | Loss G: 3.2525 | Loss DX: 0.2081 | Loss DY: 0.2025
# Step 2 | alpha 0.5578 | Epoch [1/1] | Batch [334/597] | Loss G: 4.1160 | Loss DX: 0.1658 | Loss DY: 0.1969
# Step 2 | alpha 0.5595 | Epoch [1/1] | Batch [335/597] | Loss G: 3.7588 | Loss DX: 0.2321 | Loss DY: 0.2900
# Step 2 | alpha 0.5611 | Epoch [1/1] | Batch [336/597] | Loss G: 3.3268 | Loss DX: 0.2062 | Loss DY: 0.2134
# Step 2 | alpha 0.5628 | Epoch [1/1] | Batch [337/597] | Loss G: 3.2305 | Loss DX: 0.2420 | Loss DY: 0.1937
# Step 2 | alpha 0.5645 | Epoch [1/1] | Batch [338/597] | Loss G: 3.5490 | Loss DX: 0.2199 | Loss DY: 0.2180
# Step 2 | alpha 0.5662 | Epoch [1/1] | Batch [339/597] | Loss G: 3.8037 | Loss DX: 0.1823 | Loss DY: 0.2331
# Step 2 | alpha 0.5678 | Epoch [1/1] | Batch [340/597] | Loss G: 3.3763 | Loss DX: 0.2039 | Loss DY: 0.2351
# Step 2 | alpha 0.5695 | Epoch [1/1] | Batch [341/597] | Loss G: 3.4504 | Loss DX: 0.2200 | Loss DY: 0.2238
# Step 2 | alpha 0.5712 | Epoch [1/1] | Batch [342/597] | Loss G: 3.5151 | Loss DX: 0.1815 | Loss DY: 0.2174
# Step 2 | alpha 0.5729 | Epoch [1/1] | Batch [343/597] | Loss G: 3.7076 | Loss DX: 0.2405 | Loss DY: 0.2199
# Step 2 | alpha 0.5745 | Epoch [1/1] | Batch [344/597] | Loss G: 3.1746 | Loss DX: 0.1704 | Loss DY: 0.2113
# Step 2 | alpha 0.5762 | Epoch [1/1] | Batch [345/597] | Loss G: 3.5133 | Loss DX: 0.1749 | Loss DY: 0.1855
# Step 2 | alpha 0.5779 | Epoch [1/1] | Batch [346/597] | Loss G: 3.1328 | Loss DX: 0.2061 | Loss DY: 0.2508
# Step 2 | alpha 0.5796 | Epoch [1/1] | Batch [347/597] | Loss G: 3.5560 | Loss DX: 0.2625 | Loss DY: 0.2777
# Step 2 | alpha 0.5812 | Epoch [1/1] | Batch [348/597] | Loss G: 4.0046 | Loss DX: 0.1849 | Loss DY: 0.2331
# Step 2 | alpha 0.5829 | Epoch [1/1] | Batch [349/597] | Loss G: 3.8660 | Loss DX: 0.2865 | Loss DY: 0.2378
# Step 2 | alpha 0.5846 | Epoch [1/1] | Batch [350/597] | Loss G: 3.6104 | Loss DX: 0.1833 | Loss DY: 0.2329
# Step 2 | alpha 0.5863 | Epoch [1/1] | Batch [351/597] | Loss G: 4.4282 | Loss DX: 0.1953 | Loss DY: 0.1966
# Step 2 | alpha 0.5879 | Epoch [1/1] | Batch [352/597] | Loss G: 4.1620 | Loss DX: 0.1800 | Loss DY: 0.2709
# Step 2 | alpha 0.5896 | Epoch [1/1] | Batch [353/597] | Loss G: 3.3446 | Loss DX: 0.1923 | Loss DY: 0.2054
# Step 2 | alpha 0.5913 | Epoch [1/1] | Batch [354/597] | Loss G: 3.6289 | Loss DX: 0.2295 | Loss DY: 0.2078
# Step 2 | alpha 0.5930 | Epoch [1/1] | Batch [355/597] | Loss G: 3.6349 | Loss DX: 0.2290 | Loss DY: 0.2243
# Step 2 | alpha 0.5946 | Epoch [1/1] | Batch [356/597] | Loss G: 3.0233 | Loss DX: 0.2635 | Loss DY: 0.2121
# Step 2 | alpha 0.5963 | Epoch [1/1] | Batch [357/597] | Loss G: 4.6667 | Loss DX: 0.1434 | Loss DY: 0.2121
# Step 2 | alpha 0.5980 | Epoch [1/1] | Batch [358/597] | Loss G: 4.0560 | Loss DX: 0.1671 | Loss DY: 0.2013
# Step 2 | alpha 0.5997 | Epoch [1/1] | Batch [359/597] | Loss G: 3.4825 | Loss DX: 0.2257 | Loss DY: 0.1847
# Step 2 | alpha 0.6013 | Epoch [1/1] | Batch [360/597] | Loss G: 4.1024 | Loss DX: 0.1869 | Loss DY: 0.2207
# Step 2 | alpha 0.6030 | Epoch [1/1] | Batch [361/597] | Loss G: 3.2101 | Loss DX: 0.3014 | Loss DY: 0.2033
# Step 2 | alpha 0.6047 | Epoch [1/1] | Batch [362/597] | Loss G: 3.6112 | Loss DX: 0.1985 | Loss DY: 0.2271
# Step 2 | alpha 0.6064 | Epoch [1/1] | Batch [363/597] | Loss G: 3.6362 | Loss DX: 0.2113 | Loss DY: 0.2292
# Step 2 | alpha 0.6080 | Epoch [1/1] | Batch [364/597] | Loss G: 3.1786 | Loss DX: 0.2571 | Loss DY: 0.2203
# Step 2 | alpha 0.6097 | Epoch [1/1] | Batch [365/597] | Loss G: 3.3163 | Loss DX: 0.1977 | Loss DY: 0.2333
# Step 2 | alpha 0.6114 | Epoch [1/1] | Batch [366/597] | Loss G: 3.6246 | Loss DX: 0.1598 | Loss DY: 0.1859
# Step 2 | alpha 0.6131 | Epoch [1/1] | Batch [367/597] | Loss G: 4.0971 | Loss DX: 0.2255 | Loss DY: 0.2299
# Step 2 | alpha 0.6147 | Epoch [1/1] | Batch [368/597] | Loss G: 3.7827 | Loss DX: 0.1798 | Loss DY: 0.2297
# Step 2 | alpha 0.6164 | Epoch [1/1] | Batch [369/597] | Loss G: 3.2797 | Loss DX: 0.1657 | Loss DY: 0.2473
# Step 2 | alpha 0.6181 | Epoch [1/1] | Batch [370/597] | Loss G: 3.5629 | Loss DX: 0.2352 | Loss DY: 0.2677
# Step 2 | alpha 0.6198 | Epoch [1/1] | Batch [371/597] | Loss G: 4.1025 | Loss DX: 0.2956 | Loss DY: 0.2539
# Step 2 | alpha 0.6214 | Epoch [1/1] | Batch [372/597] | Loss G: 3.5664 | Loss DX: 0.2232 | Loss DY: 0.3099
# Step 2 | alpha 0.6231 | Epoch [1/1] | Batch [373/597] | Loss G: 3.0865 | Loss DX: 0.2036 | Loss DY: 0.2204
# Step 2 | alpha 0.6248 | Epoch [1/1] | Batch [374/597] | Loss G: 3.3697 | Loss DX: 0.2770 | Loss DY: 0.2222
# Step 2 | alpha 0.6265 | Epoch [1/1] | Batch [375/597] | Loss G: 3.5578 | Loss DX: 0.1777 | Loss DY: 0.2178
# Step 2 | alpha 0.6281 | Epoch [1/1] | Batch [376/597] | Loss G: 3.5193 | Loss DX: 0.1803 | Loss DY: 0.1915
# Step 2 | alpha 0.6298 | Epoch [1/1] | Batch [377/597] | Loss G: 3.6541 | Loss DX: 0.2248 | Loss DY: 0.2556
# Step 2 | alpha 0.6315 | Epoch [1/1] | Batch [378/597] | Loss G: 3.5134 | Loss DX: 0.1586 | Loss DY: 0.1980
# Step 2 | alpha 0.6332 | Epoch [1/1] | Batch [379/597] | Loss G: 3.7216 | Loss DX: 0.2005 | Loss DY: 0.2158
# Step 2 | alpha 0.6348 | Epoch [1/1] | Batch [380/597] | Loss G: 4.9583 | Loss DX: 0.2072 | Loss DY: 0.2289
# Step 2 | alpha 0.6365 | Epoch [1/1] | Batch [381/597] | Loss G: 3.5758 | Loss DX: 0.2793 | Loss DY: 0.2685
# Step 2 | alpha 0.6382 | Epoch [1/1] | Batch [382/597] | Loss G: 4.3951 | Loss DX: 0.1742 | Loss DY: 0.1793
# Step 2 | alpha 0.6399 | Epoch [1/1] | Batch [383/597] | Loss G: 4.0074 | Loss DX: 0.1992 | Loss DY: 0.1850
# Step 2 | alpha 0.6415 | Epoch [1/1] | Batch [384/597] | Loss G: 3.8264 | Loss DX: 0.2373 | Loss DY: 0.2192
# Step 2 | alpha 0.6432 | Epoch [1/1] | Batch [385/597] | Loss G: 3.5510 | Loss DX: 0.2389 | Loss DY: 0.2179
# Step 2 | alpha 0.6449 | Epoch [1/1] | Batch [386/597] | Loss G: 4.1264 | Loss DX: 0.1805 | Loss DY: 0.1748
# Step 2 | alpha 0.6466 | Epoch [1/1] | Batch [387/597] | Loss G: 4.3337 | Loss DX: 0.1397 | Loss DY: 0.2204
# Step 2 | alpha 0.6482 | Epoch [1/1] | Batch [388/597] | Loss G: 3.8224 | Loss DX: 0.1666 | Loss DY: 0.2073
# Step 2 | alpha 0.6499 | Epoch [1/1] | Batch [389/597] | Loss G: 3.9519 | Loss DX: 0.2257 | Loss DY: 0.2148
# Step 2 | alpha 0.6516 | Epoch [1/1] | Batch [390/597] | Loss G: 3.7839 | Loss DX: 0.2102 | Loss DY: 0.2537
# Step 2 | alpha 0.6533 | Epoch [1/1] | Batch [391/597] | Loss G: 2.7842 | Loss DX: 0.2570 | Loss DY: 0.2460
# Step 2 | alpha 0.6549 | Epoch [1/1] | Batch [392/597] | Loss G: 3.3576 | Loss DX: 0.2130 | Loss DY: 0.1839
# Step 2 | alpha 0.6566 | Epoch [1/1] | Batch [393/597] | Loss G: 3.5426 | Loss DX: 0.1765 | Loss DY: 0.2137
# Step 2 | alpha 0.6583 | Epoch [1/1] | Batch [394/597] | Loss G: 3.6013 | Loss DX: 0.2971 | Loss DY: 0.2413
# Step 2 | alpha 0.6600 | Epoch [1/1] | Batch [395/597] | Loss G: 3.6207 | Loss DX: 0.1868 | Loss DY: 0.2411
# Step 2 | alpha 0.6616 | Epoch [1/1] | Batch [396/597] | Loss G: 3.3982 | Loss DX: 0.2105 | Loss DY: 0.1931
# Step 2 | alpha 0.6633 | Epoch [1/1] | Batch [397/597] | Loss G: 3.1688 | Loss DX: 0.2058 | Loss DY: 0.2130
# Step 2 | alpha 0.6650 | Epoch [1/1] | Batch [398/597] | Loss G: 3.4338 | Loss DX: 0.1321 | Loss DY: 0.1855
# Step 2 | alpha 0.6667 | Epoch [1/1] | Batch [399/597] | Loss G: 3.5228 | Loss DX: 0.2037 | Loss DY: 0.2263
# Step 2 | alpha 0.6683 | Epoch [1/1] | Batch [400/597] | Loss G: 3.5625 | Loss DX: 0.2074 | Loss DY: 0.1961
# Step 2 | alpha 0.6700 | Epoch [1/1] | Batch [401/597] | Loss G: 3.4614 | Loss DX: 0.1950 | Loss DY: 0.2130
# Step 2 | alpha 0.6717 | Epoch [1/1] | Batch [402/597] | Loss G: 2.4998 | Loss DX: 0.3119 | Loss DY: 0.2809
# Step 2 | alpha 0.6734 | Epoch [1/1] | Batch [403/597] | Loss G: 3.1086 | Loss DX: 0.2674 | Loss DY: 0.2169
# Step 2 | alpha 0.6750 | Epoch [1/1] | Batch [404/597] | Loss G: 4.1140 | Loss DX: 0.1849 | Loss DY: 0.1932
# Step 2 | alpha 0.6767 | Epoch [1/1] | Batch [405/597] | Loss G: 3.4671 | Loss DX: 0.2063 | Loss DY: 0.2105
# Step 2 | alpha 0.6784 | Epoch [1/1] | Batch [406/597] | Loss G: 4.3529 | Loss DX: 0.2272 | Loss DY: 0.1923
# Step 2 | alpha 0.6801 | Epoch [1/1] | Batch [407/597] | Loss G: 4.5191 | Loss DX: 0.2125 | Loss DY: 0.2796
# Step 2 | alpha 0.6817 | Epoch [1/1] | Batch [408/597] | Loss G: 3.8201 | Loss DX: 0.2680 | Loss DY: 0.2736
# Step 2 | alpha 0.6834 | Epoch [1/1] | Batch [409/597] | Loss G: 3.9156 | Loss DX: 0.1425 | Loss DY: 0.1794
# Step 2 | alpha 0.6851 | Epoch [1/1] | Batch [410/597] | Loss G: 4.2542 | Loss DX: 0.2487 | Loss DY: 0.2092
# Step 2 | alpha 0.6868 | Epoch [1/1] | Batch [411/597] | Loss G: 4.2088 | Loss DX: 0.2032 | Loss DY: 0.2158
# Step 2 | alpha 0.6884 | Epoch [1/1] | Batch [412/597] | Loss G: 3.5954 | Loss DX: 0.1620 | Loss DY: 0.2200
# Step 2 | alpha 0.6901 | Epoch [1/1] | Batch [413/597] | Loss G: 3.4723 | Loss DX: 0.1957 | Loss DY: 0.1994
# Step 2 | alpha 0.6918 | Epoch [1/1] | Batch [414/597] | Loss G: 4.3063 | Loss DX: 0.2157 | Loss DY: 0.2244
# Step 2 | alpha 0.6935 | Epoch [1/1] | Batch [415/597] | Loss G: 3.3609 | Loss DX: 0.2540 | Loss DY: 0.1913
# Step 2 | alpha 0.6951 | Epoch [1/1] | Batch [416/597] | Loss G: 3.8931 | Loss DX: 0.2388 | Loss DY: 0.2429
# Step 2 | alpha 0.6968 | Epoch [1/1] | Batch [417/597] | Loss G: 3.4252 | Loss DX: 0.2055 | Loss DY: 0.2334
# Step 2 | alpha 0.6985 | Epoch [1/1] | Batch [418/597] | Loss G: 4.3204 | Loss DX: 0.2579 | Loss DY: 0.2552
# Step 2 | alpha 0.7002 | Epoch [1/1] | Batch [419/597] | Loss G: 3.8630 | Loss DX: 0.2791 | Loss DY: 0.2268
# Step 2 | alpha 0.7018 | Epoch [1/1] | Batch [420/597] | Loss G: 3.2614 | Loss DX: 0.2268 | Loss DY: 0.2324
# Step 2 | alpha 0.7035 | Epoch [1/1] | Batch [421/597] | Loss G: 3.9677 | Loss DX: 0.2076 | Loss DY: 0.2024
# Step 2 | alpha 0.7052 | Epoch [1/1] | Batch [422/597] | Loss G: 3.9084 | Loss DX: 0.1762 | Loss DY: 0.1799
# Step 2 | alpha 0.7069 | Epoch [1/1] | Batch [423/597] | Loss G: 4.1508 | Loss DX: 0.1931 | Loss DY: 0.2686
# Step 2 | alpha 0.7085 | Epoch [1/1] | Batch [424/597] | Loss G: 3.6740 | Loss DX: 0.2551 | Loss DY: 0.2223
# Step 2 | alpha 0.7102 | Epoch [1/1] | Batch [425/597] | Loss G: 3.2610 | Loss DX: 0.2497 | Loss DY: 0.2134
# Step 2 | alpha 0.7119 | Epoch [1/1] | Batch [426/597] | Loss G: 3.1752 | Loss DX: 0.2632 | Loss DY: 0.2374
# Step 2 | alpha 0.7136 | Epoch [1/1] | Batch [427/597] | Loss G: 3.0847 | Loss DX: 0.1984 | Loss DY: 0.2189
# Step 2 | alpha 0.7152 | Epoch [1/1] | Batch [428/597] | Loss G: 3.5462 | Loss DX: 0.1848 | Loss DY: 0.2282
# Step 2 | alpha 0.7169 | Epoch [1/1] | Batch [429/597] | Loss G: 4.0591 | Loss DX: 0.2392 | Loss DY: 0.2435
# Step 2 | alpha 0.7186 | Epoch [1/1] | Batch [430/597] | Loss G: 3.6528 | Loss DX: 0.1652 | Loss DY: 0.2418
# Step 2 | alpha 0.7203 | Epoch [1/1] | Batch [431/597] | Loss G: 3.3554 | Loss DX: 0.2294 | Loss DY: 0.2487
# Step 2 | alpha 0.7219 | Epoch [1/1] | Batch [432/597] | Loss G: 3.6032 | Loss DX: 0.2033 | Loss DY: 0.2053
# Step 2 | alpha 0.7236 | Epoch [1/1] | Batch [433/597] | Loss G: 4.0646 | Loss DX: 0.2219 | Loss DY: 0.2039
# Step 2 | alpha 0.7253 | Epoch [1/1] | Batch [434/597] | Loss G: 3.8614 | Loss DX: 0.2309 | Loss DY: 0.2195
# Step 2 | alpha 0.7270 | Epoch [1/1] | Batch [435/597] | Loss G: 3.5747 | Loss DX: 0.2036 | Loss DY: 0.2081
# Step 2 | alpha 0.7286 | Epoch [1/1] | Batch [436/597] | Loss G: 2.7583 | Loss DX: 0.2533 | Loss DY: 0.2343
# Step 2 | alpha 0.7303 | Epoch [1/1] | Batch [437/597] | Loss G: 5.1151 | Loss DX: 0.2234 | Loss DY: 0.1862
# Step 2 | alpha 0.7320 | Epoch [1/1] | Batch [438/597] | Loss G: 3.3051 | Loss DX: 0.2562 | Loss DY: 0.2138
# Step 2 | alpha 0.7337 | Epoch [1/1] | Batch [439/597] | Loss G: 3.1083 | Loss DX: 0.2939 | Loss DY: 0.2117
# Step 2 | alpha 0.7353 | Epoch [1/1] | Batch [440/597] | Loss G: 3.3310 | Loss DX: 0.1734 | Loss DY: 0.1923
# Step 2 | alpha 0.7370 | Epoch [1/1] | Batch [441/597] | Loss G: 3.9015 | Loss DX: 0.2012 | Loss DY: 0.1965
# Step 2 | alpha 0.7387 | Epoch [1/1] | Batch [442/597] | Loss G: 4.2279 | Loss DX: 0.1626 | Loss DY: 0.2180
# Step 2 | alpha 0.7404 | Epoch [1/1] | Batch [443/597] | Loss G: 3.5545 | Loss DX: 0.2741 | Loss DY: 0.2251
# Step 2 | alpha 0.7420 | Epoch [1/1] | Batch [444/597] | Loss G: 2.9092 | Loss DX: 0.2420 | Loss DY: 0.2084
# Step 2 | alpha 0.7437 | Epoch [1/1] | Batch [445/597] | Loss G: 3.4544 | Loss DX: 0.2122 | Loss DY: 0.2252
# Step 2 | alpha 0.7454 | Epoch [1/1] | Batch [446/597] | Loss G: 3.1143 | Loss DX: 0.2258 | Loss DY: 0.2333
# Step 2 | alpha 0.7471 | Epoch [1/1] | Batch [447/597] | Loss G: 3.9582 | Loss DX: 0.2132 | Loss DY: 0.2374
# Step 2 | alpha 0.7487 | Epoch [1/1] | Batch [448/597] | Loss G: 3.9998 | Loss DX: 0.2047 | Loss DY: 0.2133
# Step 2 | alpha 0.7504 | Epoch [1/1] | Batch [449/597] | Loss G: 3.4271 | Loss DX: 0.1724 | Loss DY: 0.1977
# Step 2 | alpha 0.7521 | Epoch [1/1] | Batch [450/597] | Loss G: 3.0511 | Loss DX: 0.2566 | Loss DY: 0.2300
# Step 2 | alpha 0.7538 | Epoch [1/1] | Batch [451/597] | Loss G: 4.3960 | Loss DX: 0.2185 | Loss DY: 0.2401
# Step 2 | alpha 0.7554 | Epoch [1/1] | Batch [452/597] | Loss G: 3.2482 | Loss DX: 0.2117 | Loss DY: 0.2068
# Step 2 | alpha 0.7571 | Epoch [1/1] | Batch [453/597] | Loss G: 3.2508 | Loss DX: 0.2444 | Loss DY: 0.2424
# Step 2 | alpha 0.7588 | Epoch [1/1] | Batch [454/597] | Loss G: 3.7485 | Loss DX: 0.1753 | Loss DY: 0.1594
# Step 2 | alpha 0.7605 | Epoch [1/1] | Batch [455/597] | Loss G: 3.4579 | Loss DX: 0.2231 | Loss DY: 0.2160
# Step 2 | alpha 0.7621 | Epoch [1/1] | Batch [456/597] | Loss G: 4.1408 | Loss DX: 0.1824 | Loss DY: 0.2558
# Step 2 | alpha 0.7638 | Epoch [1/1] | Batch [457/597] | Loss G: 2.8937 | Loss DX: 0.2513 | Loss DY: 0.2628
# Step 2 | alpha 0.7655 | Epoch [1/1] | Batch [458/597] | Loss G: 3.5157 | Loss DX: 0.2459 | Loss DY: 0.2109
# Step 2 | alpha 0.7672 | Epoch [1/1] | Batch [459/597] | Loss G: 3.6374 | Loss DX: 0.2287 | Loss DY: 0.2404
# Step 2 | alpha 0.7688 | Epoch [1/1] | Batch [460/597] | Loss G: 3.3901 | Loss DX: 0.1946 | Loss DY: 0.2535
# Step 2 | alpha 0.7705 | Epoch [1/1] | Batch [461/597] | Loss G: 3.2625 | Loss DX: 0.2439 | Loss DY: 0.2585
# Step 2 | alpha 0.7722 | Epoch [1/1] | Batch [462/597] | Loss G: 4.1889 | Loss DX: 0.2530 | Loss DY: 0.2377
# Step 2 | alpha 0.7739 | Epoch [1/1] | Batch [463/597] | Loss G: 4.3158 | Loss DX: 0.2215 | Loss DY: 0.2449
# Step 2 | alpha 0.7755 | Epoch [1/1] | Batch [464/597] | Loss G: 4.1365 | Loss DX: 0.2067 | Loss DY: 0.2221
# Step 2 | alpha 0.7772 | Epoch [1/1] | Batch [465/597] | Loss G: 4.2447 | Loss DX: 0.2342 | Loss DY: 0.2160
# Step 2 | alpha 0.7789 | Epoch [1/1] | Batch [466/597] | Loss G: 4.2881 | Loss DX: 0.1872 | Loss DY: 0.2163
# Step 2 | alpha 0.7806 | Epoch [1/1] | Batch [467/597] | Loss G: 3.0818 | Loss DX: 0.2367 | Loss DY: 0.2208
# Step 2 | alpha 0.7822 | Epoch [1/1] | Batch [468/597] | Loss G: 3.6158 | Loss DX: 0.2397 | Loss DY: 0.2462
# Step 2 | alpha 0.7839 | Epoch [1/1] | Batch [469/597] | Loss G: 3.2340 | Loss DX: 0.2058 | Loss DY: 0.2102
# Step 2 | alpha 0.7856 | Epoch [1/1] | Batch [470/597] | Loss G: 3.6154 | Loss DX: 0.2395 | Loss DY: 0.2248
# Step 2 | alpha 0.7873 | Epoch [1/1] | Batch [471/597] | Loss G: 3.4028 | Loss DX: 0.2112 | Loss DY: 0.2124
# Step 2 | alpha 0.7889 | Epoch [1/1] | Batch [472/597] | Loss G: 4.7175 | Loss DX: 0.2730 | Loss DY: 0.2462
# Step 2 | alpha 0.7906 | Epoch [1/1] | Batch [473/597] | Loss G: 4.0198 | Loss DX: 0.2102 | Loss DY: 0.2267
# Step 2 | alpha 0.7923 | Epoch [1/1] | Batch [474/597] | Loss G: 3.8740 | Loss DX: 0.2084 | Loss DY: 0.1531
# Step 2 | alpha 0.7940 | Epoch [1/1] | Batch [475/597] | Loss G: 4.3950 | Loss DX: 0.2514 | Loss DY: 0.2184
# Step 2 | alpha 0.7956 | Epoch [1/1] | Batch [476/597] | Loss G: 3.9411 | Loss DX: 0.2639 | Loss DY: 0.2077
# Step 2 | alpha 0.7973 | Epoch [1/1] | Batch [477/597] | Loss G: 3.7788 | Loss DX: 0.2478 | Loss DY: 0.2418
# Step 2 | alpha 0.7990 | Epoch [1/1] | Batch [478/597] | Loss G: 3.1167 | Loss DX: 0.2193 | Loss DY: 0.2504
# Step 2 | alpha 0.8007 | Epoch [1/1] | Batch [479/597] | Loss G: 4.5175 | Loss DX: 0.1910 | Loss DY: 0.1788
# Step 2 | alpha 0.8023 | Epoch [1/1] | Batch [480/597] | Loss G: 3.4769 | Loss DX: 0.2051 | Loss DY: 0.2299
# Step 2 | alpha 0.8040 | Epoch [1/1] | Batch [481/597] | Loss G: 4.3683 | Loss DX: 0.2303 | Loss DY: 0.1872
# Step 2 | alpha 0.8057 | Epoch [1/1] | Batch [482/597] | Loss G: 3.3783 | Loss DX: 0.2095 | Loss DY: 0.2160
# Step 2 | alpha 0.8074 | Epoch [1/1] | Batch [483/597] | Loss G: 3.8532 | Loss DX: 0.2297 | Loss DY: 0.2105
# Step 2 | alpha 0.8090 | Epoch [1/1] | Batch [484/597] | Loss G: 3.1082 | Loss DX: 0.1975 | Loss DY: 0.2213
# Step 2 | alpha 0.8107 | Epoch [1/1] | Batch [485/597] | Loss G: 3.0398 | Loss DX: 0.2025 | Loss DY: 0.2016
# Step 2 | alpha 0.8124 | Epoch [1/1] | Batch [486/597] | Loss G: 3.7745 | Loss DX: 0.2048 | Loss DY: 0.1854
# Step 2 | alpha 0.8141 | Epoch [1/1] | Batch [487/597] | Loss G: 4.0624 | Loss DX: 0.2196 | Loss DY: 0.2224
# Step 2 | alpha 0.8157 | Epoch [1/1] | Batch [488/597] | Loss G: 3.9700 | Loss DX: 0.1827 | Loss DY: 0.2219
# Step 2 | alpha 0.8174 | Epoch [1/1] | Batch [489/597] | Loss G: 3.9505 | Loss DX: 0.2508 | Loss DY: 0.2649
# Step 2 | alpha 0.8191 | Epoch [1/1] | Batch [490/597] | Loss G: 3.6757 | Loss DX: 0.1990 | Loss DY: 0.2325
# Step 2 | alpha 0.8208 | Epoch [1/1] | Batch [491/597] | Loss G: 3.4929 | Loss DX: 0.1941 | Loss DY: 0.2303
# Step 2 | alpha 0.8224 | Epoch [1/1] | Batch [492/597] | Loss G: 4.0451 | Loss DX: 0.2171 | Loss DY: 0.2205
# Step 2 | alpha 0.8241 | Epoch [1/1] | Batch [493/597] | Loss G: 3.1373 | Loss DX: 0.1930 | Loss DY: 0.2782
# Step 2 | alpha 0.8258 | Epoch [1/1] | Batch [494/597] | Loss G: 3.9370 | Loss DX: 0.2605 | Loss DY: 0.2053
# Step 2 | alpha 0.8275 | Epoch [1/1] | Batch [495/597] | Loss G: 3.5115 | Loss DX: 0.2181 | Loss DY: 0.2358
# Step 2 | alpha 0.8291 | Epoch [1/1] | Batch [496/597] | Loss G: 3.6393 | Loss DX: 0.2041 | Loss DY: 0.1996
# Step 2 | alpha 0.8308 | Epoch [1/1] | Batch [497/597] | Loss G: 3.8114 | Loss DX: 0.1888 | Loss DY: 0.2006
# Step 2 | alpha 0.8325 | Epoch [1/1] | Batch [498/597] | Loss G: 2.9026 | Loss DX: 0.2275 | Loss DY: 0.1921
# Step 2 | alpha 0.8342 | Epoch [1/1] | Batch [499/597] | Loss G: 2.9811 | Loss DX: 0.2552 | Loss DY: 0.2275
# Step 2 | alpha 0.8358 | Epoch [1/1] | Batch [500/597] | Loss G: 3.6155 | Loss DX: 0.2343 | Loss DY: 0.2157
# Step 2 | alpha 0.8375 | Epoch [1/1] | Batch [501/597] | Loss G: 3.2693 | Loss DX: 0.2452 | Loss DY: 0.1680
# Step 2 | alpha 0.8392 | Epoch [1/1] | Batch [502/597] | Loss G: 3.4143 | Loss DX: 0.2371 | Loss DY: 0.2735
# Step 2 | alpha 0.8409 | Epoch [1/1] | Batch [503/597] | Loss G: 3.2781 | Loss DX: 0.2361 | Loss DY: 0.2120
# Step 2 | alpha 0.8425 | Epoch [1/1] | Batch [504/597] | Loss G: 3.3209 | Loss DX: 0.1992 | Loss DY: 0.2154
# Step 2 | alpha 0.8442 | Epoch [1/1] | Batch [505/597] | Loss G: 4.1975 | Loss DX: 0.1946 | Loss DY: 0.1951
# Step 2 | alpha 0.8459 | Epoch [1/1] | Batch [506/597] | Loss G: 3.1992 | Loss DX: 0.2507 | Loss DY: 0.2488
# Step 2 | alpha 0.8476 | Epoch [1/1] | Batch [507/597] | Loss G: 4.7960 | Loss DX: 0.2752 | Loss DY: 0.2323
# Step 2 | alpha 0.8492 | Epoch [1/1] | Batch [508/597] | Loss G: 4.4533 | Loss DX: 0.2258 | Loss DY: 0.2097
# Step 2 | alpha 0.8509 | Epoch [1/1] | Batch [509/597] | Loss G: 3.5842 | Loss DX: 0.2265 | Loss DY: 0.1995
# Step 2 | alpha 0.8526 | Epoch [1/1] | Batch [510/597] | Loss G: 4.1682 | Loss DX: 0.2269 | Loss DY: 0.2061
# Step 2 | alpha 0.8543 | Epoch [1/1] | Batch [511/597] | Loss G: 3.8327 | Loss DX: 0.1814 | Loss DY: 0.1975
# Step 2 | alpha 0.8559 | Epoch [1/1] | Batch [512/597] | Loss G: 4.8213 | Loss DX: 0.1744 | Loss DY: 0.2016
# Step 2 | alpha 0.8576 | Epoch [1/1] | Batch [513/597] | Loss G: 3.1478 | Loss DX: 0.2420 | Loss DY: 0.2506
# Step 2 | alpha 0.8593 | Epoch [1/1] | Batch [514/597] | Loss G: 3.2135 | Loss DX: 0.2308 | Loss DY: 0.2251
# Step 2 | alpha 0.8610 | Epoch [1/1] | Batch [515/597] | Loss G: 2.9878 | Loss DX: 0.1796 | Loss DY: 0.2000
# Step 2 | alpha 0.8626 | Epoch [1/1] | Batch [516/597] | Loss G: 3.1514 | Loss DX: 0.1917 | Loss DY: 0.2311
# Step 2 | alpha 0.8643 | Epoch [1/1] | Batch [517/597] | Loss G: 3.6976 | Loss DX: 0.1736 | Loss DY: 0.2091
# Step 2 | alpha 0.8660 | Epoch [1/1] | Batch [518/597] | Loss G: 2.9905 | Loss DX: 0.2321 | Loss DY: 0.2010
# Step 2 | alpha 0.8677 | Epoch [1/1] | Batch [519/597] | Loss G: 4.0493 | Loss DX: 0.2348 | Loss DY: 0.2417
# Step 2 | alpha 0.8693 | Epoch [1/1] | Batch [520/597] | Loss G: 3.4169 | Loss DX: 0.2468 | Loss DY: 0.2377
# Step 2 | alpha 0.8710 | Epoch [1/1] | Batch [521/597] | Loss G: 3.3876 | Loss DX: 0.2170 | Loss DY: 0.1709
# Step 2 | alpha 0.8727 | Epoch [1/1] | Batch [522/597] | Loss G: 3.7971 | Loss DX: 0.2143 | Loss DY: 0.2002
# Step 2 | alpha 0.8744 | Epoch [1/1] | Batch [523/597] | Loss G: 3.7997 | Loss DX: 0.2073 | Loss DY: 0.1703
# Step 2 | alpha 0.8760 | Epoch [1/1] | Batch [524/597] | Loss G: 3.1578 | Loss DX: 0.2895 | Loss DY: 0.2288
# Step 2 | alpha 0.8777 | Epoch [1/1] | Batch [525/597] | Loss G: 2.9047 | Loss DX: 0.2337 | Loss DY: 0.2578
# Step 2 | alpha 0.8794 | Epoch [1/1] | Batch [526/597] | Loss G: 2.7859 | Loss DX: 0.2514 | Loss DY: 0.2486
# Step 2 | alpha 0.8811 | Epoch [1/1] | Batch [527/597] | Loss G: 3.4062 | Loss DX: 0.2285 | Loss DY: 0.2442
# Step 2 | alpha 0.8827 | Epoch [1/1] | Batch [528/597] | Loss G: 2.9316 | Loss DX: 0.2467 | Loss DY: 0.2382
# Step 2 | alpha 0.8844 | Epoch [1/1] | Batch [529/597] | Loss G: 2.5046 | Loss DX: 0.2314 | Loss DY: 0.2431
# Step 2 | alpha 0.8861 | Epoch [1/1] | Batch [530/597] | Loss G: 2.6987 | Loss DX: 0.2113 | Loss DY: 0.2012
# Step 2 | alpha 0.8878 | Epoch [1/1] | Batch [531/597] | Loss G: 3.4792 | Loss DX: 0.1997 | Loss DY: 0.2217
# Step 2 | alpha 0.8894 | Epoch [1/1] | Batch [532/597] | Loss G: 4.2881 | Loss DX: 0.1881 | Loss DY: 0.2525
# Step 2 | alpha 0.8911 | Epoch [1/1] | Batch [533/597] | Loss G: 3.2307 | Loss DX: 0.1879 | Loss DY: 0.2112
# Step 2 | alpha 0.8928 | Epoch [1/1] | Batch [534/597] | Loss G: 3.4545 | Loss DX: 0.2516 | Loss DY: 0.2140
# Step 2 | alpha 0.8945 | Epoch [1/1] | Batch [535/597] | Loss G: 3.2777 | Loss DX: 0.2294 | Loss DY: 0.2167
# Step 2 | alpha 0.8961 | Epoch [1/1] | Batch [536/597] | Loss G: 3.7446 | Loss DX: 0.2584 | Loss DY: 0.2251
# Step 2 | alpha 0.8978 | Epoch [1/1] | Batch [537/597] | Loss G: 3.4333 | Loss DX: 0.2409 | Loss DY: 0.2363
# Step 2 | alpha 0.8995 | Epoch [1/1] | Batch [538/597] | Loss G: 4.0071 | Loss DX: 0.1995 | Loss DY: 0.2195
# Step 2 | alpha 0.9012 | Epoch [1/1] | Batch [539/597] | Loss G: 3.6495 | Loss DX: 0.2291 | Loss DY: 0.2056
# Step 2 | alpha 0.9028 | Epoch [1/1] | Batch [540/597] | Loss G: 3.1781 | Loss DX: 0.2422 | Loss DY: 0.2081
# Step 2 | alpha 0.9045 | Epoch [1/1] | Batch [541/597] | Loss G: 3.0893 | Loss DX: 0.2478 | Loss DY: 0.2619
# Step 2 | alpha 0.9062 | Epoch [1/1] | Batch [542/597] | Loss G: 3.6285 | Loss DX: 0.1868 | Loss DY: 0.1940
# Step 2 | alpha 0.9079 | Epoch [1/1] | Batch [543/597] | Loss G: 3.5192 | Loss DX: 0.2002 | Loss DY: 0.2136
# Step 2 | alpha 0.9095 | Epoch [1/1] | Batch [544/597] | Loss G: 4.4943 | Loss DX: 0.2441 | Loss DY: 0.2227
# Step 2 | alpha 0.9112 | Epoch [1/1] | Batch [545/597] | Loss G: 3.3441 | Loss DX: 0.1939 | Loss DY: 0.2014
# Step 2 | alpha 0.9129 | Epoch [1/1] | Batch [546/597] | Loss G: 3.8135 | Loss DX: 0.2077 | Loss DY: 0.2140
# Step 2 | alpha 0.9146 | Epoch [1/1] | Batch [547/597] | Loss G: 3.4197 | Loss DX: 0.2110 | Loss DY: 0.2473
# Step 2 | alpha 0.9162 | Epoch [1/1] | Batch [548/597] | Loss G: 3.7423 | Loss DX: 0.2463 | Loss DY: 0.2393
# Step 2 | alpha 0.9179 | Epoch [1/1] | Batch [549/597] | Loss G: 3.1377 | Loss DX: 0.2268 | Loss DY: 0.2092
# Step 2 | alpha 0.9196 | Epoch [1/1] | Batch [550/597] | Loss G: 3.7552 | Loss DX: 0.1746 | Loss DY: 0.2259
# Step 2 | alpha 0.9213 | Epoch [1/1] | Batch [551/597] | Loss G: 4.3793 | Loss DX: 0.2031 | Loss DY: 0.1409
# Step 2 | alpha 0.9229 | Epoch [1/1] | Batch [552/597] | Loss G: 4.0435 | Loss DX: 0.2002 | Loss DY: 0.1788
# Step 2 | alpha 0.9246 | Epoch [1/1] | Batch [553/597] | Loss G: 3.7881 | Loss DX: 0.2253 | Loss DY: 0.2161
# Step 2 | alpha 0.9263 | Epoch [1/1] | Batch [554/597] | Loss G: 3.6486 | Loss DX: 0.2566 | Loss DY: 0.2524
# Step 2 | alpha 0.9280 | Epoch [1/1] | Batch [555/597] | Loss G: 3.2098 | Loss DX: 0.2503 | Loss DY: 0.2749
# Step 2 | alpha 0.9296 | Epoch [1/1] | Batch [556/597] | Loss G: 3.0306 | Loss DX: 0.2463 | Loss DY: 0.2441
# Step 2 | alpha 0.9313 | Epoch [1/1] | Batch [557/597] | Loss G: 3.0234 | Loss DX: 0.2030 | Loss DY: 0.2487
# Step 2 | alpha 0.9330 | Epoch [1/1] | Batch [558/597] | Loss G: 3.0541 | Loss DX: 0.2244 | Loss DY: 0.2229
# Step 2 | alpha 0.9347 | Epoch [1/1] | Batch [559/597] | Loss G: 4.5214 | Loss DX: 0.1814 | Loss DY: 0.2238
# Step 2 | alpha 0.9363 | Epoch [1/1] | Batch [560/597] | Loss G: 3.3742 | Loss DX: 0.2043 | Loss DY: 0.2189
# Step 2 | alpha 0.9380 | Epoch [1/1] | Batch [561/597] | Loss G: 4.1039 | Loss DX: 0.2368 | Loss DY: 0.1960
# Step 2 | alpha 0.9397 | Epoch [1/1] | Batch [562/597] | Loss G: 3.0818 | Loss DX: 0.2359 | Loss DY: 0.2178
# Step 2 | alpha 0.9414 | Epoch [1/1] | Batch [563/597] | Loss G: 3.7537 | Loss DX: 0.2247 | Loss DY: 0.2163
# Step 2 | alpha 0.9430 | Epoch [1/1] | Batch [564/597] | Loss G: 3.8952 | Loss DX: 0.2618 | Loss DY: 0.2437
# Step 2 | alpha 0.9447 | Epoch [1/1] | Batch [565/597] | Loss G: 3.3605 | Loss DX: 0.2445 | Loss DY: 0.2184
# Step 2 | alpha 0.9464 | Epoch [1/1] | Batch [566/597] | Loss G: 3.5922 | Loss DX: 0.2273 | Loss DY: 0.2299
# Step 2 | alpha 0.9481 | Epoch [1/1] | Batch [567/597] | Loss G: 3.1392 | Loss DX: 0.2295 | Loss DY: 0.2449
# Step 2 | alpha 0.9497 | Epoch [1/1] | Batch [568/597] | Loss G: 3.7007 | Loss DX: 0.2320 | Loss DY: 0.2026
# Step 2 | alpha 0.9514 | Epoch [1/1] | Batch [569/597] | Loss G: 3.8460 | Loss DX: 0.2243 | Loss DY: 0.1901
# Step 2 | alpha 0.9531 | Epoch [1/1] | Batch [570/597] | Loss G: 3.6905 | Loss DX: 0.2045 | Loss DY: 0.2541
# Step 2 | alpha 0.9548 | Epoch [1/1] | Batch [571/597] | Loss G: 3.7164 | Loss DX: 0.2028 | Loss DY: 0.2302
# Step 2 | alpha 0.9564 | Epoch [1/1] | Batch [572/597] | Loss G: 3.5809 | Loss DX: 0.1739 | Loss DY: 0.2124
# Step 2 | alpha 0.9581 | Epoch [1/1] | Batch [573/597] | Loss G: 3.5891 | Loss DX: 0.2629 | Loss DY: 0.2182
# Step 2 | alpha 0.9598 | Epoch [1/1] | Batch [574/597] | Loss G: 3.3133 | Loss DX: 0.2932 | Loss DY: 0.2535
# Step 2 | alpha 0.9615 | Epoch [1/1] | Batch [575/597] | Loss G: 4.0049 | Loss DX: 0.2209 | Loss DY: 0.1800
# Step 2 | alpha 0.9631 | Epoch [1/1] | Batch [576/597] | Loss G: 2.9885 | Loss DX: 0.2480 | Loss DY: 0.2212
# Step 2 | alpha 0.9648 | Epoch [1/1] | Batch [577/597] | Loss G: 4.2852 | Loss DX: 0.2365 | Loss DY: 0.2209
# Step 2 | alpha 0.9665 | Epoch [1/1] | Batch [578/597] | Loss G: 3.8648 | Loss DX: 0.2320 | Loss DY: 0.2231
# Step 2 | alpha 0.9682 | Epoch [1/1] | Batch [579/597] | Loss G: 3.9962 | Loss DX: 0.2070 | Loss DY: 0.2406
# Step 2 | alpha 0.9698 | Epoch [1/1] | Batch [580/597] | Loss G: 3.4780 | Loss DX: 0.1919 | Loss DY: 0.2415
# Step 2 | alpha 0.9715 | Epoch [1/1] | Batch [581/597] | Loss G: 3.0589 | Loss DX: 0.2443 | Loss DY: 0.2174
# Step 2 | alpha 0.9732 | Epoch [1/1] | Batch [582/597] | Loss G: 3.4512 | Loss DX: 0.2286 | Loss DY: 0.2512
# Step 2 | alpha 0.9749 | Epoch [1/1] | Batch [583/597] | Loss G: 3.7371 | Loss DX: 0.2047 | Loss DY: 0.2013
# Step 2 | alpha 0.9765 | Epoch [1/1] | Batch [584/597] | Loss G: 3.8315 | Loss DX: 0.2706 | Loss DY: 0.2233
# Step 2 | alpha 0.9782 | Epoch [1/1] | Batch [585/597] | Loss G: 3.4972 | Loss DX: 0.2431 | Loss DY: 0.2707
# Step 2 | alpha 0.9799 | Epoch [1/1] | Batch [586/597] | Loss G: 2.9321 | Loss DX: 0.2221 | Loss DY: 0.2257
# Step 2 | alpha 0.9816 | Epoch [1/1] | Batch [587/597] | Loss G: 3.5408 | Loss DX: 0.2472 | Loss DY: 0.2537
# Step 2 | alpha 0.9832 | Epoch [1/1] | Batch [588/597] | Loss G: 3.3458 | Loss DX: 0.2085 | Loss DY: 0.2014
# Step 2 | alpha 0.9849 | Epoch [1/1] | Batch [589/597] | Loss G: 3.8823 | Loss DX: 0.2096 | Loss DY: 0.2339
# Step 2 | alpha 0.9866 | Epoch [1/1] | Batch [590/597] | Loss G: 4.1396 | Loss DX: 0.2324 | Loss DY: 0.1884
# Step 2 | alpha 0.9883 | Epoch [1/1] | Batch [591/597] | Loss G: 4.3301 | Loss DX: 0.2149 | Loss DY: 0.2008
# Step 2 | alpha 0.9899 | Epoch [1/1] | Batch [592/597] | Loss G: 4.1566 | Loss DX: 0.2324 | Loss DY: 0.1646
# Step 2 | alpha 0.9916 | Epoch [1/1] | Batch [593/597] | Loss G: 3.8071 | Loss DX: 0.2218 | Loss DY: 0.3014
# Step 2 | alpha 0.9933 | Epoch [1/1] | Batch [594/597] | Loss G: 4.1796 | Loss DX: 0.2291 | Loss DY: 0.2074
# Step 2 | alpha 0.9950 | Epoch [1/1] | Batch [595/597] | Loss G: 3.8856 | Loss DX: 0.2648 | Loss DY: 0.1925
# Step 2 | alpha 0.9966 | Epoch [1/1] | Batch [596/597] | Loss G: 3.8834 | Loss DX: 0.2425 | Loss DY: 0.1955
# Step 2 | alpha 0.9983 | Epoch [1/1] | Batch [597/597] | Loss G: 3.4250 | Loss DX: 0.2898 | Loss DY: 0.2295

# %%
trainer.train(dataloaders=(lsun_loader, monet_loader), n_epochs=1, step=2, fixed_alpha=1.0)
# Out:
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [1/597] | Loss G: 4.6964 | Loss DX: 0.2017 | Loss DY: 0.2294
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [2/597] | Loss G: 3.9751 | Loss DX: 0.2311 | Loss DY: 0.2674
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [3/597] | Loss G: 3.4915 | Loss DX: 0.2178 | Loss DY: 0.2432
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [4/597] | Loss G: 3.1284 | Loss DX: 0.2371 | Loss DY: 0.2063
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [5/597] | Loss G: 3.0041 | Loss DX: 0.2103 | Loss DY: 0.2649
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [6/597] | Loss G: 3.3500 | Loss DX: 0.2288 | Loss DY: 0.2756
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [7/597] | Loss G: 2.9732 | Loss DX: 0.2163 | Loss DY: 0.2530
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [8/597] | Loss G: 4.3633 | Loss DX: 0.2101 | Loss DY: 0.2407
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [9/597] | Loss G: 3.1812 | Loss DX: 0.2202 | Loss DY: 0.2364
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [10/597] | Loss G: 3.9861 | Loss DX: 0.2352 | Loss DY: 0.2315
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [11/597] | Loss G: 3.3627 | Loss DX: 0.2258 | Loss DY: 0.2167
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [12/597] | Loss G: 4.4243 | Loss DX: 0.2455 | Loss DY: 0.1933
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [13/597] | Loss G: 3.9861 | Loss DX: 0.2505 | Loss DY: 0.2266
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [14/597] | Loss G: 4.1265 | Loss DX: 0.2248 | Loss DY: 0.1439
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [15/597] | Loss G: 4.3727 | Loss DX: 0.2475 | Loss DY: 0.2474
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [16/597] | Loss G: 3.3182 | Loss DX: 0.2278 | Loss DY: 0.2024
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [17/597] | Loss G: 3.4424 | Loss DX: 0.2164 | Loss DY: 0.1878
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [18/597] | Loss G: 3.4221 | Loss DX: 0.2327 | Loss DY: 0.2453
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [19/597] | Loss G: 3.5407 | Loss DX: 0.2183 | Loss DY: 0.1756
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [20/597] | Loss G: 5.5757 | Loss DX: 0.2767 | Loss DY: 0.1413
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [21/597] | Loss G: 3.8167 | Loss DX: 0.2415 | Loss DY: 0.2175
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [22/597] | Loss G: 3.9054 | Loss DX: 0.2300 | Loss DY: 0.2897
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [23/597] | Loss G: 3.2899 | Loss DX: 0.2247 | Loss DY: 0.2512
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [24/597] | Loss G: 4.0741 | Loss DX: 0.2295 | Loss DY: 0.3026
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [25/597] | Loss G: 4.1867 | Loss DX: 0.2219 | Loss DY: 0.2283
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [26/597] | Loss G: 4.1375 | Loss DX: 0.1981 | Loss DY: 0.2272
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [27/597] | Loss G: 3.1787 | Loss DX: 0.2161 | Loss DY: 0.2564
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [28/597] | Loss G: 3.4597 | Loss DX: 0.2714 | Loss DY: 0.2236
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [29/597] | Loss G: 3.2619 | Loss DX: 0.2286 | Loss DY: 0.2540
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [30/597] | Loss G: 4.5293 | Loss DX: 0.1901 | Loss DY: 0.2019
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [31/597] | Loss G: 4.4509 | Loss DX: 0.2077 | Loss DY: 0.2448
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [32/597] | Loss G: 3.4168 | Loss DX: 0.2167 | Loss DY: 0.2572
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [33/597] | Loss G: 3.9350 | Loss DX: 0.1906 | Loss DY: 0.2946
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [34/597] | Loss G: 3.6538 | Loss DX: 0.2437 | Loss DY: 0.1880
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [35/597] | Loss G: 2.7013 | Loss DX: 0.3040 | Loss DY: 0.2535
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [36/597] | Loss G: 3.4902 | Loss DX: 0.2689 | Loss DY: 0.2401
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [37/597] | Loss G: 3.9223 | Loss DX: 0.2018 | Loss DY: 0.2740
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [38/597] | Loss G: 4.2170 | Loss DX: 0.2355 | Loss DY: 0.2276
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [39/597] | Loss G: 3.4877 | Loss DX: 0.2150 | Loss DY: 0.2377
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [40/597] | Loss G: 3.5530 | Loss DX: 0.2146 | Loss DY: 0.2065
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [41/597] | Loss G: 3.7835 | Loss DX: 0.2392 | Loss DY: 0.2306
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [42/597] | Loss G: 3.4449 | Loss DX: 0.2493 | Loss DY: 0.2221
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [43/597] | Loss G: 3.7282 | Loss DX: 0.2121 | Loss DY: 0.2236
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [44/597] | Loss G: 3.7745 | Loss DX: 0.2394 | Loss DY: 0.1936
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [45/597] | Loss G: 4.2408 | Loss DX: 0.2332 | Loss DY: 0.2154
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [46/597] | Loss G: 3.9687 | Loss DX: 0.2128 | Loss DY: 0.1521
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [47/597] | Loss G: 3.4120 | Loss DX: 0.2220 | Loss DY: 0.2927
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [48/597] | Loss G: 3.8606 | Loss DX: 0.2389 | Loss DY: 0.2084
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [49/597] | Loss G: 3.8443 | Loss DX: 0.2113 | Loss DY: 0.2454
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [50/597] | Loss G: 3.8393 | Loss DX: 0.1886 | Loss DY: 0.1880
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [51/597] | Loss G: 3.8462 | Loss DX: 0.2118 | Loss DY: 0.2579
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [52/597] | Loss G: 3.0841 | Loss DX: 0.2245 | Loss DY: 0.2106
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [53/597] | Loss G: 4.0990 | Loss DX: 0.2509 | Loss DY: 0.2355
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [54/597] | Loss G: 3.7076 | Loss DX: 0.2173 | Loss DY: 0.2675
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [55/597] | Loss G: 3.8495 | Loss DX: 0.2186 | Loss DY: 0.2430
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [56/597] | Loss G: 4.4742 | Loss DX: 0.2333 | Loss DY: 0.2515
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [57/597] | Loss G: 3.2958 | Loss DX: 0.3077 | Loss DY: 0.2679
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [58/597] | Loss G: 3.5057 | Loss DX: 0.2867 | Loss DY: 0.2663
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [59/597] | Loss G: 3.0954 | Loss DX: 0.2306 | Loss DY: 0.2445
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [60/597] | Loss G: 3.0279 | Loss DX: 0.2411 | Loss DY: 0.2428
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [61/597] | Loss G: 3.9866 | Loss DX: 0.1726 | Loss DY: 0.2467
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [62/597] | Loss G: 3.4950 | Loss DX: 0.2311 | Loss DY: 0.2215
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [63/597] | Loss G: 3.1465 | Loss DX: 0.2228 | Loss DY: 0.2305
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [64/597] | Loss G: 4.7947 | Loss DX: 0.1742 | Loss DY: 0.1925
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [65/597] | Loss G: 3.2477 | Loss DX: 0.2698 | Loss DY: 0.2224
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [66/597] | Loss G: 3.2363 | Loss DX: 0.2380 | Loss DY: 0.2208
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [67/597] | Loss G: 3.4029 | Loss DX: 0.1968 | Loss DY: 0.2323
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [68/597] | Loss G: 3.1813 | Loss DX: 0.2180 | Loss DY: 0.2767
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [69/597] | Loss G: 3.3647 | Loss DX: 0.1878 | Loss DY: 0.2405
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [70/597] | Loss G: 3.3035 | Loss DX: 0.3101 | Loss DY: 0.2362
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [71/597] | Loss G: 3.5772 | Loss DX: 0.2015 | Loss DY: 0.2403
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [72/597] | Loss G: 3.0309 | Loss DX: 0.2609 | Loss DY: 0.2340
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [73/597] | Loss G: 5.0851 | Loss DX: 0.2293 | Loss DY: 0.1910
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [74/597] | Loss G: 3.6725 | Loss DX: 0.2278 | Loss DY: 0.2313
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [75/597] | Loss G: 4.0060 | Loss DX: 0.2655 | Loss DY: 0.2326
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [76/597] | Loss G: 3.7602 | Loss DX: 0.2184 | Loss DY: 0.2488
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [77/597] | Loss G: 4.5935 | Loss DX: 0.2209 | Loss DY: 0.2041
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [78/597] | Loss G: 3.6921 | Loss DX: 0.2556 | Loss DY: 0.2328
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [79/597] | Loss G: 4.0518 | Loss DX: 0.2293 | Loss DY: 0.2464
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [80/597] | Loss G: 2.9043 | Loss DX: 0.2451 | Loss DY: 0.2178
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [81/597] | Loss G: 3.2943 | Loss DX: 0.2508 | Loss DY: 0.2448
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [82/597] | Loss G: 3.4869 | Loss DX: 0.2235 | Loss DY: 0.2151
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [83/597] | Loss G: 3.2107 | Loss DX: 0.2287 | Loss DY: 0.1810
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [84/597] | Loss G: 3.5167 | Loss DX: 0.2350 | Loss DY: 0.3415
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [85/597] | Loss G: 2.9386 | Loss DX: 0.2255 | Loss DY: 0.2314
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [86/597] | Loss G: 3.2694 | Loss DX: 0.2430 | Loss DY: 0.2493
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [87/597] | Loss G: 3.6811 | Loss DX: 0.2045 | Loss DY: 0.2039
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [88/597] | Loss G: 3.3667 | Loss DX: 0.2049 | Loss DY: 0.2438
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [89/597] | Loss G: 4.5576 | Loss DX: 0.2146 | Loss DY: 0.2144
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [90/597] | Loss G: 3.3230 | Loss DX: 0.2254 | Loss DY: 0.2526
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [91/597] | Loss G: 3.1533 | Loss DX: 0.2598 | Loss DY: 0.2125
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [92/597] | Loss G: 3.2141 | Loss DX: 0.2405 | Loss DY: 0.2146
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [93/597] | Loss G: 2.8856 | Loss DX: 0.2172 | Loss DY: 0.2228
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [94/597] | Loss G: 3.1071 | Loss DX: 0.2391 | Loss DY: 0.2129
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [95/597] | Loss G: 2.9954 | Loss DX: 0.2673 | Loss DY: 0.2792
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [96/597] | Loss G: 3.7900 | Loss DX: 0.2283 | Loss DY: 0.2173
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [97/597] | Loss G: 3.6570 | Loss DX: 0.2168 | Loss DY: 0.2537
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [98/597] | Loss G: 3.7606 | Loss DX: 0.2344 | Loss DY: 0.2551
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [99/597] | Loss G: 4.9727 | Loss DX: 0.2222 | Loss DY: 0.2207
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [100/597] | Loss G: 3.7282 | Loss DX: 0.2161 | Loss DY: 0.2135
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [101/597] | Loss G: 3.1159 | Loss DX: 0.2443 | Loss DY: 0.2562
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [102/597] | Loss G: 3.9999 | Loss DX: 0.2208 | Loss DY: 0.2301
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [103/597] | Loss G: 4.5033 | Loss DX: 0.2193 | Loss DY: 0.2163
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [104/597] | Loss G: 4.3726 | Loss DX: 0.1876 | Loss DY: 0.1761
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [105/597] | Loss G: 3.6249 | Loss DX: 0.2326 | Loss DY: 0.2545
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [106/597] | Loss G: 3.1252 | Loss DX: 0.2148 | Loss DY: 0.2490
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [107/597] | Loss G: 2.9670 | Loss DX: 0.2101 | Loss DY: 0.2271
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [108/597] | Loss G: 3.6405 | Loss DX: 0.1884 | Loss DY: 0.2396
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [109/597] | Loss G: 3.1506 | Loss DX: 0.2470 | Loss DY: 0.2238
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [110/597] | Loss G: 4.1565 | Loss DX: 0.2124 | Loss DY: 0.1906
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [111/597] | Loss G: 3.1415 | Loss DX: 0.2428 | Loss DY: 0.2213
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [112/597] | Loss G: 3.6078 | Loss DX: 0.2345 | Loss DY: 0.2671
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [113/597] | Loss G: 3.9271 | Loss DX: 0.2275 | Loss DY: 0.1734
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [114/597] | Loss G: 3.7413 | Loss DX: 0.1845 | Loss DY: 0.2993
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [115/597] | Loss G: 3.5764 | Loss DX: 0.2459 | Loss DY: 0.3171
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [116/597] | Loss G: 4.6338 | Loss DX: 0.2020 | Loss DY: 0.2455
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [117/597] | Loss G: 3.2179 | Loss DX: 0.2350 | Loss DY: 0.2249
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [118/597] | Loss G: 3.9728 | Loss DX: 0.1942 | Loss DY: 0.2112
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [119/597] | Loss G: 3.4521 | Loss DX: 0.1634 | Loss DY: 0.2689
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [120/597] | Loss G: 3.3059 | Loss DX: 0.1919 | Loss DY: 0.2236
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [121/597] | Loss G: 3.2374 | Loss DX: 0.1804 | Loss DY: 0.2185
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [122/597] | Loss G: 3.0677 | Loss DX: 0.2282 | Loss DY: 0.2194
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [123/597] | Loss G: 3.9115 | Loss DX: 0.2456 | Loss DY: 0.2347
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [124/597] | Loss G: 4.3515 | Loss DX: 0.1790 | Loss DY: 0.2541
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [125/597] | Loss G: 4.1375 | Loss DX: 0.2136 | Loss DY: 0.2153
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [126/597] | Loss G: 3.7626 | Loss DX: 0.1950 | Loss DY: 0.2329
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [127/597] | Loss G: 3.0837 | Loss DX: 0.2738 | Loss DY: 0.2304
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [128/597] | Loss G: 3.0920 | Loss DX: 0.2495 | Loss DY: 0.1917
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [129/597] | Loss G: 3.7869 | Loss DX: 0.2285 | Loss DY: 0.2293
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [130/597] | Loss G: 3.9344 | Loss DX: 0.2526 | Loss DY: 0.1941
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [131/597] | Loss G: 3.4415 | Loss DX: 0.2157 | Loss DY: 0.2206
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [132/597] | Loss G: 3.0735 | Loss DX: 0.2148 | Loss DY: 0.1939
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [133/597] | Loss G: 3.2144 | Loss DX: 0.2200 | Loss DY: 0.2166
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [134/597] | Loss G: 3.5906 | Loss DX: 0.2039 | Loss DY: 0.2165
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [135/597] | Loss G: 4.4059 | Loss DX: 0.2340 | Loss DY: 0.2188
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [136/597] | Loss G: 3.6893 | Loss DX: 0.2355 | Loss DY: 0.3053
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [137/597] | Loss G: 3.5455 | Loss DX: 0.2005 | Loss DY: 0.1815
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [138/597] | Loss G: 3.2967 | Loss DX: 0.2636 | Loss DY: 0.2546
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [139/597] | Loss G: 4.3009 | Loss DX: 0.1855 | Loss DY: 0.2388
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [140/597] | Loss G: 3.9842 | Loss DX: 0.2096 | Loss DY: 0.2447
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [141/597] | Loss G: 3.5967 | Loss DX: 0.2440 | Loss DY: 0.2495
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [142/597] | Loss G: 3.8265 | Loss DX: 0.2716 | Loss DY: 0.1966
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [143/597] | Loss G: 3.4928 | Loss DX: 0.2213 | Loss DY: 0.2532
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [144/597] | Loss G: 3.5884 | Loss DX: 0.1822 | Loss DY: 0.2152
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [145/597] | Loss G: 3.3769 | Loss DX: 0.1810 | Loss DY: 0.1893
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [146/597] | Loss G: 4.0325 | Loss DX: 0.2212 | Loss DY: 0.2331
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [147/597] | Loss G: 3.5270 | Loss DX: 0.2265 | Loss DY: 0.2601
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [148/597] | Loss G: 3.2781 | Loss DX: 0.2498 | Loss DY: 0.2401
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [149/597] | Loss G: 4.3938 | Loss DX: 0.1870 | Loss DY: 0.2174
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [150/597] | Loss G: 4.0646 | Loss DX: 0.2130 | Loss DY: 0.1996
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [151/597] | Loss G: 3.1221 | Loss DX: 0.2060 | Loss DY: 0.2258
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [152/597] | Loss G: 3.2462 | Loss DX: 0.2327 | Loss DY: 0.2389
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [153/597] | Loss G: 4.0286 | Loss DX: 0.1484 | Loss DY: 0.2250
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [154/597] | Loss G: 3.4785 | Loss DX: 0.1779 | Loss DY: 0.2422
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [155/597] | Loss G: 2.7505 | Loss DX: 0.2583 | Loss DY: 0.2657
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [156/597] | Loss G: 2.7731 | Loss DX: 0.2462 | Loss DY: 0.2725
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [157/597] | Loss G: 3.8653 | Loss DX: 0.2900 | Loss DY: 0.2591
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [158/597] | Loss G: 3.6772 | Loss DX: 0.1963 | Loss DY: 0.2513
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [159/597] | Loss G: 3.5867 | Loss DX: 0.1630 | Loss DY: 0.2535
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [160/597] | Loss G: 3.0488 | Loss DX: 0.2079 | Loss DY: 0.1994
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [161/597] | Loss G: 3.6826 | Loss DX: 0.2213 | Loss DY: 0.1890
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [162/597] | Loss G: 4.0644 | Loss DX: 0.2803 | Loss DY: 0.2535
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [163/597] | Loss G: 3.7820 | Loss DX: 0.2863 | Loss DY: 0.2222
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [164/597] | Loss G: 3.6487 | Loss DX: 0.3491 | Loss DY: 0.3125
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [165/597] | Loss G: 2.9067 | Loss DX: 0.2694 | Loss DY: 0.2408
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [166/597] | Loss G: 3.6987 | Loss DX: 0.2661 | Loss DY: 0.2447
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [167/597] | Loss G: 3.4074 | Loss DX: 0.2669 | Loss DY: 0.2593
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [168/597] | Loss G: 4.4264 | Loss DX: 0.2436 | Loss DY: 0.2220
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [169/597] | Loss G: 3.8483 | Loss DX: 0.2343 | Loss DY: 0.2427
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [170/597] | Loss G: 4.5691 | Loss DX: 0.2018 | Loss DY: 0.2417
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [171/597] | Loss G: 3.0387 | Loss DX: 0.2872 | Loss DY: 0.2478
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [172/597] | Loss G: 3.2168 | Loss DX: 0.2409 | Loss DY: 0.2167
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [173/597] | Loss G: 2.7389 | Loss DX: 0.2234 | Loss DY: 0.2609
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [174/597] | Loss G: 3.3629 | Loss DX: 0.2024 | Loss DY: 0.2339
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [175/597] | Loss G: 3.5004 | Loss DX: 0.2318 | Loss DY: 0.2373
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [176/597] | Loss G: 3.0016 | Loss DX: 0.2355 | Loss DY: 0.2211
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [177/597] | Loss G: 3.3720 | Loss DX: 0.2524 | Loss DY: 0.2240
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [178/597] | Loss G: 3.1541 | Loss DX: 0.2555 | Loss DY: 0.2245
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [179/597] | Loss G: 3.6877 | Loss DX: 0.2080 | Loss DY: 0.2631
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [180/597] | Loss G: 4.4778 | Loss DX: 0.2248 | Loss DY: 0.1760
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [181/597] | Loss G: 3.9874 | Loss DX: 0.2149 | Loss DY: 0.1929
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [182/597] | Loss G: 3.7287 | Loss DX: 0.1587 | Loss DY: 0.2122
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [183/597] | Loss G: 3.7594 | Loss DX: 0.2522 | Loss DY: 0.1835
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [184/597] | Loss G: 3.2711 | Loss DX: 0.2429 | Loss DY: 0.2074
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [185/597] | Loss G: 4.4409 | Loss DX: 0.2371 | Loss DY: 0.1497
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [186/597] | Loss G: 2.9200 | Loss DX: 0.2559 | Loss DY: 0.2509
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [187/597] | Loss G: 3.0883 | Loss DX: 0.2325 | Loss DY: 0.1907
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [188/597] | Loss G: 4.0741 | Loss DX: 0.1955 | Loss DY: 0.2357
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [189/597] | Loss G: 3.6887 | Loss DX: 0.2454 | Loss DY: 0.3276
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [190/597] | Loss G: 3.1211 | Loss DX: 0.2231 | Loss DY: 0.2727
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [191/597] | Loss G: 5.7876 | Loss DX: 0.1669 | Loss DY: 0.2385
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [192/597] | Loss G: 3.3579 | Loss DX: 0.2207 | Loss DY: 0.2459
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [193/597] | Loss G: 3.1907 | Loss DX: 0.2502 | Loss DY: 0.2219
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [194/597] | Loss G: 3.1807 | Loss DX: 0.1914 | Loss DY: 0.2331
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [195/597] | Loss G: 4.3785 | Loss DX: 0.2200 | Loss DY: 0.2614
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [196/597] | Loss G: 3.1397 | Loss DX: 0.2195 | Loss DY: 0.2592
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [197/597] | Loss G: 3.6306 | Loss DX: 0.1952 | Loss DY: 0.2334
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [198/597] | Loss G: 3.7681 | Loss DX: 0.2594 | Loss DY: 0.3132
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [199/597] | Loss G: 3.1621 | Loss DX: 0.2366 | Loss DY: 0.2300
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [200/597] | Loss G: 3.0487 | Loss DX: 0.2039 | Loss DY: 0.2172
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [201/597] | Loss G: 2.8944 | Loss DX: 0.2007 | Loss DY: 0.2070
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [202/597] | Loss G: 3.4471 | Loss DX: 0.2119 | Loss DY: 0.2519
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [203/597] | Loss G: 2.9841 | Loss DX: 0.2347 | Loss DY: 0.2032
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [204/597] | Loss G: 3.8807 | Loss DX: 0.2151 | Loss DY: 0.2035
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [205/597] | Loss G: 3.6502 | Loss DX: 0.2122 | Loss DY: 0.2070
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [206/597] | Loss G: 4.4282 | Loss DX: 0.2244 | Loss DY: 0.2333
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [207/597] | Loss G: 3.9742 | Loss DX: 0.2213 | Loss DY: 0.2685
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [208/597] | Loss G: 3.0691 | Loss DX: 0.2522 | Loss DY: 0.2520
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [209/597] | Loss G: 3.7974 | Loss DX: 0.1670 | Loss DY: 0.2598
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [210/597] | Loss G: 4.6977 | Loss DX: 0.1622 | Loss DY: 0.2192
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [211/597] | Loss G: 3.9376 | Loss DX: 0.2528 | Loss DY: 0.2188
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [212/597] | Loss G: 3.2207 | Loss DX: 0.2670 | Loss DY: 0.2168
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [213/597] | Loss G: 3.1773 | Loss DX: 0.2373 | Loss DY: 0.2345
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [214/597] | Loss G: 2.9760 | Loss DX: 0.2197 | Loss DY: 0.2368
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [215/597] | Loss G: 3.9387 | Loss DX: 0.2367 | Loss DY: 0.2646
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [216/597] | Loss G: 2.9799 | Loss DX: 0.2393 | Loss DY: 0.2052
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [217/597] | Loss G: 3.1516 | Loss DX: 0.2417 | Loss DY: 0.2122
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [218/597] | Loss G: 3.5128 | Loss DX: 0.2165 | Loss DY: 0.2356
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [219/597] | Loss G: 4.1250 | Loss DX: 0.1973 | Loss DY: 0.2741
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [220/597] | Loss G: 3.3244 | Loss DX: 0.2220 | Loss DY: 0.2261
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [221/597] | Loss G: 3.6502 | Loss DX: 0.1924 | Loss DY: 0.2229
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [222/597] | Loss G: 2.5374 | Loss DX: 0.2210 | Loss DY: 0.2316
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [223/597] | Loss G: 3.6334 | Loss DX: 0.1929 | Loss DY: 0.2177
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [224/597] | Loss G: 3.9341 | Loss DX: 0.2150 | Loss DY: 0.2605
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [225/597] | Loss G: 3.9048 | Loss DX: 0.1550 | Loss DY: 0.2430
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [226/597] | Loss G: 3.5310 | Loss DX: 0.1793 | Loss DY: 0.2080
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [227/597] | Loss G: 3.4823 | Loss DX: 0.2381 | Loss DY: 0.2190
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [228/597] | Loss G: 4.2832 | Loss DX: 0.2067 | Loss DY: 0.2045
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [229/597] | Loss G: 3.3518 | Loss DX: 0.2281 | Loss DY: 0.2266
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [230/597] | Loss G: 4.9031 | Loss DX: 0.2002 | Loss DY: 0.1660
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [231/597] | Loss G: 2.9175 | Loss DX: 0.2815 | Loss DY: 0.2466
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [232/597] | Loss G: 3.5803 | Loss DX: 0.2498 | Loss DY: 0.2308
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [233/597] | Loss G: 3.2086 | Loss DX: 0.2183 | Loss DY: 0.2025
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [234/597] | Loss G: 3.3650 | Loss DX: 0.1695 | Loss DY: 0.2316
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [235/597] | Loss G: 3.0926 | Loss DX: 0.2013 | Loss DY: 0.3104
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [236/597] | Loss G: 3.7195 | Loss DX: 0.2021 | Loss DY: 0.1877
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [237/597] | Loss G: 3.3529 | Loss DX: 0.1853 | Loss DY: 0.2497
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [238/597] | Loss G: 3.3051 | Loss DX: 0.3219 | Loss DY: 0.2480
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [239/597] | Loss G: 2.5785 | Loss DX: 0.2785 | Loss DY: 0.2356
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [240/597] | Loss G: 3.1543 | Loss DX: 0.2510 | Loss DY: 0.2341
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [241/597] | Loss G: 3.4710 | Loss DX: 0.2057 | Loss DY: 0.1979
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [242/597] | Loss G: 3.0488 | Loss DX: 0.2131 | Loss DY: 0.2016
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [243/597] | Loss G: 3.7004 | Loss DX: 0.2057 | Loss DY: 0.2613
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [244/597] | Loss G: 3.4702 | Loss DX: 0.2413 | Loss DY: 0.1820
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [245/597] | Loss G: 3.3945 | Loss DX: 0.2966 | Loss DY: 0.2064
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [246/597] | Loss G: 3.2240 | Loss DX: 0.2358 | Loss DY: 0.2044
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [247/597] | Loss G: 3.6093 | Loss DX: 0.2195 | Loss DY: 0.2318
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [248/597] | Loss G: 2.9693 | Loss DX: 0.2041 | Loss DY: 0.2025
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [249/597] | Loss G: 3.2136 | Loss DX: 0.2623 | Loss DY: 0.2562
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [250/597] | Loss G: 3.1941 | Loss DX: 0.2546 | Loss DY: 0.2443
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [251/597] | Loss G: 3.7465 | Loss DX: 0.2558 | Loss DY: 0.2274
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [252/597] | Loss G: 3.7044 | Loss DX: 0.2458 | Loss DY: 0.2280
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [253/597] | Loss G: 3.5138 | Loss DX: 0.2246 | Loss DY: 0.2027
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [254/597] | Loss G: 4.2572 | Loss DX: 0.2255 | Loss DY: 0.2469
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [255/597] | Loss G: 3.5271 | Loss DX: 0.2594 | Loss DY: 0.2903
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [256/597] | Loss G: 3.4085 | Loss DX: 0.2181 | Loss DY: 0.2280
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [257/597] | Loss G: 3.3728 | Loss DX: 0.2504 | Loss DY: 0.2554
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [258/597] | Loss G: 3.5123 | Loss DX: 0.2239 | Loss DY: 0.2183
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [259/597] | Loss G: 3.9230 | Loss DX: 0.2956 | Loss DY: 0.2309
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [260/597] | Loss G: 2.7531 | Loss DX: 0.2331 | Loss DY: 0.2365
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [261/597] | Loss G: 2.8520 | Loss DX: 0.2310 | Loss DY: 0.2031
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [262/597] | Loss G: 3.1395 | Loss DX: 0.2430 | Loss DY: 0.2281
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [263/597] | Loss G: 3.1657 | Loss DX: 0.2330 | Loss DY: 0.2194
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [264/597] | Loss G: 3.2672 | Loss DX: 0.2304 | Loss DY: 0.1867
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [265/597] | Loss G: 2.8852 | Loss DX: 0.2534 | Loss DY: 0.2695
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [266/597] | Loss G: 4.9025 | Loss DX: 0.1948 | Loss DY: 0.3083
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [267/597] | Loss G: 4.5217 | Loss DX: 0.2238 | Loss DY: 0.2159
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [268/597] | Loss G: 2.7265 | Loss DX: 0.2600 | Loss DY: 0.2412
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [269/597] | Loss G: 3.8152 | Loss DX: 0.2148 | Loss DY: 0.2099
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [270/597] | Loss G: 3.5362 | Loss DX: 0.2163 | Loss DY: 0.2172
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [271/597] | Loss G: 4.0460 | Loss DX: 0.2460 | Loss DY: 0.2397
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [272/597] | Loss G: 3.6525 | Loss DX: 0.2133 | Loss DY: 0.2202
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [273/597] | Loss G: 4.4079 | Loss DX: 0.2093 | Loss DY: 0.2260
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [274/597] | Loss G: 3.5720 | Loss DX: 0.2311 | Loss DY: 0.2017
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [275/597] | Loss G: 3.4807 | Loss DX: 0.2018 | Loss DY: 0.1764
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [276/597] | Loss G: 3.8728 | Loss DX: 0.1892 | Loss DY: 0.2351
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [277/597] | Loss G: 4.0399 | Loss DX: 0.1714 | Loss DY: 0.2611
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [278/597] | Loss G: 3.0426 | Loss DX: 0.1855 | Loss DY: 0.2524
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [279/597] | Loss G: 3.6223 | Loss DX: 0.1405 | Loss DY: 0.1956
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [280/597] | Loss G: 3.9242 | Loss DX: 0.2105 | Loss DY: 0.2087
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [281/597] | Loss G: 3.6139 | Loss DX: 0.1333 | Loss DY: 0.2665
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [282/597] | Loss G: 3.3819 | Loss DX: 0.2853 | Loss DY: 0.2586
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [283/597] | Loss G: 3.4716 | Loss DX: 0.1685 | Loss DY: 0.1869
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [284/597] | Loss G: 3.3748 | Loss DX: 0.2692 | Loss DY: 0.1884
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [285/597] | Loss G: 2.8818 | Loss DX: 0.2238 | Loss DY: 0.2007
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [286/597] | Loss G: 3.8263 | Loss DX: 0.2110 | Loss DY: 0.2126
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [287/597] | Loss G: 2.9294 | Loss DX: 0.2794 | Loss DY: 0.2299
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [288/597] | Loss G: 2.9609 | Loss DX: 0.2511 | Loss DY: 0.2984
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [289/597] | Loss G: 2.6691 | Loss DX: 0.2317 | Loss DY: 0.2317
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [290/597] | Loss G: 4.4034 | Loss DX: 0.2027 | Loss DY: 0.2051
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [291/597] | Loss G: 3.5000 | Loss DX: 0.2054 | Loss DY: 0.2403
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [292/597] | Loss G: 3.3604 | Loss DX: 0.2006 | Loss DY: 0.2678
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [293/597] | Loss G: 3.8811 | Loss DX: 0.2110 | Loss DY: 0.2369
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [294/597] | Loss G: 3.5880 | Loss DX: 0.1977 | Loss DY: 0.2772
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [295/597] | Loss G: 3.6258 | Loss DX: 0.1767 | Loss DY: 0.2381
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [296/597] | Loss G: 2.9491 | Loss DX: 0.2324 | Loss DY: 0.2698
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [297/597] | Loss G: 4.5465 | Loss DX: 0.2290 | Loss DY: 0.2669
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [298/597] | Loss G: 3.9750 | Loss DX: 0.2013 | Loss DY: 0.2374
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [299/597] | Loss G: 3.4836 | Loss DX: 0.2288 | Loss DY: 0.2293
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [300/597] | Loss G: 3.7350 | Loss DX: 0.2284 | Loss DY: 0.2247
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [301/597] | Loss G: 3.3307 | Loss DX: 0.2212 | Loss DY: 0.1820
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [302/597] | Loss G: 2.8542 | Loss DX: 0.2243 | Loss DY: 0.2111
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [303/597] | Loss G: 4.0683 | Loss DX: 0.1998 | Loss DY: 0.2221
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [304/597] | Loss G: 3.0542 | Loss DX: 0.1798 | Loss DY: 0.2364
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [305/597] | Loss G: 3.0421 | Loss DX: 0.2577 | Loss DY: 0.2277
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [306/597] | Loss G: 3.2966 | Loss DX: 0.1300 | Loss DY: 0.2198
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [307/597] | Loss G: 3.1349 | Loss DX: 0.2035 | Loss DY: 0.2510
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [308/597] | Loss G: 3.3444 | Loss DX: 0.1415 | Loss DY: 0.2329
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [309/597] | Loss G: 3.7699 | Loss DX: 0.2205 | Loss DY: 0.1875
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [310/597] | Loss G: 2.6275 | Loss DX: 0.2262 | Loss DY: 0.2289
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [311/597] | Loss G: 3.4384 | Loss DX: 0.2058 | Loss DY: 0.2289
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [312/597] | Loss G: 3.4670 | Loss DX: 0.1966 | Loss DY: 0.2283
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [313/597] | Loss G: 3.9714 | Loss DX: 0.2214 | Loss DY: 0.2158
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [314/597] | Loss G: 3.4614 | Loss DX: 0.2098 | Loss DY: 0.2226
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [315/597] | Loss G: 3.4420 | Loss DX: 0.2627 | Loss DY: 0.2447
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [316/597] | Loss G: 3.0184 | Loss DX: 0.2735 | Loss DY: 0.2693
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [317/597] | Loss G: 3.5498 | Loss DX: 0.2744 | Loss DY: 0.2841
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [318/597] | Loss G: 3.5044 | Loss DX: 0.2171 | Loss DY: 0.2353
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [319/597] | Loss G: 4.8459 | Loss DX: 0.1879 | Loss DY: 0.2038
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [320/597] | Loss G: 3.2151 | Loss DX: 0.2076 | Loss DY: 0.2054
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [321/597] | Loss G: 3.5600 | Loss DX: 0.2185 | Loss DY: 0.2859
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [322/597] | Loss G: 3.3972 | Loss DX: 0.2298 | Loss DY: 0.2298
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [323/597] | Loss G: 3.2992 | Loss DX: 0.2058 | Loss DY: 0.2242
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [324/597] | Loss G: 4.4921 | Loss DX: 0.1949 | Loss DY: 0.2246
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [325/597] | Loss G: 2.7794 | Loss DX: 0.2202 | Loss DY: 0.2472
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [326/597] | Loss G: 3.2443 | Loss DX: 0.2307 | Loss DY: 0.1981
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [327/597] | Loss G: 3.3949 | Loss DX: 0.2476 | Loss DY: 0.2102
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [328/597] | Loss G: 3.8407 | Loss DX: 0.2805 | Loss DY: 0.2223
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [329/597] | Loss G: 3.0301 | Loss DX: 0.2515 | Loss DY: 0.2394
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [330/597] | Loss G: 3.0776 | Loss DX: 0.1849 | Loss DY: 0.2058
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [331/597] | Loss G: 3.2286 | Loss DX: 0.2376 | Loss DY: 0.1675
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [332/597] | Loss G: 3.4290 | Loss DX: 0.2304 | Loss DY: 0.1570
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [333/597] | Loss G: 4.1690 | Loss DX: 0.2025 | Loss DY: 0.1554
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [334/597] | Loss G: 2.7231 | Loss DX: 0.2465 | Loss DY: 0.2099
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [335/597] | Loss G: 3.3732 | Loss DX: 0.2132 | Loss DY: 0.2390
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [336/597] | Loss G: 3.7451 | Loss DX: 0.2219 | Loss DY: 0.2375
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [337/597] | Loss G: 3.3510 | Loss DX: 0.2022 | Loss DY: 0.2116
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [338/597] | Loss G: 2.9848 | Loss DX: 0.2457 | Loss DY: 0.2495
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [339/597] | Loss G: 3.5247 | Loss DX: 0.2270 | Loss DY: 0.2560
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [340/597] | Loss G: 3.5464 | Loss DX: 0.2337 | Loss DY: 0.2804
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [341/597] | Loss G: 3.0237 | Loss DX: 0.2283 | Loss DY: 0.2268
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [342/597] | Loss G: 2.4921 | Loss DX: 0.2391 | Loss DY: 0.2343
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [343/597] | Loss G: 2.9417 | Loss DX: 0.2152 | Loss DY: 0.1979
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [344/597] | Loss G: 2.5763 | Loss DX: 0.2498 | Loss DY: 0.2252
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [345/597] | Loss G: 3.4529 | Loss DX: 0.2274 | Loss DY: 0.2835
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [346/597] | Loss G: 3.2944 | Loss DX: 0.1489 | Loss DY: 0.2310
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [347/597] | Loss G: 3.3251 | Loss DX: 0.2208 | Loss DY: 0.1881
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [348/597] | Loss G: 3.9781 | Loss DX: 0.1960 | Loss DY: 0.1890
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [349/597] | Loss G: 3.1709 | Loss DX: 0.2801 | Loss DY: 0.1980
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [350/597] | Loss G: 3.2960 | Loss DX: 0.2047 | Loss DY: 0.2264
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [351/597] | Loss G: 3.2298 | Loss DX: 0.2255 | Loss DY: 0.2051
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [352/597] | Loss G: 3.5732 | Loss DX: 0.2054 | Loss DY: 0.2239
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [353/597] | Loss G: 2.9408 | Loss DX: 0.2101 | Loss DY: 0.2560
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [354/597] | Loss G: 3.1469 | Loss DX: 0.2236 | Loss DY: 0.2167
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [355/597] | Loss G: 3.6021 | Loss DX: 0.2173 | Loss DY: 0.2670
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [356/597] | Loss G: 3.3220 | Loss DX: 0.2057 | Loss DY: 0.2539
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [357/597] | Loss G: 4.9179 | Loss DX: 0.2363 | Loss DY: 0.2114
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [358/597] | Loss G: 4.5739 | Loss DX: 0.2312 | Loss DY: 0.2399
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [359/597] | Loss G: 4.2976 | Loss DX: 0.2499 | Loss DY: 0.2600
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [360/597] | Loss G: 2.9948 | Loss DX: 0.2261 | Loss DY: 0.2099
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [361/597] | Loss G: 3.8221 | Loss DX: 0.2222 | Loss DY: 0.1987
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [362/597] | Loss G: 2.9744 | Loss DX: 0.1880 | Loss DY: 0.2093
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [363/597] | Loss G: 3.4691 | Loss DX: 0.2090 | Loss DY: 0.1981
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [364/597] | Loss G: 3.4296 | Loss DX: 0.2424 | Loss DY: 0.1854
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [365/597] | Loss G: 4.6691 | Loss DX: 0.1716 | Loss DY: 0.1999
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [366/597] | Loss G: 3.4618 | Loss DX: 0.1886 | Loss DY: 0.2335
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [367/597] | Loss G: 4.0048 | Loss DX: 0.2211 | Loss DY: 0.2315
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [368/597] | Loss G: 3.1644 | Loss DX: 0.2471 | Loss DY: 0.3040
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [369/597] | Loss G: 3.4708 | Loss DX: 0.2063 | Loss DY: 0.2846
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [370/597] | Loss G: 3.2212 | Loss DX: 0.2349 | Loss DY: 0.3068
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [371/597] | Loss G: 3.9335 | Loss DX: 0.2513 | Loss DY: 0.2290
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [372/597] | Loss G: 3.2722 | Loss DX: 0.2532 | Loss DY: 0.2466
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [373/597] | Loss G: 3.4286 | Loss DX: 0.1901 | Loss DY: 0.2512
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [374/597] | Loss G: 2.8450 | Loss DX: 0.2431 | Loss DY: 0.2382
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [375/597] | Loss G: 3.2417 | Loss DX: 0.2165 | Loss DY: 0.2453
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [376/597] | Loss G: 3.1595 | Loss DX: 0.1599 | Loss DY: 0.2162
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [377/597] | Loss G: 2.7555 | Loss DX: 0.2127 | Loss DY: 0.2084
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [378/597] | Loss G: 3.9945 | Loss DX: 0.1339 | Loss DY: 0.1893
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [379/597] | Loss G: 3.9147 | Loss DX: 0.1753 | Loss DY: 0.1668
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [380/597] | Loss G: 4.7328 | Loss DX: 0.1883 | Loss DY: 0.2746
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [381/597] | Loss G: 5.3017 | Loss DX: 0.1611 | Loss DY: 0.1893
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [382/597] | Loss G: 4.2235 | Loss DX: 0.1659 | Loss DY: 0.2025
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [383/597] | Loss G: 3.3576 | Loss DX: 0.2325 | Loss DY: 0.2431
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [384/597] | Loss G: 3.7518 | Loss DX: 0.2045 | Loss DY: 0.2195
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [385/597] | Loss G: 3.2638 | Loss DX: 0.2776 | Loss DY: 0.2255
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [386/597] | Loss G: 5.1483 | Loss DX: 0.1969 | Loss DY: 0.2743
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [387/597] | Loss G: 3.8755 | Loss DX: 0.2529 | Loss DY: 0.2324
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [388/597] | Loss G: 2.9825 | Loss DX: 0.1921 | Loss DY: 0.2349
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [389/597] | Loss G: 4.0260 | Loss DX: 0.2426 | Loss DY: 0.2164
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [390/597] | Loss G: 3.7684 | Loss DX: 0.2237 | Loss DY: 0.2250
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [391/597] | Loss G: 4.0334 | Loss DX: 0.1614 | Loss DY: 0.2073
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [392/597] | Loss G: 3.6758 | Loss DX: 0.2240 | Loss DY: 0.2216
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [393/597] | Loss G: 3.2926 | Loss DX: 0.2435 | Loss DY: 0.1623
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [394/597] | Loss G: 3.8862 | Loss DX: 0.1734 | Loss DY: 0.2003
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [395/597] | Loss G: 3.9897 | Loss DX: 0.1915 | Loss DY: 0.2199
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [396/597] | Loss G: 3.0026 | Loss DX: 0.1900 | Loss DY: 0.2076
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [397/597] | Loss G: 3.0037 | Loss DX: 0.2945 | Loss DY: 0.2491
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [398/597] | Loss G: 3.8826 | Loss DX: 0.2038 | Loss DY: 0.1852
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [399/597] | Loss G: 3.5272 | Loss DX: 0.1991 | Loss DY: 0.1959
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [400/597] | Loss G: 4.1628 | Loss DX: 0.2045 | Loss DY: 0.2323
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [401/597] | Loss G: 3.3364 | Loss DX: 0.1962 | Loss DY: 0.2496
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [402/597] | Loss G: 3.0486 | Loss DX: 0.2175 | Loss DY: 0.2698
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [403/597] | Loss G: 4.1058 | Loss DX: 0.2478 | Loss DY: 0.2135
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [404/597] | Loss G: 3.3050 | Loss DX: 0.2499 | Loss DY: 0.2427
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [405/597] | Loss G: 3.4629 | Loss DX: 0.2003 | Loss DY: 0.2635
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [406/597] | Loss G: 3.4189 | Loss DX: 0.2450 | Loss DY: 0.1817
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [407/597] | Loss G: 3.7440 | Loss DX: 0.2274 | Loss DY: 0.1864
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [408/597] | Loss G: 3.3521 | Loss DX: 0.2718 | Loss DY: 0.2457
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [409/597] | Loss G: 3.6806 | Loss DX: 0.2182 | Loss DY: 0.2333
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [410/597] | Loss G: 3.7678 | Loss DX: 0.2067 | Loss DY: 0.2166
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [411/597] | Loss G: 3.9045 | Loss DX: 0.1696 | Loss DY: 0.2158
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [412/597] | Loss G: 3.3083 | Loss DX: 0.2326 | Loss DY: 0.2779
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [413/597] | Loss G: 4.2824 | Loss DX: 0.2143 | Loss DY: 0.2563
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [414/597] | Loss G: 3.7001 | Loss DX: 0.1438 | Loss DY: 0.2100
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [415/597] | Loss G: 3.8744 | Loss DX: 0.1232 | Loss DY: 0.2441
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [416/597] | Loss G: 4.8871 | Loss DX: 0.2975 | Loss DY: 0.1341
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [417/597] | Loss G: 3.5316 | Loss DX: 0.2079 | Loss DY: 0.2405
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [418/597] | Loss G: 2.9976 | Loss DX: 0.2423 | Loss DY: 0.2334
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [419/597] | Loss G: 3.2461 | Loss DX: 0.2543 | Loss DY: 0.1700
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [420/597] | Loss G: 3.7889 | Loss DX: 0.2104 | Loss DY: 0.1851
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [421/597] | Loss G: 3.3175 | Loss DX: 0.1652 | Loss DY: 0.2533
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [422/597] | Loss G: 4.6974 | Loss DX: 0.1972 | Loss DY: 0.2383
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [423/597] | Loss G: 3.2131 | Loss DX: 0.2077 | Loss DY: 0.1834
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [424/597] | Loss G: 3.5090 | Loss DX: 0.2551 | Loss DY: 0.2221
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [425/597] | Loss G: 3.3792 | Loss DX: 0.2644 | Loss DY: 0.1855
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [426/597] | Loss G: 3.8352 | Loss DX: 0.2162 | Loss DY: 0.1915
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [427/597] | Loss G: 3.4124 | Loss DX: 0.1956 | Loss DY: 0.2035
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [428/597] | Loss G: 3.4055 | Loss DX: 0.2279 | Loss DY: 0.1906
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [429/597] | Loss G: 4.1988 | Loss DX: 0.2048 | Loss DY: 0.2500
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [430/597] | Loss G: 3.2372 | Loss DX: 0.3314 | Loss DY: 0.2991
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [431/597] | Loss G: 3.5423 | Loss DX: 0.2193 | Loss DY: 0.2381
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [432/597] | Loss G: 3.5174 | Loss DX: 0.2246 | Loss DY: 0.2699
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [433/597] | Loss G: 3.5687 | Loss DX: 0.2537 | Loss DY: 0.1952
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [434/597] | Loss G: 4.1767 | Loss DX: 0.2479 | Loss DY: 0.2264
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [435/597] | Loss G: 3.0658 | Loss DX: 0.2302 | Loss DY: 0.2064
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [436/597] | Loss G: 3.1717 | Loss DX: 0.2373 | Loss DY: 0.2398
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [437/597] | Loss G: 3.0061 | Loss DX: 0.2135 | Loss DY: 0.2219
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [438/597] | Loss G: 4.0127 | Loss DX: 0.2417 | Loss DY: 0.2610
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [439/597] | Loss G: 3.5064 | Loss DX: 0.2413 | Loss DY: 0.2183
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [440/597] | Loss G: 3.2508 | Loss DX: 0.2198 | Loss DY: 0.2158
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [441/597] | Loss G: 3.2560 | Loss DX: 0.2056 | Loss DY: 0.2759
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [442/597] | Loss G: 3.5476 | Loss DX: 0.1899 | Loss DY: 0.2564
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [443/597] | Loss G: 4.0834 | Loss DX: 0.2290 | Loss DY: 0.2248
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [444/597] | Loss G: 3.3220 | Loss DX: 0.2406 | Loss DY: 0.2601
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [445/597] | Loss G: 3.8683 | Loss DX: 0.1439 | Loss DY: 0.2174
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [446/597] | Loss G: 3.4950 | Loss DX: 0.2725 | Loss DY: 0.1991
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [447/597] | Loss G: 2.8561 | Loss DX: 0.2096 | Loss DY: 0.2440
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [448/597] | Loss G: 4.2331 | Loss DX: 0.1736 | Loss DY: 0.1647
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [449/597] | Loss G: 3.5546 | Loss DX: 0.2361 | Loss DY: 0.1980
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [450/597] | Loss G: 3.3574 | Loss DX: 0.2102 | Loss DY: 0.2338
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [451/597] | Loss G: 4.3949 | Loss DX: 0.2181 | Loss DY: 0.2471
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [452/597] | Loss G: 3.5501 | Loss DX: 0.2052 | Loss DY: 0.2227
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [453/597] | Loss G: 3.1544 | Loss DX: 0.2187 | Loss DY: 0.1828
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [454/597] | Loss G: 3.2137 | Loss DX: 0.2192 | Loss DY: 0.2326
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [455/597] | Loss G: 3.8137 | Loss DX: 0.1868 | Loss DY: 0.1926
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [456/597] | Loss G: 3.1669 | Loss DX: 0.2268 | Loss DY: 0.1613
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [457/597] | Loss G: 2.9584 | Loss DX: 0.1892 | Loss DY: 0.3070
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [458/597] | Loss G: 3.3539 | Loss DX: 0.2360 | Loss DY: 0.2724
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [459/597] | Loss G: 3.7620 | Loss DX: 0.1292 | Loss DY: 0.1984
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [460/597] | Loss G: 3.1864 | Loss DX: 0.2532 | Loss DY: 0.1732
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [461/597] | Loss G: 3.2874 | Loss DX: 0.2815 | Loss DY: 0.2282
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [462/597] | Loss G: 2.9921 | Loss DX: 0.2515 | Loss DY: 0.2154
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [463/597] | Loss G: 3.0412 | Loss DX: 0.1965 | Loss DY: 0.1939
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [464/597] | Loss G: 3.5286 | Loss DX: 0.2126 | Loss DY: 0.2011
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [465/597] | Loss G: 4.2564 | Loss DX: 0.1800 | Loss DY: 0.2321
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [466/597] | Loss G: 3.5996 | Loss DX: 0.2495 | Loss DY: 0.2674
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [467/597] | Loss G: 2.9135 | Loss DX: 0.2223 | Loss DY: 0.2416
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [468/597] | Loss G: 3.0652 | Loss DX: 0.2160 | Loss DY: 0.1926
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [469/597] | Loss G: 3.3009 | Loss DX: 0.2056 | Loss DY: 0.1735
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [470/597] | Loss G: 3.2902 | Loss DX: 0.2278 | Loss DY: 0.1686
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [471/597] | Loss G: 3.8115 | Loss DX: 0.1870 | Loss DY: 0.1682
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [472/597] | Loss G: 3.2661 | Loss DX: 0.2344 | Loss DY: 0.1870
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [473/597] | Loss G: 2.9400 | Loss DX: 0.1867 | Loss DY: 0.2152
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [474/597] | Loss G: 3.4082 | Loss DX: 0.2078 | Loss DY: 0.1730
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [475/597] | Loss G: 3.1429 | Loss DX: 0.1831 | Loss DY: 0.2695
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [476/597] | Loss G: 3.0269 | Loss DX: 0.1827 | Loss DY: 0.2555
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [477/597] | Loss G: 3.4669 | Loss DX: 0.2147 | Loss DY: 0.2321
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [478/597] | Loss G: 3.3517 | Loss DX: 0.2135 | Loss DY: 0.2362
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [479/597] | Loss G: 3.6470 | Loss DX: 0.1691 | Loss DY: 0.2006
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [480/597] | Loss G: 2.9757 | Loss DX: 0.2181 | Loss DY: 0.2595
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [481/597] | Loss G: 3.6037 | Loss DX: 0.2643 | Loss DY: 0.2494
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [482/597] | Loss G: 2.9851 | Loss DX: 0.2982 | Loss DY: 0.3033
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [483/597] | Loss G: 3.1723 | Loss DX: 0.2001 | Loss DY: 0.1747
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [484/597] | Loss G: 3.0535 | Loss DX: 0.2828 | Loss DY: 0.2305
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [485/597] | Loss G: 4.4235 | Loss DX: 0.1897 | Loss DY: 0.2069
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [486/597] | Loss G: 4.0009 | Loss DX: 0.2559 | Loss DY: 0.2382
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [487/597] | Loss G: 3.4987 | Loss DX: 0.2165 | Loss DY: 0.1810
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [488/597] | Loss G: 3.4457 | Loss DX: 0.2161 | Loss DY: 0.2393
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [489/597] | Loss G: 3.8100 | Loss DX: 0.1880 | Loss DY: 0.2625
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [490/597] | Loss G: 3.7337 | Loss DX: 0.2289 | Loss DY: 0.2406
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [491/597] | Loss G: 4.1550 | Loss DX: 0.2115 | Loss DY: 0.1799
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [492/597] | Loss G: 3.6295 | Loss DX: 0.1624 | Loss DY: 0.1890
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [493/597] | Loss G: 3.2981 | Loss DX: 0.2336 | Loss DY: 0.2034
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [494/597] | Loss G: 2.8699 | Loss DX: 0.2930 | Loss DY: 0.2070
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [495/597] | Loss G: 3.1261 | Loss DX: 0.2664 | Loss DY: 0.2064
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [496/597] | Loss G: 3.7971 | Loss DX: 0.1825 | Loss DY: 0.1766
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [497/597] | Loss G: 2.9103 | Loss DX: 0.2582 | Loss DY: 0.1902
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [498/597] | Loss G: 3.1444 | Loss DX: 0.2671 | Loss DY: 0.2287
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [499/597] | Loss G: 2.9496 | Loss DX: 0.1925 | Loss DY: 0.3339
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [500/597] | Loss G: 3.3951 | Loss DX: 0.1389 | Loss DY: 0.1682
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [501/597] | Loss G: 4.1138 | Loss DX: 0.2469 | Loss DY: 0.2844
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [502/597] | Loss G: 3.9278 | Loss DX: 0.2232 | Loss DY: 0.3208
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [503/597] | Loss G: 3.7072 | Loss DX: 0.1849 | Loss DY: 0.2309
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [504/597] | Loss G: 3.0284 | Loss DX: 0.1844 | Loss DY: 0.2476
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [505/597] | Loss G: 3.6958 | Loss DX: 0.1567 | Loss DY: 0.2284
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [506/597] | Loss G: 3.4476 | Loss DX: 0.2221 | Loss DY: 0.2361
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [507/597] | Loss G: 3.0566 | Loss DX: 0.2371 | Loss DY: 0.2477
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [508/597] | Loss G: 2.8225 | Loss DX: 0.2218 | Loss DY: 0.2376
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [509/597] | Loss G: 3.7011 | Loss DX: 0.2570 | Loss DY: 0.1915
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [510/597] | Loss G: 3.3577 | Loss DX: 0.1601 | Loss DY: 0.1991
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [511/597] | Loss G: 3.9648 | Loss DX: 0.1898 | Loss DY: 0.1869
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [512/597] | Loss G: 2.8483 | Loss DX: 0.2536 | Loss DY: 0.2035
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [513/597] | Loss G: 3.7166 | Loss DX: 0.2532 | Loss DY: 0.1842
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [514/597] | Loss G: 2.9976 | Loss DX: 0.2345 | Loss DY: 0.2020
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [515/597] | Loss G: 3.7330 | Loss DX: 0.2397 | Loss DY: 0.2237
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [516/597] | Loss G: 5.1431 | Loss DX: 0.2221 | Loss DY: 0.1484
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [517/597] | Loss G: 3.0430 | Loss DX: 0.2134 | Loss DY: 0.2066
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [518/597] | Loss G: 3.5469 | Loss DX: 0.2733 | Loss DY: 0.2666
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [519/597] | Loss G: 3.1951 | Loss DX: 0.2415 | Loss DY: 0.2755
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [520/597] | Loss G: 3.5203 | Loss DX: 0.1981 | Loss DY: 0.2117
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [521/597] | Loss G: 3.9476 | Loss DX: 0.2558 | Loss DY: 0.2136
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [522/597] | Loss G: 4.5638 | Loss DX: 0.1946 | Loss DY: 0.2193
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [523/597] | Loss G: 3.7883 | Loss DX: 0.2167 | Loss DY: 0.1961
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [524/597] | Loss G: 4.4718 | Loss DX: 0.1776 | Loss DY: 0.3076
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [525/597] | Loss G: 3.9512 | Loss DX: 0.2271 | Loss DY: 0.2417
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [526/597] | Loss G: 3.5064 | Loss DX: 0.2866 | Loss DY: 0.2180
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [527/597] | Loss G: 4.1193 | Loss DX: 0.2110 | Loss DY: 0.2540
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [528/597] | Loss G: 3.4690 | Loss DX: 0.2388 | Loss DY: 0.2530
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [529/597] | Loss G: 3.6443 | Loss DX: 0.1980 | Loss DY: 0.2210
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [530/597] | Loss G: 3.5315 | Loss DX: 0.1938 | Loss DY: 0.2036
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [531/597] | Loss G: 3.3963 | Loss DX: 0.2228 | Loss DY: 0.2464
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [532/597] | Loss G: 3.3916 | Loss DX: 0.2202 | Loss DY: 0.1592
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [533/597] | Loss G: 3.1279 | Loss DX: 0.2060 | Loss DY: 0.1631
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [534/597] | Loss G: 3.2809 | Loss DX: 0.1912 | Loss DY: 0.1949
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [535/597] | Loss G: 3.3061 | Loss DX: 0.2171 | Loss DY: 0.2050
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [536/597] | Loss G: 3.0838 | Loss DX: 0.1941 | Loss DY: 0.2418
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [537/597] | Loss G: 3.4570 | Loss DX: 0.2195 | Loss DY: 0.2401
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [538/597] | Loss G: 3.6192 | Loss DX: 0.1959 | Loss DY: 0.2708
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [539/597] | Loss G: 3.8389 | Loss DX: 0.1927 | Loss DY: 0.2658
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [540/597] | Loss G: 3.3379 | Loss DX: 0.1958 | Loss DY: 0.2147
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [541/597] | Loss G: 3.4280 | Loss DX: 0.1909 | Loss DY: 0.2163
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [542/597] | Loss G: 3.9399 | Loss DX: 0.1808 | Loss DY: 0.2350
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [543/597] | Loss G: 4.1839 | Loss DX: 0.1522 | Loss DY: 0.2691
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [544/597] | Loss G: 4.1559 | Loss DX: 0.1774 | Loss DY: 0.2485
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [545/597] | Loss G: 3.3254 | Loss DX: 0.3057 | Loss DY: 0.2335
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [546/597] | Loss G: 3.4163 | Loss DX: 0.2356 | Loss DY: 0.2130
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [547/597] | Loss G: 3.7265 | Loss DX: 0.1732 | Loss DY: 0.2407
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [548/597] | Loss G: 3.0275 | Loss DX: 0.1858 | Loss DY: 0.2206
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [549/597] | Loss G: 3.3305 | Loss DX: 0.1785 | Loss DY: 0.1745
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [550/597] | Loss G: 3.4216 | Loss DX: 0.2078 | Loss DY: 0.2057
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [551/597] | Loss G: 3.8180 | Loss DX: 0.2488 | Loss DY: 0.1550
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [552/597] | Loss G: 3.4206 | Loss DX: 0.1808 | Loss DY: 0.2341
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [553/597] | Loss G: 3.8668 | Loss DX: 0.2680 | Loss DY: 0.2066
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [554/597] | Loss G: 3.1128 | Loss DX: 0.2122 | Loss DY: 0.2434
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [555/597] | Loss G: 2.9537 | Loss DX: 0.2379 | Loss DY: 0.1476
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [556/597] | Loss G: 3.5993 | Loss DX: 0.2336 | Loss DY: 0.2085
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [557/597] | Loss G: 3.1972 | Loss DX: 0.2159 | Loss DY: 0.2201
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [558/597] | Loss G: 3.0369 | Loss DX: 0.2276 | Loss DY: 0.1853
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [559/597] | Loss G: 3.6585 | Loss DX: 0.2223 | Loss DY: 0.2221
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [560/597] | Loss G: 3.2196 | Loss DX: 0.1670 | Loss DY: 0.2683
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [561/597] | Loss G: 3.3946 | Loss DX: 0.1640 | Loss DY: 0.2405
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [562/597] | Loss G: 4.1244 | Loss DX: 0.1921 | Loss DY: 0.2254
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [563/597] | Loss G: 3.1954 | Loss DX: 0.2309 | Loss DY: 0.2319
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [564/597] | Loss G: 3.5209 | Loss DX: 0.2629 | Loss DY: 0.2221
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [565/597] | Loss G: 3.6095 | Loss DX: 0.2487 | Loss DY: 0.2639
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [566/597] | Loss G: 3.4421 | Loss DX: 0.2485 | Loss DY: 0.2132
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [567/597] | Loss G: 3.8135 | Loss DX: 0.1782 | Loss DY: 0.1998
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [568/597] | Loss G: 3.6861 | Loss DX: 0.2430 | Loss DY: 0.2228
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [569/597] | Loss G: 3.1106 | Loss DX: 0.2214 | Loss DY: 0.2209
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [570/597] | Loss G: 3.4925 | Loss DX: 0.2467 | Loss DY: 0.2363
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [571/597] | Loss G: 3.3061 | Loss DX: 0.1973 | Loss DY: 0.2447
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [572/597] | Loss G: 4.1229 | Loss DX: 0.2441 | Loss DY: 0.1804
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [573/597] | Loss G: 3.4478 | Loss DX: 0.2465 | Loss DY: 0.2692
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [574/597] | Loss G: 3.5575 | Loss DX: 0.2101 | Loss DY: 0.2225
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [575/597] | Loss G: 3.5915 | Loss DX: 0.2335 | Loss DY: 0.2193
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [576/597] | Loss G: 3.5643 | Loss DX: 0.1945 | Loss DY: 0.2357
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [577/597] | Loss G: 2.9448 | Loss DX: 0.2530 | Loss DY: 0.2653
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [578/597] | Loss G: 3.3774 | Loss DX: 0.1596 | Loss DY: 0.2576
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [579/597] | Loss G: 3.7366 | Loss DX: 0.1741 | Loss DY: 0.2336
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [580/597] | Loss G: 3.6115 | Loss DX: 0.1840 | Loss DY: 0.2366
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [581/597] | Loss G: 3.0548 | Loss DX: 0.2134 | Loss DY: 0.2364
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [582/597] | Loss G: 2.9114 | Loss DX: 0.2441 | Loss DY: 0.2300
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [583/597] | Loss G: 3.4534 | Loss DX: 0.2008 | Loss DY: 0.2031
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [584/597] | Loss G: 3.2769 | Loss DX: 0.2725 | Loss DY: 0.2680
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [585/597] | Loss G: 3.3028 | Loss DX: 0.2191 | Loss DY: 0.2226
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [586/597] | Loss G: 3.7511 | Loss DX: 0.1959 | Loss DY: 0.2374
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [587/597] | Loss G: 2.9560 | Loss DX: 0.2751 | Loss DY: 0.2581
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [588/597] | Loss G: 3.4074 | Loss DX: 0.2012 | Loss DY: 0.2174
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [589/597] | Loss G: 3.7875 | Loss DX: 0.1840 | Loss DY: 0.1552
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [590/597] | Loss G: 3.4740 | Loss DX: 0.1928 | Loss DY: 0.2498
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [591/597] | Loss G: 3.4668 | Loss DX: 0.2328 | Loss DY: 0.2196
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [592/597] | Loss G: 2.8783 | Loss DX: 0.1984 | Loss DY: 0.2328
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [593/597] | Loss G: 5.3555 | Loss DX: 0.1396 | Loss DY: 0.1988
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [594/597] | Loss G: 3.0634 | Loss DX: 0.2349 | Loss DY: 0.2464
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [595/597] | Loss G: 3.1989 | Loss DX: 0.2260 | Loss DY: 0.1968
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [596/597] | Loss G: 4.0441 | Loss DX: 0.2228 | Loss DY: 0.2397
# Step 2 | alpha 1.0000 | Epoch [1/1] | Batch [597/597] | Loss G: 3.2484 | Loss DX: 0.2460 | Loss DY: 0.1465

# %%
# now let's test our cyclegan after training to see if it actually works:

real_x  = next(iter(lsun_loader))
real_x = real_x.cuda()

fake_y = generator_g(real_x).detach()
reconstructed_x = generator_f(fake_y).detach()

fake_y = fake_y.cpu()
reconstructed_x = reconstructed_x.cpu()

n_to_show = 2  # less than or equal to batch size
print("LSUN Images")
show_images(real_x[:n_to_show].cpu())
print("Generated Monet-style Images")
show_images(fake_y[:n_to_show])
print("Reconstructed LSUN Images")
show_images(reconstructed_x[:n_to_show])
# Out:
# LSUN Images
# Generated Monet-style Images
# Reconstructed LSUN Images
