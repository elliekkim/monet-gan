# %% [markdown]
# Goals:
# - Train GAN to more epochs and resize Monet images to get reasonable output of CycleGAN <--
# - ProgressiveGAN: only upsampling + downsampling <--
#   - ask if problems?

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import kagglehub
import torchvision.transforms as T
from torchvision.utils import make_grid
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
from tqdm import tqdm

# %%
to_tensor = T.ToTensor()

def load_image(path):
    return to_tensor(Image.open(path))


def show_images(imgs):
    # imgs is a tensor of shape: B x C x H x W
    grid = make_grid(imgs, nrow=4, padding=10, pad_value=1)
    plt.imshow(grid.permute(1, 2, 0))
    plt.axis("off")
    plt.gcf().set_figwidth(8)
    plt.show()

# %%
class Monet(Dataset):
    def __init__(self, img_size=256):
        self.data_path = kagglehub.dataset_download(
            "dimitreoliveira/monet-paintings-jpg-berkeley")
        self.img_names = os.listdir(self.data_path)
        self.img_names = list(filter(lambda s: os.path.isfile(os.path.join(self.data_path, s)), self.img_names))

        # resize images to lower resolution
        print("Image size:", img_size)
        if img_size == 256:
            self.resized_data_path = self.data_path
        else:
            self.resized_data_path = os.path.join(self.data_path, f"resized_{img_size}")
        
        print("Saving resized images...")
        for img_name in tqdm(self.img_names):
            resized_path = os.path.join(self.resized_data_path, img_name)
            if os.path.exists(resized_path):
                continue

            # resize to specified img size
            orig_img_path = os.path.join(self.data_path, img_name)
            with Image.open(orig_img_path) as img:
                resized_img = img.resize((img_size, img_size))
                # save
                os.makedirs(os.path.dirname(resized_path), exist_ok=True)
                resized_img.save(resized_path)

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, index):
        return load_image(os.path.join(self.resized_data_path, self.img_names[index]))

# %%
from torchvision.datasets import CIFAR10
from torchvision import transforms

monet = Monet()
cifar = CIFAR10(root="./cifar10", train=True,
                download=True, transform=to_tensor)

batch_size = 1
monet_loader = DataLoader(monet, batch_size=batch_size, shuffle=True)
cifar_loader = DataLoader(cifar, batch_size=batch_size, shuffle=True)
# Out:
# Image size: 256
# Saving resized images...
# 100%|██████████| 1193/1193 [00:00<00:00, 14102.61it/s]
# Files already downloaded and verified

# %% [markdown]
# Define models

# %%
from torch import nn

class GeneratorResidualBlock(nn.Module):
    def __init__(self, n_channels):
        super().__init__()
        self.layers = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(n_channels, n_channels, kernel_size=3),
            nn.InstanceNorm2d(n_channels),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(n_channels, n_channels, kernel_size=3),
            nn.InstanceNorm2d(n_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return x + self.layers(x)


class Generator(nn.Module):
    def __init__(self):
        super().__init__()

        layers = []

        # initial convolution
        layers += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(3, 64, kernel_size=7),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
        ]
        # downsample
        layers += [
            nn.ReflectionPad2d(1),
            nn.Conv2d(64, 128, kernel_size=3, stride=2),
            nn.InstanceNorm2d(128),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(128, 256, kernel_size=3, stride=2),
            nn.InstanceNorm2d(256),
            nn.ReLU(),
        ]
        # residual blocks
        for _ in range(6):
            layers.append(GeneratorResidualBlock(256))
        # upsample
        layers += [
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
        ]
        # final convolution
        layers += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(64, 3, kernel_size=7),
            nn.Sigmoid()
        ]

        # put all the layers together
        self.layers = nn.Sequential(*layers)


    def forward(self, x):
        return self.layers(x)


class Discriminator(nn.Module):
    def __init__(self, input_channels=3):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(input_channels, 64, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(256, 512, kernel_size=4, stride=1, padding=1),
            nn.InstanceNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),

            # Output Layer: Conv -> Sigmoid
            nn.Conv2d(512, 1, kernel_size=3, stride=1),
            nn.Flatten(1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# %%
import torch._dynamo
torch._dynamo.reset()
torch._dynamo.config.suppress_errors = True

g = torch.compile(Generator())
d = torch.compile(Discriminator())

# Test with CIFAR
imgs, _ = next(iter(cifar_loader))
fake_imgs = g(imgs)
print("Generated Images:")
show_images(fake_imgs[:8].detach().cpu())
# Out:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward C:\Users\annak\AppData\Local\Temp\ipykernel_20660\4222143741.py line 68
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpp_builder.py", line 130, in check_compiler_exist_windows
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     subprocess.check_output([compiler, "/help"], stderr=subprocess.STDOUT)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 424, in check_output
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 505, in run
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     with Popen(*popenargs, **kwargs) as process:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 951, in __init__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self._execute_child(args, executable, preexec_fn, close_fds,
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 1420, in _execute_child
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] FileNotFoundError: [WinError 2] The system cannot find the file specified
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\__init__.py", line 2235, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 586, in aot_dispatch_autograd
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1784, in codegen
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler.codegen()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\scheduler.py", line 3383, in codegen
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._codegen()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\scheduler.py", line 3461, in _codegen
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.get_backend(device).codegen_node(node)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\codegen\cpp.py", line 4468, in codegen_node
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     cpp_kernel_proxy = CppKernelProxy(kernel_group)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\codegen\cpp.py", line 3466, in __init__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 360, in pick_vec_isa
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     _valid_vec_isa_list: List[VecISA] = valid_vec_isa_list()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 350, in valid_vec_isa_list
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 148, in __bool__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.check_build(VecISA._avx_code)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 101, in check_build
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 27, in _get_isa_dry_compile_fingerprint
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiler_info = get_compiler_version_info(get_cpp_compiler())
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpp_builder.py", line 144, in get_cpp_compiler
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     check_compiler_exist_windows(compiler)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpp_builder.py", line 135, in check_compiler_exist_windows
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpp_builder.py", line 130, in check_compiler_exist_windows
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     subprocess.check_output([compiler, "/help"], stderr=subprocess.STDOUT)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 424, in check_output
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 505, in run
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     with Popen(*popenargs, **kwargs) as process:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 951, in __init__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self._execute_child(args, executable, preexec_fn, close_fds,
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 1420, in _execute_child
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] FileNotFoundError: [WinError 2] The system cannot find the file specified
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\__init__.py", line 2235, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 586, in aot_dispatch_autograd
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1784, in codegen
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler.codegen()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\scheduler.py", line 3383, in codegen
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._codegen()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\scheduler.py", line 3461, in _codegen
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.get_backend(device).codegen_node(node)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\codegen\cpp.py", line 4468, in codegen_node
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     cpp_kernel_proxy = CppKernelProxy(kernel_group)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\codegen\cpp.py", line 3466, in __init__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 360, in pick_vec_isa
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     _valid_vec_isa_list: List[VecISA] = valid_vec_isa_list()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 350, in valid_vec_isa_list
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 148, in __bool__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.check_build(VecISA._avx_code)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 101, in check_build
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 27, in _get_isa_dry_compile_fingerprint
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiler_info = get_compiler_version_info(get_cpp_compiler())
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpp_builder.py", line 144, in get_cpp_compiler
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     check_compiler_exist_windows(compiler)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpp_builder.py", line 135, in check_compiler_exist_windows
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1130 02:10:04.662603 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward C:\Users\annak\AppData\Local\Temp\ipykernel_20660\4222143741.py line 17
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpp_builder.py", line 130, in check_compiler_exist_windows
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     subprocess.check_output([compiler, "/help"], stderr=subprocess.STDOUT)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 424, in check_output
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 505, in run
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     with Popen(*popenargs, **kwargs) as process:
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 951, in __init__
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self._execute_child(args, executable, preexec_fn, close_fds,
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 1420, in _execute_child
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] FileNotFoundError: [WinError 2] The system cannot find the file specified
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\__init__.py", line 2235, in __call__
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# ...
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 586, in aot_dispatch_autograd
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\graph.py", line 1784, in codegen
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler.codegen()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\scheduler.py", line 3383, in codegen
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._codegen()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\scheduler.py", line 3461, in _codegen
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.get_backend(device).codegen_node(node)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\codegen\cpp.py", line 4468, in codegen_node
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     cpp_kernel_proxy = CppKernelProxy(kernel_group)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\codegen\cpp.py", line 3466, in __init__
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 360, in pick_vec_isa
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     _valid_vec_isa_list: List[VecISA] = valid_vec_isa_list()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 350, in valid_vec_isa_list
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa:
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 148, in __bool__
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.check_build(VecISA._avx_code)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 101, in check_build
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 27, in _get_isa_dry_compile_fingerprint
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiler_info = get_compiler_version_info(get_cpp_compiler())
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpp_builder.py", line 144, in get_cpp_compiler
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     check_compiler_exist_windows(compiler)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_inductor\cpp_builder.py", line 135, in check_compiler_exist_windows
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\annak\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1130 02:10:05.228550 20660 site-packages\torch\_dynamo\convert_frame.py:1125]
# Generated Images:

# %%
import torch
import torch.optim as optim
from torch.autograd import Variable

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
num_epochs = 10
lr = 0.0002
lambda_cycle = 10
lambda_identity = 5

# Initialize models
generator_g = Generator().to(device)  # original img -> monet
generator_f = Generator().to(device)  # monet -> cifar

discriminator_x = Discriminator().to(device)  # For CIFAR
discriminator_y = Discriminator().to(device)  # For Monet

# Loss functions
adversarial_loss = nn.MSELoss()
cycle_loss = nn.L1Loss()
identity_loss = nn.L1Loss()

# Optimizers
optimizer_g = optim.Adam(list(generator_g.parameters()) + list(generator_f.parameters()), lr=lr, betas=(0.5, 0.999))
optimizer_dx = optim.Adam(discriminator_x.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_dy = optim.Adam(discriminator_y.parameters(), lr=lr, betas=(0.5, 0.999))

# Labels
real_label = 1.0
fake_label = 0.0

# Training loop
for epoch in range(num_epochs):
    for b, (real_x, real_y) in enumerate(zip(cifar_loader, monet_loader)):
        # Prepare data
        real_x = real_x[0].to(device)  # CIFAR images
        real_y = real_y.to(device)  # Monet images

        # -------------------------------------------
        #  Train Generators (G and F)
        # -------------------------------------------
        optimizer_g.zero_grad()

        # Adversarial loss
        fake_y = generator_g(real_x)  # X -> Y
        pred_fake_y = discriminator_y(fake_y)
        loss_g_adv = adversarial_loss(pred_fake_y, torch.ones_like(pred_fake_y).to(device))

        fake_x = generator_f(real_y)  # Y -> X
        pred_fake_x = discriminator_x(fake_x)
        loss_f_adv = adversarial_loss(pred_fake_x, torch.ones_like(pred_fake_x).to(device))

        # Cycle consistency loss
        cycle_x = generator_f(fake_y)  # X -> Y -> X
        loss_cycle_x = cycle_loss(cycle_x, real_x)

        cycle_y = generator_g(fake_x)  # Y -> X -> Y
        loss_cycle_y = cycle_loss(cycle_y, real_y)

        # Identity loss
        identity_x = generator_f(real_x)  # X -> X
        loss_id_x = identity_loss(identity_x, real_x)

        identity_y = generator_g(real_y)  # Y -> Y
        loss_id_y = identity_loss(identity_y, real_y)

        # Total generator loss
        loss_g = loss_g_adv + loss_f_adv + lambda_cycle * (loss_cycle_x + loss_cycle_y) + lambda_identity * (loss_id_x + loss_id_y)
        loss_g.backward()
        optimizer_g.step()

        # -------------------------------------------
        #  Train Discriminators (X and Y)
        # -------------------------------------------
        # Discriminator X
        optimizer_dx.zero_grad()

        pred_real_x = discriminator_x(real_x)
        loss_dx_real = adversarial_loss(pred_real_x, torch.ones_like(pred_real_x).to(device))

        pred_fake_x = discriminator_x(fake_x.detach())
        loss_dx_fake = adversarial_loss(pred_fake_x, torch.zeros_like(pred_fake_x).to(device))

        loss_dx = (loss_dx_real + loss_dx_fake) * 0.5
        loss_dx.backward()
        optimizer_dx.step()

        # Discriminator Y
        optimizer_dy.zero_grad()

        pred_real_y = discriminator_y(real_y)
        loss_dy_real = adversarial_loss(pred_real_y, torch.ones_like(pred_real_y).to(device))

        pred_fake_y = discriminator_y(fake_y.detach())
        loss_dy_fake = adversarial_loss(pred_fake_y, torch.zeros_like(pred_fake_y).to(device))

        loss_dy = (loss_dy_real + loss_dy_fake) * 0.5
        loss_dy.backward()
        optimizer_dy.step()

        print(f"Epoch [{epoch + 1}/{num_epochs}] Batch [{b + 1}/{len(monet_loader)}] | Loss G: {loss_g.item():.4f} | Loss DX: {loss_dx.item():.4f} | Loss DY: {loss_dy.item():.4f}")

    print(f"Epoch [{epoch + 1}/{num_epochs}] | Loss G: {loss_g.item():.4f} | Loss DX: {loss_dx.item():.4f} | Loss DY: {loss_dy.item():.4f}")

# Save models
torch.save(generator_g.state_dict(), "generator_g.pth")
torch.save(generator_f.state_dict(), "generator_f.pth")
torch.save(discriminator_x.state_dict(), "discriminator_x.pth")
torch.save(discriminator_y.state_dict(), "discriminator_y.pth")
# Out:
# Epoch [1/10] Batch [1/1193] | Loss G: 8.2297 | Loss DX: 0.2419 | Loss DY: 0.3237
# Epoch [1/10] Batch [2/1193] | Loss G: 8.4416 | Loss DX: 0.1234 | Loss DY: 0.1274
# Epoch [1/10] Batch [3/1193] | Loss G: 5.9356 | Loss DX: 0.1030 | Loss DY: 0.1129
# Epoch [1/10] Batch [4/1193] | Loss G: 8.8031 | Loss DX: 0.2843 | Loss DY: 0.0956
# Epoch [1/10] Batch [5/1193] | Loss G: 6.6997 | Loss DX: 0.0772 | Loss DY: 0.0749
# Epoch [1/10] Batch [6/1193] | Loss G: 9.1478 | Loss DX: 0.0720 | Loss DY: 0.0529
# Epoch [1/10] Batch [7/1193] | Loss G: 7.2947 | Loss DX: 0.0602 | Loss DY: 0.0362
# Epoch [1/10] Batch [8/1193] | Loss G: 8.4978 | Loss DX: 0.0408 | Loss DY: 0.0231
# Epoch [1/10] Batch [9/1193] | Loss G: 8.6705 | Loss DX: 0.0325 | Loss DY: 0.0269
# Epoch [1/10] Batch [10/1193] | Loss G: 7.6288 | Loss DX: 0.0262 | Loss DY: 0.0202
# Epoch [1/10] Batch [11/1193] | Loss G: 7.7060 | Loss DX: 0.0203 | Loss DY: 0.0181
# Epoch [1/10] Batch [12/1193] | Loss G: 7.2850 | Loss DX: 0.0181 | Loss DY: 0.0139
# Epoch [1/10] Batch [13/1193] | Loss G: 9.1691 | Loss DX: 0.0155 | Loss DY: 0.0122
# Epoch [1/10] Batch [14/1193] | Loss G: 7.3659 | Loss DX: 0.0153 | Loss DY: 0.0131
# Epoch [1/10] Batch [15/1193] | Loss G: 6.8208 | Loss DX: 0.0110 | Loss DY: 0.0079
# Epoch [1/10] Batch [16/1193] | Loss G: 8.8726 | Loss DX: 0.0398 | Loss DY: 0.0109
# Epoch [1/10] Batch [17/1193] | Loss G: 6.2815 | Loss DX: 0.0125 | Loss DY: 0.0118
# Epoch [1/10] Batch [18/1193] | Loss G: 7.9544 | Loss DX: 0.0115 | Loss DY: 0.0071
# Epoch [1/10] Batch [19/1193] | Loss G: 6.8368 | Loss DX: 0.0117 | Loss DY: 0.0062
# Epoch [1/10] Batch [20/1193] | Loss G: 6.0969 | Loss DX: 0.0110 | Loss DY: 0.0095
# Epoch [1/10] Batch [21/1193] | Loss G: 7.0988 | Loss DX: 0.0355 | Loss DY: 0.0061
# Epoch [1/10] Batch [22/1193] | Loss G: 5.8228 | Loss DX: 0.0104 | Loss DY: 0.0057
# Epoch [1/10] Batch [23/1193] | Loss G: 6.0825 | Loss DX: 0.0093 | Loss DY: 0.0042
# Epoch [1/10] Batch [24/1193] | Loss G: 7.1952 | Loss DX: 0.0098 | Loss DY: 0.0044
# Epoch [1/10] Batch [25/1193] | Loss G: 5.9449 | Loss DX: 0.0076 | Loss DY: 0.0057
# Epoch [1/10] Batch [26/1193] | Loss G: 5.7091 | Loss DX: 0.0086 | Loss DY: 0.0040
# Epoch [1/10] Batch [27/1193] | Loss G: 5.5912 | Loss DX: 0.0059 | Loss DY: 0.0031
# Epoch [1/10] Batch [28/1193] | Loss G: 6.8815 | Loss DX: 0.0068 | Loss DY: 0.0042
# Epoch [1/10] Batch [29/1193] | Loss G: 5.2855 | Loss DX: 0.0072 | Loss DY: 0.0029
# Epoch [1/10] Batch [30/1193] | Loss G: 7.5194 | Loss DX: 0.0056 | Loss DY: 0.0028
# Epoch [1/10] Batch [31/1193] | Loss G: 5.9920 | Loss DX: 0.0043 | Loss DY: 0.0028
# Epoch [1/10] Batch [32/1193] | Loss G: 6.5093 | Loss DX: 0.0044 | Loss DY: 0.0026
# Epoch [1/10] Batch [33/1193] | Loss G: 5.9060 | Loss DX: 0.0032 | Loss DY: 0.0022
# Epoch [1/10] Batch [34/1193] | Loss G: 5.6401 | Loss DX: 0.0026 | Loss DY: 0.0017
# Epoch [1/10] Batch [35/1193] | Loss G: 7.7247 | Loss DX: 0.0037 | Loss DY: 0.0024
# Epoch [1/10] Batch [36/1193] | Loss G: 8.1647 | Loss DX: 0.0042 | Loss DY: 0.0033
# Epoch [1/10] Batch [37/1193] | Loss G: 6.2412 | Loss DX: 0.0042 | Loss DY: 0.0015
# Epoch [1/10] Batch [38/1193] | Loss G: 7.1051 | Loss DX: 0.0036 | Loss DY: 0.0021
# Epoch [1/10] Batch [39/1193] | Loss G: 5.6960 | Loss DX: 0.0029 | Loss DY: 0.0022
# Epoch [1/10] Batch [40/1193] | Loss G: 7.4467 | Loss DX: 0.0063 | Loss DY: 0.0042
# Epoch [1/10] Batch [41/1193] | Loss G: 6.1353 | Loss DX: 0.0029 | Loss DY: 0.0020
# Epoch [1/10] Batch [42/1193] | Loss G: 7.4058 | Loss DX: 0.0035 | Loss DY: 0.0027
# Epoch [1/10] Batch [43/1193] | Loss G: 6.3074 | Loss DX: 0.0037 | Loss DY: 0.0028
# Epoch [1/10] Batch [44/1193] | Loss G: 6.2973 | Loss DX: 0.0027 | Loss DY: 0.0024
# Epoch [1/10] Batch [45/1193] | Loss G: 8.2817 | Loss DX: 0.0029 | Loss DY: 0.0019
# Epoch [1/10] Batch [46/1193] | Loss G: 5.9945 | Loss DX: 0.0028 | Loss DY: 0.0020
# Epoch [1/10] Batch [47/1193] | Loss G: 7.7321 | Loss DX: 0.0021 | Loss DY: 0.0016
# Epoch [1/10] Batch [48/1193] | Loss G: 6.2152 | Loss DX: 0.0029 | Loss DY: 0.0023
# Epoch [1/10] Batch [49/1193] | Loss G: 5.5701 | Loss DX: 0.0029 | Loss DY: 0.0021
# Epoch [1/10] Batch [50/1193] | Loss G: 7.0924 | Loss DX: 0.0017 | Loss DY: 0.0010
# Epoch [1/10] Batch [51/1193] | Loss G: 6.5138 | Loss DX: 0.0018 | Loss DY: 0.0014
# Epoch [1/10] Batch [52/1193] | Loss G: 7.4779 | Loss DX: 0.0012 | Loss DY: 0.0009
# Epoch [1/10] Batch [53/1193] | Loss G: 8.1762 | Loss DX: 0.0016 | Loss DY: 0.0010
# Epoch [1/10] Batch [54/1193] | Loss G: 6.2380 | Loss DX: 0.0014 | Loss DY: 0.0010
# Epoch [1/10] Batch [55/1193] | Loss G: 7.1599 | Loss DX: 0.0018 | Loss DY: 0.0011
# Epoch [1/10] Batch [56/1193] | Loss G: 8.1041 | Loss DX: 0.0017 | Loss DY: 0.0008
# Epoch [1/10] Batch [57/1193] | Loss G: 5.1496 | Loss DX: 0.0010 | Loss DY: 0.0007
# Epoch [1/10] Batch [58/1193] | Loss G: 5.3971 | Loss DX: 0.0011 | Loss DY: 0.0008
# Epoch [1/10] Batch [59/1193] | Loss G: 9.5281 | Loss DX: 0.0013 | Loss DY: 0.0013
# Epoch [1/10] Batch [60/1193] | Loss G: 5.4725 | Loss DX: 0.0009 | Loss DY: 0.0009
# Epoch [1/10] Batch [61/1193] | Loss G: 6.4557 | Loss DX: 0.0008 | Loss DY: 0.0007
# Epoch [1/10] Batch [62/1193] | Loss G: 6.3343 | Loss DX: 0.0014 | Loss DY: 0.0010
# Epoch [1/10] Batch [63/1193] | Loss G: 6.1964 | Loss DX: 0.0020 | Loss DY: 0.0011
# Epoch [1/10] Batch [64/1193] | Loss G: 7.9854 | Loss DX: 0.0008 | Loss DY: 0.0009
# Epoch [1/10] Batch [65/1193] | Loss G: 7.5217 | Loss DX: 0.0009 | Loss DY: 0.0006
# Epoch [1/10] Batch [66/1193] | Loss G: 7.2175 | Loss DX: 0.0007 | Loss DY: 0.0009
# Epoch [1/10] Batch [67/1193] | Loss G: 7.0128 | Loss DX: 0.0007 | Loss DY: 0.0006
# Epoch [1/10] Batch [68/1193] | Loss G: 8.7796 | Loss DX: 0.0007 | Loss DY: 0.0007
# Epoch [1/10] Batch [69/1193] | Loss G: 7.0435 | Loss DX: 0.0014 | Loss DY: 0.0009
# Epoch [1/10] Batch [70/1193] | Loss G: 5.9332 | Loss DX: 0.0009 | Loss DY: 0.0006
# Epoch [1/10] Batch [71/1193] | Loss G: 6.5391 | Loss DX: 0.0025 | Loss DY: 0.0008
# Epoch [1/10] Batch [72/1193] | Loss G: 7.5685 | Loss DX: 0.0019 | Loss DY: 0.0010
# Epoch [1/10] Batch [73/1193] | Loss G: 7.3179 | Loss DX: 0.0015 | Loss DY: 0.0013
# Epoch [1/10] Batch [74/1193] | Loss G: 5.1244 | Loss DX: 0.0010 | Loss DY: 0.0008
# Epoch [1/10] Batch [75/1193] | Loss G: 7.6507 | Loss DX: 0.0007 | Loss DY: 0.0006
# Epoch [1/10] Batch [76/1193] | Loss G: 6.1782 | Loss DX: 0.0009 | Loss DY: 0.0008
# Epoch [1/10] Batch [77/1193] | Loss G: 6.6476 | Loss DX: 0.0010 | Loss DY: 0.0009
# Epoch [1/10] Batch [78/1193] | Loss G: 5.6964 | Loss DX: 0.0008 | Loss DY: 0.0010
# Epoch [1/10] Batch [79/1193] | Loss G: 4.9899 | Loss DX: 0.0008 | Loss DY: 0.0007
# Epoch [1/10] Batch [80/1193] | Loss G: 7.7678 | Loss DX: 0.0007 | Loss DY: 0.0007
# Epoch [1/10] Batch [81/1193] | Loss G: 5.1821 | Loss DX: 0.0009 | Loss DY: 0.0005
# Epoch [1/10] Batch [82/1193] | Loss G: 6.1417 | Loss DX: 0.0007 | Loss DY: 0.0005
# Epoch [1/10] Batch [83/1193] | Loss G: 6.9825 | Loss DX: 0.0009 | Loss DY: 0.0003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 103
#     100         loss_dy.backward()
#     101         optimizer_dy.step()
# --> 103         print(f"Epoch [{epoch + 1}/{num_epochs}] Batch [{b + 1}/{len(monet_loader)}] | Loss G: {loss_g.item():.4f} | Loss DX: {loss_dx.item():.4f} | Loss DY: {loss_dy.item():.4f}")
#     105     print(f"Epoch [{epoch + 1}/{num_epochs}] | Loss G: {loss_g.item():.4f} | Loss DX: {loss_dx.item():.4f} | Loss DY: {loss_dy.item():.4f}")
#     107 # Save models
#
# KeyboardInterrupt:

# %%
torch.save(generator_g.state_dict(), "generator_g.pth")
torch.save(generator_f.state_dict(), "generator_f.pth")
torch.save(discriminator_x.state_dict(), "discriminator_x.pth")
torch.save(discriminator_y.state_dict(), "discriminator_y.pth")

# %%
# now let's test our cyclegan after training to see if it actually works:

# generator_g.load_state_dict(torch.load("generator_g.pth"))
# generator_f.load_state_dict(torch.load("generator_f.pth"))
# generator_g.eval()
# generator_f.eval()

real_x, _ = next(iter(cifar_loader))
real_x = real_x.cuda()

fake_y = generator_g(real_x).detach()
reconstructed_x = generator_f(fake_y).detach()

fake_y = fake_y.cpu()
reconstructed_x = reconstructed_x.cpu()

print("CIFAR Images")
show_images(real_x[:8].cpu())
print("Generated Monet-style Images")
show_images(fake_y[:8])
print("Reconstructed CIFAR Images")
show_images(reconstructed_x[:8])
# Out:
# CIFAR Images
# Generated Monet-style Images
# Reconstructed CIFAR Images
