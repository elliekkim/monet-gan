# %% [markdown]
# Goals:
# - Train GAN to more epochs and resize Monet images to get reasonable output of CycleGAN <--
# - ProgressiveGAN: only upsampling + downsampling <--
#   - ask if problems?

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import kagglehub
import torchvision.transforms as T
from torchvision.utils import make_grid
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
from tqdm import tqdm

# %%
to_tensor = T.ToTensor()

def load_image(path):
    return to_tensor(Image.open(path))


def show_images(imgs):
    # imgs is a tensor of shape: B x C x H x W
    grid = make_grid(imgs, nrow=4, padding=10, pad_value=1)
    plt.imshow(grid.permute(1, 2, 0))
    plt.axis("off")
    plt.gcf().set_figwidth(8)
    plt.show()

# %%
class Monet(Dataset):
    def __init__(self, img_size=256):
        self.data_path = kagglehub.dataset_download(
            "dimitreoliveira/monet-paintings-jpg-berkeley")
        self.img_names = os.listdir(self.data_path)
        self.img_names = list(filter(lambda s: os.path.isfile(os.path.join(self.data_path, s)), self.img_names))

        # resize images to lower resolution
        print("Image size:", img_size)
        if img_size == 256:
            self.resized_data_path = self.data_path
        else:
            self.resized_data_path = os.path.join(self.data_path, f"resized_{img_size}")
        
        print("Saving resized images...")
        for img_name in tqdm(self.img_names):
            resized_path = os.path.join(self.resized_data_path, img_name)
            if os.path.exists(resized_path):
                continue

            # resize to specified img size
            orig_img_path = os.path.join(self.data_path, img_name)
            with Image.open(orig_img_path) as img:
                resized_img = img.resize((img_size, img_size))
                # save
                os.makedirs(os.path.dirname(resized_path), exist_ok=True)
                resized_img.save(resized_path)

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, index):
        return load_image(os.path.join(self.resized_data_path, self.img_names[index]))

# %%
from torchvision.datasets import CIFAR10
from torchvision import transforms

monet = Monet(img_size=32)
cifar = CIFAR10(root="./cifar10", train=True,
                download=True, transform=to_tensor)

batch_size = 32
monet_loader = DataLoader(monet, batch_size=batch_size, shuffle=True)
cifar_loader = DataLoader(cifar, batch_size=batch_size, shuffle=True)
# Out:
# Image size: 32
# Saving resized images...
# 100%|██████████| 1193/1193 [00:00<00:00, 17073.29it/s]
# Files already downloaded and verified

# %% [markdown]
# Define models

# %%
from torch import nn
from torch.nn.utils.parametrizations import spectral_norm

class GeneratorResidualBlock(nn.Module):
    def __init__(self, n_channels):
        super().__init__()
        self.layers = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(n_channels, n_channels, kernel_size=3),
            nn.InstanceNorm2d(n_channels),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(n_channels, n_channels, kernel_size=3),
            nn.InstanceNorm2d(n_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return x + self.layers(x)


class Generator(nn.Module):
    def __init__(self):
        super().__init__()

        layers = []

        # initial convolution
        layers += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(3, 64, kernel_size=7),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
        ]
        # downsample
        layers += [
            nn.ReflectionPad2d(1),
            nn.Conv2d(64, 128, kernel_size=3, stride=2),
            nn.InstanceNorm2d(128),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(128, 256, kernel_size=3, stride=2),
            nn.InstanceNorm2d(256),
            nn.ReLU(),
        ]
        # residual blocks
        for _ in range(6):
            layers.append(GeneratorResidualBlock(256))
        # upsample
        layers += [
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
        ]
        # final convolution
        layers += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(64, 3, kernel_size=7),
            nn.Sigmoid()
        ]

        # put all the layers together
        self.layers = nn.Sequential(*layers)


    def forward(self, x):
        return self.layers(x)


class Discriminator(nn.Module):
    def __init__(self, input_channels=3):
        super().__init__()
        self.model = nn.Sequential(
            spectral_norm(nn.Conv2d(input_channels, 64, kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=True),

            spectral_norm(nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1)),
            # nn.InstanceNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            spectral_norm(nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1)),
            # nn.InstanceNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),

            spectral_norm(nn.Conv2d(256, 512, kernel_size=4, stride=1, padding=1)),
            # nn.InstanceNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),

            # Output Layer: Conv -> Sigmoid
            spectral_norm(nn.Conv2d(512, 1, kernel_size=3, stride=1)),
            nn.Flatten(1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# %%
g = Generator()
d = Discriminator()

# Test with CIFAR
imgs, _ = next(iter(cifar_loader))
fake_imgs = g(imgs)
print("Generated Images:")
show_images(fake_imgs[:8].detach().cpu())
# Out:
# Generated Images:

# %%
import torch
import torch.optim as optim
from torch.autograd import Variable

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
num_epochs = 10
lr = 0.0002
lambda_cycle = 10
lambda_identity = 5

# Initialize models
generator_g = Generator().to(device)  # original img -> monet
generator_f = Generator().to(device)  # monet -> cifar

discriminator_x = Discriminator().to(device)  # For CIFAR
discriminator_y = Discriminator().to(device)  # For Monet

# Loss functions
adversarial_loss = nn.MSELoss()
cycle_loss = nn.L1Loss()
identity_loss = nn.L1Loss()

# Optimizers
optimizer_g = optim.Adam(list(generator_g.parameters()) + list(generator_f.parameters()), lr=lr, betas=(0.5, 0.999))
optimizer_dx = optim.Adam(discriminator_x.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_dy = optim.Adam(discriminator_y.parameters(), lr=lr, betas=(0.5, 0.999))

# Labels
real_label = 1.0
fake_label = 0.0

# %%
# Training loop
for epoch in range(num_epochs):
    for b, (real_x, real_y) in enumerate(zip(cifar_loader, monet_loader)):
        # Prepare data
        real_x = real_x[0].to(device)  # CIFAR images
        real_y = real_y.to(device)  # Monet images

        # -------------------------------------------
        #  Train Generators (G and F)
        # -------------------------------------------
        optimizer_g.zero_grad()

        # Adversarial loss
        fake_y = generator_g(real_x)  # X -> Y
        pred_fake_y = discriminator_y(fake_y)
        loss_g_adv = adversarial_loss(pred_fake_y, torch.ones_like(pred_fake_y).to(device))

        fake_x = generator_f(real_y)  # Y -> X
        pred_fake_x = discriminator_x(fake_x)
        loss_f_adv = adversarial_loss(pred_fake_x, torch.ones_like(pred_fake_x).to(device))

        # Cycle consistency loss
        cycle_x = generator_f(fake_y)  # X -> Y -> X
        loss_cycle_x = cycle_loss(cycle_x, real_x)

        cycle_y = generator_g(fake_x)  # Y -> X -> Y
        loss_cycle_y = cycle_loss(cycle_y, real_y)

        # Identity loss
        identity_x = generator_f(real_x)  # X -> X
        loss_id_x = identity_loss(identity_x, real_x)

        identity_y = generator_g(real_y)  # Y -> Y
        loss_id_y = identity_loss(identity_y, real_y)

        # Total generator loss
        loss_g = loss_g_adv + loss_f_adv + lambda_cycle * (loss_cycle_x + loss_cycle_y) + lambda_identity * (loss_id_x + loss_id_y)
        loss_g.backward()
        optimizer_g.step()

        # -------------------------------------------
        #  Train Discriminators (X and Y)
        # -------------------------------------------
        # Discriminator X
        optimizer_dx.zero_grad()

        pred_real_x = discriminator_x(real_x)
        loss_dx_real = adversarial_loss(pred_real_x, torch.ones_like(pred_real_x).to(device))

        pred_fake_x = discriminator_x(fake_x.detach())
        loss_dx_fake = adversarial_loss(pred_fake_x, torch.zeros_like(pred_fake_x).to(device))

        loss_dx = (loss_dx_real + loss_dx_fake) * 0.5
        loss_dx.backward()
        optimizer_dx.step()

        # Discriminator Y
        optimizer_dy.zero_grad()

        pred_real_y = discriminator_y(real_y)
        loss_dy_real = adversarial_loss(pred_real_y, torch.ones_like(pred_real_y).to(device))

        pred_fake_y = discriminator_y(fake_y.detach())
        loss_dy_fake = adversarial_loss(pred_fake_y, torch.zeros_like(pred_fake_y).to(device))

        loss_dy = (loss_dy_real + loss_dy_fake) * 0.5
        loss_dy.backward()
        optimizer_dy.step()

        print(f"Epoch [{epoch + 1}/{num_epochs}] Batch [{b + 1}/{len(monet_loader)}] | Loss G: {loss_g.item():.4f} | Loss DX: {loss_dx.item():.4f} | Loss DY: {loss_dy.item():.4f}")
# Out:
# Epoch [1/10] Batch [1/38] | Loss G: 2.7331 | Loss DX: 0.2054 | Loss DY: 0.2360
# Epoch [1/10] Batch [2/38] | Loss G: 3.4360 | Loss DX: 0.2444 | Loss DY: 0.2074
# Epoch [1/10] Batch [3/38] | Loss G: 2.9837 | Loss DX: 0.2006 | Loss DY: 0.2204
# Epoch [1/10] Batch [4/38] | Loss G: 2.6525 | Loss DX: 0.2336 | Loss DY: 0.2209
# Epoch [1/10] Batch [5/38] | Loss G: 2.7888 | Loss DX: 0.2074 | Loss DY: 0.2038
# Epoch [1/10] Batch [6/38] | Loss G: 2.7048 | Loss DX: 0.2004 | Loss DY: 0.1986
# Epoch [1/10] Batch [7/38] | Loss G: 2.9539 | Loss DX: 0.1998 | Loss DY: 0.1898
# Epoch [1/10] Batch [8/38] | Loss G: 2.6676 | Loss DX: 0.2196 | Loss DY: 0.2152
# Epoch [1/10] Batch [9/38] | Loss G: 3.1124 | Loss DX: 0.2177 | Loss DY: 0.2385
# Epoch [1/10] Batch [10/38] | Loss G: 2.8143 | Loss DX: 0.1949 | Loss DY: 0.2037
# Epoch [1/10] Batch [11/38] | Loss G: 2.7582 | Loss DX: 0.1992 | Loss DY: 0.1994
# Epoch [1/10] Batch [12/38] | Loss G: 2.7206 | Loss DX: 0.1874 | Loss DY: 0.2000
# Epoch [1/10] Batch [13/38] | Loss G: 2.7340 | Loss DX: 0.2045 | Loss DY: 0.1882
# Epoch [1/10] Batch [14/38] | Loss G: 2.7711 | Loss DX: 0.2138 | Loss DY: 0.2059
# Epoch [1/10] Batch [15/38] | Loss G: 3.0355 | Loss DX: 0.2466 | Loss DY: 0.2091
# Epoch [1/10] Batch [16/38] | Loss G: 3.0456 | Loss DX: 0.2464 | Loss DY: 0.2088
# Epoch [1/10] Batch [17/38] | Loss G: 2.9516 | Loss DX: 0.2231 | Loss DY: 0.2026
# Epoch [1/10] Batch [18/38] | Loss G: 2.6866 | Loss DX: 0.2384 | Loss DY: 0.2293
# Epoch [1/10] Batch [19/38] | Loss G: 2.8339 | Loss DX: 0.2158 | Loss DY: 0.2005
# Epoch [1/10] Batch [20/38] | Loss G: 2.6953 | Loss DX: 0.2234 | Loss DY: 0.2046
# Epoch [1/10] Batch [21/38] | Loss G: 3.1578 | Loss DX: 0.2166 | Loss DY: 0.1933
# Epoch [1/10] Batch [22/38] | Loss G: 2.8762 | Loss DX: 0.2104 | Loss DY: 0.2013
# Epoch [1/10] Batch [23/38] | Loss G: 2.8901 | Loss DX: 0.1858 | Loss DY: 0.2206
# Epoch [1/10] Batch [24/38] | Loss G: 2.8599 | Loss DX: 0.2122 | Loss DY: 0.2024
# Epoch [1/10] Batch [25/38] | Loss G: 3.0846 | Loss DX: 0.2294 | Loss DY: 0.2060
# Epoch [1/10] Batch [26/38] | Loss G: 3.1136 | Loss DX: 0.2311 | Loss DY: 0.2077
# Epoch [1/10] Batch [27/38] | Loss G: 2.7303 | Loss DX: 0.2264 | Loss DY: 0.2210
# Epoch [1/10] Batch [28/38] | Loss G: 2.7590 | Loss DX: 0.2137 | Loss DY: 0.2076
# Epoch [1/10] Batch [29/38] | Loss G: 2.8667 | Loss DX: 0.2117 | Loss DY: 0.2290
# Epoch [1/10] Batch [30/38] | Loss G: 2.8067 | Loss DX: 0.2237 | Loss DY: 0.2261
# Epoch [1/10] Batch [31/38] | Loss G: 2.7230 | Loss DX: 0.2252 | Loss DY: 0.2102
# Epoch [1/10] Batch [32/38] | Loss G: 2.7700 | Loss DX: 0.2416 | Loss DY: 0.2351
# Epoch [1/10] Batch [33/38] | Loss G: 2.7813 | Loss DX: 0.2247 | Loss DY: 0.2108
# Epoch [1/10] Batch [34/38] | Loss G: 2.8593 | Loss DX: 0.2067 | Loss DY: 0.2015
# Epoch [1/10] Batch [35/38] | Loss G: 3.0121 | Loss DX: 0.2014 | Loss DY: 0.2011
# Epoch [1/10] Batch [36/38] | Loss G: 2.8400 | Loss DX: 0.2045 | Loss DY: 0.2285
# Epoch [1/10] Batch [37/38] | Loss G: 2.6344 | Loss DX: 0.2170 | Loss DY: 0.2154
# Epoch [1/10] Batch [38/38] | Loss G: 2.6788 | Loss DX: 0.2098 | Loss DY: 0.1944
# Epoch [2/10] Batch [1/38] | Loss G: 2.7832 | Loss DX: 0.2370 | Loss DY: 0.2150
# Epoch [2/10] Batch [2/38] | Loss G: 2.7747 | Loss DX: 0.2074 | Loss DY: 0.2237
# Epoch [2/10] Batch [3/38] | Loss G: 2.7858 | Loss DX: 0.1909 | Loss DY: 0.2001
# Epoch [2/10] Batch [4/38] | Loss G: 3.1724 | Loss DX: 0.2158 | Loss DY: 0.2076
# Epoch [2/10] Batch [5/38] | Loss G: 3.1479 | Loss DX: 0.2126 | Loss DY: 0.2100
# Epoch [2/10] Batch [6/38] | Loss G: 2.9073 | Loss DX: 0.2174 | Loss DY: 0.1848
# Epoch [2/10] Batch [7/38] | Loss G: 2.9076 | Loss DX: 0.2039 | Loss DY: 0.1938
# Epoch [2/10] Batch [8/38] | Loss G: 2.7759 | Loss DX: 0.2049 | Loss DY: 0.1802
# Epoch [2/10] Batch [9/38] | Loss G: 2.7867 | Loss DX: 0.2379 | Loss DY: 0.2041
# Epoch [2/10] Batch [10/38] | Loss G: 3.0070 | Loss DX: 0.1981 | Loss DY: 0.1778
# Epoch [2/10] Batch [11/38] | Loss G: 2.8874 | Loss DX: 0.2115 | Loss DY: 0.2081
# Epoch [2/10] Batch [12/38] | Loss G: 2.8052 | Loss DX: 0.1984 | Loss DY: 0.1939
# Epoch [2/10] Batch [13/38] | Loss G: 2.8807 | Loss DX: 0.2095 | Loss DY: 0.2089
# Epoch [2/10] Batch [14/38] | Loss G: 2.7422 | Loss DX: 0.2275 | Loss DY: 0.2103
# Epoch [2/10] Batch [15/38] | Loss G: 2.6349 | Loss DX: 0.2054 | Loss DY: 0.2067
# Epoch [2/10] Batch [16/38] | Loss G: 2.5698 | Loss DX: 0.2129 | Loss DY: 0.2320
# Epoch [2/10] Batch [17/38] | Loss G: 2.7022 | Loss DX: 0.2156 | Loss DY: 0.2052
# Epoch [2/10] Batch [18/38] | Loss G: 2.8825 | Loss DX: 0.2206 | Loss DY: 0.2108
# Epoch [2/10] Batch [19/38] | Loss G: 2.8035 | Loss DX: 0.2270 | Loss DY: 0.2013
# Epoch [2/10] Batch [20/38] | Loss G: 2.6745 | Loss DX: 0.2033 | Loss DY: 0.2129
# Epoch [2/10] Batch [21/38] | Loss G: 2.7407 | Loss DX: 0.2144 | Loss DY: 0.2143
# Epoch [2/10] Batch [22/38] | Loss G: 2.9302 | Loss DX: 0.2117 | Loss DY: 0.2348
# Epoch [2/10] Batch [23/38] | Loss G: 2.9323 | Loss DX: 0.2115 | Loss DY: 0.2169
# Epoch [2/10] Batch [24/38] | Loss G: 2.8605 | Loss DX: 0.2090 | Loss DY: 0.1997
# Epoch [2/10] Batch [25/38] | Loss G: 2.9121 | Loss DX: 0.2090 | Loss DY: 0.2146
# Epoch [2/10] Batch [26/38] | Loss G: 2.9764 | Loss DX: 0.2110 | Loss DY: 0.2123
# Epoch [2/10] Batch [27/38] | Loss G: 2.8075 | Loss DX: 0.2024 | Loss DY: 0.2072
# Epoch [2/10] Batch [28/38] | Loss G: 2.7197 | Loss DX: 0.2060 | Loss DY: 0.1885
# Epoch [2/10] Batch [29/38] | Loss G: 2.6673 | Loss DX: 0.2252 | Loss DY: 0.1946
# Epoch [2/10] Batch [30/38] | Loss G: 2.8771 | Loss DX: 0.2247 | Loss DY: 0.1903
# Epoch [2/10] Batch [31/38] | Loss G: 2.7822 | Loss DX: 0.2389 | Loss DY: 0.2235
# Epoch [2/10] Batch [32/38] | Loss G: 2.9440 | Loss DX: 0.2036 | Loss DY: 0.2413
# Epoch [2/10] Batch [33/38] | Loss G: 2.8195 | Loss DX: 0.2239 | Loss DY: 0.2056
# Epoch [2/10] Batch [34/38] | Loss G: 2.6702 | Loss DX: 0.2186 | Loss DY: 0.2152
# Epoch [2/10] Batch [35/38] | Loss G: 2.7306 | Loss DX: 0.2277 | Loss DY: 0.2217
# Epoch [2/10] Batch [36/38] | Loss G: 2.9024 | Loss DX: 0.2233 | Loss DY: 0.2022
# Epoch [2/10] Batch [37/38] | Loss G: 2.7027 | Loss DX: 0.2269 | Loss DY: 0.2335
# Epoch [2/10] Batch [38/38] | Loss G: 2.7851 | Loss DX: 0.2228 | Loss DY: 0.2013
# Epoch [3/10] Batch [1/38] | Loss G: 2.7844 | Loss DX: 0.2107 | Loss DY: 0.1795
# Epoch [3/10] Batch [2/38] | Loss G: 2.7881 | Loss DX: 0.2048 | Loss DY: 0.2104
# Epoch [3/10] Batch [3/38] | Loss G: 2.8311 | Loss DX: 0.2302 | Loss DY: 0.2142
# Epoch [3/10] Batch [4/38] | Loss G: 2.8730 | Loss DX: 0.2214 | Loss DY: 0.2166
# Epoch [3/10] Batch [5/38] | Loss G: 3.0825 | Loss DX: 0.2215 | Loss DY: 0.1900
# Epoch [3/10] Batch [6/38] | Loss G: 3.0217 | Loss DX: 0.1808 | Loss DY: 0.2050
# Epoch [3/10] Batch [7/38] | Loss G: 2.7122 | Loss DX: 0.2050 | Loss DY: 0.2076
# Epoch [3/10] Batch [8/38] | Loss G: 3.1105 | Loss DX: 0.2129 | Loss DY: 0.2109
# Epoch [3/10] Batch [9/38] | Loss G: 2.9143 | Loss DX: 0.2307 | Loss DY: 0.2087
# Epoch [3/10] Batch [10/38] | Loss G: 2.7349 | Loss DX: 0.2283 | Loss DY: 0.2003
# Epoch [3/10] Batch [11/38] | Loss G: 2.7614 | Loss DX: 0.2226 | Loss DY: 0.1994
# Epoch [3/10] Batch [12/38] | Loss G: 2.8764 | Loss DX: 0.1953 | Loss DY: 0.1883
# Epoch [3/10] Batch [13/38] | Loss G: 2.8882 | Loss DX: 0.2182 | Loss DY: 0.2221
# Epoch [3/10] Batch [14/38] | Loss G: 2.7023 | Loss DX: 0.2130 | Loss DY: 0.2026
# Epoch [3/10] Batch [15/38] | Loss G: 2.6620 | Loss DX: 0.2102 | Loss DY: 0.2360
# Epoch [3/10] Batch [16/38] | Loss G: 2.7440 | Loss DX: 0.2209 | Loss DY: 0.2101
# Epoch [3/10] Batch [17/38] | Loss G: 2.7663 | Loss DX: 0.2136 | Loss DY: 0.2063
# Epoch [3/10] Batch [18/38] | Loss G: 2.8114 | Loss DX: 0.1942 | Loss DY: 0.2173
# Epoch [3/10] Batch [19/38] | Loss G: 2.9134 | Loss DX: 0.2177 | Loss DY: 0.2299
# Epoch [3/10] Batch [20/38] | Loss G: 2.7528 | Loss DX: 0.2147 | Loss DY: 0.2092
# Epoch [3/10] Batch [21/38] | Loss G: 2.6953 | Loss DX: 0.2211 | Loss DY: 0.2065
# Epoch [3/10] Batch [22/38] | Loss G: 2.8606 | Loss DX: 0.2204 | Loss DY: 0.1953
# Epoch [3/10] Batch [23/38] | Loss G: 2.8568 | Loss DX: 0.2065 | Loss DY: 0.2027
# Epoch [3/10] Batch [24/38] | Loss G: 2.8167 | Loss DX: 0.2079 | Loss DY: 0.2094
# Epoch [3/10] Batch [25/38] | Loss G: 2.5614 | Loss DX: 0.1979 | Loss DY: 0.2212
# Epoch [3/10] Batch [26/38] | Loss G: 2.7665 | Loss DX: 0.2054 | Loss DY: 0.2305
# Epoch [3/10] Batch [27/38] | Loss G: 2.8536 | Loss DX: 0.2266 | Loss DY: 0.2082
# Epoch [3/10] Batch [28/38] | Loss G: 2.8188 | Loss DX: 0.2132 | Loss DY: 0.1901
# Epoch [3/10] Batch [29/38] | Loss G: 2.9211 | Loss DX: 0.1947 | Loss DY: 0.2046
# Epoch [3/10] Batch [30/38] | Loss G: 2.8326 | Loss DX: 0.1945 | Loss DY: 0.2275
# Epoch [3/10] Batch [31/38] | Loss G: 2.8939 | Loss DX: 0.2251 | Loss DY: 0.2292
# Epoch [3/10] Batch [32/38] | Loss G: 2.6079 | Loss DX: 0.2264 | Loss DY: 0.2085
# Epoch [3/10] Batch [33/38] | Loss G: 2.6909 | Loss DX: 0.2026 | Loss DY: 0.2062
# Epoch [3/10] Batch [34/38] | Loss G: 2.6881 | Loss DX: 0.2144 | Loss DY: 0.1967
# Epoch [3/10] Batch [35/38] | Loss G: 2.6295 | Loss DX: 0.2123 | Loss DY: 0.1944
# Epoch [3/10] Batch [36/38] | Loss G: 2.6663 | Loss DX: 0.2244 | Loss DY: 0.2144
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 70
#      67 loss_dy.backward()
#      68 optimizer_dy.step()
# ---> 70 print(f"Epoch [{epoch + 1}/{num_epochs}] Batch [{b + 1}/{len(monet_loader)}] | Loss G: {loss_g.item():.4f} | Loss DX: {loss_dx.item():.4f} | Loss DY: {loss_dy.item():.4f}")
#
# KeyboardInterrupt:

# %%
torch.save(generator_g.state_dict(), "generator_g.pth")
torch.save(generator_f.state_dict(), "generator_f.pth")
torch.save(discriminator_x.state_dict(), "discriminator_x.pth")
torch.save(discriminator_y.state_dict(), "discriminator_y.pth")

# %%
generator_g.load_state_dict(torch.load("generator_g.pth", weights_only=True))
generator_f.load_state_dict(torch.load("generator_f.pth", weights_only=True))
discriminator_x.load_state_dict(torch.load("discriminator_x.pth", weights_only=True))
discriminator_y.load_state_dict(torch.load("discriminator_y.pth", weights_only=True))
# Out:
# <All keys matched successfully>

# %%
# now let's test our cyclegan after training to see if it actually works:

real_x, _ = next(iter(cifar_loader))
real_x = real_x.cuda()

fake_y = generator_g(real_x).detach()
reconstructed_x = generator_f(fake_y).detach()

fake_y = fake_y.cpu()
reconstructed_x = reconstructed_x.cpu()

print("CIFAR Images")
show_images(real_x[:8].cpu())
print("Generated Monet-style Images")
show_images(fake_y[:8])
print("Reconstructed CIFAR Images")
show_images(reconstructed_x[:8])
# Out:
# CIFAR Images
# Generated Monet-style Images
# Reconstructed CIFAR Images
