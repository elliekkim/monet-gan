# %% [markdown]
# Goals:
# - Train GAN to more epochs and resize Monet images to get reasonable output of CycleGAN <--
# - ProgressiveGAN: only upsampling + downsampling <--
#   - ask if problems?

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import kagglehub
import torchvision.transforms as T
from torchvision.utils import make_grid
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
from tqdm import tqdm

# %%
to_tensor = T.ToTensor()

def load_image(path):
    return to_tensor(Image.open(path))


def show_images(imgs):
    # imgs is a tensor of shape: B x C x H x W
    grid = make_grid(imgs, nrow=4, padding=10, pad_value=1)
    plt.imshow(grid.permute(1, 2, 0))
    plt.axis("off")
    plt.gcf().set_figwidth(8)
    plt.show()

# %%
class Monet(Dataset):
    def __init__(self, img_size=256):
        self.data_path = kagglehub.dataset_download(
            "dimitreoliveira/monet-paintings-jpg-berkeley")
        self.img_names = os.listdir(self.data_path)
        self.img_names = list(filter(lambda s: os.path.isfile(os.path.join(self.data_path, s)), self.img_names))

        # resize images to lower resolution
        print("Image size:", img_size)
        if img_size == 256:
            self.resized_data_path = self.data_path
        else:
            self.resized_data_path = os.path.join(self.data_path, f"resized_{img_size}")
        
        print("Saving resized images...")
        for img_name in tqdm(self.img_names):
            resized_path = os.path.join(self.resized_data_path, img_name)
            if os.path.exists(resized_path):
                continue

            # resize to specified img size
            orig_img_path = os.path.join(self.data_path, img_name)
            with Image.open(orig_img_path) as img:
                resized_img = img.resize((img_size, img_size))
                # save
                os.makedirs(os.path.dirname(resized_path), exist_ok=True)
                resized_img.save(resized_path)

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, index):
        return load_image(os.path.join(self.resized_data_path, self.img_names[index]))

# %%
from torchvision.datasets import CIFAR10
from torchvision import transforms

monet = Monet(img_size=32)
cifar = CIFAR10(root="./cifar10", train=True,
                download=True, transform=to_tensor)

batch_size = 32
monet_loader = DataLoader(monet, batch_size=batch_size, shuffle=True)
cifar_loader = DataLoader(cifar, batch_size=batch_size, shuffle=True)
# Out:
# Image size: 32
# Saving resized images...
# 100%|██████████| 1193/1193 [00:00<00:00, 17535.31it/s]
# Files already downloaded and verified

# %% [markdown]
# Define models

# %%
from torch import nn
from torch.nn.utils.parametrizations import spectral_norm

class GeneratorResidualBlock(nn.Module):
    def __init__(self, n_channels):
        super().__init__()
        self.layers = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(n_channels, n_channels, kernel_size=3),
            nn.InstanceNorm2d(n_channels),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(n_channels, n_channels, kernel_size=3),
            nn.InstanceNorm2d(n_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return x + self.layers(x)


class Generator(nn.Module):
    def __init__(self):
        super().__init__()

        layers = []

        # initial convolution
        layers += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(3, 64, kernel_size=7),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
        ]
        # downsample
        layers += [
            nn.ReflectionPad2d(1),
            nn.Conv2d(64, 128, kernel_size=3, stride=2),
            nn.InstanceNorm2d(128),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(128, 256, kernel_size=3, stride=2),
            nn.InstanceNorm2d(256),
            nn.ReLU(),
        ]
        # residual blocks
        for _ in range(6):
            layers.append(GeneratorResidualBlock(256))
        # upsample
        layers += [
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
        ]
        # final convolution
        layers += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(64, 3, kernel_size=7),
            nn.Sigmoid()
        ]

        # put all the layers together
        self.layers = nn.Sequential(*layers)


    def forward(self, x):
        return self.layers(x)


class Discriminator(nn.Module):
    def __init__(self, input_channels=3):
        super().__init__()
        self.model = nn.Sequential(
            spectral_norm(nn.Conv2d(input_channels, 64, kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=True),

            spectral_norm(nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1)),
            # nn.InstanceNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            spectral_norm(nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1)),
            # nn.InstanceNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),

            spectral_norm(nn.Conv2d(256, 512, kernel_size=4, stride=1, padding=1)),
            # nn.InstanceNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),

            # Output Layer: Conv -> Sigmoid
            spectral_norm(nn.Conv2d(512, 1, kernel_size=3, stride=1)),
            nn.Flatten(1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# %%
g = Generator()
d = Discriminator()

# Test with CIFAR
imgs, _ = next(iter(cifar_loader))
fake_imgs = g(imgs)
print("Generated Images:")
show_images(fake_imgs[:8].detach().cpu())
# Out:
# Generated Images:

# %%
import torch
import torch.optim as optim
from torch.autograd import Variable

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
num_epochs = 10
lr = 0.0002
lambda_cycle = 10
lambda_identity = 5

# Initialize models
generator_g = Generator().to(device)  # original img -> monet
generator_f = Generator().to(device)  # monet -> cifar

discriminator_x = Discriminator().to(device)  # For CIFAR
discriminator_y = Discriminator().to(device)  # For Monet

# Loss functions
adversarial_loss = nn.MSELoss()
cycle_loss = nn.L1Loss()
identity_loss = nn.L1Loss()

# Optimizers
optimizer_g = optim.Adam(list(generator_g.parameters()) + list(generator_f.parameters()), lr=lr, betas=(0.5, 0.999))
optimizer_dx = optim.Adam(discriminator_x.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_dy = optim.Adam(discriminator_y.parameters(), lr=lr, betas=(0.5, 0.999))

# Labels
real_label = 1.0
fake_label = 0.0

# %%
# Training loop
for epoch in range(num_epochs):
    for b, (real_x, real_y) in enumerate(zip(cifar_loader, monet_loader)):
        # Prepare data
        real_x = real_x[0].to(device)  # CIFAR images
        real_y = real_y.to(device)  # Monet images

        # -------------------------------------------
        #  Train Generators (G and F)
        # -------------------------------------------
        optimizer_g.zero_grad()

        # Adversarial loss
        fake_y = generator_g(real_x)  # X -> Y
        pred_fake_y = discriminator_y(fake_y)
        loss_g_adv = adversarial_loss(pred_fake_y, torch.ones_like(pred_fake_y).to(device))

        fake_x = generator_f(real_y)  # Y -> X
        pred_fake_x = discriminator_x(fake_x)
        loss_f_adv = adversarial_loss(pred_fake_x, torch.ones_like(pred_fake_x).to(device))

        # Cycle consistency loss
        cycle_x = generator_f(fake_y)  # X -> Y -> X
        loss_cycle_x = cycle_loss(cycle_x, real_x)

        cycle_y = generator_g(fake_x)  # Y -> X -> Y
        loss_cycle_y = cycle_loss(cycle_y, real_y)

        # Identity loss
        identity_x = generator_f(real_x)  # X -> X
        loss_id_x = identity_loss(identity_x, real_x)

        identity_y = generator_g(real_y)  # Y -> Y
        loss_id_y = identity_loss(identity_y, real_y)

        # Total generator loss
        loss_g = loss_g_adv + loss_f_adv + lambda_cycle * (loss_cycle_x + loss_cycle_y) + lambda_identity * (loss_id_x + loss_id_y)
        loss_g.backward()
        optimizer_g.step()

        # -------------------------------------------
        #  Train Discriminators (X and Y)
        # -------------------------------------------
        # Discriminator X
        optimizer_dx.zero_grad()

        pred_real_x = discriminator_x(real_x)
        loss_dx_real = adversarial_loss(pred_real_x, torch.ones_like(pred_real_x).to(device))

        pred_fake_x = discriminator_x(fake_x.detach())
        loss_dx_fake = adversarial_loss(pred_fake_x, torch.zeros_like(pred_fake_x).to(device))

        loss_dx = (loss_dx_real + loss_dx_fake) * 0.5
        loss_dx.backward()
        optimizer_dx.step()

        # Discriminator Y
        optimizer_dy.zero_grad()

        pred_real_y = discriminator_y(real_y)
        loss_dy_real = adversarial_loss(pred_real_y, torch.ones_like(pred_real_y).to(device))

        pred_fake_y = discriminator_y(fake_y.detach())
        loss_dy_fake = adversarial_loss(pred_fake_y, torch.zeros_like(pred_fake_y).to(device))

        loss_dy = (loss_dy_real + loss_dy_fake) * 0.5
        loss_dy.backward()
        optimizer_dy.step()

        print(f"Epoch [{epoch + 1}/{num_epochs}] Batch [{b + 1}/{len(monet_loader)}] | Loss G: {loss_g.item():.4f} | Loss DX: {loss_dx.item():.4f} | Loss DY: {loss_dy.item():.4f}")
# Out:
# Epoch [1/10] Batch [1/38] | Loss G: 2.9604 | Loss DX: 0.2252 | Loss DY: 0.1923
# Epoch [1/10] Batch [2/38] | Loss G: 3.0587 | Loss DX: 0.1975 | Loss DY: 0.1775
# Epoch [1/10] Batch [3/38] | Loss G: 2.9434 | Loss DX: 0.1825 | Loss DY: 0.1926
# Epoch [1/10] Batch [4/38] | Loss G: 2.7805 | Loss DX: 0.2022 | Loss DY: 0.2845
# Epoch [1/10] Batch [5/38] | Loss G: 2.8153 | Loss DX: 0.1943 | Loss DY: 0.2641
# Epoch [1/10] Batch [6/38] | Loss G: 3.2567 | Loss DX: 0.2175 | Loss DY: 0.2825
# Epoch [1/10] Batch [7/38] | Loss G: 3.4607 | Loss DX: 0.2177 | Loss DY: 0.2485
# Epoch [1/10] Batch [8/38] | Loss G: 3.5945 | Loss DX: 0.2106 | Loss DY: 0.2112
# Epoch [1/10] Batch [9/38] | Loss G: 3.3076 | Loss DX: 0.2001 | Loss DY: 0.1757
# Epoch [1/10] Batch [10/38] | Loss G: 2.9886 | Loss DX: 0.2017 | Loss DY: 0.1985
# Epoch [1/10] Batch [11/38] | Loss G: 2.8467 | Loss DX: 0.2214 | Loss DY: 0.2521
# Epoch [1/10] Batch [12/38] | Loss G: 3.0461 | Loss DX: 0.2109 | Loss DY: 0.2572
# Epoch [1/10] Batch [13/38] | Loss G: 3.2652 | Loss DX: 0.2204 | Loss DY: 0.2297
# Epoch [1/10] Batch [14/38] | Loss G: 3.2517 | Loss DX: 0.2184 | Loss DY: 0.2300
# Epoch [1/10] Batch [15/38] | Loss G: 3.1458 | Loss DX: 0.2583 | Loss DY: 0.2390
# Epoch [1/10] Batch [16/38] | Loss G: 3.0548 | Loss DX: 0.2512 | Loss DY: 0.2359
# Epoch [1/10] Batch [17/38] | Loss G: 2.9611 | Loss DX: 0.2190 | Loss DY: 0.2279
# Epoch [1/10] Batch [18/38] | Loss G: 3.0942 | Loss DX: 0.2334 | Loss DY: 0.2161
# Epoch [1/10] Batch [19/38] | Loss G: 3.5159 | Loss DX: 0.1953 | Loss DY: 0.2091
# Epoch [1/10] Batch [20/38] | Loss G: 3.3837 | Loss DX: 0.1777 | Loss DY: 0.1948
# Epoch [1/10] Batch [21/38] | Loss G: 3.0704 | Loss DX: 0.1742 | Loss DY: 0.1908
# Epoch [1/10] Batch [22/38] | Loss G: 3.0246 | Loss DX: 0.2037 | Loss DY: 0.1794
# Epoch [1/10] Batch [23/38] | Loss G: 3.0578 | Loss DX: 0.2043 | Loss DY: 0.1883
# Epoch [1/10] Batch [24/38] | Loss G: 2.9809 | Loss DX: 0.2044 | Loss DY: 0.1780
# Epoch [1/10] Batch [25/38] | Loss G: 3.0466 | Loss DX: 0.1950 | Loss DY: 0.1840
# Epoch [1/10] Batch [26/38] | Loss G: 3.1351 | Loss DX: 0.2331 | Loss DY: 0.2004
# Epoch [1/10] Batch [27/38] | Loss G: 3.2700 | Loss DX: 0.1778 | Loss DY: 0.1780
# Epoch [1/10] Batch [28/38] | Loss G: 3.2377 | Loss DX: 0.2106 | Loss DY: 0.1842
# Epoch [1/10] Batch [29/38] | Loss G: 3.2124 | Loss DX: 0.1951 | Loss DY: 0.1715
# Epoch [1/10] Batch [30/38] | Loss G: 3.0689 | Loss DX: 0.1996 | Loss DY: 0.1658
# Epoch [1/10] Batch [31/38] | Loss G: 2.8837 | Loss DX: 0.2227 | Loss DY: 0.2132
# Epoch [1/10] Batch [32/38] | Loss G: 3.0400 | Loss DX: 0.2172 | Loss DY: 0.1994
# Epoch [1/10] Batch [33/38] | Loss G: 3.0953 | Loss DX: 0.2035 | Loss DY: 0.2188
# Epoch [1/10] Batch [34/38] | Loss G: 3.0591 | Loss DX: 0.2170 | Loss DY: 0.2550
# Epoch [1/10] Batch [35/38] | Loss G: 3.2888 | Loss DX: 0.1967 | Loss DY: 0.2481
# Epoch [1/10] Batch [36/38] | Loss G: 3.0174 | Loss DX: 0.2014 | Loss DY: 0.2486
# Epoch [1/10] Batch [37/38] | Loss G: 3.2222 | Loss DX: 0.2012 | Loss DY: 0.2390
# Epoch [1/10] Batch [38/38] | Loss G: 3.3302 | Loss DX: 0.1819 | Loss DY: 0.2482
# Epoch [2/10] Batch [1/38] | Loss G: 3.0482 | Loss DX: 0.1919 | Loss DY: 0.2024
# Epoch [2/10] Batch [2/38] | Loss G: 2.9864 | Loss DX: 0.2332 | Loss DY: 0.1976
# Epoch [2/10] Batch [3/38] | Loss G: 3.0446 | Loss DX: 0.2038 | Loss DY: 0.2183
# Epoch [2/10] Batch [4/38] | Loss G: 3.2184 | Loss DX: 0.2216 | Loss DY: 0.2181
# Epoch [2/10] Batch [5/38] | Loss G: 3.0737 | Loss DX: 0.2006 | Loss DY: 0.1989
# Epoch [2/10] Batch [6/38] | Loss G: 3.0399 | Loss DX: 0.2153 | Loss DY: 0.1960
# Epoch [2/10] Batch [7/38] | Loss G: 3.0708 | Loss DX: 0.2101 | Loss DY: 0.2276
# Epoch [2/10] Batch [8/38] | Loss G: 3.1559 | Loss DX: 0.2057 | Loss DY: 0.2010
# Epoch [2/10] Batch [9/38] | Loss G: 3.1782 | Loss DX: 0.2169 | Loss DY: 0.1980
# Epoch [2/10] Batch [10/38] | Loss G: 2.9848 | Loss DX: 0.2323 | Loss DY: 0.1960
# Epoch [2/10] Batch [11/38] | Loss G: 2.8570 | Loss DX: 0.2407 | Loss DY: 0.1837
# Epoch [2/10] Batch [12/38] | Loss G: 2.9835 | Loss DX: 0.2311 | Loss DY: 0.1997
# Epoch [2/10] Batch [13/38] | Loss G: 3.0682 | Loss DX: 0.2523 | Loss DY: 0.2130
# Epoch [2/10] Batch [14/38] | Loss G: 2.9018 | Loss DX: 0.2217 | Loss DY: 0.2255
# Epoch [2/10] Batch [15/38] | Loss G: 2.9831 | Loss DX: 0.1928 | Loss DY: 0.2260
# Epoch [2/10] Batch [16/38] | Loss G: 3.1058 | Loss DX: 0.2170 | Loss DY: 0.2188
# Epoch [2/10] Batch [17/38] | Loss G: 3.2758 | Loss DX: 0.1977 | Loss DY: 0.1963
# Epoch [2/10] Batch [18/38] | Loss G: 3.1245 | Loss DX: 0.2086 | Loss DY: 0.1805
# Epoch [2/10] Batch [19/38] | Loss G: 2.7150 | Loss DX: 0.2289 | Loss DY: 0.2047
# Epoch [2/10] Batch [20/38] | Loss G: 3.0622 | Loss DX: 0.2023 | Loss DY: 0.2341
# Epoch [2/10] Batch [21/38] | Loss G: 3.1497 | Loss DX: 0.2238 | Loss DY: 0.2547
# Epoch [2/10] Batch [22/38] | Loss G: 3.1165 | Loss DX: 0.2122 | Loss DY: 0.2600
# Epoch [2/10] Batch [23/38] | Loss G: 3.1328 | Loss DX: 0.2087 | Loss DY: 0.2576
# Epoch [2/10] Batch [24/38] | Loss G: 3.3438 | Loss DX: 0.2000 | Loss DY: 0.2074
# Epoch [2/10] Batch [25/38] | Loss G: 3.0749 | Loss DX: 0.2137 | Loss DY: 0.2202
# Epoch [2/10] Batch [26/38] | Loss G: 3.2627 | Loss DX: 0.2107 | Loss DY: 0.2194
# Epoch [2/10] Batch [27/38] | Loss G: 3.2003 | Loss DX: 0.2054 | Loss DY: 0.2051
# Epoch [2/10] Batch [28/38] | Loss G: 2.8479 | Loss DX: 0.2375 | Loss DY: 0.2128
# Epoch [2/10] Batch [29/38] | Loss G: 3.0168 | Loss DX: 0.1991 | Loss DY: 0.2241
# Epoch [2/10] Batch [30/38] | Loss G: 2.8579 | Loss DX: 0.2093 | Loss DY: 0.2092
# Epoch [2/10] Batch [31/38] | Loss G: 3.1596 | Loss DX: 0.1832 | Loss DY: 0.1921
# Epoch [2/10] Batch [32/38] | Loss G: 2.9122 | Loss DX: 0.1985 | Loss DY: 0.1816
# Epoch [2/10] Batch [33/38] | Loss G: 2.9672 | Loss DX: 0.1887 | Loss DY: 0.1736
# Epoch [2/10] Batch [34/38] | Loss G: 3.0349 | Loss DX: 0.2164 | Loss DY: 0.1754
# Epoch [2/10] Batch [35/38] | Loss G: 3.0318 | Loss DX: 0.2417 | Loss DY: 0.1873
# Epoch [2/10] Batch [36/38] | Loss G: 2.8438 | Loss DX: 0.2062 | Loss DY: 0.1771
# Epoch [2/10] Batch [37/38] | Loss G: 2.9675 | Loss DX: 0.1985 | Loss DY: 0.1652
# Epoch [2/10] Batch [38/38] | Loss G: 2.9984 | Loss DX: 0.2231 | Loss DY: 0.1998
# Epoch [3/10] Batch [1/38] | Loss G: 3.0081 | Loss DX: 0.2152 | Loss DY: 0.1971
# Epoch [3/10] Batch [2/38] | Loss G: 2.9647 | Loss DX: 0.2046 | Loss DY: 0.1921
# Epoch [3/10] Batch [3/38] | Loss G: 2.9534 | Loss DX: 0.2023 | Loss DY: 0.2070
# Epoch [3/10] Batch [4/38] | Loss G: 2.9695 | Loss DX: 0.1913 | Loss DY: 0.1861
# Epoch [3/10] Batch [5/38] | Loss G: 2.9075 | Loss DX: 0.2233 | Loss DY: 0.2771
# Epoch [3/10] Batch [6/38] | Loss G: 3.1441 | Loss DX: 0.2114 | Loss DY: 0.2718
# Epoch [3/10] Batch [7/38] | Loss G: 3.3469 | Loss DX: 0.2156 | Loss DY: 0.2161
# Epoch [3/10] Batch [8/38] | Loss G: 3.1405 | Loss DX: 0.1917 | Loss DY: 0.1738
# Epoch [3/10] Batch [9/38] | Loss G: 2.9234 | Loss DX: 0.2169 | Loss DY: 0.2158
# Epoch [3/10] Batch [10/38] | Loss G: 2.7224 | Loss DX: 0.2069 | Loss DY: 0.2412
# Epoch [3/10] Batch [11/38] | Loss G: 2.9959 | Loss DX: 0.1835 | Loss DY: 0.2789
# Epoch [3/10] Batch [12/38] | Loss G: 3.1331 | Loss DX: 0.1881 | Loss DY: 0.2633
# Epoch [3/10] Batch [13/38] | Loss G: 3.1984 | Loss DX: 0.2170 | Loss DY: 0.2746
# Epoch [3/10] Batch [14/38] | Loss G: 3.2473 | Loss DX: 0.2244 | Loss DY: 0.2505
# Epoch [3/10] Batch [15/38] | Loss G: 3.2836 | Loss DX: 0.2148 | Loss DY: 0.2288
# Epoch [3/10] Batch [16/38] | Loss G: 3.1249 | Loss DX: 0.2245 | Loss DY: 0.2381
# Epoch [3/10] Batch [17/38] | Loss G: 2.9850 | Loss DX: 0.2095 | Loss DY: 0.2377
# Epoch [3/10] Batch [18/38] | Loss G: 3.2191 | Loss DX: 0.2140 | Loss DY: 0.2186
# Epoch [3/10] Batch [19/38] | Loss G: 2.8156 | Loss DX: 0.1961 | Loss DY: 0.2162
# Epoch [3/10] Batch [20/38] | Loss G: 2.7863 | Loss DX: 0.1796 | Loss DY: 0.2049
# Epoch [3/10] Batch [21/38] | Loss G: 3.0214 | Loss DX: 0.1990 | Loss DY: 0.2233
# Epoch [3/10] Batch [22/38] | Loss G: 3.0671 | Loss DX: 0.1960 | Loss DY: 0.2108
# Epoch [3/10] Batch [23/38] | Loss G: 3.0552 | Loss DX: 0.2199 | Loss DY: 0.2113
# Epoch [3/10] Batch [24/38] | Loss G: 2.9895 | Loss DX: 0.1864 | Loss DY: 0.2139
# Epoch [3/10] Batch [25/38] | Loss G: 2.8964 | Loss DX: 0.2232 | Loss DY: 0.2133
# Epoch [3/10] Batch [26/38] | Loss G: 2.9497 | Loss DX: 0.2015 | Loss DY: 0.2003
# Epoch [3/10] Batch [27/38] | Loss G: 3.0732 | Loss DX: 0.2301 | Loss DY: 0.1972
# Epoch [3/10] Batch [28/38] | Loss G: 3.1259 | Loss DX: 0.2208 | Loss DY: 0.1965
# Epoch [3/10] Batch [29/38] | Loss G: 3.0827 | Loss DX: 0.2331 | Loss DY: 0.1811
# Epoch [3/10] Batch [30/38] | Loss G: 2.9773 | Loss DX: 0.2167 | Loss DY: 0.1926
# Epoch [3/10] Batch [31/38] | Loss G: 3.0220 | Loss DX: 0.1953 | Loss DY: 0.1952
# Epoch [3/10] Batch [32/38] | Loss G: 3.0557 | Loss DX: 0.1959 | Loss DY: 0.2052
# Epoch [3/10] Batch [33/38] | Loss G: 3.1263 | Loss DX: 0.1856 | Loss DY: 0.2060
# Epoch [3/10] Batch [34/38] | Loss G: 3.0761 | Loss DX: 0.2061 | Loss DY: 0.2207
# Epoch [3/10] Batch [35/38] | Loss G: 3.0936 | Loss DX: 0.1957 | Loss DY: 0.1934
# Epoch [3/10] Batch [36/38] | Loss G: 3.1004 | Loss DX: 0.1911 | Loss DY: 0.1808
# Epoch [3/10] Batch [37/38] | Loss G: 3.0518 | Loss DX: 0.2349 | Loss DY: 0.1836
# Epoch [3/10] Batch [38/38] | Loss G: 2.9601 | Loss DX: 0.2270 | Loss DY: 0.2126
# Epoch [4/10] Batch [1/38] | Loss G: 2.9950 | Loss DX: 0.1991 | Loss DY: 0.2270
# Epoch [4/10] Batch [2/38] | Loss G: 3.0211 | Loss DX: 0.2075 | Loss DY: 0.2155
# Epoch [4/10] Batch [3/38] | Loss G: 3.0212 | Loss DX: 0.2063 | Loss DY: 0.2084
# Epoch [4/10] Batch [4/38] | Loss G: 3.1180 | Loss DX: 0.2176 | Loss DY: 0.1956
# Epoch [4/10] Batch [5/38] | Loss G: 2.8647 | Loss DX: 0.2250 | Loss DY: 0.2021
# Epoch [4/10] Batch [6/38] | Loss G: 3.2275 | Loss DX: 0.2176 | Loss DY: 0.1849
# Epoch [4/10] Batch [7/38] | Loss G: 3.3384 | Loss DX: 0.1824 | Loss DY: 0.1949
# Epoch [4/10] Batch [8/38] | Loss G: 3.0528 | Loss DX: 0.2042 | Loss DY: 0.2608
# Epoch [4/10] Batch [9/38] | Loss G: 3.3673 | Loss DX: 0.1968 | Loss DY: 0.2200
# Epoch [4/10] Batch [10/38] | Loss G: 3.1706 | Loss DX: 0.2249 | Loss DY: 0.1945
# Epoch [4/10] Batch [11/38] | Loss G: 3.2379 | Loss DX: 0.1869 | Loss DY: 0.1846
# Epoch [4/10] Batch [12/38] | Loss G: 2.9539 | Loss DX: 0.2188 | Loss DY: 0.2116
# Epoch [4/10] Batch [13/38] | Loss G: 2.8306 | Loss DX: 0.1877 | Loss DY: 0.3276
# Epoch [4/10] Batch [14/38] | Loss G: 3.1545 | Loss DX: 0.1748 | Loss DY: 0.2497
# Epoch [4/10] Batch [15/38] | Loss G: 2.9502 | Loss DX: 0.1962 | Loss DY: 0.2507
# Epoch [4/10] Batch [16/38] | Loss G: 3.1786 | Loss DX: 0.1481 | Loss DY: 0.2351
# Epoch [4/10] Batch [17/38] | Loss G: 3.0179 | Loss DX: 0.1740 | Loss DY: 0.2149
# Epoch [4/10] Batch [18/38] | Loss G: 3.1517 | Loss DX: 0.2133 | Loss DY: 0.2353
# Epoch [4/10] Batch [19/38] | Loss G: 2.9555 | Loss DX: 0.2198 | Loss DY: 0.2295
# Epoch [4/10] Batch [20/38] | Loss G: 3.2204 | Loss DX: 0.2337 | Loss DY: 0.2250
# Epoch [4/10] Batch [21/38] | Loss G: 2.9882 | Loss DX: 0.2317 | Loss DY: 0.2156
# Epoch [4/10] Batch [22/38] | Loss G: 3.0530 | Loss DX: 0.2178 | Loss DY: 0.2191
# Epoch [4/10] Batch [23/38] | Loss G: 2.9240 | Loss DX: 0.2289 | Loss DY: 0.2089
# Epoch [4/10] Batch [24/38] | Loss G: 3.0703 | Loss DX: 0.2396 | Loss DY: 0.2165
# Epoch [4/10] Batch [25/38] | Loss G: 2.7787 | Loss DX: 0.2165 | Loss DY: 0.2097
# Epoch [4/10] Batch [26/38] | Loss G: 2.8396 | Loss DX: 0.2413 | Loss DY: 0.2073
# Epoch [4/10] Batch [27/38] | Loss G: 2.9393 | Loss DX: 0.2401 | Loss DY: 0.2114
# Epoch [4/10] Batch [28/38] | Loss G: 3.0453 | Loss DX: 0.1995 | Loss DY: 0.1870
# Epoch [4/10] Batch [29/38] | Loss G: 3.0375 | Loss DX: 0.2279 | Loss DY: 0.1991
# Epoch [4/10] Batch [30/38] | Loss G: 2.9617 | Loss DX: 0.2002 | Loss DY: 0.2030
# Epoch [4/10] Batch [31/38] | Loss G: 3.1242 | Loss DX: 0.2082 | Loss DY: 0.1975
# Epoch [4/10] Batch [32/38] | Loss G: 3.1279 | Loss DX: 0.2298 | Loss DY: 0.1972
# Epoch [4/10] Batch [33/38] | Loss G: 3.0860 | Loss DX: 0.2109 | Loss DY: 0.1679
# Epoch [4/10] Batch [34/38] | Loss G: 2.9121 | Loss DX: 0.2096 | Loss DY: 0.2100
# Epoch [4/10] Batch [35/38] | Loss G: 3.1948 | Loss DX: 0.2053 | Loss DY: 0.1820
# Epoch [4/10] Batch [36/38] | Loss G: 3.0033 | Loss DX: 0.2115 | Loss DY: 0.1951
# Epoch [4/10] Batch [37/38] | Loss G: 3.0587 | Loss DX: 0.2404 | Loss DY: 0.2081
# Epoch [4/10] Batch [38/38] | Loss G: 3.0683 | Loss DX: 0.2049 | Loss DY: 0.1913
# Epoch [5/10] Batch [1/38] | Loss G: 3.0477 | Loss DX: 0.2003 | Loss DY: 0.1998
# Epoch [5/10] Batch [2/38] | Loss G: 3.2102 | Loss DX: 0.2351 | Loss DY: 0.1842
# Epoch [5/10] Batch [3/38] | Loss G: 3.1796 | Loss DX: 0.1997 | Loss DY: 0.1935
# Epoch [5/10] Batch [4/38] | Loss G: 2.9351 | Loss DX: 0.2144 | Loss DY: 0.1817
# Epoch [5/10] Batch [5/38] | Loss G: 3.0301 | Loss DX: 0.2219 | Loss DY: 0.1989
# Epoch [5/10] Batch [6/38] | Loss G: 2.8742 | Loss DX: 0.2172 | Loss DY: 0.2179
# Epoch [5/10] Batch [7/38] | Loss G: 2.9670 | Loss DX: 0.2024 | Loss DY: 0.2290
# Epoch [5/10] Batch [8/38] | Loss G: 3.0794 | Loss DX: 0.2058 | Loss DY: 0.2392
# Epoch [5/10] Batch [9/38] | Loss G: 3.2234 | Loss DX: 0.1906 | Loss DY: 0.1540
# Epoch [5/10] Batch [10/38] | Loss G: 3.0420 | Loss DX: 0.2076 | Loss DY: 0.1620
# Epoch [5/10] Batch [11/38] | Loss G: 2.6405 | Loss DX: 0.2255 | Loss DY: 0.2824
# Epoch [5/10] Batch [12/38] | Loss G: 2.9383 | Loss DX: 0.2097 | Loss DY: 0.2796
# Epoch [5/10] Batch [13/38] | Loss G: 3.3552 | Loss DX: 0.2202 | Loss DY: 0.2782
# Epoch [5/10] Batch [14/38] | Loss G: 3.1892 | Loss DX: 0.2005 | Loss DY: 0.2510
# Epoch [5/10] Batch [15/38] | Loss G: 3.2043 | Loss DX: 0.2235 | Loss DY: 0.2334
# Epoch [5/10] Batch [16/38] | Loss G: 3.1558 | Loss DX: 0.2141 | Loss DY: 0.2180
# Epoch [5/10] Batch [17/38] | Loss G: 2.9446 | Loss DX: 0.2351 | Loss DY: 0.2290
# Epoch [5/10] Batch [18/38] | Loss G: 3.0526 | Loss DX: 0.2269 | Loss DY: 0.2158
# Epoch [5/10] Batch [19/38] | Loss G: 2.8718 | Loss DX: 0.2134 | Loss DY: 0.2025
# Epoch [5/10] Batch [20/38] | Loss G: 2.8669 | Loss DX: 0.2121 | Loss DY: 0.2068
# Epoch [5/10] Batch [21/38] | Loss G: 2.7775 | Loss DX: 0.2137 | Loss DY: 0.2244
# Epoch [5/10] Batch [22/38] | Loss G: 2.6986 | Loss DX: 0.2276 | Loss DY: 0.2213
# Epoch [5/10] Batch [23/38] | Loss G: 2.8330 | Loss DX: 0.2222 | Loss DY: 0.1982
# Epoch [5/10] Batch [24/38] | Loss G: 2.8941 | Loss DX: 0.2189 | Loss DY: 0.2084
# Epoch [5/10] Batch [25/38] | Loss G: 2.8970 | Loss DX: 0.2229 | Loss DY: 0.1810
# Epoch [5/10] Batch [26/38] | Loss G: 2.8881 | Loss DX: 0.2261 | Loss DY: 0.2143
# Epoch [5/10] Batch [27/38] | Loss G: 3.3108 | Loss DX: 0.2178 | Loss DY: 0.1803
# Epoch [5/10] Batch [28/38] | Loss G: 3.0894 | Loss DX: 0.1799 | Loss DY: 0.1643
# Epoch [5/10] Batch [29/38] | Loss G: 2.7510 | Loss DX: 0.2053 | Loss DY: 0.1979
# Epoch [5/10] Batch [30/38] | Loss G: 2.9680 | Loss DX: 0.1933 | Loss DY: 0.1600
# Epoch [5/10] Batch [31/38] | Loss G: 2.8891 | Loss DX: 0.2064 | Loss DY: 0.1934
# Epoch [5/10] Batch [32/38] | Loss G: 3.0084 | Loss DX: 0.2378 | Loss DY: 0.2037
# Epoch [5/10] Batch [33/38] | Loss G: 2.9762 | Loss DX: 0.1945 | Loss DY: 0.2008
# Epoch [5/10] Batch [34/38] | Loss G: 3.1076 | Loss DX: 0.2145 | Loss DY: 0.1916
# Epoch [5/10] Batch [35/38] | Loss G: 3.3029 | Loss DX: 0.2050 | Loss DY: 0.1963
# Epoch [5/10] Batch [36/38] | Loss G: 3.2346 | Loss DX: 0.2076 | Loss DY: 0.2001
# Epoch [5/10] Batch [37/38] | Loss G: 3.1347 | Loss DX: 0.1934 | Loss DY: 0.1897
# Epoch [5/10] Batch [38/38] | Loss G: 2.8751 | Loss DX: 0.2088 | Loss DY: 0.2572
# Epoch [6/10] Batch [1/38] | Loss G: 3.1320 | Loss DX: 0.1915 | Loss DY: 0.2308
# Epoch [6/10] Batch [2/38] | Loss G: 3.1035 | Loss DX: 0.2113 | Loss DY: 0.2721
# Epoch [6/10] Batch [3/38] | Loss G: 3.0522 | Loss DX: 0.2046 | Loss DY: 0.2120
# Epoch [6/10] Batch [4/38] | Loss G: 3.2533 | Loss DX: 0.1969 | Loss DY: 0.1990
# Epoch [6/10] Batch [5/38] | Loss G: 2.9739 | Loss DX: 0.2188 | Loss DY: 0.2232
# Epoch [6/10] Batch [6/38] | Loss G: 2.8305 | Loss DX: 0.2085 | Loss DY: 0.2470
# Epoch [6/10] Batch [7/38] | Loss G: 2.9991 | Loss DX: 0.2091 | Loss DY: 0.2407
# Epoch [6/10] Batch [8/38] | Loss G: 2.7376 | Loss DX: 0.2323 | Loss DY: 0.2458
# Epoch [6/10] Batch [9/38] | Loss G: 3.0521 | Loss DX: 0.1962 | Loss DY: 0.2315
# Epoch [6/10] Batch [10/38] | Loss G: 3.0752 | Loss DX: 0.1895 | Loss DY: 0.2301
# Epoch [6/10] Batch [11/38] | Loss G: 3.0255 | Loss DX: 0.1991 | Loss DY: 0.2045
# Epoch [6/10] Batch [12/38] | Loss G: 3.0498 | Loss DX: 0.2189 | Loss DY: 0.2139
# Epoch [6/10] Batch [13/38] | Loss G: 2.9681 | Loss DX: 0.2220 | Loss DY: 0.2059
# Epoch [6/10] Batch [14/38] | Loss G: 3.0970 | Loss DX: 0.2373 | Loss DY: 0.2381
# Epoch [6/10] Batch [15/38] | Loss G: 3.1044 | Loss DX: 0.2222 | Loss DY: 0.2151
# Epoch [6/10] Batch [16/38] | Loss G: 3.0659 | Loss DX: 0.2011 | Loss DY: 0.2031
# Epoch [6/10] Batch [17/38] | Loss G: 3.1573 | Loss DX: 0.2309 | Loss DY: 0.1808
# Epoch [6/10] Batch [18/38] | Loss G: 3.0391 | Loss DX: 0.2079 | Loss DY: 0.1746
# Epoch [6/10] Batch [19/38] | Loss G: 2.7930 | Loss DX: 0.2112 | Loss DY: 0.2078
# Epoch [6/10] Batch [20/38] | Loss G: 3.0420 | Loss DX: 0.2037 | Loss DY: 0.2041
# Epoch [6/10] Batch [21/38] | Loss G: 3.1157 | Loss DX: 0.2287 | Loss DY: 0.2062
# Epoch [6/10] Batch [22/38] | Loss G: 2.9029 | Loss DX: 0.2199 | Loss DY: 0.2028
# Epoch [6/10] Batch [23/38] | Loss G: 3.0521 | Loss DX: 0.2116 | Loss DY: 0.2005
# Epoch [6/10] Batch [24/38] | Loss G: 3.0037 | Loss DX: 0.1866 | Loss DY: 0.1906
# Epoch [6/10] Batch [25/38] | Loss G: 2.9520 | Loss DX: 0.2233 | Loss DY: 0.1909
# Epoch [6/10] Batch [26/38] | Loss G: 3.2765 | Loss DX: 0.1852 | Loss DY: 0.1826
# Epoch [6/10] Batch [27/38] | Loss G: 3.0857 | Loss DX: 0.2228 | Loss DY: 0.2163
# Epoch [6/10] Batch [28/38] | Loss G: 3.2655 | Loss DX: 0.2249 | Loss DY: 0.2002
# Epoch [6/10] Batch [29/38] | Loss G: 3.1788 | Loss DX: 0.2073 | Loss DY: 0.2073
# Epoch [6/10] Batch [30/38] | Loss G: 2.9998 | Loss DX: 0.1952 | Loss DY: 0.2070
# Epoch [6/10] Batch [31/38] | Loss G: 2.9670 | Loss DX: 0.2205 | Loss DY: 0.1842
# Epoch [6/10] Batch [32/38] | Loss G: 3.0447 | Loss DX: 0.1999 | Loss DY: 0.2557
# Epoch [6/10] Batch [33/38] | Loss G: 2.9772 | Loss DX: 0.2027 | Loss DY: 0.2360
# Epoch [6/10] Batch [34/38] | Loss G: 3.3677 | Loss DX: 0.1918 | Loss DY: 0.2172
# Epoch [6/10] Batch [35/38] | Loss G: 3.1270 | Loss DX: 0.2030 | Loss DY: 0.2087
# Epoch [6/10] Batch [36/38] | Loss G: 3.0911 | Loss DX: 0.1967 | Loss DY: 0.2102
# Epoch [6/10] Batch [37/38] | Loss G: 2.9593 | Loss DX: 0.1876 | Loss DY: 0.2108
# Epoch [6/10] Batch [38/38] | Loss G: 2.7680 | Loss DX: 0.2337 | Loss DY: 0.2845
# Epoch [7/10] Batch [1/38] | Loss G: 2.9467 | Loss DX: 0.2287 | Loss DY: 0.2364
# Epoch [7/10] Batch [2/38] | Loss G: 3.0868 | Loss DX: 0.2346 | Loss DY: 0.2299
# Epoch [7/10] Batch [3/38] | Loss G: 3.1636 | Loss DX: 0.2163 | Loss DY: 0.2118
# Epoch [7/10] Batch [4/38] | Loss G: 2.9569 | Loss DX: 0.2299 | Loss DY: 0.2165
# Epoch [7/10] Batch [5/38] | Loss G: 3.0779 | Loss DX: 0.2112 | Loss DY: 0.2157
# Epoch [7/10] Batch [6/38] | Loss G: 3.0844 | Loss DX: 0.1925 | Loss DY: 0.1862
# Epoch [7/10] Batch [7/38] | Loss G: 2.8085 | Loss DX: 0.2035 | Loss DY: 0.2005
# Epoch [7/10] Batch [8/38] | Loss G: 2.7960 | Loss DX: 0.2103 | Loss DY: 0.1818
# Epoch [7/10] Batch [9/38] | Loss G: 2.8534 | Loss DX: 0.2012 | Loss DY: 0.1917
# Epoch [7/10] Batch [10/38] | Loss G: 2.8801 | Loss DX: 0.2171 | Loss DY: 0.1769
# Epoch [7/10] Batch [11/38] | Loss G: 2.9919 | Loss DX: 0.1877 | Loss DY: 0.1621
# Epoch [7/10] Batch [12/38] | Loss G: 3.0381 | Loss DX: 0.2226 | Loss DY: 0.2041
# Epoch [7/10] Batch [13/38] | Loss G: 2.9063 | Loss DX: 0.2311 | Loss DY: 0.2033
# Epoch [7/10] Batch [14/38] | Loss G: 3.1131 | Loss DX: 0.2161 | Loss DY: 0.2038
# Epoch [7/10] Batch [15/38] | Loss G: 3.0404 | Loss DX: 0.2272 | Loss DY: 0.1992
# Epoch [7/10] Batch [16/38] | Loss G: 2.9383 | Loss DX: 0.2116 | Loss DY: 0.1883
# Epoch [7/10] Batch [17/38] | Loss G: 2.9544 | Loss DX: 0.2019 | Loss DY: 0.1994
# Epoch [7/10] Batch [18/38] | Loss G: 2.8945 | Loss DX: 0.2303 | Loss DY: 0.2252
# Epoch [7/10] Batch [19/38] | Loss G: 3.0328 | Loss DX: 0.1906 | Loss DY: 0.2178
# Epoch [7/10] Batch [20/38] | Loss G: 3.0355 | Loss DX: 0.1888 | Loss DY: 0.2979
# Epoch [7/10] Batch [21/38] | Loss G: 3.2469 | Loss DX: 0.1996 | Loss DY: 0.2177
# Epoch [7/10] Batch [22/38] | Loss G: 3.0757 | Loss DX: 0.2158 | Loss DY: 0.1772
# Epoch [7/10] Batch [23/38] | Loss G: 3.0790 | Loss DX: 0.1862 | Loss DY: 0.1828
# Epoch [7/10] Batch [24/38] | Loss G: 2.8198 | Loss DX: 0.2036 | Loss DY: 0.2464
# Epoch [7/10] Batch [25/38] | Loss G: 2.9202 | Loss DX: 0.2242 | Loss DY: 0.3189
# Epoch [7/10] Batch [26/38] | Loss G: 3.0617 | Loss DX: 0.2395 | Loss DY: 0.2385
# Epoch [7/10] Batch [27/38] | Loss G: 3.1273 | Loss DX: 0.2118 | Loss DY: 0.2549
# Epoch [7/10] Batch [28/38] | Loss G: 3.0926 | Loss DX: 0.2087 | Loss DY: 0.2478
# Epoch [7/10] Batch [29/38] | Loss G: 3.0685 | Loss DX: 0.1911 | Loss DY: 0.2317
# Epoch [7/10] Batch [30/38] | Loss G: 3.0064 | Loss DX: 0.2420 | Loss DY: 0.2187
# Epoch [7/10] Batch [31/38] | Loss G: 2.9579 | Loss DX: 0.2176 | Loss DY: 0.2092
# Epoch [7/10] Batch [32/38] | Loss G: 2.9806 | Loss DX: 0.2194 | Loss DY: 0.2201
# Epoch [7/10] Batch [33/38] | Loss G: 2.9650 | Loss DX: 0.2194 | Loss DY: 0.2094
# Epoch [7/10] Batch [34/38] | Loss G: 2.9934 | Loss DX: 0.2322 | Loss DY: 0.1994
# Epoch [7/10] Batch [35/38] | Loss G: 3.1227 | Loss DX: 0.2162 | Loss DY: 0.2141
# Epoch [7/10] Batch [36/38] | Loss G: 2.8017 | Loss DX: 0.2153 | Loss DY: 0.2108
# Epoch [7/10] Batch [37/38] | Loss G: 2.8984 | Loss DX: 0.2022 | Loss DY: 0.2012
# Epoch [7/10] Batch [38/38] | Loss G: 2.8860 | Loss DX: 0.2017 | Loss DY: 0.1807
# Epoch [8/10] Batch [1/38] | Loss G: 2.7732 | Loss DX: 0.2119 | Loss DY: 0.2001
# Epoch [8/10] Batch [2/38] | Loss G: 2.9691 | Loss DX: 0.1979 | Loss DY: 0.1836
# Epoch [8/10] Batch [3/38] | Loss G: 2.9078 | Loss DX: 0.2125 | Loss DY: 0.1792
# Epoch [8/10] Batch [4/38] | Loss G: 3.1503 | Loss DX: 0.2029 | Loss DY: 0.1686
# Epoch [8/10] Batch [5/38] | Loss G: 3.0711 | Loss DX: 0.1916 | Loss DY: 0.1943
# Epoch [8/10] Batch [6/38] | Loss G: 2.9692 | Loss DX: 0.2212 | Loss DY: 0.2107
# Epoch [8/10] Batch [7/38] | Loss G: 2.9733 | Loss DX: 0.2133 | Loss DY: 0.2200
# Epoch [8/10] Batch [8/38] | Loss G: 3.0933 | Loss DX: 0.2274 | Loss DY: 0.2016
# Epoch [8/10] Batch [9/38] | Loss G: 2.8847 | Loss DX: 0.2072 | Loss DY: 0.2074
# Epoch [8/10] Batch [10/38] | Loss G: 2.8882 | Loss DX: 0.2224 | Loss DY: 0.2040
# Epoch [8/10] Batch [11/38] | Loss G: 2.8490 | Loss DX: 0.2146 | Loss DY: 0.1951
# Epoch [8/10] Batch [12/38] | Loss G: 2.9726 | Loss DX: 0.2209 | Loss DY: 0.1963
# Epoch [8/10] Batch [13/38] | Loss G: 3.0484 | Loss DX: 0.1948 | Loss DY: 0.1955
# Epoch [8/10] Batch [14/38] | Loss G: 3.2016 | Loss DX: 0.1981 | Loss DY: 0.1787
# Epoch [8/10] Batch [15/38] | Loss G: 3.1917 | Loss DX: 0.1954 | Loss DY: 0.2005
# Epoch [8/10] Batch [16/38] | Loss G: 2.9658 | Loss DX: 0.2207 | Loss DY: 0.2039
# Epoch [8/10] Batch [17/38] | Loss G: 3.0519 | Loss DX: 0.2219 | Loss DY: 0.1903
# Epoch [8/10] Batch [18/38] | Loss G: 2.9711 | Loss DX: 0.2141 | Loss DY: 0.2095
# Epoch [8/10] Batch [19/38] | Loss G: 2.8906 | Loss DX: 0.1922 | Loss DY: 0.2253
# Epoch [8/10] Batch [20/38] | Loss G: 3.1108 | Loss DX: 0.2126 | Loss DY: 0.2082
# Epoch [8/10] Batch [21/38] | Loss G: 2.9688 | Loss DX: 0.2254 | Loss DY: 0.2408
# Epoch [8/10] Batch [22/38] | Loss G: 3.1826 | Loss DX: 0.2006 | Loss DY: 0.1996
# Epoch [8/10] Batch [23/38] | Loss G: 3.0768 | Loss DX: 0.2349 | Loss DY: 0.2079
# Epoch [8/10] Batch [24/38] | Loss G: 2.8445 | Loss DX: 0.2184 | Loss DY: 0.2099
# Epoch [8/10] Batch [25/38] | Loss G: 2.9560 | Loss DX: 0.2074 | Loss DY: 0.2028
# Epoch [8/10] Batch [26/38] | Loss G: 2.9113 | Loss DX: 0.2115 | Loss DY: 0.2340
# Epoch [8/10] Batch [27/38] | Loss G: 2.8377 | Loss DX: 0.2155 | Loss DY: 0.2132
# Epoch [8/10] Batch [28/38] | Loss G: 2.8968 | Loss DX: 0.2510 | Loss DY: 0.2346
# Epoch [8/10] Batch [29/38] | Loss G: 3.1669 | Loss DX: 0.2253 | Loss DY: 0.1970
# Epoch [8/10] Batch [30/38] | Loss G: 3.1168 | Loss DX: 0.2048 | Loss DY: 0.2275
# Epoch [8/10] Batch [31/38] | Loss G: 2.9914 | Loss DX: 0.2138 | Loss DY: 0.2086
# Epoch [8/10] Batch [32/38] | Loss G: 2.8957 | Loss DX: 0.2198 | Loss DY: 0.2126
# Epoch [8/10] Batch [33/38] | Loss G: 2.9253 | Loss DX: 0.2153 | Loss DY: 0.2981
# Epoch [8/10] Batch [34/38] | Loss G: 3.0742 | Loss DX: 0.2060 | Loss DY: 0.2966
# Epoch [8/10] Batch [35/38] | Loss G: 2.8260 | Loss DX: 0.2107 | Loss DY: 0.2218
# Epoch [8/10] Batch [36/38] | Loss G: 2.9440 | Loss DX: 0.2430 | Loss DY: 0.2100
# Epoch [8/10] Batch [37/38] | Loss G: 3.1878 | Loss DX: 0.2217 | Loss DY: 0.1918
# Epoch [8/10] Batch [38/38] | Loss G: 3.0043 | Loss DX: 0.2164 | Loss DY: 0.2151
# Epoch [9/10] Batch [1/38] | Loss G: 2.9430 | Loss DX: 0.2112 | Loss DY: 0.2376
# Epoch [9/10] Batch [2/38] | Loss G: 2.7918 | Loss DX: 0.2207 | Loss DY: 0.2209
# Epoch [9/10] Batch [3/38] | Loss G: 2.9661 | Loss DX: 0.1934 | Loss DY: 0.2071
# Epoch [9/10] Batch [4/38] | Loss G: 3.1156 | Loss DX: 0.2218 | Loss DY: 0.2112
# Epoch [9/10] Batch [5/38] | Loss G: 2.8506 | Loss DX: 0.2225 | Loss DY: 0.2166
# Epoch [9/10] Batch [6/38] | Loss G: 3.0783 | Loss DX: 0.2015 | Loss DY: 0.1901
# Epoch [9/10] Batch [7/38] | Loss G: 2.9912 | Loss DX: 0.2123 | Loss DY: 0.1923
# Epoch [9/10] Batch [8/38] | Loss G: 2.7985 | Loss DX: 0.2016 | Loss DY: 0.1869
# Epoch [9/10] Batch [9/38] | Loss G: 3.0730 | Loss DX: 0.2280 | Loss DY: 0.1838
# Epoch [9/10] Batch [10/38] | Loss G: 3.1253 | Loss DX: 0.2160 | Loss DY: 0.2091
# Epoch [9/10] Batch [11/38] | Loss G: 2.8216 | Loss DX: 0.2406 | Loss DY: 0.2081
# Epoch [9/10] Batch [12/38] | Loss G: 2.7662 | Loss DX: 0.2303 | Loss DY: 0.1899
# Epoch [9/10] Batch [13/38] | Loss G: 2.9080 | Loss DX: 0.2168 | Loss DY: 0.2185
# Epoch [9/10] Batch [14/38] | Loss G: 3.0362 | Loss DX: 0.2076 | Loss DY: 0.1853
# Epoch [9/10] Batch [15/38] | Loss G: 2.8878 | Loss DX: 0.2248 | Loss DY: 0.2016
# Epoch [9/10] Batch [16/38] | Loss G: 2.7023 | Loss DX: 0.2130 | Loss DY: 0.1863
# Epoch [9/10] Batch [17/38] | Loss G: 2.8069 | Loss DX: 0.2090 | Loss DY: 0.2005
# Epoch [9/10] Batch [18/38] | Loss G: 2.8504 | Loss DX: 0.2056 | Loss DY: 0.1887
# Epoch [9/10] Batch [19/38] | Loss G: 2.9581 | Loss DX: 0.2166 | Loss DY: 0.1696
# Epoch [9/10] Batch [20/38] | Loss G: 2.9632 | Loss DX: 0.2019 | Loss DY: 0.2040
# Epoch [9/10] Batch [21/38] | Loss G: 2.9950 | Loss DX: 0.2075 | Loss DY: 0.2103
# Epoch [9/10] Batch [22/38] | Loss G: 2.9832 | Loss DX: 0.2098 | Loss DY: 0.2118
# Epoch [9/10] Batch [23/38] | Loss G: 3.1657 | Loss DX: 0.2011 | Loss DY: 0.1999
# Epoch [9/10] Batch [24/38] | Loss G: 2.8724 | Loss DX: 0.1830 | Loss DY: 0.2363
# Epoch [9/10] Batch [25/38] | Loss G: 2.9113 | Loss DX: 0.2084 | Loss DY: 0.2018
# Epoch [9/10] Batch [26/38] | Loss G: 3.0521 | Loss DX: 0.2068 | Loss DY: 0.2231
# Epoch [9/10] Batch [27/38] | Loss G: 2.9296 | Loss DX: 0.2092 | Loss DY: 0.2042
# Epoch [9/10] Batch [28/38] | Loss G: 3.0079 | Loss DX: 0.2435 | Loss DY: 0.2275
# Epoch [9/10] Batch [29/38] | Loss G: 2.8564 | Loss DX: 0.2108 | Loss DY: 0.2124
# Epoch [9/10] Batch [30/38] | Loss G: 2.8783 | Loss DX: 0.2246 | Loss DY: 0.2106
# Epoch [9/10] Batch [31/38] | Loss G: 3.1100 | Loss DX: 0.2385 | Loss DY: 0.2229
# Epoch [9/10] Batch [32/38] | Loss G: 3.0846 | Loss DX: 0.2099 | Loss DY: 0.2284
# Epoch [9/10] Batch [33/38] | Loss G: 2.9197 | Loss DX: 0.2372 | Loss DY: 0.2304
# Epoch [9/10] Batch [34/38] | Loss G: 2.9965 | Loss DX: 0.2113 | Loss DY: 0.2292
# Epoch [9/10] Batch [35/38] | Loss G: 3.1580 | Loss DX: 0.1857 | Loss DY: 0.2195
# Epoch [9/10] Batch [36/38] | Loss G: 3.0595 | Loss DX: 0.1973 | Loss DY: 0.1970
# Epoch [9/10] Batch [37/38] | Loss G: 3.1700 | Loss DX: 0.2063 | Loss DY: 0.2068
# Epoch [9/10] Batch [38/38] | Loss G: 3.1016 | Loss DX: 0.2190 | Loss DY: 0.2251
# Epoch [10/10] Batch [1/38] | Loss G: 2.9594 | Loss DX: 0.2245 | Loss DY: 0.1861
# Epoch [10/10] Batch [2/38] | Loss G: 3.0525 | Loss DX: 0.1827 | Loss DY: 0.1822
# Epoch [10/10] Batch [3/38] | Loss G: 2.9698 | Loss DX: 0.2110 | Loss DY: 0.1806
# Epoch [10/10] Batch [4/38] | Loss G: 2.9027 | Loss DX: 0.2264 | Loss DY: 0.1872
# Epoch [10/10] Batch [5/38] | Loss G: 2.8632 | Loss DX: 0.2130 | Loss DY: 0.1937
# Epoch [10/10] Batch [6/38] | Loss G: 2.9809 | Loss DX: 0.2105 | Loss DY: 0.1969
# Epoch [10/10] Batch [7/38] | Loss G: 2.9485 | Loss DX: 0.2189 | Loss DY: 0.2064
# Epoch [10/10] Batch [8/38] | Loss G: 2.8854 | Loss DX: 0.2184 | Loss DY: 0.1936
# Epoch [10/10] Batch [9/38] | Loss G: 2.8529 | Loss DX: 0.2194 | Loss DY: 0.2208
# Epoch [10/10] Batch [10/38] | Loss G: 2.9928 | Loss DX: 0.2016 | Loss DY: 0.2476
# Epoch [10/10] Batch [11/38] | Loss G: 3.5493 | Loss DX: 0.2161 | Loss DY: 0.2275
# Epoch [10/10] Batch [12/38] | Loss G: 3.2927 | Loss DX: 0.2075 | Loss DY: 0.2124
# Epoch [10/10] Batch [13/38] | Loss G: 2.9009 | Loss DX: 0.2160 | Loss DY: 0.2137
# Epoch [10/10] Batch [14/38] | Loss G: 3.1947 | Loss DX: 0.1976 | Loss DY: 0.1879
# Epoch [10/10] Batch [15/38] | Loss G: 2.9327 | Loss DX: 0.2179 | Loss DY: 0.2078
# Epoch [10/10] Batch [16/38] | Loss G: 2.8792 | Loss DX: 0.2152 | Loss DY: 0.2260
# Epoch [10/10] Batch [17/38] | Loss G: 2.9461 | Loss DX: 0.2152 | Loss DY: 0.2046
# Epoch [10/10] Batch [18/38] | Loss G: 2.9236 | Loss DX: 0.2221 | Loss DY: 0.2394
# Epoch [10/10] Batch [19/38] | Loss G: 3.0831 | Loss DX: 0.2031 | Loss DY: 0.2000
# Epoch [10/10] Batch [20/38] | Loss G: 2.9671 | Loss DX: 0.2073 | Loss DY: 0.1895
# Epoch [10/10] Batch [21/38] | Loss G: 3.0435 | Loss DX: 0.2043 | Loss DY: 0.1957
# Epoch [10/10] Batch [22/38] | Loss G: 2.7629 | Loss DX: 0.2032 | Loss DY: 0.1888
# Epoch [10/10] Batch [23/38] | Loss G: 2.8833 | Loss DX: 0.2022 | Loss DY: 0.1966
# Epoch [10/10] Batch [24/38] | Loss G: 3.2711 | Loss DX: 0.2176 | Loss DY: 0.1957
# Epoch [10/10] Batch [25/38] | Loss G: 3.3725 | Loss DX: 0.2443 | Loss DY: 0.1948
# Epoch [10/10] Batch [26/38] | Loss G: 2.9920 | Loss DX: 0.2212 | Loss DY: 0.1636
# Epoch [10/10] Batch [27/38] | Loss G: 3.2338 | Loss DX: 0.2183 | Loss DY: 0.1863
# Epoch [10/10] Batch [28/38] | Loss G: 2.9477 | Loss DX: 0.2188 | Loss DY: 0.1918
# Epoch [10/10] Batch [29/38] | Loss G: 2.9116 | Loss DX: 0.2206 | Loss DY: 0.1999
# Epoch [10/10] Batch [30/38] | Loss G: 2.8917 | Loss DX: 0.1923 | Loss DY: 0.2250
# Epoch [10/10] Batch [31/38] | Loss G: 2.7842 | Loss DX: 0.1944 | Loss DY: 0.2353
# Epoch [10/10] Batch [32/38] | Loss G: 2.9735 | Loss DX: 0.2184 | Loss DY: 0.2124
# Epoch [10/10] Batch [33/38] | Loss G: 3.1709 | Loss DX: 0.2006 | Loss DY: 0.2162
# Epoch [10/10] Batch [34/38] | Loss G: 3.0090 | Loss DX: 0.2129 | Loss DY: 0.1853
# Epoch [10/10] Batch [35/38] | Loss G: 2.9182 | Loss DX: 0.2162 | Loss DY: 0.2035
# Epoch [10/10] Batch [36/38] | Loss G: 2.9775 | Loss DX: 0.2196 | Loss DY: 0.1861
# Epoch [10/10] Batch [37/38] | Loss G: 2.8804 | Loss DX: 0.2387 | Loss DY: 0.2091
# Epoch [10/10] Batch [38/38] | Loss G: 2.7452 | Loss DX: 0.2108 | Loss DY: 0.2172

# %%
torch.save(generator_g.state_dict(), "generator_g.pth")
torch.save(generator_f.state_dict(), "generator_f.pth")
torch.save(discriminator_x.state_dict(), "discriminator_x.pth")
torch.save(discriminator_y.state_dict(), "discriminator_y.pth")

# %%
generator_g.load_state_dict(torch.load("generator_g.pth", weights_only=True))
generator_f.load_state_dict(torch.load("generator_f.pth", weights_only=True))
discriminator_x.load_state_dict(torch.load("discriminator_x.pth", weights_only=True))
discriminator_y.load_state_dict(torch.load("discriminator_y.pth", weights_only=True))
# Out:
# <All keys matched successfully>

# %%
# now let's test our cyclegan after training to see if it actually works:

real_x, _ = next(iter(cifar_loader))
real_x = real_x.cuda()

fake_y = generator_g(real_x).detach()
reconstructed_x = generator_f(fake_y).detach()

fake_y = fake_y.cpu()
reconstructed_x = reconstructed_x.cpu()

print("CIFAR Images")
show_images(real_x[:8].cpu())
print("Generated Monet-style Images")
show_images(fake_y[:8])
print("Reconstructed CIFAR Images")
show_images(reconstructed_x[:8])
# Out:
# CIFAR Images
# Generated Monet-style Images
# Reconstructed CIFAR Images
